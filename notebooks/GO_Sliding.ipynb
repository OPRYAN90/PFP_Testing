# %%
"""
Generate ProtT5 (XL-UniRef50) sequence embeddings for PIDs that appear under
CAFA_Style <split>/mf/*, reading sequences from
CAFA_Style/sequences/<PID>/seq.txt and writing the embeddings to
CAFA_Style/sequences/<PID>/prot_t5_emb.pt.

Output per PID:
    sequences/<PID>/prot_t5_emb.pt   # torch.Tensor, shape (1, L+2, DIM)
                                     # CLS/EOS slots are zero-filled

Notes
-----
- We *only* embed PIDs that exist under <split>/mf (splits: train/val/test).
- Tokenization follows the official ProtT5 recipe: space-separated residues.
- Ambiguous residues U,Z,O,B are mapped to 'X' (per official ProtT5 preprocessing).
- If L <= WINDOW_EFF, run a single forward pass (fast path).
- If L > WINDOW_EFF, use sliding windows with overlap and **context-trim**:
  in each window keep only the non-overlap core (no weighting). Only indices
  0 and L+1 are zero.
- Existing files are skipped silently; progress bar shows overall progress.
- Preserves original embedding logic; only I/O and PID enumeration changed.
"""
from __future__ import annotations

from pathlib import Path
from typing import Iterable, Set, List, Tuple
import re
import math

import torch
from tqdm.auto import tqdm
from transformers import AutoTokenizer, T5EncoderModel

# ─────────────────────────────── config ─────────────────────────────── #
BASE          = Path("/teamspace/studios/this_studio/CAFA_Style")
ONTOLOGY      = "mf"                       # only embed PIDs that appear under this ontology
SPLITS        = ["train", "val", "test"]
SEQS_DIR      = BASE / "sequences"         # source of seq.txt and target for embeddings
OUT_FILENAME  = "prot_t5_emb.pt"           # (1, L+2, DIM) with zero CLS/EOS rows
MODEL_NAME    = "Rostlab/prot_t5_xl_uniref50"

DEVICE        = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DTYPE         = torch.float32
DIM           = 1024                       # ProtT5 embedding dimension

# Sliding-window hyperparams for ProtT5 (T5 has EOS but no BOS; we keep your (1,L+2,*) interface)
MAX_LEN_TOKENS = 512     # effective model token limit (incl. EOS)
N_SPECIALS_WIN = 1        # EOS only inside each window
WINDOW_EFF     = MAX_LEN_TOKENS - N_SPECIALS_WIN  # residues per window
OVERLAP        = 128      # residues of overlap between adjacent windows (64–128 is a good default)
# ────────────────────────────────────────────────────────────────────── #


def gather_pids_from_mf(base: Path, splits: Iterable[str]) -> Set[str]:
    """Union of subfolder names under <base>/<split>/mf/* for all splits.
    Missing split folders are ignored with a warning.
    """
    pids: Set[str] = set()
    for split in splits:
        root = base / split / ONTOLOGY
        if not root.exists():
            tqdm.write(f"[WARN] Missing folder: {root} — skipping this split")
            continue
        for item in root.iterdir():
            if item.is_dir():
                pids.add(item.name)
    return pids


def read_sequence(seqs_dir: Path, pid: str) -> str:
    seq_path = seqs_dir / pid / "seq.txt"
    if not seq_path.exists():
        return ""
    seq_parts = []
    with seq_path.open("r", encoding="utf-8") as fh:
        for line in fh:
            if line.startswith(">"):
                continue
            seq_parts.append(line.strip())
    # Build raw sequence (uppercase), then map ambiguous residues per official ProtT5 recipe
    seq = ("".join(seq_parts)).upper()
    seq = re.sub(r"[UZOB]", "X", seq)
    if not seq:
        return ""
    return seq


@torch.inference_mode()
def _embed_window(model: T5EncoderModel, tok: AutoTokenizer, subseq: str) -> torch.Tensor:
    """Embed a *subsequence* with ProtT5, returning (Li, DIM) residue embeddings.

    - Space-separate residues.
    - add_special_tokens=True to append EOS.
    - Drop the final EOS row to keep only residues.
    """
    spaced = " ".join(subseq)
    enc = tok(spaced, return_tensors="pt", add_special_tokens=True)
    enc = {k: v.to(DEVICE) for k, v in enc.items()}

    out = model(**enc).last_hidden_state[0]  # [T, DIM], where T = Li + 1 (EOS)
    # Drop EOS (last row)
    kept = out[:-1]  # [Li, DIM]
    if kept.size(0) != len(subseq):
        raise RuntimeError(
            f"[ProtT5] Token/AA mismatch in window: tokens_no_eos={kept.size(0)} vs Li={len(subseq)}"
        )
    return kept.to(DTYPE)


def _plan_windows(L: int) -> List[Tuple[int, int]]:
    """Return inclusive-exclusive windows [(s,e), ...] covering [0, L) with overlap."""
    if L <= WINDOW_EFF:
        return [(0, L)]
    stride = max(1, WINDOW_EFF - OVERLAP)
    windows: List[Tuple[int, int]] = []
    s = 0
    while s < L:
        e = min(s + WINDOW_EFF, L)
        windows.append((s, e))
        if e == L:
            break
        s += stride
    return windows


@torch.inference_mode()
def embed_prott5_stitched(model: T5EncoderModel, tok: AutoTokenizer, seq: str) -> torch.Tensor:
    """Return ProtT5 embeddings as (1, L+2, DIM) with zero CLS/EOS rows."""
    L = len(seq)

    # Fast path: one shot, identical to your original logic.
    if L <= WINDOW_EFF:
        kept = _embed_window(model, tok, seq)  # (L, DIM)
        emb = torch.zeros(1, L + 2, kept.size(-1), dtype=DTYPE, device="cpu")
        emb[0, 1 : L + 1] = kept.detach().cpu()
        return emb

    # Sliding-window path
    windows = _plan_windows(L)

    # Output buffer (CPU to control memory)
    E = torch.empty(L, DIM, dtype=DTYPE, device="cpu")

    for (s, e) in windows:
        subseq = seq[s:e]
        Li = e - s
        if Li > WINDOW_EFF:
            raise RuntimeError(f"Internal window larger than WINDOW_EFF: Li={Li} > {WINDOW_EFF}")

        R = _embed_window(model, tok, subseq).detach().cpu()  # (Li, DIM)

        # Context-trim stitching: keep only the non-overlap core of each window.
        # First window keeps its full left edge; last window keeps its full right edge.
        left_trim  = 0 if s == 0 else OVERLAP // 2
        right_trim = 0 if e == L else (OVERLAP - OVERLAP // 2)

        gs = s + left_trim           # global start to write
        ge = e - right_trim          # global end   to write (exclusive)
        ls = left_trim               # local  start to read
        le = Li - right_trim         # local  end   to read (exclusive)

        if ge <= gs:
            raise RuntimeError(f"Empty keep range for window {(s,e)} with trims {left_trim},{right_trim}")
        if (le - ls) != (ge - gs):
            raise RuntimeError("Keep lengths disagree (local vs global) during trim-stitch.")

        E[gs:ge] = R[ls:le]

    # Pack to (1, L+2, DIM) with zeros at [0] and [L+1]
    emb = torch.zeros(1, L + 2, DIM, dtype=DTYPE, device="cpu")
    emb[0, 1 : L + 1] = E
    return emb


def main() -> None:
    if not BASE.exists():
        raise FileNotFoundError(f"CAFA_Style base not found: {BASE}")
    SEQS_DIR.mkdir(parents=True, exist_ok=True)

    pids = sorted(gather_pids_from_mf(BASE, SPLITS))
    if not pids:
        print("No PIDs found under <split>/mf — nothing to do.")
        return

    # Load model & tokenizer once
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, do_lower_case=False, use_fast=False)
    model = T5EncoderModel.from_pretrained(MODEL_NAME).to(DEVICE).eval()

    made, skipped_exist, skipped_empty = 0, 0, 0
    for pid in tqdm(pids, desc="ProtT5 embedding"):
        out_path = SEQS_DIR / pid / OUT_FILENAME
        if out_path.exists():
            skipped_exist += 1
            continue  # skip silently

        seq = read_sequence(SEQS_DIR, pid)
        if not seq:
            skipped_empty += 1
            continue

        emb = embed_prott5_stitched(model, tokenizer, seq)  # (1, L+2, DIM); zeros only at [0] and [L+1]
        out_path.parent.mkdir(parents=True, exist_ok=True)
        torch.save(emb, out_path)
        made += 1

    print(
        f"Done. created={made} | existing_skipped={skipped_exist} | missing_seq_skipped={skipped_empty}"
    )


if __name__ == "__main__":
    main()
# Out:
# ProtT5 embedding:   0%|          | 0/32546 [00:00<?, ?it/s]
# Done. created=12708 | existing_skipped=19838 | missing_seq_skipped=0

# %%
"""
Generate ESM-C (600M) sequence embeddings for PIDs that appear under the
CAFA_Style <split>/mf/* directories, *reading sequences from*
CAFA_Style/sequences/<PID>/seq.txt and *writing*
CAFA_Style/sequences/<PID>/esmc_emb.pt.

Output per PID:
    sequences/<PID>/esmc_emb.pt     # torch.Tensor, shape (1, L+2, 1152)

Logic
-----
- If L <= WINDOW_EFF, run a single forward pass (fast path). This preserves
  the original ESM-C behavior, including native [CLS]/[EOS] embeddings.
- If L > WINDOW_EFF, use sliding windows with overlap and **context-trim**:
  for each window, embed, drop CLS/EOS to get per-residue rows, then keep
  only the non-overlap core (no weighting). Stitch into a full [L, 1152]
  buffer. We then pack to (1, L+2, 1152) with zeros at positions [0] and
  [L+1] (global CLS/EOS are not available under windowing).

Notes
-----
- We *only* embed PIDs that exist under <split>/mf (splits: train/val/test).
- Existing files are skipped.
- Uses GPU if available.
"""
from __future__ import annotations

import re
from pathlib import Path
from typing import Iterable, Set, List, Tuple

import torch
from tqdm.auto import tqdm

# ─────────────────────────────── config ─────────────────────────────── #
BASE          = Path("/teamspace/studios/this_studio/CAFA_Style")
ONTOLOGY      = "mf"                       # only embed PIDs that appear under this ontology
SPLITS        = ["train", "val", "test"]
SEQS_DIR      = BASE / "sequences"        # source of seq.txt and target for esmc_emb.pt
OUT_FILENAME  = "esmc_emb.pt"             # what downstream expects
MODEL_NAME    = "esmc_600m"               # Fair-ESM registry tag

DEVICE        = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DTYPE         = torch.float32
DIM           = 1152

# Sliding-window hyperparameters (mirroring your ProtT5 setup)
# ESM-C has both CLS and EOS per window → 2 specials inside each window.
MAX_LEN_TOKENS = 2048     # effective model token limit (incl. CLS+EOS)
N_SPECIALS_WIN = 2        # CLS + EOS
WINDOW_EFF     = MAX_LEN_TOKENS - N_SPECIALS_WIN   # residues per window
OVERLAP        = 256      # residues overlapped between adjacent windows
# ────────────────────────────────────────────────────────────────────── #


def gather_pids_from_mf(base: Path, splits: Iterable[str]) -> Set[str]:
    """Union of subfolder names under <base>/<split>/mf/* for all splits."""
    pids: Set[str] = set()
    for split in splits:
        root = base / split / ONTOLOGY
        if not root.exists():
            tqdm.write(f"[WARN] Missing folder: {root} — skipping this split")
            continue
        for item in root.iterdir():
            if item.is_dir():
                pids.add(item.name)
    return pids


def read_sequence(seqs_dir: Path, pid: str) -> str:
    """Read FASTA-like or plain sequence, strip headers/whitespace, uppercase."""
    seq_path = seqs_dir / pid / "seq.txt"
    if not seq_path.exists():
        return ""
    seq_parts = []
    with seq_path.open("r", encoding="utf-8") as fh:
        for line in fh:
            if line.startswith(">"):
                continue
            seq_parts.append(line.strip())
    seq = ("".join(seq_parts)).upper()
    return seq


def _plan_windows(L: int) -> List[Tuple[int, int]]:
    """Return inclusive-exclusive windows [(s,e), ...] covering [0, L) with overlap."""
    if L <= WINDOW_EFF:
        return [(0, L)]
    stride = max(1, WINDOW_EFF - OVERLAP)
    windows: List[Tuple[int, int]] = []
    s = 0
    while s < L:
        e = min(s + WINDOW_EFF, L)
        windows.append((s, e))
        if e == L:
            break
        s += stride
    return windows


@torch.inference_mode()
def _embed_window_esmc(model, subseq: str) -> torch.Tensor:
    """
    Embed a *subsequence* with ESM-C and return per-residue embeddings [Li, DIM].

    We call model.encode + model.logits(..., return_embeddings=True), which returns
    (1, Li+2, DIM) including CLS/EOS. We drop [CLS]/[EOS] here and only return
    residue rows.
    """
    from esm.sdk.api import ESMProtein, LogitsConfig

    prot   = ESMProtein(sequence=subseq)
    hidden = model.encode(prot)  # device-aware; model already on DEVICE
    out    = model.logits(hidden, LogitsConfig(sequence=True, return_embeddings=True))
    # out.embeddings: (1, Li+2, DIM)
    R = out.embeddings[0, 1:-1].to(DTYPE)  # (Li, DIM), drop CLS/EOS
    if R.size(0) != len(subseq):
        raise RuntimeError(
            f"[ESM-C] Token/AA mismatch in window: residues={len(subseq)} vs got={R.size(0)} rows"
        )
    return R


@torch.inference_mode()
def _embed_full_esmc(model, seq: str) -> torch.Tensor:
    """
    Full-sequence ESM-C embedding → (1, L+2, DIM), keeping native CLS/EOS.
    This matches your original single-pass behavior.
    """
    from esm.sdk.api import ESMProtein, LogitsConfig

    prot   = ESMProtein(sequence=seq)
    hidden = model.encode(prot)
    out    = model.logits(hidden, LogitsConfig(sequence=True, return_embeddings=True))
    return out.embeddings.to(DTYPE).cpu()  # (1, L+2, DIM)


@torch.inference_mode()
def embed_esmc_stitched(model, seq: str) -> torch.Tensor:
    """
    Return ESM-C embeddings as (1, L+2, 1152).

    - Short sequences (L <= WINDOW_EFF): single pass; preserve native CLS/EOS.
    - Long sequences: sliding windows + context-trim stitching for residues;
      pack to (1, L+2, DIM) with zeros at [0] and [L+1].
    """
    L = len(seq)
    if L == 0:
        raise ValueError("Empty sequence.")

    # Fast path (identical to original logic)
    if L <= WINDOW_EFF:
        return _embed_full_esmc(model, seq)

    # Sliding-window path
    windows = _plan_windows(L)
    E = torch.empty(L, DIM, dtype=DTYPE, device="cpu")

    for (s, e) in windows:
        subseq = seq[s:e]
        Li = e - s
        if Li > WINDOW_EFF:
            raise RuntimeError(f"Internal window larger than WINDOW_EFF: Li={Li} > {WINDOW_EFF}")

        R = _embed_window_esmc(model, subseq).detach().cpu()  # (Li, DIM)

        # Context-trim stitching (same as in your ProtT5 script).
        left_trim  = 0 if s == 0 else OVERLAP // 2
        right_trim = 0 if e == L else (OVERLAP - OVERLAP // 2)

        gs = s + left_trim           # global start
        ge = e - right_trim          # global end (exclusive)
        ls = left_trim               # local start
        le = Li - right_trim         # local end (exclusive)

        if ge <= gs:
            raise RuntimeError(f"Empty keep range for window {(s, e)}")
        if (le - ls) != (ge - gs):
            raise RuntimeError("Keep lengths disagree during trim-stitch.")

        E[gs:ge] = R[ls:le]

    # Pack to (1, L+2, DIM); under sliding we zero CLS/EOS to keep interface stable.
    emb = torch.zeros(1, L + 2, DIM, dtype=DTYPE, device="cpu")
    emb[0, 1 : L + 1] = E
    return emb


def main() -> None:
    if not BASE.exists():
        raise FileNotFoundError(f"CAFA_Style base not found: {BASE}")
    SEQS_DIR.mkdir(parents=True, exist_ok=True)

    pids = sorted(gather_pids_from_mf(BASE, SPLITS))
    if not pids:
        print("No PIDs found under <split>/mf — nothing to do.")
        return

    print(f"Found {len(pids)} unique PIDs under mf across {SPLITS}\n")
    print(f"⇢ Loading {MODEL_NAME} onto {DEVICE} …")
    from esm.models.esmc import ESMC

    model = ESMC.from_pretrained(MODEL_NAME).to(DEVICE).eval()

    made, skipped_exist, skipped_empty = 0, 0, 0
    for pid in tqdm(pids, desc="Embedding (ESM-C, sliding-aware)"):
        out_path = SEQS_DIR / pid / OUT_FILENAME
        if out_path.exists():
            skipped_exist += 1
            continue

        # Read sequence (accept FASTA-like; strip headers/whitespace)
        seq_path = SEQS_DIR / pid / "seq.txt"
        if not seq_path.exists():
            tqdm.write(f"[WARN] {pid}: missing sequences/seq.txt — skipping")
            skipped_empty += 1
            continue

        raw = seq_path.read_text(encoding="utf-8")
        seq = "".join(line.strip() for line in raw.splitlines() if not line.startswith(">")).upper()
        if not seq:
            tqdm.write(f"[WARN] {pid}: empty sequence — skipping")
            skipped_empty += 1
            continue

        # Embed (fast path or sliding-stitch)
        emb = embed_esmc_stitched(model, seq)  # (1, L+2, 1152)
        out_path.parent.mkdir(parents=True, exist_ok=True)
        torch.save(emb, out_path)
        made += 1
        tqdm.write(f"✓ {pid}: L={len(seq):4d} → {OUT_FILENAME}")

    print(
        f"\nDone. created={made} | existing_skipped={skipped_exist} | missing/empty_seq_skipped={skipped_empty}"
    )


if __name__ == "__main__":
    main()
# Out:
# Found 32546 unique PIDs under mf across ['train', 'val', 'test']
#
# ⇢ Loading esmc_600m onto cuda …
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# README.md: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# esmc_600m_2024_12_v0.pth:   0%|          | 0.00/2.30G [00:00<?, ?B/s]
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/esm/pretrained.py:92: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(
# Embedding (ESM-C, sliding-aware):   0%|          | 0/32546 [00:00<?, ?it/s]
# ✓ 128UP_DROME: L= 368 → esmc_emb.pt
# ✓ 14310_ARATH: L= 254 → esmc_emb.pt
# ✓ 14311_ARATH: L= 252 → esmc_emb.pt
# ✓ 14333_ARATH: L= 255 → esmc_emb.pt
# ✓ 14335_ARATH: L= 268 → esmc_emb.pt
# ✓ 1433B_HUMAN: L= 246 → esmc_emb.pt
# ✓ 1433B_MOUSE: L= 246 → esmc_emb.pt
# ✓ 1433B_RAT: L= 246 → esmc_emb.pt
# ✓ 1433E_DROME: L= 262 → esmc_emb.pt
# ✓ 1433E_HUMAN: L= 255 → esmc_emb.pt
# ✓ 1433E_MOUSE: L= 255 → esmc_emb.pt
# ✓ 1433E_RAT: L= 255 → esmc_emb.pt
# ✓ 1433F_HUMAN: L= 246 → esmc_emb.pt
# ✓ 1433F_MOUSE: L= 246 → esmc_emb.pt
# ✓ 1433G_HUMAN: L= 247 → esmc_emb.pt
# ✓ 1433G_MOUSE: L= 247 → esmc_emb.pt
# ✓ 1433G_RAT: L= 247 → esmc_emb.pt
# ✓ 1433S_HUMAN: L= 248 → esmc_emb.pt
# ✓ 1433S_MOUSE: L= 248 → esmc_emb.pt
# ✓ 1433T_HUMAN: L= 245 → esmc_emb.pt
# ✓ 1433T_MOUSE: L= 245 → esmc_emb.pt
# ✓ 1433T_RAT: L= 245 → esmc_emb.pt
# ✓ 1433Z_HUMAN: L= 245 → esmc_emb.pt
# ✓ 1433Z_MOUSE: L= 245 → esmc_emb.pt
# ✓ 1433Z_RAT: L= 245 → esmc_emb.pt
# ✓ 1433_DICDI: L= 252 → esmc_emb.pt
# ✓ 1A111_ARATH: L= 460 → esmc_emb.pt
# ✓ 1A12_ARATH: L= 496 → esmc_emb.pt
# ✓ 1A14_ARATH: L= 474 → esmc_emb.pt
# ✓ 1A15_ARATH: L= 470 → esmc_emb.pt
# ✓ 1A16_ARATH: L= 495 → esmc_emb.pt
# ✓ 1A17_ARATH: L= 447 → esmc_emb.pt
# ✓ 1A18_ARATH: L= 469 → esmc_emb.pt
# ✓ 1A19_ARATH: L= 470 → esmc_emb.pt
# ✓ 1A1L1_HUMAN: L= 501 → esmc_emb.pt
# ✓ 1MMP_ARATH: L= 364 → esmc_emb.pt
# ✓ 2A5A_HUMAN: L= 486 → esmc_emb.pt
# ✓ 2A5B_HUMAN: L= 497 → esmc_emb.pt
# ✓ 2A5D_HUMAN: L= 602 → esmc_emb.pt
# ✓ 2A5D_YEAST: L= 757 → esmc_emb.pt
# ✓ 2A5E_HUMAN: L= 467 → esmc_emb.pt
# ✓ 2A5G_ARATH: L= 522 → esmc_emb.pt
# ✓ 2A5G_HUMAN: L= 524 → esmc_emb.pt
# ✓ 2AAA_HUMAN: L= 589 → esmc_emb.pt
# ✓ 2AAA_MOUSE: L= 589 → esmc_emb.pt
# ✓ 2ABA_DROME: L= 499 → esmc_emb.pt
# ✓ 2ABA_HUMAN: L= 447 → esmc_emb.pt
# ✓ 2ABA_RAT: L= 447 → esmc_emb.pt
# ✓ 2ABA_SCHPO: L= 463 → esmc_emb.pt
# ✓ 2ABA_YEAST: L= 526 → esmc_emb.pt
# ✓ 2ABB_RAT: L= 443 → esmc_emb.pt
# ✓ 2ABD_XENLA: L= 447 → esmc_emb.pt
# ✓ 2AD2_SCHPO: L= 627 → esmc_emb.pt
# ✓ 2MMP_ARATH: L= 378 → esmc_emb.pt
# ✓ 2SS3_ARATH: L= 164 → esmc_emb.pt
# ✓ 3BHS1_RAT: L= 373 → esmc_emb.pt
# ✓ 3BHS2_HUMAN: L= 372 → esmc_emb.pt
# ✓ 3BHS4_RAT: L= 373 → esmc_emb.pt
# ✓ 3BHS5_RAT: L= 373 → esmc_emb.pt
# ✓ 3BHS7_HUMAN: L= 369 → esmc_emb.pt
# ✓ 3BHS7_MOUSE: L= 369 → esmc_emb.pt
# ✓ 3BHS7_RAT: L= 338 → esmc_emb.pt
# ✓ 3BP1_HUMAN: L= 701 → esmc_emb.pt
# ✓ 3BP1_MOUSE: L= 680 → esmc_emb.pt
# ✓ 3BP1_RAT: L= 689 → esmc_emb.pt
# ✓ 3BP2_HUMAN: L= 561 → esmc_emb.pt
# ✓ 3BP2_MOUSE: L= 559 → esmc_emb.pt
# ✓ 3BP5H_DROME: L= 477 → esmc_emb.pt
# ✓ 3BP5L_HUMAN: L= 393 → esmc_emb.pt
# ✓ 3BP5_HUMAN: L= 455 → esmc_emb.pt
# ✓ 3BP5_MOUSE: L= 463 → esmc_emb.pt
# ✓ 3BP5_RAT: L= 457 → esmc_emb.pt
# ✓ 3HAO_HUMAN: L= 286 → esmc_emb.pt
# ✓ 3HAO_MOUSE: L= 286 → esmc_emb.pt
# ✓ 3HAO_RAT: L= 286 → esmc_emb.pt
# ✓ 3HAO_YEAST: L= 177 → esmc_emb.pt
# ✓ 3HIDH_ARATH: L= 347 → esmc_emb.pt
# ✓ 3HIDH_HUMAN: L= 336 → esmc_emb.pt
# ✓ 3MG2_ECOLI: L= 282 → esmc_emb.pt
# ✓ 3MG_HUMAN: L= 298 → esmc_emb.pt
# ✓ 3MG_MOUSE: L= 333 → esmc_emb.pt
# ✓ 3MMP_ARATH: L= 384 → esmc_emb.pt
# ✓ 3PASE_ECOLI: L= 433 → esmc_emb.pt
# ✓ 4CL1_ARATH: L= 561 → esmc_emb.pt
# ✓ 4CL2_ARATH: L= 556 → esmc_emb.pt
# ✓ 4CL3_ARATH: L= 561 → esmc_emb.pt
# ✓ 4CL4_ARATH: L= 570 → esmc_emb.pt
# ✓ 4CLL1_ARATH: L= 542 → esmc_emb.pt
# ✓ 4CLL4_ARATH: L= 550 → esmc_emb.pt
# ✓ 4CLL6_ARATH: L= 566 → esmc_emb.pt
# ✓ 4CLL7_ARATH: L= 544 → esmc_emb.pt
# ✓ 4CLL8_ARATH: L= 550 → esmc_emb.pt
# ✓ 4CLL9_ARATH: L= 562 → esmc_emb.pt
# ✓ 4CLLA_ARATH: L= 514 → esmc_emb.pt
# ✓ 4EBP1_HUMAN: L= 118 → esmc_emb.pt
# ✓ 4EBP1_MOUSE: L= 117 → esmc_emb.pt
# ✓ 4EBP1_RAT: L= 117 → esmc_emb.pt
# ✓ 4EBP2_MOUSE: L= 120 → esmc_emb.pt
# ✓ 4EBP_DROME: L= 117 → esmc_emb.pt
# ✓ 4ET_DROME: L=1010 → esmc_emb.pt
# ✓ 4ET_HUMAN: L= 985 → esmc_emb.pt
# ✓ 4ET_MOUSE: L= 983 → esmc_emb.pt
# ✓ 4F2_HUMAN: L= 630 → esmc_emb.pt
# ✓ 4F2_RAT: L= 527 → esmc_emb.pt
# ✓ 4MMP_ARATH: L= 342 → esmc_emb.pt
# ✓ 4OT_BACSU: L=  62 → esmc_emb.pt
# ✓ 5DNU_ECOLI: L= 199 → esmc_emb.pt
# ✓ 5FCL_ARATH: L= 277 → esmc_emb.pt
# ✓ 5FCL_ECOLI: L= 182 → esmc_emb.pt
# ✓ 5HT1A_HUMAN: L= 422 → esmc_emb.pt
# ✓ 5HT1A_MOUSE: L= 421 → esmc_emb.pt
# ✓ 5HT1A_RAT: L= 422 → esmc_emb.pt
# ✓ 5HT1B_HUMAN: L= 390 → esmc_emb.pt
# ✓ 5HT1B_MOUSE: L= 386 → esmc_emb.pt
# ✓ 5HT1B_RAT: L= 386 → esmc_emb.pt
# ✓ 5HT1D_HUMAN: L= 377 → esmc_emb.pt
# ✓ 5HT1D_MOUSE: L= 374 → esmc_emb.pt
# ✓ 5HT1E_HUMAN: L= 365 → esmc_emb.pt
# ✓ 5HT1F_HUMAN: L= 366 → esmc_emb.pt
# ✓ 5HT1R_DROME: L= 564 → esmc_emb.pt
# ✓ 5HT2A_DROME: L= 834 → esmc_emb.pt
# ✓ 5HT2A_HUMAN: L= 471 → esmc_emb.pt
# ✓ 5HT2A_RAT: L= 471 → esmc_emb.pt
# ✓ 5HT2B_DROME: L= 617 → esmc_emb.pt
# ✓ 5HT2B_HUMAN: L= 481 → esmc_emb.pt
# ✓ 5HT2B_MOUSE: L= 479 → esmc_emb.pt
# ✓ 5HT2B_RAT: L= 479 → esmc_emb.pt
# ✓ 5HT2C_HUMAN: L= 458 → esmc_emb.pt
# ✓ 5HT2C_MOUSE: L= 459 → esmc_emb.pt
# ✓ 5HT2C_RAT: L= 460 → esmc_emb.pt
# ✓ 5HT3A_HUMAN: L= 478 → esmc_emb.pt
# ✓ 5HT3A_MOUSE: L= 487 → esmc_emb.pt
# ✓ 5HT3A_RAT: L= 483 → esmc_emb.pt
# ✓ 5HT3B_HUMAN: L= 441 → esmc_emb.pt
# ✓ 5HT3B_MOUSE: L= 437 → esmc_emb.pt
# ✓ 5HT3C_HUMAN: L= 447 → esmc_emb.pt
# ✓ 5HT3D_HUMAN: L= 454 → esmc_emb.pt
# ✓ 5HT3E_HUMAN: L= 456 → esmc_emb.pt
# ✓ 5HT4R_HUMAN: L= 388 → esmc_emb.pt
# ✓ 5HT4R_RAT: L= 406 → esmc_emb.pt
# ✓ 5HT5A_HUMAN: L= 357 → esmc_emb.pt
# ✓ 5HT5A_RAT: L= 357 → esmc_emb.pt
# ✓ 5HT5B_MOUSE: L= 370 → esmc_emb.pt
# ✓ 5HT5B_RAT: L= 370 → esmc_emb.pt
# ✓ 5HT6R_HUMAN: L= 440 → esmc_emb.pt
# ✓ 5HT6R_RAT: L= 436 → esmc_emb.pt
# ✓ 5HT7R_RAT: L= 448 → esmc_emb.pt
# ✓ 5MAT_ARATH: L= 449 → esmc_emb.pt
# ✓ 5MMP_ARATH: L= 360 → esmc_emb.pt
# ✓ 5NT1B_MOUSE: L= 573 → esmc_emb.pt
# ✓ 5NT3A_HUMAN: L= 336 → esmc_emb.pt
# ✓ 5NT3A_MOUSE: L= 331 → esmc_emb.pt
# ✓ 5NT3B_DROME: L= 319 → esmc_emb.pt
# ✓ 5NT3B_HUMAN: L= 300 → esmc_emb.pt
# ✓ 5NTC_RAT: L= 560 → esmc_emb.pt
# ✓ 5NTD_HUMAN: L= 574 → esmc_emb.pt
# ✓ 5NTD_MOUSE: L= 576 → esmc_emb.pt
# ✓ 5NTD_RAT: L= 576 → esmc_emb.pt
# ✓ 60A_DROME: L= 455 → esmc_emb.pt
# ✓ 6HN3M_PSEPK: L= 382 → esmc_emb.pt
# ✓ 6P21_YEAST: L= 827 → esmc_emb.pt
# ✓ 6PGD1_ARATH: L= 487 → esmc_emb.pt
# ✓ 6PGD1_YEAST: L= 489 → esmc_emb.pt
# ✓ 6PGD2_ARATH: L= 486 → esmc_emb.pt
# ✓ 6PGD2_YEAST: L= 492 → esmc_emb.pt
# ✓ 6PGD3_ARATH: L= 487 → esmc_emb.pt
# ✓ 6PGD_ECOLI: L= 468 → esmc_emb.pt
# ✓ 6PGD_MOUSE: L= 483 → esmc_emb.pt
# ✓ 6PGD_RAT: L= 483 → esmc_emb.pt
# ✓ 6PGD_SCHPO: L= 492 → esmc_emb.pt
# ✓ 6PGL3_ARATH: L= 325 → esmc_emb.pt
# ✓ 6PGL_ECOLI: L= 331 → esmc_emb.pt
# ✓ 6PGL_HUMAN: L= 258 → esmc_emb.pt
# ✓ 6PGL_RAT: L= 257 → esmc_emb.pt
# ✓ 6PGL_SCHPO: L= 257 → esmc_emb.pt
# ✓ 7B2_HUMAN: L= 212 → esmc_emb.pt
# ✓ 7B2_MOUSE: L= 212 → esmc_emb.pt
# ✓ 7LESS_DROME: L=2554 → esmc_emb.pt
# ✓ 7UP1_DROME: L= 543 → esmc_emb.pt
# ✓ 7UP2_DROME: L= 746 → esmc_emb.pt
# ✓ 8ODP_DANRE: L= 156 → esmc_emb.pt
# ✓ 8ODP_HUMAN: L= 197 → esmc_emb.pt
# ✓ 8ODP_MOUSE: L= 156 → esmc_emb.pt
# ✓ A16L1_HUMAN: L= 607 → esmc_emb.pt
# ✓ A16L1_MOUSE: L= 607 → esmc_emb.pt
# ✓ A1AT2_MOUSE: L= 413 → esmc_emb.pt
# ✓ A1AT_HUMAN: L= 418 → esmc_emb.pt
# ✓ A1AT_RAT: L= 411 → esmc_emb.pt
# ✓ A1CF_HUMAN: L= 594 → esmc_emb.pt
# ✓ A1CF_RAT: L= 594 → esmc_emb.pt
# ✓ A1M_RAT: L=1500 → esmc_emb.pt
# ✓ A2AP_HUMAN: L= 491 → esmc_emb.pt
# ✓ A2MG_ECOLI: L=1653 → esmc_emb.pt
# ✓ A2MG_HUMAN: L=1474 → esmc_emb.pt
# ✓ A2MG_MOUSE: L=1474 → esmc_emb.pt
# ✓ A2MG_RAT: L=1472 → esmc_emb.pt
# ✓ A2ML1_HUMAN: L=1454 → esmc_emb.pt
# ✓ A3LT2_MOUSE: L= 370 → esmc_emb.pt
# ✓ A3LT2_RAT: L= 339 → esmc_emb.pt
# ✓ A4GAT_HUMAN: L= 353 → esmc_emb.pt
# ✓ A4GAT_MOUSE: L= 359 → esmc_emb.pt
# ✓ A4GAT_RAT: L= 360 → esmc_emb.pt
# ✓ A4GCT_HUMAN: L= 340 → esmc_emb.pt
# ✓ A4GCT_MOUSE: L= 341 → esmc_emb.pt
# ✓ A4_HUMAN: L= 770 → esmc_emb.pt
# ✓ A4_MOUSE: L= 770 → esmc_emb.pt
# ✓ A4_RAT: L= 770 → esmc_emb.pt
# ✓ A62F_DROME: L= 115 → esmc_emb.pt
# ✓ A70A_DROME: L=  55 → esmc_emb.pt
# ✓ AA1R_RAT: L= 326 → esmc_emb.pt
# ✓ AA2AR_HUMAN: L= 412 → esmc_emb.pt
# ✓ AA2AR_MOUSE: L= 410 → esmc_emb.pt
# ✓ AA2AR_RAT: L= 410 → esmc_emb.pt
# ✓ AA2BR_MOUSE: L= 332 → esmc_emb.pt
# ✓ AA2DA_DANRE: L= 408 → esmc_emb.pt
# ✓ AA2DB_DANRE: L= 415 → esmc_emb.pt
# ✓ AA3R_MOUSE: L= 319 → esmc_emb.pt
# ✓ AA3R_RAT: L= 320 → esmc_emb.pt
# ✓ AAA1_HUMAN: L= 523 → esmc_emb.pt
# ✓ AAA1_MOUSE: L= 530 → esmc_emb.pt
# ✓ AAAD_HUMAN: L= 399 → esmc_emb.pt
# ✓ AAAD_MOUSE: L= 398 → esmc_emb.pt
# ✓ AAAT_ECOLI: L= 162 → esmc_emb.pt
# ✓ AAAT_HUMAN: L= 541 → esmc_emb.pt
# ✓ AAAT_MOUSE: L= 553 → esmc_emb.pt
# ✓ AACS_RAT: L= 672 → esmc_emb.pt
# ✓ AACT_HUMAN: L= 423 → esmc_emb.pt
# ✓ AAD14_YEAST: L= 376 → esmc_emb.pt
# ✓ AAD4_YEAST: L= 329 → esmc_emb.pt
# ✓ AADAT_HUMAN: L= 425 → esmc_emb.pt
# ✓ AADAT_RAT: L= 425 → esmc_emb.pt
# ✓ AADK_BACSU: L= 284 → esmc_emb.pt
# ✓ AAE11_ARATH: L= 572 → esmc_emb.pt
# ✓ AAE13_ARATH: L= 608 → esmc_emb.pt
# ✓ AAE15_ARATH: L= 727 → esmc_emb.pt
# ✓ AAE20_ARATH: L= 580 → esmc_emb.pt
# ✓ AAH_ARATH: L= 525 → esmc_emb.pt
# ✓ AAK1_HUMAN: L= 961 → esmc_emb.pt
# ✓ AAK1_RAT: L= 962 → esmc_emb.pt
# ✓ AAKB1_HUMAN: L= 270 → esmc_emb.pt
# ✓ AAKB1_MOUSE: L= 270 → esmc_emb.pt
# ✓ AAKB1_RAT: L= 270 → esmc_emb.pt
# ✓ AAKB2_HUMAN: L= 272 → esmc_emb.pt
# ✓ AAKB2_RAT: L= 271 → esmc_emb.pt
# ✓ AAKG1_HUMAN: L= 331 → esmc_emb.pt
# ✓ AAKG1_MOUSE: L= 330 → esmc_emb.pt
# ✓ AAKG1_RAT: L= 330 → esmc_emb.pt
# ✓ AAKG2_HUMAN: L= 569 → esmc_emb.pt
# ✓ AAKG2_MOUSE: L= 566 → esmc_emb.pt
# ✓ AAKG3_HUMAN: L= 489 → esmc_emb.pt
# ✓ AAKG_SCHPO: L= 334 → esmc_emb.pt
# ✓ AAKG_YEAST: L= 322 → esmc_emb.pt
# ✓ AAMP_HUMAN: L= 434 → esmc_emb.pt
# ✓ AAP1_ARATH: L= 485 → esmc_emb.pt
# ✓ AAP1_SCHPO: L= 594 → esmc_emb.pt
# ✓ AAP4_ARATH: L= 466 → esmc_emb.pt
# ✓ AAP5_ARATH: L= 480 → esmc_emb.pt
# ✓ AAP6_ARATH: L= 481 → esmc_emb.pt
# ✓ AAPK1_HUMAN: L= 559 → esmc_emb.pt
# ✓ AAPK1_MOUSE: L= 559 → esmc_emb.pt
# ✓ AAPK1_RAT: L= 559 → esmc_emb.pt
# ✓ AAPK2_HUMAN: L= 552 → esmc_emb.pt
# ✓ AAPK2_MOUSE: L= 552 → esmc_emb.pt
# ✓ AAPK2_RAT: L= 552 → esmc_emb.pt
# ✓ AAP_YEAST: L=  25 → esmc_emb.pt
# ✓ AARA_DICDI: L= 757 → esmc_emb.pt
# ✓ AARE_ARATH: L= 764 → esmc_emb.pt
# ✓ AASD1_MOUSE: L= 412 → esmc_emb.pt
# ✓ AASS_MOUSE: L= 926 → esmc_emb.pt
# ✓ AAS_ECOLI: L= 719 → esmc_emb.pt
# ✓ AAT1_ARATH: L= 430 → esmc_emb.pt
# ✓ AAT2_ARATH: L= 405 → esmc_emb.pt
# ✓ AATC_HUMAN: L= 413 → esmc_emb.pt
# ✓ AATC_MOUSE: L= 413 → esmc_emb.pt
# ✓ AATC_RAT: L= 413 → esmc_emb.pt
# ✓ AATC_YEAST: L= 418 → esmc_emb.pt
# ✓ AATF_HUMAN: L= 560 → esmc_emb.pt
# ✓ AATF_RAT: L= 523 → esmc_emb.pt
# ✓ AATM_HUMAN: L= 430 → esmc_emb.pt
# ✓ AATM_MOUSE: L= 430 → esmc_emb.pt
# ✓ AATM_RAT: L= 430 → esmc_emb.pt
# ✓ AAT_ECOLI: L= 396 → esmc_emb.pt
# ✓ AB11G_ARATH: L= 703 → esmc_emb.pt
# ✓ AB12G_ARATH: L= 687 → esmc_emb.pt
# ✓ AB140_YEAST: L= 628 → esmc_emb.pt
# ✓ AB14G_ARATH: L= 648 → esmc_emb.pt
# ✓ AB17A_HUMAN: L= 310 → esmc_emb.pt
# ✓ AB17A_RAT: L= 310 → esmc_emb.pt
# ✓ AB17B_HUMAN: L= 288 → esmc_emb.pt
# ✓ AB17B_MOUSE: L= 288 → esmc_emb.pt
# ✓ AB17C_HUMAN: L= 329 → esmc_emb.pt
# ✓ AB17C_MOUSE: L= 320 → esmc_emb.pt
# ✓ AB19B_ARATH: L=1252 → esmc_emb.pt
# ✓ AB1B_ARATH: L=1286 → esmc_emb.pt
# ✓ AB1C_ARATH: L=1622 → esmc_emb.pt
# ✓ AB1K1_ARATH: L= 682 → esmc_emb.pt
# ✓ AB1K3_ARATH: L= 711 → esmc_emb.pt
# ✓ AB21B_ARATH: L=1296 → esmc_emb.pt
# ✓ AB25G_ARATH: L= 662 → esmc_emb.pt
# ✓ AB26G_ARATH: L= 685 → esmc_emb.pt
# ✓ AB2C_ARATH: L=1623 → esmc_emb.pt
# ✓ AB2F_ARATH: L= 678 → esmc_emb.pt
# ✓ AB30G_ARATH: L=1400 → esmc_emb.pt
# ✓ AB31G_ARATH: L=1426 → esmc_emb.pt
# ✓ AB36G_ARATH: L=1469 → esmc_emb.pt
# ✓ AB37G_ARATH: L=1450 → esmc_emb.pt
# ✓ AB3C_ARATH: L=1514 → esmc_emb.pt
# ✓ AB40G_ARATH: L=1423 → esmc_emb.pt
# ✓ AB4B_ARATH: L=1286 → esmc_emb.pt
# ✓ AB5C_ARATH: L=1514 → esmc_emb.pt
# ✓ AB5F_ARATH: L= 692 → esmc_emb.pt
# ✓ AB6I_ARATH: L= 338 → esmc_emb.pt
# ✓ AB8I_ARATH: L= 557 → esmc_emb.pt
# ✓ AB9A_ARATH: L= 950 → esmc_emb.pt
# ✓ AB9G_ARATH: L= 638 → esmc_emb.pt
# ✓ ABA2_ARATH: L= 285 → esmc_emb.pt
# ✓ ABAH2_ARATH: L= 482 → esmc_emb.pt
# ✓ ABAH3_ARATH: L= 463 → esmc_emb.pt
# ✓ ABAH4_ARATH: L= 468 → esmc_emb.pt
# ✓ ABC2_SCHPO: L=1478 → esmc_emb.pt
# ✓ ABC3A_HUMAN: L= 199 → esmc_emb.pt
# ✓ ABC3B_HUMAN: L= 382 → esmc_emb.pt
# ✓ ABC3F_HUMAN: L= 373 → esmc_emb.pt
# ✓ ABC3G_HUMAN: L= 384 → esmc_emb.pt
# ✓ ABC3H_HUMAN: L= 200 → esmc_emb.pt
# ✓ ABC3_SCHPO: L=1465 → esmc_emb.pt
# ✓ ABCA1_HUMAN: L=2261 → esmc_emb.pt
# ✓ ABCA1_MOUSE: L=2261 → esmc_emb.pt
# ✓ ABCA2_HUMAN: L=2435 → esmc_emb.pt
# ✓ ABCA2_RAT: L=2434 → esmc_emb.pt
# ✓ ABCA4_HUMAN: L=2273 → esmc_emb.pt
# ✓ ABCA4_MOUSE: L=2310 → esmc_emb.pt
# ✓ ABCA7_HUMAN: L=2146 → esmc_emb.pt
# ✓ ABCA7_MOUSE: L=2159 → esmc_emb.pt
# ✓ ABCA8_HUMAN: L=1581 → esmc_emb.pt
# ✓ ABCAC_HUMAN: L=2595 → esmc_emb.pt
# ✓ ABCB5_HUMAN: L=1257 → esmc_emb.pt
# ✓ ABCB6_HUMAN: L= 842 → esmc_emb.pt
# ✓ ABCB7_HUMAN: L= 752 → esmc_emb.pt
# ✓ ABCB9_HUMAN: L= 766 → esmc_emb.pt
# ✓ ABCBA_MOUSE: L= 715 → esmc_emb.pt
# ✓ ABCBB_HUMAN: L=1321 → esmc_emb.pt
# ✓ ABCBB_MOUSE: L=1321 → esmc_emb.pt
# ✓ ABCBB_RAT: L=1321 → esmc_emb.pt
# ✓ ABCC8_HUMAN: L=1581 → esmc_emb.pt
# ✓ ABCC9_HUMAN: L=1549 → esmc_emb.pt
# ✓ ABCC9_RAT: L=1545 → esmc_emb.pt
# ✓ ABCCB_HUMAN: L=1382 → esmc_emb.pt
# ✓ ABCD1_HUMAN: L= 745 → esmc_emb.pt
# ✓ ABCD1_RAT: L= 737 → esmc_emb.pt
# ✓ ABCD2_HUMAN: L= 740 → esmc_emb.pt
# ✓ ABCD3_HUMAN: L= 659 → esmc_emb.pt
# ✓ ABCD3_RAT: L= 659 → esmc_emb.pt
# ✓ ABCD4_HUMAN: L= 606 → esmc_emb.pt
# ✓ ABCE1_DROME: L= 611 → esmc_emb.pt
# ✓ ABCE1_HUMAN: L= 599 → esmc_emb.pt
# ✓ ABCF1_HUMAN: L= 845 → esmc_emb.pt
# ✓ ABCG1_HUMAN: L= 678 → esmc_emb.pt
# ✓ ABCG2_HUMAN: L= 655 → esmc_emb.pt
# ✓ ABCG2_MOUSE: L= 657 → esmc_emb.pt
# ✓ ABCG2_RAT: L= 657 → esmc_emb.pt
# ✓ ABCG4_HUMAN: L= 646 → esmc_emb.pt
# ✓ ABCG4_MOUSE: L= 646 → esmc_emb.pt
# ✓ ABCG5_HUMAN: L= 651 → esmc_emb.pt
# ✓ ABCG5_MOUSE: L= 652 → esmc_emb.pt
# ✓ ABCG8_HUMAN: L= 673 → esmc_emb.pt
# ✓ ABCG8_MOUSE: L= 673 → esmc_emb.pt
# ✓ ABD12_HUMAN: L= 398 → esmc_emb.pt
# ✓ ABD12_MOUSE: L= 398 → esmc_emb.pt
# ✓ ABDA_DROME: L= 590 → esmc_emb.pt
# ✓ ABDB_DROME: L= 493 → esmc_emb.pt
# ✓ ABDH_ECOLI: L= 474 → esmc_emb.pt
# ✓ ABEC1_HUMAN: L= 236 → esmc_emb.pt
# ✓ ABEC1_MOUSE: L= 229 → esmc_emb.pt
# ✓ ABEC1_RAT: L= 229 → esmc_emb.pt
# ✓ ABEC2_HUMAN: L= 224 → esmc_emb.pt
# ✓ ABEC2_MOUSE: L= 224 → esmc_emb.pt
# ✓ ABF1_YEAST: L= 731 → esmc_emb.pt
# ✓ ABF2_YEAST: L= 183 → esmc_emb.pt
# ✓ ABGA_ECOLI: L= 436 → esmc_emb.pt
# ✓ ABGB_ECOLI: L= 481 → esmc_emb.pt
# ✓ ABGT_ECOLI: L= 508 → esmc_emb.pt
# ✓ ABHD2_DROME: L= 398 → esmc_emb.pt
# ✓ ABHD2_HUMAN: L= 425 → esmc_emb.pt
# ✓ ABHD3_HUMAN: L= 409 → esmc_emb.pt
# ✓ ABHD4_HUMAN: L= 342 → esmc_emb.pt
# ✓ ABHD4_MOUSE: L= 342 → esmc_emb.pt
# ✓ ABHD5_HUMAN: L= 349 → esmc_emb.pt
# ✓ ABHD6_HUMAN: L= 337 → esmc_emb.pt
# ✓ ABHD6_MOUSE: L= 336 → esmc_emb.pt
# ✓ ABHDA_HUMAN: L= 306 → esmc_emb.pt
# ✓ ABHDA_MOUSE: L= 297 → esmc_emb.pt
# ✓ ABHDD_MOUSE: L= 337 → esmc_emb.pt
# ✓ ABHEB_HUMAN: L= 210 → esmc_emb.pt
# ✓ ABHGA_HUMAN: L= 558 → esmc_emb.pt
# ✓ ABHGA_MOUSE: L= 558 → esmc_emb.pt
# ✓ ABI1_HUMAN: L= 508 → esmc_emb.pt
# ✓ ABI1_MOUSE: L= 481 → esmc_emb.pt
# ✓ ABI1_RAT: L= 476 → esmc_emb.pt
# ✓ ABI2_HUMAN: L= 513 → esmc_emb.pt
# ✓ ABI3_ARATH: L= 720 → esmc_emb.pt
# ✓ ABI3_HUMAN: L= 366 → esmc_emb.pt
# ✓ ABI4_ARATH: L= 328 → esmc_emb.pt
# ✓ ABITM_MOUSE: L= 193 → esmc_emb.pt
# ✓ ABL1_HUMAN: L=1130 → esmc_emb.pt
# ✓ ABL1_MOUSE: L=1123 → esmc_emb.pt
# ✓ ABL2_HUMAN: L=1182 → esmc_emb.pt
# ✓ ABL2_MOUSE: L=1182 → esmc_emb.pt
# ✓ ABLM1_HUMAN: L= 778 → esmc_emb.pt
# ✓ ABLM1_MOUSE: L= 861 → esmc_emb.pt
# ✓ ABL_DROME: L=1620 → esmc_emb.pt
# ✓ ABP1_ARATH: L= 198 → esmc_emb.pt
# ✓ ABP1_SCHPO: L= 522 → esmc_emb.pt
# ✓ ABP1_YEAST: L= 592 → esmc_emb.pt
# ✓ ABP2_SCHPO: L= 527 → esmc_emb.pt
# ✓ ABRA_MOUSE: L= 375 → esmc_emb.pt
# ✓ ABRB_BACSU: L=  96 → esmc_emb.pt
# ✓ ABRX1_HUMAN: L= 409 → esmc_emb.pt
# ✓ ABRX2_HUMAN: L= 415 → esmc_emb.pt
# ✓ ABR_HUMAN: L= 859 → esmc_emb.pt
# ✓ ABR_MOUSE: L= 859 → esmc_emb.pt
# ✓ ABT1_HUMAN: L= 272 → esmc_emb.pt
# ✓ AC78C_DROME: L=1718 → esmc_emb.pt
# ✓ ACA1_ARATH: L=1020 → esmc_emb.pt
# ✓ ACA1_SCHPO: L= 209 → esmc_emb.pt
# ✓ ACA1_YEAST: L= 489 → esmc_emb.pt
# ✓ ACA2_ARATH: L=1014 → esmc_emb.pt
# ✓ ACA2_YEAST: L= 587 → esmc_emb.pt
# ✓ ACA4_ARATH: L=1030 → esmc_emb.pt
# ✓ ACA8_ARATH: L=1074 → esmc_emb.pt
# ✓ ACA9_ARATH: L=1086 → esmc_emb.pt
# ✓ ACACA_HUMAN: L=2346 → esmc_emb.pt
# ✓ ACACA_MOUSE: L=2345 → esmc_emb.pt
# ✓ ACACA_RAT: L=2345 → esmc_emb.pt
# ✓ ACACB_HUMAN: L=2458 → esmc_emb.pt
# ✓ ACACB_MOUSE: L=2448 → esmc_emb.pt
# ✓ ACAC_YEAST: L=2233 → esmc_emb.pt
# ✓ ACAD8_HUMAN: L= 415 → esmc_emb.pt
# ✓ ACAD9_HUMAN: L= 621 → esmc_emb.pt
# ✓ ACADL_MOUSE: L= 430 → esmc_emb.pt
# ✓ ACADL_RAT: L= 430 → esmc_emb.pt
# ✓ ACADM_DROME: L= 419 → esmc_emb.pt
# ✓ ACADM_HUMAN: L= 421 → esmc_emb.pt
# ✓ ACADM_MOUSE: L= 421 → esmc_emb.pt
# ✓ ACADM_RAT: L= 421 → esmc_emb.pt
# ✓ ACADS_HUMAN: L= 412 → esmc_emb.pt
# ✓ ACADS_RAT: L= 412 → esmc_emb.pt
# ✓ ACADV_HUMAN: L= 655 → esmc_emb.pt
# ✓ ACADV_RAT: L= 655 → esmc_emb.pt
# ✓ ACAP2_HUMAN: L= 778 → esmc_emb.pt
# ✓ ACAP2_MOUSE: L= 770 → esmc_emb.pt
# ✓ ACASE_DROME: L= 283 → esmc_emb.pt
# ✓ ACATN_HUMAN: L= 549 → esmc_emb.pt
# ✓ ACBG1_HUMAN: L= 724 → esmc_emb.pt
# ✓ ACBG2_HUMAN: L= 666 → esmc_emb.pt
# ✓ ACBG2_MOUSE: L= 667 → esmc_emb.pt
# ✓ ACBP1_ARATH: L= 338 → esmc_emb.pt
# ✓ ACBP2_ARATH: L= 354 → esmc_emb.pt
# ✓ ACBP3_ARATH: L= 362 → esmc_emb.pt
# ✓ ACBP4_ARATH: L= 668 → esmc_emb.pt
# ✓ ACBP5_ARATH: L= 648 → esmc_emb.pt
# ✓ ACBP6_ARATH: L=  92 → esmc_emb.pt
# ✓ ACBP_DICDI: L=  84 → esmc_emb.pt
# ✓ ACBP_HUMAN: L=  87 → esmc_emb.pt
# ✓ ACBP_RAT: L=  87 → esmc_emb.pt
# ✓ ACBP_YEAST: L=  87 → esmc_emb.pt
# ✓ ACC2_ARATH: L=2355 → esmc_emb.pt
# ✓ ACCA_ECOLI: L= 319 → esmc_emb.pt
# ✓ ACCC_ECOLI: L= 449 → esmc_emb.pt
# ✓ ACCD_ECOLI: L= 304 → esmc_emb.pt
# ✓ ACCO2_ARATH: L= 320 → esmc_emb.pt
# ✓ ACCO3_ARATH: L= 320 → esmc_emb.pt
# ✓ ACCR1_ARATH: L= 775 → esmc_emb.pt
# ✓ ACCR2_ARATH: L= 776 → esmc_emb.pt
# ✓ ACCR3_ARATH: L= 814 → esmc_emb.pt
# ✓ ACCR4_ARATH: L= 751 → esmc_emb.pt
# ✓ ACD10_HUMAN: L=1059 → esmc_emb.pt
# ✓ ACD11_HUMAN: L= 780 → esmc_emb.pt
# ✓ ACDH_ECOLI: L= 316 → esmc_emb.pt
# ✓ ACDSB_HUMAN: L= 432 → esmc_emb.pt
# ✓ ACDSB_RAT: L= 432 → esmc_emb.pt
# ✓ ACD_HUMAN: L= 458 → esmc_emb.pt
# ✓ ACD_MOUSE: L= 416 → esmc_emb.pt
# ✓ ACE2_HUMAN: L= 805 → esmc_emb.pt
# ✓ ACE2_RAT: L= 805 → esmc_emb.pt
# ✓ ACE2_SCHPO: L= 533 → esmc_emb.pt
# ✓ ACE2_YEAST: L= 770 → esmc_emb.pt
# ✓ ACEA_ECOLI: L= 434 → esmc_emb.pt
# ✓ ACEA_YEAST: L= 557 → esmc_emb.pt
# ✓ ACEB_YEAST: L= 575 → esmc_emb.pt
# ✓ ACEK_ECOLI: L= 578 → esmc_emb.pt
# ✓ ACER1_HUMAN: L= 264 → esmc_emb.pt
# ✓ ACER1_MOUSE: L= 273 → esmc_emb.pt
# ✓ ACER2_HUMAN: L= 275 → esmc_emb.pt
# ✓ ACER2_MOUSE: L= 275 → esmc_emb.pt
# ✓ ACER3_HUMAN: L= 267 → esmc_emb.pt
# ✓ ACER3_MOUSE: L= 267 → esmc_emb.pt
# ✓ ACER_DROME: L= 630 → esmc_emb.pt
# ✓ ACES_DANRE: L= 634 → esmc_emb.pt
# ✓ ACES_DROME: L= 649 → esmc_emb.pt
# ✓ ACES_HUMAN: L= 614 → esmc_emb.pt
# ✓ ACES_MOUSE: L= 614 → esmc_emb.pt
# ✓ ACES_RAT: L= 614 → esmc_emb.pt
# ✓ ACE_DROME: L= 615 → esmc_emb.pt
# ✓ ACE_HUMAN: L=1306 → esmc_emb.pt
# ✓ ACE_MOUSE: L=1312 → esmc_emb.pt
# ✓ ACE_RAT: L=1313 → esmc_emb.pt
# ✓ ACFR1_ARATH: L= 239 → esmc_emb.pt
# ✓ ACH10_HUMAN: L= 450 → esmc_emb.pt
# ✓ ACH10_RAT: L= 447 → esmc_emb.pt
# ✓ ACH1_CANAL: L= 524 → esmc_emb.pt
# ✓ ACH1_YEAST: L= 526 → esmc_emb.pt
# ✓ ACH2_ARATH: L= 427 → esmc_emb.pt
# ✓ ACHA2_HUMAN: L= 529 → esmc_emb.pt
# ✓ ACHA2_RAT: L= 511 → esmc_emb.pt
# ✓ ACHA3_HUMAN: L= 505 → esmc_emb.pt
# ✓ ACHA3_MOUSE: L= 499 → esmc_emb.pt
# ✓ ACHA3_RAT: L= 499 → esmc_emb.pt
# ✓ ACHA4_HUMAN: L= 627 → esmc_emb.pt
# ✓ ACHA4_MOUSE: L= 629 → esmc_emb.pt
# ✓ ACHA4_RAT: L= 630 → esmc_emb.pt
# ✓ ACHA5_HUMAN: L= 468 → esmc_emb.pt
# ✓ ACHA5_RAT: L= 452 → esmc_emb.pt
# ✓ ACHA6_HUMAN: L= 494 → esmc_emb.pt
# ✓ ACHA6_MOUSE: L= 494 → esmc_emb.pt
# ✓ ACHA6_RAT: L= 493 → esmc_emb.pt
# ✓ ACHA7_HUMAN: L= 502 → esmc_emb.pt
# ✓ ACHA7_MOUSE: L= 502 → esmc_emb.pt
# ✓ ACHA7_RAT: L= 502 → esmc_emb.pt
# ✓ ACHA9_HUMAN: L= 479 → esmc_emb.pt
# ✓ ACHA9_RAT: L= 479 → esmc_emb.pt
# ✓ ACHA_DANRE: L= 456 → esmc_emb.pt
# ✓ ACHA_HUMAN: L= 482 → esmc_emb.pt
# ✓ ACHA_RAT: L= 457 → esmc_emb.pt
# ✓ ACHB2_HUMAN: L= 502 → esmc_emb.pt
# ✓ ACHB2_MOUSE: L= 501 → esmc_emb.pt
# ✓ ACHB2_RAT: L= 500 → esmc_emb.pt
# ✓ ACHB3_HUMAN: L= 458 → esmc_emb.pt
# ✓ ACHB3_RAT: L= 464 → esmc_emb.pt
# ✓ ACHB4_HUMAN: L= 498 → esmc_emb.pt
# ✓ ACHB4_MOUSE: L= 495 → esmc_emb.pt
# ✓ ACHB4_RAT: L= 495 → esmc_emb.pt
# ✓ ACHB_HUMAN: L= 501 → esmc_emb.pt
# ✓ ACHB_MOUSE: L= 501 → esmc_emb.pt
# ✓ ACHB_RAT: L= 501 → esmc_emb.pt
# ✓ ACHD_HUMAN: L= 517 → esmc_emb.pt
# ✓ ACHD_MOUSE: L= 520 → esmc_emb.pt
# ✓ ACHD_RAT: L= 517 → esmc_emb.pt
# ✓ ACHE_HUMAN: L= 493 → esmc_emb.pt
# ✓ ACHE_RAT: L= 494 → esmc_emb.pt
# ✓ ACHG_HUMAN: L= 517 → esmc_emb.pt
# ✓ ACHG_MOUSE: L= 519 → esmc_emb.pt
# ✓ ACHG_RAT: L= 519 → esmc_emb.pt
# ✓ ACK1_HUMAN: L=1038 → esmc_emb.pt
# ✓ ACK1_MOUSE: L=1055 → esmc_emb.pt
# ✓ ACK1_RAT: L=1040 → esmc_emb.pt
# ✓ ACKA_ECOLI: L= 400 → esmc_emb.pt
# ✓ ACKA_SALTY: L= 400 → esmc_emb.pt
# ✓ ACKMT_HUMAN: L= 233 → esmc_emb.pt
# ✓ ACKMT_MOUSE: L= 247 → esmc_emb.pt
# ✓ ACKR1_HUMAN: L= 336 → esmc_emb.pt
# ✓ ACKR2_HUMAN: L= 384 → esmc_emb.pt
# ✓ ACKR2_MOUSE: L= 378 → esmc_emb.pt
# ✓ ACKR3_HUMAN: L= 362 → esmc_emb.pt
# ✓ ACKR4_HUMAN: L= 350 → esmc_emb.pt
# ✓ ACK_DROME: L=1073 → esmc_emb.pt
# ✓ ACL4_YEAST: L= 387 → esmc_emb.pt
# ✓ ACL5_ARATH: L= 339 → esmc_emb.pt
# ✓ ACL6A_MOUSE: L= 429 → esmc_emb.pt
# ✓ ACL6B_HUMAN: L= 426 → esmc_emb.pt
# ✓ ACL7A_HUMAN: L= 435 → esmc_emb.pt
# ✓ ACL7B_HUMAN: L= 415 → esmc_emb.pt
# ✓ ACLB2_ARATH: L= 608 → esmc_emb.pt
# ✓ ACLY_HUMAN: L=1101 → esmc_emb.pt
# ✓ ACLY_MOUSE: L=1091 → esmc_emb.pt
# ✓ ACLY_RAT: L=1100 → esmc_emb.pt
# ✓ ACM1_DROME: L= 805 → esmc_emb.pt
# ✓ ACM1_HUMAN: L= 460 → esmc_emb.pt
# ✓ ACM1_MOUSE: L= 460 → esmc_emb.pt
# ✓ ACM1_RAT: L= 460 → esmc_emb.pt
# ✓ ACM1_YEAST: L= 209 → esmc_emb.pt
# ✓ ACM2_HUMAN: L= 466 → esmc_emb.pt
# ✓ ACM2_MOUSE: L= 466 → esmc_emb.pt
# ✓ ACM2_RAT: L= 466 → esmc_emb.pt
# ✓ ACM3_HUMAN: L= 590 → esmc_emb.pt
# ✓ ACM3_RAT: L= 589 → esmc_emb.pt
# ✓ ACM4_MOUSE: L= 479 → esmc_emb.pt
# ✓ ACM5_HUMAN: L= 532 → esmc_emb.pt
# ✓ ACM5_MOUSE: L= 532 → esmc_emb.pt
# ✓ ACM5_RAT: L= 531 → esmc_emb.pt
# ✓ ACMSD_HUMAN: L= 336 → esmc_emb.pt
# ✓ ACMSD_RAT: L= 336 → esmc_emb.pt
# ✓ ACNA_BACSU: L= 909 → esmc_emb.pt
# ✓ ACNA_ECOLI: L= 891 → esmc_emb.pt
# ✓ ACNA_SALTY: L= 891 → esmc_emb.pt
# ✓ ACNB_ECOLI: L= 865 → esmc_emb.pt
# ✓ ACNB_SALTY: L= 865 → esmc_emb.pt
# ✓ ACNT1_MOUSE: L= 416 → esmc_emb.pt
# ✓ ACO10_MOUSE: L= 439 → esmc_emb.pt
# ✓ ACO11_HUMAN: L= 607 → esmc_emb.pt
# ✓ ACO12_HUMAN: L= 555 → esmc_emb.pt
# ✓ ACO12_MOUSE: L= 556 → esmc_emb.pt
# ✓ ACO12_RAT: L= 556 → esmc_emb.pt
# ✓ ACO13_HUMAN: L= 140 → esmc_emb.pt
# ✓ ACO1_ARATH: L= 898 → esmc_emb.pt
# ✓ ACO1_YEAST: L= 510 → esmc_emb.pt
# ✓ ACO2M_ARATH: L= 995 → esmc_emb.pt
# ✓ ACO3M_ARATH: L= 990 → esmc_emb.pt
# ✓ ACOCT_ECOLI: L= 381 → esmc_emb.pt
# ✓ ACOC_HUMAN: L= 889 → esmc_emb.pt
# ✓ ACOC_MOUSE: L= 889 → esmc_emb.pt
# ✓ ACOC_RAT: L= 889 → esmc_emb.pt
# ✓ ACOD1_MOUSE: L= 355 → esmc_emb.pt
# ✓ ACOD1_RAT: L= 358 → esmc_emb.pt
# ✓ ACOHC_HUMAN: L= 889 → esmc_emb.pt
# ✓ ACOHC_MOUSE: L= 889 → esmc_emb.pt
# ✓ ACOHC_RAT: L= 889 → esmc_emb.pt
# ✓ ACON_HUMAN: L= 780 → esmc_emb.pt
# ✓ ACON_MOUSE: L= 780 → esmc_emb.pt
# ✓ ACON_RAT: L= 780 → esmc_emb.pt
# ✓ ACON_YEAST: L= 778 → esmc_emb.pt
# ✓ ACOT1_HUMAN: L= 421 → esmc_emb.pt
# ✓ ACOT1_MOUSE: L= 419 → esmc_emb.pt
# ✓ ACOT1_RAT: L= 419 → esmc_emb.pt
# ✓ ACOT2_HUMAN: L= 483 → esmc_emb.pt
# ✓ ACOT2_RAT: L= 453 → esmc_emb.pt
# ✓ ACOT3_MOUSE: L= 432 → esmc_emb.pt
# ✓ ACOT4_HUMAN: L= 421 → esmc_emb.pt
# ✓ ACOT4_MOUSE: L= 421 → esmc_emb.pt
# ✓ ACOT5_MOUSE: L= 421 → esmc_emb.pt
# ✓ ACOT8_HUMAN: L= 319 → esmc_emb.pt
# ✓ ACOT8_MOUSE: L= 320 → esmc_emb.pt
# ✓ ACOT8_RAT: L= 320 → esmc_emb.pt
# ✓ ACOT9_MOUSE: L= 439 → esmc_emb.pt
# ✓ ACOX1_ARATH: L= 664 → esmc_emb.pt
# ✓ ACOX1_DROME: L= 669 → esmc_emb.pt
# ✓ ACOX1_HUMAN: L= 660 → esmc_emb.pt
# ✓ ACOX1_RAT: L= 661 → esmc_emb.pt
# ✓ ACOX2_ARATH: L= 692 → esmc_emb.pt
# ✓ ACOX2_HUMAN: L= 681 → esmc_emb.pt
# ✓ ACOX2_RAT: L= 681 → esmc_emb.pt
# ✓ ACOX3_RAT: L= 700 → esmc_emb.pt
# ✓ ACOX4_ARATH: L= 436 → esmc_emb.pt
# ✓ ACP1_ARATH: L= 137 → esmc_emb.pt
# ✓ ACP2_ARATH: L= 136 → esmc_emb.pt
# ✓ ACPH_ECOLI: L= 193 → esmc_emb.pt
# ✓ ACPH_HUMAN: L= 732 → esmc_emb.pt
# ✓ ACPM2_ARATH: L= 126 → esmc_emb.pt
# ✓ ACPM3_ARATH: L= 131 → esmc_emb.pt
# ✓ ACPS_ECOLI: L= 126 → esmc_emb.pt
# ✓ ACPT_ECOLI: L= 195 → esmc_emb.pt
# ✓ ACP_ECOLI: L=  78 → esmc_emb.pt
# ✓ ACR4L_ARATH: L= 895 → esmc_emb.pt
# ✓ ACRA_ECOLI: L= 397 → esmc_emb.pt
# ✓ ACRB_ECOLI: L=1049 → esmc_emb.pt
# ✓ ACRD_ECOLI: L=1037 → esmc_emb.pt
# ✓ ACRO_HUMAN: L= 421 → esmc_emb.pt
# ✓ ACRO_MOUSE: L= 436 → esmc_emb.pt
# ✓ ACRR_ECOLI: L= 215 → esmc_emb.pt
# ✓ ACRZ_ECOLI: L=  49 → esmc_emb.pt
# ✓ ACS1_YEAST: L= 713 → esmc_emb.pt
# ✓ ACS2A_HUMAN: L= 577 → esmc_emb.pt
# ✓ ACS2B_HUMAN: L= 577 → esmc_emb.pt
# ✓ ACS2L_HUMAN: L= 689 → esmc_emb.pt
# ✓ ACS2L_MOUSE: L= 682 → esmc_emb.pt
# ✓ ACS2_CANAL: L= 671 → esmc_emb.pt
# ✓ ACS2_YEAST: L= 683 → esmc_emb.pt
# ✓ ACSA_DROME: L= 670 → esmc_emb.pt
# ✓ ACSA_ECOLI: L= 652 → esmc_emb.pt
# ✓ ACSA_HUMAN: L= 701 → esmc_emb.pt
# ✓ ACSA_MOUSE: L= 701 → esmc_emb.pt
# ✓ ACSA_SALTY: L= 652 → esmc_emb.pt
# ✓ ACSF2_HUMAN: L= 615 → esmc_emb.pt
# ✓ ACSF3_HUMAN: L= 576 → esmc_emb.pt
# ✓ ACSL1_HUMAN: L= 698 → esmc_emb.pt
# ✓ ACSL1_RAT: L= 699 → esmc_emb.pt
# ✓ ACSL3_HUMAN: L= 720 → esmc_emb.pt
# ✓ ACSL3_RAT: L= 720 → esmc_emb.pt
# ✓ ACSL4_HUMAN: L= 711 → esmc_emb.pt
# ✓ ACSL4_MOUSE: L= 711 → esmc_emb.pt
# ✓ ACSL4_RAT: L= 711 → esmc_emb.pt
# ✓ ACSL5_HUMAN: L= 683 → esmc_emb.pt
# ✓ ACSL5_MOUSE: L= 683 → esmc_emb.pt
# ✓ ACSL5_RAT: L= 683 → esmc_emb.pt
# ✓ ACSL6_HUMAN: L= 697 → esmc_emb.pt
# ✓ ACSL6_MOUSE: L= 697 → esmc_emb.pt
# ✓ ACSL6_RAT: L= 697 → esmc_emb.pt
# ✓ ACSM1_HUMAN: L= 577 → esmc_emb.pt
# ✓ ACSM1_MOUSE: L= 573 → esmc_emb.pt
# ✓ ACSM3_MOUSE: L= 580 → esmc_emb.pt
# ✓ ACSM4_RAT: L= 580 → esmc_emb.pt
# ✓ ACSS3_HUMAN: L= 686 → esmc_emb.pt
# ✓ ACSS3_RAT: L= 683 → esmc_emb.pt
# ✓ ACS_ARATH: L= 743 → esmc_emb.pt
# ✓ ACT10_DICDI: L= 376 → esmc_emb.pt
# ✓ ACT1_DICDI: L= 376 → esmc_emb.pt
# ✓ ACT28_DICDI: L= 353 → esmc_emb.pt
# ✓ ACT2_ARATH: L= 377 → esmc_emb.pt
# ✓ ACT8_ARATH: L= 377 → esmc_emb.pt
# ✓ ACTA_MOUSE: L= 377 → esmc_emb.pt
# ✓ ACTB_DICDI: L= 295 → esmc_emb.pt
# ✓ ACTB_HUMAN: L= 375 → esmc_emb.pt
# ✓ ACTB_RAT: L= 375 → esmc_emb.pt
# ✓ ACTC_HUMAN: L= 377 → esmc_emb.pt
# ✓ ACTG_HUMAN: L= 375 → esmc_emb.pt
# ✓ ACTG_MOUSE: L= 375 → esmc_emb.pt
# ✓ ACTG_RAT: L= 375 → esmc_emb.pt
# ✓ ACTHR_HUMAN: L= 297 → esmc_emb.pt
# ✓ ACTN1_HUMAN: L= 892 → esmc_emb.pt
# ✓ ACTN1_MOUSE: L= 892 → esmc_emb.pt
# ✓ ACTN1_RAT: L= 892 → esmc_emb.pt
# ✓ ACTN2_HUMAN: L= 894 → esmc_emb.pt
# ✓ ACTN2_MOUSE: L= 894 → esmc_emb.pt
# ✓ ACTN3_HUMAN: L= 901 → esmc_emb.pt
# ✓ ACTN3_MOUSE: L= 900 → esmc_emb.pt
# ✓ ACTN4_HUMAN: L= 911 → esmc_emb.pt
# ✓ ACTN4_MOUSE: L= 912 → esmc_emb.pt
# ✓ ACTN4_RAT: L= 911 → esmc_emb.pt
# ✓ ACTNA_DICDI: L= 861 → esmc_emb.pt
# ✓ ACTN_DROME: L= 924 → esmc_emb.pt
# ✓ ACTP_ECOLI: L= 549 → esmc_emb.pt
# ✓ ACTS_HUMAN: L= 377 → esmc_emb.pt
# ✓ ACTT1_HUMAN: L= 376 → esmc_emb.pt
# ✓ ACTY_DICDI: L= 383 → esmc_emb.pt
# ✓ ACT_YEAST: L= 375 → esmc_emb.pt
# ✓ ACUA_BACSU: L= 210 → esmc_emb.pt
# ✓ ACUI_ECOLI: L= 324 → esmc_emb.pt
# ✓ ACV1B_HUMAN: L= 505 → esmc_emb.pt
# ✓ ACV1B_MOUSE: L= 505 → esmc_emb.pt
# ✓ ACV1B_RAT: L= 505 → esmc_emb.pt
# ✓ ACV1C_HUMAN: L= 493 → esmc_emb.pt
# ✓ ACV1C_RAT: L= 493 → esmc_emb.pt
# ✓ ACVL1_HUMAN: L= 503 → esmc_emb.pt
# ✓ ACVL1_RAT: L= 504 → esmc_emb.pt
# ✓ ACVR1_HUMAN: L= 509 → esmc_emb.pt
# ✓ ACVR1_MOUSE: L= 509 → esmc_emb.pt
# ✓ ACVR1_RAT: L= 509 → esmc_emb.pt
# ✓ ACY1A_RAT: L= 408 → esmc_emb.pt
# ✓ ACY1B_RAT: L= 408 → esmc_emb.pt
# ✓ ACY1_HUMAN: L= 408 → esmc_emb.pt
# ✓ ACY2_HUMAN: L= 313 → esmc_emb.pt
# ✓ ACY2_MOUSE: L= 312 → esmc_emb.pt
# ✓ ACY2_RAT: L= 312 → esmc_emb.pt
# ✓ ACY3_MOUSE: L= 318 → esmc_emb.pt
# ✓ ACYP1_DROME: L= 120 → esmc_emb.pt
# ✓ ACYP2_DROME: L= 102 → esmc_emb.pt
# ✓ ACYP2_HUMAN: L=  99 → esmc_emb.pt
# ✓ ACYP_ECOLI: L=  92 → esmc_emb.pt
# ✓ ADA10_HUMAN: L= 748 → esmc_emb.pt
# ✓ ADA10_MOUSE: L= 749 → esmc_emb.pt
# ✓ ADA10_RAT: L= 749 → esmc_emb.pt
# ✓ ADA11_HUMAN: L= 769 → esmc_emb.pt
# ✓ ADA12_HUMAN: L= 909 → esmc_emb.pt
# ✓ ADA15_HUMAN: L= 863 → esmc_emb.pt
# ✓ ADA15_RAT: L= 864 → esmc_emb.pt
# ✓ ADA17_DROME: L= 732 → esmc_emb.pt
# ✓ ADA17_HUMAN: L= 824 → esmc_emb.pt
# ✓ ADA17_MOUSE: L= 827 → esmc_emb.pt
# ✓ ADA18_HUMAN: L= 739 → esmc_emb.pt
# ✓ ADA19_HUMAN: L= 955 → esmc_emb.pt
# ✓ ADA19_MOUSE: L= 920 → esmc_emb.pt
# ✓ ADA1A_HUMAN: L= 466 → esmc_emb.pt
# ✓ ADA1A_MOUSE: L= 466 → esmc_emb.pt
# ✓ ADA1A_RAT: L= 466 → esmc_emb.pt
# ✓ ADA1B_HUMAN: L= 520 → esmc_emb.pt
# ✓ ADA1B_MOUSE: L= 514 → esmc_emb.pt
# ✓ ADA1B_RAT: L= 515 → esmc_emb.pt
# ✓ ADA1D_HUMAN: L= 572 → esmc_emb.pt
# ✓ ADA1D_MOUSE: L= 562 → esmc_emb.pt
# ✓ ADA1D_RAT: L= 561 → esmc_emb.pt
# ✓ ADA20_HUMAN: L= 726 → esmc_emb.pt
# ✓ ADA21_HUMAN: L= 722 → esmc_emb.pt
# ✓ ADA23_HUMAN: L= 832 → esmc_emb.pt
# ✓ ADA28_HUMAN: L= 775 → esmc_emb.pt
# ✓ ADA29_HUMAN: L= 820 → esmc_emb.pt
# ✓ ADA2A_DANRE: L= 388 → esmc_emb.pt
# ✓ ADA2A_HUMAN: L= 465 → esmc_emb.pt
# ✓ ADA2A_MOUSE: L= 465 → esmc_emb.pt
# ✓ ADA2A_RAT: L= 465 → esmc_emb.pt
# ✓ ADA2B_DANRE: L= 510 → esmc_emb.pt
# ✓ ADA2B_HUMAN: L= 450 → esmc_emb.pt
# ✓ ADA2B_MOUSE: L= 450 → esmc_emb.pt
# ✓ ADA2B_RAT: L= 453 → esmc_emb.pt
# ✓ ADA2C_DANRE: L= 432 → esmc_emb.pt
# ✓ ADA2C_HUMAN: L= 462 → esmc_emb.pt
# ✓ ADA2C_MOUSE: L= 458 → esmc_emb.pt
# ✓ ADA2_CANAL: L= 445 → esmc_emb.pt
# ✓ ADA2_HUMAN: L= 511 → esmc_emb.pt
# ✓ ADA2_YEAST: L= 434 → esmc_emb.pt
# ✓ ADA30_HUMAN: L= 790 → esmc_emb.pt
# ✓ ADAD1_MOUSE: L= 619 → esmc_emb.pt
# ✓ ADAL_ARATH: L= 355 → esmc_emb.pt
# ✓ ADAM2_HUMAN: L= 735 → esmc_emb.pt
# ✓ ADAM7_MOUSE: L= 789 → esmc_emb.pt
# ✓ ADAM8_HUMAN: L= 824 → esmc_emb.pt
# ✓ ADAM8_MOUSE: L= 826 → esmc_emb.pt
# ✓ ADAM9_HUMAN: L= 819 → esmc_emb.pt
# ✓ ADAM9_MOUSE: L= 845 → esmc_emb.pt
# ✓ ADAP1_HUMAN: L= 374 → esmc_emb.pt
# ✓ ADAP2_HUMAN: L= 381 → esmc_emb.pt
# ✓ ADAP2_RAT: L= 376 → esmc_emb.pt
# ✓ ADAR_DROME: L= 676 → esmc_emb.pt
# ✓ ADAS_DICDI: L= 611 → esmc_emb.pt
# ✓ ADAS_HUMAN: L= 658 → esmc_emb.pt
# ✓ ADAS_RAT: L= 644 → esmc_emb.pt
# ✓ ADAT1_DROME: L= 394 → esmc_emb.pt
# ✓ ADAT1_HUMAN: L= 502 → esmc_emb.pt
# ✓ ADA_DANRE: L= 359 → esmc_emb.pt
# ✓ ADA_ECOLI: L= 354 → esmc_emb.pt
# ✓ ADA_HUMAN: L= 363 → esmc_emb.pt
# ✓ ADA_MOUSE: L= 352 → esmc_emb.pt
# ✓ ADA_RAT: L= 352 → esmc_emb.pt
# ✓ ADCB_DICDI: L= 617 → esmc_emb.pt
# ✓ ADCC_DICDI: L= 654 → esmc_emb.pt
# ✓ ADCS_ARATH: L= 919 → esmc_emb.pt
# ✓ ADCS_YEAST: L= 787 → esmc_emb.pt
# ✓ ADCY1_MOUSE: L=1118 → esmc_emb.pt
# ✓ ADCY2_DROME: L=1307 → esmc_emb.pt
# ✓ ADCY2_MOUSE: L=1090 → esmc_emb.pt
# ✓ ADCY2_RAT: L=1090 → esmc_emb.pt
# ✓ ADCY3_MOUSE: L=1145 → esmc_emb.pt
# ✓ ADCY3_RAT: L=1144 → esmc_emb.pt
# ✓ ADCY4_HUMAN: L=1077 → esmc_emb.pt
# ✓ ADCY4_RAT: L=1064 → esmc_emb.pt
# ✓ ADCY5_HUMAN: L=1261 → esmc_emb.pt
# ✓ ADCY5_MOUSE: L=1262 → esmc_emb.pt
# ✓ ADCY5_RAT: L=1262 → esmc_emb.pt
# ✓ ADCY6_HUMAN: L=1168 → esmc_emb.pt
# ✓ ADCY6_MOUSE: L=1165 → esmc_emb.pt
# ✓ ADCY6_RAT: L=1166 → esmc_emb.pt
# ✓ ADCY7_HUMAN: L=1080 → esmc_emb.pt
# ✓ ADCY7_MOUSE: L=1099 → esmc_emb.pt
# ✓ ADCY8_MOUSE: L=1249 → esmc_emb.pt
# ✓ ADCY8_RAT: L=1248 → esmc_emb.pt
# ✓ ADCY9_HUMAN: L=1353 → esmc_emb.pt
# ✓ ADCY9_MOUSE: L=1353 → esmc_emb.pt
# ✓ ADCYA_HUMAN: L=1610 → esmc_emb.pt
# ✓ ADCYA_RAT: L=1608 → esmc_emb.pt
# ✓ ADDA_HUMAN: L= 737 → esmc_emb.pt
# ✓ ADDA_MOUSE: L= 735 → esmc_emb.pt
# ✓ ADDA_RAT: L= 735 → esmc_emb.pt
# ✓ ADDB_HUMAN: L= 726 → esmc_emb.pt
# ✓ ADDB_MOUSE: L= 725 → esmc_emb.pt
# ✓ ADDG_HUMAN: L= 706 → esmc_emb.pt
# ✓ ADDG_MOUSE: L= 706 → esmc_emb.pt
# ✓ ADDG_RAT: L= 705 → esmc_emb.pt
# ✓ ADD_ECOLI: L= 333 → esmc_emb.pt
# ✓ ADEC_ECOLI: L= 588 → esmc_emb.pt
# ✓ ADEP_ECOLI: L= 445 → esmc_emb.pt
# ✓ ADEQ_ECOLI: L= 444 → esmc_emb.pt
# ✓ ADE_SCHPO: L= 367 → esmc_emb.pt
# ✓ ADE_YEAST: L= 347 → esmc_emb.pt
# ✓ ADF12_ARATH: L= 137 → esmc_emb.pt
# ✓ ADF1_YEAST: L= 113 → esmc_emb.pt
# ✓ ADH1A_HUMAN: L= 375 → esmc_emb.pt
# ✓ ADH1B_HUMAN: L= 375 → esmc_emb.pt
# ✓ ADH1G_HUMAN: L= 375 → esmc_emb.pt
# ✓ ADH1_ARATH: L= 379 → esmc_emb.pt
# ✓ ADH1_MOUSE: L= 375 → esmc_emb.pt
# ✓ ADH1_RAT: L= 376 → esmc_emb.pt
# ✓ ADH1_YEAST: L= 348 → esmc_emb.pt
# ✓ ADH2_ECOLI: L= 383 → esmc_emb.pt
# ✓ ADH2_YEAST: L= 348 → esmc_emb.pt
# ✓ ADH3_YEAST: L= 375 → esmc_emb.pt
# ✓ ADH4_HUMAN: L= 380 → esmc_emb.pt
# ✓ ADH4_MOUSE: L= 377 → esmc_emb.pt
# ✓ ADH4_RAT: L= 377 → esmc_emb.pt
# ✓ ADH4_SCHPO: L= 422 → esmc_emb.pt
# ✓ ADH4_YEAST: L= 382 → esmc_emb.pt
# ✓ ADH6_HUMAN: L= 368 → esmc_emb.pt
# ✓ ADH6_YEAST: L= 360 → esmc_emb.pt
# ✓ ADH7_HUMAN: L= 386 → esmc_emb.pt
# ✓ ADH7_MOUSE: L= 374 → esmc_emb.pt
# ✓ ADH7_RAT: L= 374 → esmc_emb.pt
# ✓ ADH7_YEAST: L= 361 → esmc_emb.pt
# ✓ ADHE_ECOLI: L= 891 → esmc_emb.pt
# ✓ ADHP_ECOLI: L= 336 → esmc_emb.pt
# ✓ ADHX_DROME: L= 379 → esmc_emb.pt
# ✓ ADHX_HUMAN: L= 374 → esmc_emb.pt
# ✓ ADHX_MOUSE: L= 374 → esmc_emb.pt
# ✓ ADHX_RAT: L= 374 → esmc_emb.pt
# ✓ ADH_DROME: L= 256 → esmc_emb.pt
# ✓ ADH_SCHPO: L= 350 → esmc_emb.pt
# ✓ ADIA_ECOLI: L= 755 → esmc_emb.pt
# ✓ ADIC_ECOLI: L= 445 → esmc_emb.pt
# ✓ ADIC_SALTY: L= 445 → esmc_emb.pt
# ✓ ADIPA_XENLA: L= 554 → esmc_emb.pt
# ✓ ADIPL_MOUSE: L= 308 → esmc_emb.pt
# ✓ ADIPO_HUMAN: L= 244 → esmc_emb.pt
# ✓ ADIPO_MOUSE: L= 247 → esmc_emb.pt
# ✓ ADIP_RAT: L= 613 → esmc_emb.pt
# ✓ ADIY_ECOLI: L= 253 → esmc_emb.pt
# ✓ ADK1_ARATH: L= 344 → esmc_emb.pt
# ✓ ADK2_ARATH: L= 345 → esmc_emb.pt
# ✓ ADK_MOUSE: L= 361 → esmc_emb.pt
# ✓ ADK_RAT: L= 361 → esmc_emb.pt
# ✓ ADK_YEAST: L= 340 → esmc_emb.pt
# ✓ ADLO1_ARATH: L= 930 → esmc_emb.pt
# ✓ ADM2_HUMAN: L= 148 → esmc_emb.pt
# ✓ ADM2_RAT: L= 146 → esmc_emb.pt
# ✓ ADML_HUMAN: L= 185 → esmc_emb.pt
# ✓ ADML_RAT: L= 185 → esmc_emb.pt
# ✓ ADNP_MOUSE: L=1108 → esmc_emb.pt
# ✓ ADNP_RAT: L=1103 → esmc_emb.pt
# ✓ ADPG1_ARATH: L= 431 → esmc_emb.pt
# ✓ ADPG2_ARATH: L= 433 → esmc_emb.pt
# ✓ ADPGK_HUMAN: L= 497 → esmc_emb.pt
# ✓ ADPGK_MOUSE: L= 496 → esmc_emb.pt
# ✓ ADPPT_HUMAN: L= 309 → esmc_emb.pt
# ✓ ADPP_ECOLI: L= 209 → esmc_emb.pt
# ✓ ADPP_YEAST: L= 231 → esmc_emb.pt
# ✓ ADPRH_HUMAN: L= 357 → esmc_emb.pt
# ✓ ADPRH_MOUSE: L= 362 → esmc_emb.pt
# ✓ ADPRH_RAT: L= 362 → esmc_emb.pt
# ✓ ADPRM_DANRE: L= 322 → esmc_emb.pt
# ✓ ADPRS_HUMAN: L= 363 → esmc_emb.pt
# ✓ ADPRS_MOUSE: L= 370 → esmc_emb.pt
# ✓ ADR1_ARATH: L= 787 → esmc_emb.pt
# ✓ ADR1_YEAST: L=1323 → esmc_emb.pt
# ✓ ADRB1_HUMAN: L= 477 → esmc_emb.pt
# ✓ ADRB1_MOUSE: L= 466 → esmc_emb.pt
# ✓ ADRB1_RAT: L= 466 → esmc_emb.pt
# ✓ ADRB2_HUMAN: L= 413 → esmc_emb.pt
# ✓ ADRB2_MOUSE: L= 418 → esmc_emb.pt
# ✓ ADRB2_RAT: L= 418 → esmc_emb.pt
# ✓ ADRB3_HUMAN: L= 408 → esmc_emb.pt
# ✓ ADRB3_MOUSE: L= 400 → esmc_emb.pt
# ✓ ADRB3_RAT: L= 400 → esmc_emb.pt
# ✓ ADRC1_ARATH: L= 288 → esmc_emb.pt
# ✓ ADRC2_ARATH: L= 272 → esmc_emb.pt
# ✓ ADRM1_HUMAN: L= 407 → esmc_emb.pt
# ✓ ADRO_HUMAN: L= 491 → esmc_emb.pt
# ✓ ADRO_RAT: L= 494 → esmc_emb.pt
# ✓ ADRO_SCHPO: L= 469 → esmc_emb.pt
# ✓ ADRO_YEAST: L= 493 → esmc_emb.pt
# ✓ ADRX_YEAST: L= 172 → esmc_emb.pt
# ✓ ADSL5_ARATH: L= 299 → esmc_emb.pt
# ✓ ADSV_HUMAN: L= 715 → esmc_emb.pt
# ✓ ADT1_ARATH: L= 381 → esmc_emb.pt
# ✓ ADT1_HUMAN: L= 298 → esmc_emb.pt
# ✓ ADT1_RAT: L= 298 → esmc_emb.pt
# ✓ ADT1_YEAST: L= 309 → esmc_emb.pt
# ✓ ADT2_ARATH: L= 385 → esmc_emb.pt
# ✓ ADT2_HUMAN: L= 298 → esmc_emb.pt
# ✓ ADT2_YEAST: L= 318 → esmc_emb.pt
# ✓ ADT3_ARATH: L= 379 → esmc_emb.pt
# ✓ ADT3_YEAST: L= 307 → esmc_emb.pt
# ✓ ADT4_ARATH: L= 306 → esmc_emb.pt
# ✓ ADT5_ARATH: L= 330 → esmc_emb.pt
# ✓ ADTRP_HUMAN: L= 230 → esmc_emb.pt
# ✓ ADT_DROME: L= 312 → esmc_emb.pt
# ✓ ADT_SCHPO: L= 322 → esmc_emb.pt
# ✓ ADX_HUMAN: L= 184 → esmc_emb.pt
# ✓ ADX_RAT: L= 188 → esmc_emb.pt
# ✓ ADY2_YEAST: L= 283 → esmc_emb.pt
# ✓ ADY4_YEAST: L= 493 → esmc_emb.pt
# ✓ AE7_ARATH: L= 157 → esmc_emb.pt
# ✓ AEBP1_HUMAN: L=1158 → esmc_emb.pt
# ✓ AEBP1_MOUSE: L=1128 → esmc_emb.pt
# ✓ AEBP2_MOUSE: L= 504 → esmc_emb.pt
# ✓ AEDO_MOUSE: L= 256 → esmc_emb.pt
# ✓ AEE7_ARATH: L= 569 → esmc_emb.pt
# ✓ AEEP_ECOLI: L= 321 → esmc_emb.pt
# ✓ AEN_HUMAN: L= 325 → esmc_emb.pt
# ✓ AEP1_DANRE: L= 315 → esmc_emb.pt
# ✓ AEP1_YEAST: L= 518 → esmc_emb.pt
# ✓ AER_ARATH: L= 345 → esmc_emb.pt
# ✓ AER_ECOLI: L= 506 → esmc_emb.pt
# ✓ AES_ECOLI: L= 319 → esmc_emb.pt
# ✓ AF10_HUMAN: L=1068 → esmc_emb.pt
# ✓ AF17_HUMAN: L=1093 → esmc_emb.pt
# ✓ AF1L2_HUMAN: L= 818 → esmc_emb.pt
# ✓ AF9_HUMAN: L= 568 → esmc_emb.pt
# ✓ AFAD_HUMAN: L=1824 → esmc_emb.pt
# ✓ AFAD_MOUSE: L=1820 → esmc_emb.pt
# ✓ AFAD_RAT: L=1829 → esmc_emb.pt
# ✓ AFAM_HUMAN: L= 599 → esmc_emb.pt
# ✓ AFAP1_RAT: L= 731 → esmc_emb.pt
# ✓ AFB2_ARATH: L= 575 → esmc_emb.pt
# ✓ AFB3_ARATH: L= 577 → esmc_emb.pt
# ✓ AFC2_ARATH: L= 427 → esmc_emb.pt
# ✓ AFC3_ARATH: L= 400 → esmc_emb.pt
# ✓ AFF1_MOUSE: L=1216 → esmc_emb.pt
# ✓ AFF2_MOUSE: L=1272 → esmc_emb.pt
# ✓ AFF3_HUMAN: L=1226 → esmc_emb.pt
# ✓ AFF3_MOUSE: L=1254 → esmc_emb.pt
# ✓ AFFL_DROME: L=1673 → esmc_emb.pt
# ✓ AFG2_YEAST: L= 780 → esmc_emb.pt
# ✓ AFG32_HUMAN: L= 797 → esmc_emb.pt
# ✓ AFG3_YEAST: L= 761 → esmc_emb.pt
# ✓ AFT1_YEAST: L= 690 → esmc_emb.pt
# ✓ AFT2_YEAST: L= 416 → esmc_emb.pt
# ✓ AFTIN_HUMAN: L= 936 → esmc_emb.pt
# ✓ AG10B_HUMAN: L= 473 → esmc_emb.pt
# ✓ AGA1_YEAST: L= 725 → esmc_emb.pt
# ✓ AGA2_YEAST: L=  87 → esmc_emb.pt
# ✓ AGAL2_ARATH: L= 396 → esmc_emb.pt
# ✓ AGAL3_ARATH: L= 437 → esmc_emb.pt
# ✓ AGAL_ECOLI: L= 451 → esmc_emb.pt
# ✓ AGAL_HUMAN: L= 429 → esmc_emb.pt
# ✓ AGAL_MOUSE: L= 419 → esmc_emb.pt
# ✓ AGAL_SCHPO: L= 436 → esmc_emb.pt
# ✓ AGAP1_HUMAN: L= 857 → esmc_emb.pt
# ✓ AGAP2_HUMAN: L=1192 → esmc_emb.pt
# ✓ AGAP2_RAT: L=1186 → esmc_emb.pt
# ✓ AGAP3_MOUSE: L= 910 → esmc_emb.pt
# ✓ AGAR_ECOLI: L= 269 → esmc_emb.pt
# ✓ AGC1_YEAST: L= 902 → esmc_emb.pt
# ✓ AGCT_ARATH: L= 452 → esmc_emb.pt
# ✓ AGD12_ARATH: L= 337 → esmc_emb.pt
# ✓ AGD3_ARATH: L= 827 → esmc_emb.pt
# ✓ AGD5_ARATH: L= 483 → esmc_emb.pt
# ✓ AGDP1_ARATH: L= 517 → esmc_emb.pt
# ✓ AGE1_YEAST: L= 482 → esmc_emb.pt
# ✓ AGE2_YEAST: L= 298 → esmc_emb.pt
# ✓ AGFG1_HUMAN: L= 562 → esmc_emb.pt
# ✓ AGK_HUMAN: L= 422 → esmc_emb.pt
# ✓ AGK_MOUSE: L= 421 → esmc_emb.pt
# ✓ AGL14_ARATH: L= 221 → esmc_emb.pt
# ✓ AGL15_ARATH: L= 268 → esmc_emb.pt
# ✓ AGL16_ARATH: L= 240 → esmc_emb.pt
# ✓ AGL21_ARATH: L= 228 → esmc_emb.pt
# ✓ AGL24_ARATH: L= 220 → esmc_emb.pt
# ✓ AGL8_ARATH: L= 242 → esmc_emb.pt
# ✓ AGLUP_ARATH: L= 351 → esmc_emb.pt
# ✓ AGLU_SCHPO: L= 969 → esmc_emb.pt
# ✓ AGM1_HUMAN: L= 542 → esmc_emb.pt
# ✓ AGM1_MOUSE: L= 542 → esmc_emb.pt
# ✓ AGM1_YEAST: L= 557 → esmc_emb.pt
# ✓ AGN1_SCHPO: L= 424 → esmc_emb.pt
# ✓ AGN2_SCHPO: L= 433 → esmc_emb.pt
# ✓ AGO10_ARATH: L= 988 → esmc_emb.pt
# ✓ AGO1_ARATH: L=1048 → esmc_emb.pt
# ✓ AGO1_HUMAN: L= 857 → esmc_emb.pt
# ✓ AGO1_MOUSE: L= 857 → esmc_emb.pt
# ✓ AGO1_SCHPO: L= 834 → esmc_emb.pt
# ✓ AGO2_ARATH: L=1014 → esmc_emb.pt
# ✓ AGO2_DROME: L=1214 → esmc_emb.pt
# ✓ AGO2_HUMAN: L= 859 → esmc_emb.pt
# ✓ AGO2_MOUSE: L= 860 → esmc_emb.pt
# ✓ AGO3_DROME: L= 867 → esmc_emb.pt
# ✓ AGO3_HUMAN: L= 860 → esmc_emb.pt
# ✓ AGO3_MOUSE: L= 860 → esmc_emb.pt
# ✓ AGO4_ARATH: L= 924 → esmc_emb.pt
# ✓ AGO4_HUMAN: L= 861 → esmc_emb.pt
# ✓ AGO4_MOUSE: L= 861 → esmc_emb.pt
# ✓ AGO6_ARATH: L= 878 → esmc_emb.pt
# ✓ AGO9_ARATH: L= 896 → esmc_emb.pt
# ✓ AGP1_YEAST: L= 633 → esmc_emb.pt
# ✓ AGP3_YEAST: L= 558 → esmc_emb.pt
# ✓ AGP_ECOLI: L= 413 → esmc_emb.pt
# ✓ AGR2_HUMAN: L= 175 → esmc_emb.pt
# ✓ AGR3_HUMAN: L= 166 → esmc_emb.pt
# ✓ AGRA1_HUMAN: L= 560 → esmc_emb.pt
# ✓ AGRA2_HUMAN: L=1338 → esmc_emb.pt
# ✓ AGRA3_HUMAN: L=1321 → esmc_emb.pt
# ✓ AGRB1_HUMAN: L=1584 → esmc_emb.pt
# ✓ AGRB1_MOUSE: L=1582 → esmc_emb.pt
# ✓ AGRB2_HUMAN: L=1585 → esmc_emb.pt
# ✓ AGRB3_MOUSE: L=1522 → esmc_emb.pt
# ✓ AGRD1_HUMAN: L= 874 → esmc_emb.pt
# ✓ AGRE2_HUMAN: L= 823 → esmc_emb.pt
# ✓ AGRE5_HUMAN: L= 835 → esmc_emb.pt
# ✓ AGRE5_MOUSE: L= 818 → esmc_emb.pt
# ✓ AGRF1_HUMAN: L= 910 → esmc_emb.pt
# ✓ AGRF1_MOUSE: L= 908 → esmc_emb.pt
# ✓ AGRF2_HUMAN: L= 708 → esmc_emb.pt
# ✓ AGRF3_HUMAN: L=1079 → esmc_emb.pt
# ✓ AGRF4_HUMAN: L= 695 → esmc_emb.pt
# ✓ AGRF5_HUMAN: L=1346 → esmc_emb.pt
# ✓ AGRG1_HUMAN: L= 693 → esmc_emb.pt
# ✓ AGRG1_MOUSE: L= 687 → esmc_emb.pt
# ✓ AGRG6_DANRE: L=1185 → esmc_emb.pt
# ✓ AGRG6_HUMAN: L=1221 → esmc_emb.pt
# ✓ AGRG6_MOUSE: L=1165 → esmc_emb.pt
# ✓ AGRIN_HUMAN: L=2068 → esmc_emb.pt
# ✓ AGRIN_MOUSE: L=1950 → esmc_emb.pt
# ✓ AGRIN_RAT: L=1959 → esmc_emb.pt
# ✓ AGRL1_RAT: L=1515 → esmc_emb.pt
# ✓ AGRL2_RAT: L=1487 → esmc_emb.pt
# ✓ AGRL3_HUMAN: L=1447 → esmc_emb.pt
# ✓ AGRL3_MOUSE: L=1537 → esmc_emb.pt
# ✓ AGRP_HUMAN: L= 132 → esmc_emb.pt
# ✓ AGRP_MOUSE: L= 131 → esmc_emb.pt
# ✓ AGS1_SCHPO: L=2410 → esmc_emb.pt
# ✓ AGT1_HUMAN: L= 392 → esmc_emb.pt
# ✓ AGT1_MOUSE: L= 414 → esmc_emb.pt
# ✓ AGT1_RAT: L= 414 → esmc_emb.pt
# ✓ AGT21_ARATH: L= 476 → esmc_emb.pt
# ✓ AGT2_HUMAN: L= 514 → esmc_emb.pt
# ✓ AGT2_MOUSE: L= 513 → esmc_emb.pt
# ✓ AGTA_DICDI: L= 648 → esmc_emb.pt
# ✓ AGTR1_HUMAN: L= 359 → esmc_emb.pt
# ✓ AGTR2_HUMAN: L= 363 → esmc_emb.pt
# ✓ AGTR2_MOUSE: L= 363 → esmc_emb.pt
# ✓ AGTR2_RAT: L= 363 → esmc_emb.pt
# ✓ AGTRA_MOUSE: L= 359 → esmc_emb.pt
# ✓ AGTRA_RAT: L= 359 → esmc_emb.pt
# ✓ AGTRA_XENLA: L= 362 → esmc_emb.pt
# ✓ AGTRB_XENLA: L= 363 → esmc_emb.pt
# ✓ AGT_DROME: L= 394 → esmc_emb.pt
# ✓ AGUA_ARATH: L= 383 → esmc_emb.pt
# ✓ AGX1_YEAST: L= 385 → esmc_emb.pt
# ✓ AHA1_YEAST: L= 350 → esmc_emb.pt
# ✓ AHDC1_HUMAN: L=1603 → esmc_emb.pt
# ✓ AHI1_HUMAN: L=1196 → esmc_emb.pt
# ✓ AHK1_ARATH: L=1207 → esmc_emb.pt
# ✓ AHK2_ARATH: L=1176 → esmc_emb.pt
# ✓ AHK3_ARATH: L=1036 → esmc_emb.pt
# ✓ AHK4_ARATH: L=1080 → esmc_emb.pt
# ✓ AHK5_ARATH: L= 922 → esmc_emb.pt
# ✓ AHL12_ARATH: L= 361 → esmc_emb.pt
# ✓ AHL16_ARATH: L= 257 → esmc_emb.pt
# ✓ AHL1_ARATH: L= 356 → esmc_emb.pt
# ✓ AHL21_ARATH: L= 285 → esmc_emb.pt
# ✓ AHL22_ARATH: L= 317 → esmc_emb.pt
# ✓ AHL25_ARATH: L= 299 → esmc_emb.pt
# ✓ AHL27_ARATH: L= 311 → esmc_emb.pt
# ✓ AHL29_ARATH: L= 302 → esmc_emb.pt
# ✓ AHL3_ARATH: L= 404 → esmc_emb.pt
# ✓ AHL4_ARATH: L= 419 → esmc_emb.pt
# ✓ AHP1_ARATH: L= 154 → esmc_emb.pt
# ✓ AHP1_YEAST: L= 176 → esmc_emb.pt
# ✓ AHP2_ARATH: L= 156 → esmc_emb.pt
# ✓ AHP3_ARATH: L= 155 → esmc_emb.pt
# ✓ AHP5_ARATH: L= 157 → esmc_emb.pt
# ✓ AHPC_ECOLI: L= 187 → esmc_emb.pt
# ✓ AHPF_ECOLI: L= 521 → esmc_emb.pt
# ✓ AHR1_CANAL: L= 624 → esmc_emb.pt
# ✓ AHR_ECOLI: L= 339 → esmc_emb.pt
# ✓ AHR_HUMAN: L= 848 → esmc_emb.pt
# ✓ AHR_MOUSE: L= 848 → esmc_emb.pt
# ✓ AHR_RAT: L= 853 → esmc_emb.pt
# ✓ AHSA1_HUMAN: L= 338 → esmc_emb.pt
# ✓ AHSA1_MOUSE: L= 338 → esmc_emb.pt
# ✓ AI1M_YEAST: L= 834 → esmc_emb.pt
# ✓ AI2A_DICDI: L= 309 → esmc_emb.pt
# ✓ AI2M_YEAST: L= 854 → esmc_emb.pt
# ✓ AI5L1_ARATH: L= 331 → esmc_emb.pt
# ✓ AI5L3_ARATH: L= 262 → esmc_emb.pt
# ✓ AI5L6_ARATH: L= 454 → esmc_emb.pt
# ✓ AIB_ARATH: L= 566 → esmc_emb.pt
# ✓ AICDA_HUMAN: L= 198 → esmc_emb.pt
# ✓ AICDA_MOUSE: L= 198 → esmc_emb.pt
# ✓ AIDA_DANRE: L= 303 → esmc_emb.pt
# ✓ AIDA_MOUSE: L= 305 → esmc_emb.pt
# ✓ AIDB_ECOLI: L= 541 → esmc_emb.pt
# ✓ AIF1L_HUMAN: L= 150 → esmc_emb.pt
# ✓ AIF1_HUMAN: L= 147 → esmc_emb.pt
# ✓ AIF1_MOUSE: L= 147 → esmc_emb.pt
# ✓ AIFM1_HUMAN: L= 613 → esmc_emb.pt
# ✓ AIFM1_MOUSE: L= 612 → esmc_emb.pt
# ✓ AIG1_HUMAN: L= 245 → esmc_emb.pt
# ✓ AIG2B_ARATH: L= 169 → esmc_emb.pt
# ✓ AIL1_ARATH: L= 415 → esmc_emb.pt
# ✓ AIM14_YEAST: L= 570 → esmc_emb.pt
# ✓ AIM1_ARATH: L= 721 → esmc_emb.pt
# ✓ AIM23_YEAST: L= 356 → esmc_emb.pt
# ✓ AIM2_HUMAN: L= 343 → esmc_emb.pt
# ✓ AIM2_MOUSE: L= 354 → esmc_emb.pt
# ✓ AIM7_YEAST: L= 149 → esmc_emb.pt
# ✓ AIMP1_HUMAN: L= 312 → esmc_emb.pt
# ✓ AIMP1_MOUSE: L= 310 → esmc_emb.pt
# ✓ AIMP2_MOUSE: L= 320 → esmc_emb.pt
# ✓ AIN1_SCHPO: L= 621 → esmc_emb.pt
# ✓ AINX_HUMAN: L= 499 → esmc_emb.pt
# ✓ AINX_MOUSE: L= 501 → esmc_emb.pt
# ✓ AINX_RAT: L= 505 → esmc_emb.pt
# ✓ AIP11_ARATH: L= 611 → esmc_emb.pt
# ✓ AIP1_DICDI: L= 597 → esmc_emb.pt
# ✓ AIP1_YEAST: L= 615 → esmc_emb.pt
# ✓ AIP2_ARATH: L= 310 → esmc_emb.pt
# ✓ AIPL1_HUMAN: L= 384 → esmc_emb.pt
# ✓ AIP_HUMAN: L= 330 → esmc_emb.pt
# ✓ AIP_MOUSE: L= 330 → esmc_emb.pt
# ✓ AIR2_YEAST: L= 344 → esmc_emb.pt
# ✓ AIRE_HUMAN: L= 545 → esmc_emb.pt
# ✓ AIRE_MOUSE: L= 552 → esmc_emb.pt
# ✓ AIRP1_ARATH: L= 153 → esmc_emb.pt
# ✓ AIRP2_ARATH: L= 242 → esmc_emb.pt
# ✓ AJAP1_HUMAN: L= 411 → esmc_emb.pt
# ✓ AJUBA_DROME: L= 728 → esmc_emb.pt
# ✓ AJUBA_HUMAN: L= 538 → esmc_emb.pt
# ✓ AJUBA_MOUSE: L= 547 → esmc_emb.pt
# ✓ AK10B_ARATH: L= 569 → esmc_emb.pt
# ✓ AK17A_HUMAN: L= 695 → esmc_emb.pt
# ✓ AK1A1_HUMAN: L= 325 → esmc_emb.pt
# ✓ AK1A1_MOUSE: L= 325 → esmc_emb.pt
# ✓ AK1A1_RAT: L= 325 → esmc_emb.pt
# ✓ AK1BA_HUMAN: L= 316 → esmc_emb.pt
# ✓ AK1BF_HUMAN: L= 316 → esmc_emb.pt
# ✓ AK1C1_HUMAN: L= 323 → esmc_emb.pt
# ✓ AK1C2_HUMAN: L= 323 → esmc_emb.pt
# ✓ AK1C3_HUMAN: L= 323 → esmc_emb.pt
# ✓ AK1C4_HUMAN: L= 323 → esmc_emb.pt
# ✓ AK1CA_RAT: L= 324 → esmc_emb.pt
# ✓ AK1CL_MOUSE: L= 323 → esmc_emb.pt
# ✓ AK1D1_HUMAN: L= 326 → esmc_emb.pt
# ✓ AK1D1_RAT: L= 326 → esmc_emb.pt
# ✓ AK1H_ECOLI: L= 820 → esmc_emb.pt
# ✓ AK1_DICDI: L=1352 → esmc_emb.pt
# ✓ AK200_DROME: L= 753 → esmc_emb.pt
# ✓ AK2H_ECOLI: L= 810 → esmc_emb.pt
# ✓ AK3_BACSU: L= 454 → esmc_emb.pt
# ✓ AK3_ECOLI: L= 449 → esmc_emb.pt
# ✓ AKA10_HUMAN: L= 662 → esmc_emb.pt
# ✓ AKA11_HUMAN: L=1901 → esmc_emb.pt
# ✓ AKA11_RAT: L=1129 → esmc_emb.pt
# ✓ AKA12_HUMAN: L=1782 → esmc_emb.pt
# ✓ AKA12_MOUSE: L=1684 → esmc_emb.pt
# ✓ AKA14_RAT: L= 502 → esmc_emb.pt
# ✓ AKA28_HUMAN: L= 197 → esmc_emb.pt
# ✓ AKA7A_HUMAN: L= 104 → esmc_emb.pt
# ✓ AKA7A_MOUSE: L=  81 → esmc_emb.pt
# ✓ AKA7G_HUMAN: L= 348 → esmc_emb.pt
# ✓ AKA7G_MOUSE: L= 314 → esmc_emb.pt
# ✓ AKA7G_RAT: L= 353 → esmc_emb.pt
# ✓ AKAI1_HUMAN: L=  69 → esmc_emb.pt
# ✓ AKAI1_MOUSE: L=  69 → esmc_emb.pt
# ✓ AKAP1_HUMAN: L= 903 → esmc_emb.pt
# ✓ AKAP1_RAT: L= 854 → esmc_emb.pt
# ✓ AKAP2_RAT: L= 870 → esmc_emb.pt
# ✓ AKAP3_MOUSE: L= 864 → esmc_emb.pt
# ✓ AKAP4_MOUSE: L= 849 → esmc_emb.pt
# ✓ AKAP5_HUMAN: L= 427 → esmc_emb.pt
# ✓ AKAP5_MOUSE: L= 745 → esmc_emb.pt
# ✓ AKAP5_RAT: L= 714 → esmc_emb.pt
# ✓ AKAP6_HUMAN: L=2319 → esmc_emb.pt
# ✓ AKAP6_RAT: L=2314 → esmc_emb.pt
# ✓ AKAP8_HUMAN: L= 692 → esmc_emb.pt
# ✓ AKAP8_MOUSE: L= 687 → esmc_emb.pt
# ✓ AKAP8_RAT: L= 687 → esmc_emb.pt
# ✓ AKB9B_ARATH: L= 507 → esmc_emb.pt
# ✓ AKC1H_MOUSE: L= 323 → esmc_emb.pt
# ✓ AKC1H_RAT: L= 323 → esmc_emb.pt
# ✓ AKCL2_HUMAN: L= 320 → esmc_emb.pt
# ✓ AKH1_ARATH: L= 911 → esmc_emb.pt
# ✓ AKH2_ARATH: L= 916 → esmc_emb.pt
# ✓ AKH_DROME: L=  79 → esmc_emb.pt
# ✓ AKIR2_HUMAN: L= 203 → esmc_emb.pt
# ✓ AKIR2_XENLA: L= 181 → esmc_emb.pt
# ✓ AKIRN_DROME: L= 201 → esmc_emb.pt
# ✓ AKL1_YEAST: L=1108 → esmc_emb.pt
# ✓ AKL2A_DANRE: L= 169 → esmc_emb.pt
# ✓ AKL2B_DANRE: L= 195 → esmc_emb.pt
# ✓ AKNA_HUMAN: L=1439 → esmc_emb.pt
# ✓ AKP8L_HUMAN: L= 646 → esmc_emb.pt
# ✓ AKR1_YEAST: L= 764 → esmc_emb.pt
# ✓ AKR2A_ARATH: L= 342 → esmc_emb.pt
# ✓ AKRC8_ARATH: L= 311 → esmc_emb.pt
# ✓ AKRC9_ARATH: L= 315 → esmc_emb.pt
# ✓ AKRMG_ECOLI: L= 326 → esmc_emb.pt
# ✓ AKT1_ARATH: L= 857 → esmc_emb.pt
# ✓ AKT1_DROME: L= 611 → esmc_emb.pt
# ✓ AKT1_HUMAN: L= 480 → esmc_emb.pt
# ✓ AKT1_MOUSE: L= 480 → esmc_emb.pt
# ✓ AKT1_RAT: L= 480 → esmc_emb.pt
# ✓ AKT2_ARATH: L= 802 → esmc_emb.pt
# ✓ AKT2_HUMAN: L= 481 → esmc_emb.pt
# ✓ AKT2_MOUSE: L= 481 → esmc_emb.pt
# ✓ AKT2_RAT: L= 481 → esmc_emb.pt
# ✓ AKT3_HUMAN: L= 479 → esmc_emb.pt
# ✓ AKT3_RAT: L= 479 → esmc_emb.pt
# ✓ AK_PSEPK: L= 411 → esmc_emb.pt
# ✓ AK_YEAST: L= 527 → esmc_emb.pt
# ✓ AL121_ARATH: L= 556 → esmc_emb.pt
# ✓ AL1A1_HUMAN: L= 501 → esmc_emb.pt
# ✓ AL1A1_MOUSE: L= 501 → esmc_emb.pt
# ✓ AL1A1_RAT: L= 501 → esmc_emb.pt
# ✓ AL1A2_HUMAN: L= 518 → esmc_emb.pt
# ✓ AL1A2_MOUSE: L= 518 → esmc_emb.pt
# ✓ AL1A2_RAT: L= 518 → esmc_emb.pt
# ✓ AL1A3_HUMAN: L= 512 → esmc_emb.pt
# ✓ AL1A3_MOUSE: L= 512 → esmc_emb.pt
# ✓ AL1A3_RAT: L= 512 → esmc_emb.pt
# ✓ AL1A7_RAT: L= 501 → esmc_emb.pt
# ✓ AL1L1_HUMAN: L= 902 → esmc_emb.pt
# ✓ AL1L1_MOUSE: L= 902 → esmc_emb.pt
# ✓ AL1L1_RAT: L= 902 → esmc_emb.pt
# ✓ AL1L2_MOUSE: L= 923 → esmc_emb.pt
# ✓ AL2B4_ARATH: L= 538 → esmc_emb.pt
# ✓ AL2C4_ARATH: L= 501 → esmc_emb.pt
# ✓ AL2CL_HUMAN: L= 953 → esmc_emb.pt
# ✓ AL2CL_MOUSE: L= 952 → esmc_emb.pt
# ✓ AL3A1_HUMAN: L= 453 → esmc_emb.pt
# ✓ AL3A1_MOUSE: L= 453 → esmc_emb.pt
# ✓ AL3A1_RAT: L= 453 → esmc_emb.pt
# ✓ AL3A2_HUMAN: L= 485 → esmc_emb.pt
# ✓ AL3A2_MOUSE: L= 484 → esmc_emb.pt
# ✓ AL3A2_RAT: L= 484 → esmc_emb.pt
# ✓ AL3B1_HUMAN: L= 468 → esmc_emb.pt
# ✓ AL3B1_MOUSE: L= 468 → esmc_emb.pt
# ✓ AL3B2_HUMAN: L= 385 → esmc_emb.pt
# ✓ AL3B2_MOUSE: L= 479 → esmc_emb.pt
# ✓ AL3B3_MOUSE: L= 479 → esmc_emb.pt
# ✓ AL3H1_ARATH: L= 484 → esmc_emb.pt
# ✓ AL3I1_ARATH: L= 550 → esmc_emb.pt
# ✓ AL4A1_HUMAN: L= 563 → esmc_emb.pt
# ✓ AL4A1_MOUSE: L= 562 → esmc_emb.pt
# ✓ AL5AP_HUMAN: L= 161 → esmc_emb.pt
# ✓ AL5AP_RAT: L= 161 → esmc_emb.pt
# ✓ AL7A1_HUMAN: L= 539 → esmc_emb.pt
# ✓ AL8A1_HUMAN: L= 487 → esmc_emb.pt
# ✓ AL8A1_MOUSE: L= 487 → esmc_emb.pt
# ✓ AL9A1_HUMAN: L= 494 → esmc_emb.pt
# ✓ AL9A1_MOUSE: L= 494 → esmc_emb.pt
# ✓ AL9A1_RAT: L= 494 → esmc_emb.pt
# ✓ ALA10_ARATH: L=1202 → esmc_emb.pt
# ✓ ALA3_ARATH: L=1213 → esmc_emb.pt
# ✓ ALA5_ARATH: L=1228 → esmc_emb.pt
# ✓ ALA6_ARATH: L=1240 → esmc_emb.pt
# ✓ ALAA_ECOLI: L= 405 → esmc_emb.pt
# ✓ ALAC_ECOLI: L= 412 → esmc_emb.pt
# ✓ ALAE_ECOLI: L= 149 → esmc_emb.pt
# ✓ ALAM_YEAST: L= 592 → esmc_emb.pt
# ✓ ALAT1_ARATH: L= 543 → esmc_emb.pt
# ✓ ALAT2_HUMAN: L= 523 → esmc_emb.pt
# ✓ ALAXM_SACS2: L= 236 → esmc_emb.pt
# ✓ ALB3_ARATH: L= 462 → esmc_emb.pt
# ✓ ALBA1_SACS2: L=  97 → esmc_emb.pt
# ✓ ALBU_HUMAN: L= 609 → esmc_emb.pt
# ✓ ALBU_RAT: L= 608 → esmc_emb.pt
# ✓ ALC_ARATH: L= 210 → esmc_emb.pt
# ...
# ✓ YSC84_YEAST: L= 468 → esmc_emb.pt
# ✓ YSH1_YEAST: L= 779 → esmc_emb.pt
# ✓ YSP2_YEAST: L=1438 → esmc_emb.pt
# ✓ YTA12_YEAST: L= 825 → esmc_emb.pt
# ✓ YTDC1_DROME: L= 721 → esmc_emb.pt
# ✓ YTDC1_HUMAN: L= 727 → esmc_emb.pt
# ✓ YTDC1_RAT: L= 738 → esmc_emb.pt
# ✓ YTDC2_HUMAN: L=1430 → esmc_emb.pt
# ✓ YTDC2_MOUSE: L=1445 → esmc_emb.pt
# ✓ YTFE_ECOLI: L= 220 → esmc_emb.pt
# ✓ YTFQ_ECOLI: L= 318 → esmc_emb.pt
# ✓ YTH1_YEAST: L= 208 → esmc_emb.pt
# ✓ YTHD1_HUMAN: L= 559 → esmc_emb.pt
# ✓ YTHD1_MOUSE: L= 559 → esmc_emb.pt
# ✓ YTHD2_DANRE: L= 613 → esmc_emb.pt
# ✓ YTHD2_HUMAN: L= 579 → esmc_emb.pt
# ✓ YTHD2_MOUSE: L= 579 → esmc_emb.pt
# ✓ YTHD3_HUMAN: L= 585 → esmc_emb.pt
# ✓ YTHDF_DROME: L= 700 → esmc_emb.pt
# ✓ YU88_ARATH: L= 410 → esmc_emb.pt
# ✓ YUC4_ARATH: L= 411 → esmc_emb.pt
# ✓ YUC8_ARATH: L= 426 → esmc_emb.pt
# ✓ YUR1_YEAST: L= 428 → esmc_emb.pt
# ✓ YVAP_BACSU: L= 108 → esmc_emb.pt
# ✓ YVC1_YEAST: L= 675 → esmc_emb.pt
# ✓ YY1_ARATH: L= 387 → esmc_emb.pt
# ✓ YZR3_ARATH: L= 288 → esmc_emb.pt
# ✓ Z354A_RAT: L= 576 → esmc_emb.pt
# ✓ Z354B_MOUSE: L= 601 → esmc_emb.pt
# ✓ Z36L3_MOUSE: L= 725 → esmc_emb.pt
# ✓ Z385A_HUMAN: L= 386 → esmc_emb.pt
# ✓ Z385A_MOUSE: L= 386 → esmc_emb.pt
# ✓ Z385B_HUMAN: L= 471 → esmc_emb.pt
# ✓ Z385D_HUMAN: L= 395 → esmc_emb.pt
# ✓ Z3H7A_HUMAN: L= 971 → esmc_emb.pt
# ✓ Z3H7B_HUMAN: L= 977 → esmc_emb.pt
# ✓ Z600_DROME: L=  90 → esmc_emb.pt
# ✓ ZACN_HUMAN: L= 412 → esmc_emb.pt
# ✓ ZAK1_DICDI: L= 781 → esmc_emb.pt
# ✓ ZAK2_DICDI: L= 635 → esmc_emb.pt
# ✓ ZAP1_YEAST: L= 880 → esmc_emb.pt
# ✓ ZAP70_HUMAN: L= 619 → esmc_emb.pt
# ✓ ZAP70_MOUSE: L= 618 → esmc_emb.pt
# ✓ ZAPA_ECOLI: L= 109 → esmc_emb.pt
# ✓ ZAPB_ECOLI: L=  81 → esmc_emb.pt
# ✓ ZAPC_ECOLI: L= 180 → esmc_emb.pt
# ✓ ZAPD_ECOLI: L= 247 → esmc_emb.pt
# ✓ ZAPE_ECOLI: L= 375 → esmc_emb.pt
# ✓ ZAR1_ARATH: L= 716 → esmc_emb.pt
# ✓ ZAR1_DANRE: L= 329 → esmc_emb.pt
# ✓ ZAS1_SCHPO: L= 897 → esmc_emb.pt
# ✓ ZASP_DROME: L=2194 → esmc_emb.pt
# ✓ ZAT10_ARATH: L= 227 → esmc_emb.pt
# ✓ ZAT6_ARATH: L= 238 → esmc_emb.pt
# ✓ ZBED1_HUMAN: L= 694 → esmc_emb.pt
# ✓ ZBED2_HUMAN: L= 218 → esmc_emb.pt
# ✓ ZBP1_HUMAN: L= 429 → esmc_emb.pt
# ✓ ZBP1_MOUSE: L= 411 → esmc_emb.pt
# ✓ ZBT10_RAT: L= 836 → esmc_emb.pt
# ✓ ZBT12_HUMAN: L= 459 → esmc_emb.pt
# ✓ ZBT14_HUMAN: L= 449 → esmc_emb.pt
# ✓ ZBT14_MOUSE: L= 449 → esmc_emb.pt
# ✓ ZBT16_HUMAN: L= 673 → esmc_emb.pt
# ✓ ZBT17_HUMAN: L= 803 → esmc_emb.pt
# ✓ ZBT17_MOUSE: L= 794 → esmc_emb.pt
# ✓ ZBT18_HUMAN: L= 522 → esmc_emb.pt
# ✓ ZBT20_MOUSE: L= 741 → esmc_emb.pt
# ✓ ZBT21_HUMAN: L=1066 → esmc_emb.pt
# ✓ ZBT22_HUMAN: L= 634 → esmc_emb.pt
# ✓ ZBT25_HUMAN: L= 435 → esmc_emb.pt
# ✓ ZBT26_HUMAN: L= 441 → esmc_emb.pt
# ✓ ZBT32_HUMAN: L= 487 → esmc_emb.pt
# ✓ ZBT32_MOUSE: L= 465 → esmc_emb.pt
# ✓ ZBT37_HUMAN: L= 503 → esmc_emb.pt
# ✓ ZBT38_HUMAN: L=1195 → esmc_emb.pt
# ✓ ZBT38_RAT: L=1203 → esmc_emb.pt
# ✓ ZBT43_HUMAN: L= 467 → esmc_emb.pt
# ✓ ZBT45_HUMAN: L= 511 → esmc_emb.pt
# ✓ ZBT49_HUMAN: L= 765 → esmc_emb.pt
# ✓ ZBT7A_HUMAN: L= 584 → esmc_emb.pt
# ✓ ZBT7A_MOUSE: L= 569 → esmc_emb.pt
# ✓ ZBT7A_RAT: L= 569 → esmc_emb.pt
# ✓ ZBT7B_MOUSE: L= 544 → esmc_emb.pt
# ✓ ZBT8A_HUMAN: L= 441 → esmc_emb.pt
# ✓ ZBTB1_HUMAN: L= 713 → esmc_emb.pt
# ✓ ZBTB1_MOUSE: L= 713 → esmc_emb.pt
# ✓ ZBTB2_HUMAN: L= 514 → esmc_emb.pt
# ✓ ZBTB4_HUMAN: L=1013 → esmc_emb.pt
# ✓ ZBTB5_HUMAN: L= 677 → esmc_emb.pt
# ✓ ZBTB6_HUMAN: L= 424 → esmc_emb.pt
# ✓ ZBTB9_HUMAN: L= 473 → esmc_emb.pt
# ✓ ZC12A_HUMAN: L= 599 → esmc_emb.pt
# ✓ ZC12A_MOUSE: L= 596 → esmc_emb.pt
# ✓ ZC3C1_HUMAN: L= 502 → esmc_emb.pt
# ✓ ZC3H3_MOUSE: L= 950 → esmc_emb.pt
# ✓ ZC3H4_MOUSE: L=1304 → esmc_emb.pt
# ✓ ZC3H8_HUMAN: L= 291 → esmc_emb.pt
# ✓ ZC3H8_MOUSE: L= 305 → esmc_emb.pt
# ✓ ZC3HA_HUMAN: L= 434 → esmc_emb.pt
# ✓ ZCC17_HUMAN: L= 241 → esmc_emb.pt
# ✓ ZCCHV_RAT: L= 776 → esmc_emb.pt
# ✓ ZCH12_MOUSE: L= 402 → esmc_emb.pt
# ✓ ZCHC3_HUMAN: L= 403 → esmc_emb.pt
# ✓ ZCHC4_HUMAN: L= 513 → esmc_emb.pt
# ✓ ZCHC8_HUMAN: L= 707 → esmc_emb.pt
# ✓ ZCIS_ARATH: L= 367 → esmc_emb.pt
# ✓ ZCPW1_HUMAN: L= 648 → esmc_emb.pt
# ✓ ZCPW1_MOUSE: L= 630 → esmc_emb.pt
# ✓ ZCPW2_HUMAN: L= 356 → esmc_emb.pt
# ✓ ZDH11_HUMAN: L= 412 → esmc_emb.pt
# ✓ ZDH11_MOUSE: L= 347 → esmc_emb.pt
# ✓ ZDH12_HUMAN: L= 267 → esmc_emb.pt
# ✓ ZDH12_MOUSE: L= 267 → esmc_emb.pt
# ✓ ZDH13_MOUSE: L= 622 → esmc_emb.pt
# ✓ ZDH14_ARATH: L= 307 → esmc_emb.pt
# ✓ ZDH14_HUMAN: L= 488 → esmc_emb.pt
# ✓ ZDH15_HUMAN: L= 337 → esmc_emb.pt
# ✓ ZDH15_MOUSE: L= 337 → esmc_emb.pt
# ✓ ZDH16_HUMAN: L= 377 → esmc_emb.pt
# ✓ ZDH16_MOUSE: L= 361 → esmc_emb.pt
# ✓ ZDH17_HUMAN: L= 632 → esmc_emb.pt
# ✓ ZDH17_MOUSE: L= 632 → esmc_emb.pt
# ✓ ZDH18_HUMAN: L= 388 → esmc_emb.pt
# ✓ ZDH18_MOUSE: L= 380 → esmc_emb.pt
# ✓ ZDH19_HUMAN: L= 309 → esmc_emb.pt
# ✓ ZDH20_HUMAN: L= 365 → esmc_emb.pt
# ✓ ZDH21_HUMAN: L= 265 → esmc_emb.pt
# ✓ ZDH21_MOUSE: L= 265 → esmc_emb.pt
# ✓ ZDH22_ARATH: L= 620 → esmc_emb.pt
# ✓ ZDHC1_HUMAN: L= 485 → esmc_emb.pt
# ✓ ZDHC1_MOUSE: L= 484 → esmc_emb.pt
# ✓ ZDHC2_HUMAN: L= 367 → esmc_emb.pt
# ✓ ZDHC2_MOUSE: L= 366 → esmc_emb.pt
# ✓ ZDHC3_ARATH: L= 565 → esmc_emb.pt
# ✓ ZDHC3_HUMAN: L= 299 → esmc_emb.pt
# ✓ ZDHC3_MOUSE: L= 299 → esmc_emb.pt
# ✓ ZDHC5_HUMAN: L= 715 → esmc_emb.pt
# ✓ ZDHC5_MOUSE: L= 715 → esmc_emb.pt
# ✓ ZDHC6_HUMAN: L= 413 → esmc_emb.pt
# ✓ ZDHC7_DANRE: L= 299 → esmc_emb.pt
# ✓ ZDHC7_HUMAN: L= 308 → esmc_emb.pt
# ✓ ZDHC7_MOUSE: L= 308 → esmc_emb.pt
# ✓ ZDHC8_HUMAN: L= 765 → esmc_emb.pt
# ✓ ZDHC9_HUMAN: L= 364 → esmc_emb.pt
# ✓ ZDS1_YEAST: L= 915 → esmc_emb.pt
# ✓ ZDS_ARATH: L= 558 → esmc_emb.pt
# ✓ ZEB1_HUMAN: L=1124 → esmc_emb.pt
# ✓ ZEB1_MOUSE: L=1117 → esmc_emb.pt
# ✓ ZEB1_RAT: L=1109 → esmc_emb.pt
# ✓ ZEB2_HUMAN: L=1214 → esmc_emb.pt
# ✓ ZEB2_MOUSE: L=1215 → esmc_emb.pt
# ✓ ZEN1_DROME: L= 353 → esmc_emb.pt
# ✓ ZEP2_HUMAN: L=2446 → esmc_emb.pt
# ✓ ZEP3_MOUSE: L=2348 → esmc_emb.pt
# ✓ ZEP_ARATH: L= 667 → esmc_emb.pt
# ✓ ZEST_DROME: L= 575 → esmc_emb.pt
# ✓ ZFAN1_HUMAN: L= 268 → esmc_emb.pt
# ✓ ZFAN6_MOUSE: L= 223 → esmc_emb.pt
# ✓ ZFAT_MOUSE: L=1237 → esmc_emb.pt
# ✓ ZFH1_DROME: L=1054 → esmc_emb.pt
# ✓ ZFN2B_HUMAN: L= 257 → esmc_emb.pt
# ✓ ZFN2B_MOUSE: L= 257 → esmc_emb.pt
# ✓ ZFP13_MOUSE: L= 512 → esmc_emb.pt
# ✓ ZFP1_HUMAN: L= 407 → esmc_emb.pt
# ✓ ZFP37_MOUSE: L= 594 → esmc_emb.pt
# ✓ ZFP41_HUMAN: L= 198 → esmc_emb.pt
# ✓ ZFP42_MOUSE: L= 288 → esmc_emb.pt
# ✓ ZFP57_HUMAN: L= 452 → esmc_emb.pt
# ✓ ZFP57_MOUSE: L= 421 → esmc_emb.pt
# ✓ ZFP7_ARATH: L= 209 → esmc_emb.pt
# ✓ ZFP90_MOUSE: L= 636 → esmc_emb.pt
# ✓ ZFP91_HUMAN: L= 570 → esmc_emb.pt
# ✓ ZFS1_SCHPO: L= 404 → esmc_emb.pt
# ✓ ZFX_HUMAN: L= 805 → esmc_emb.pt
# ✓ ZFY16_HUMAN: L=1539 → esmc_emb.pt
# ✓ ZFY26_HUMAN: L=2539 → esmc_emb.pt
# ✓ ZFY27_HUMAN: L= 411 → esmc_emb.pt
# ✓ ZFYV1_HUMAN: L= 777 → esmc_emb.pt
# ✓ ZFYV9_HUMAN: L=1425 → esmc_emb.pt
# ✓ ZG16_MOUSE: L= 167 → esmc_emb.pt
# ✓ ZGPAT_HUMAN: L= 531 → esmc_emb.pt
# ✓ ZH15B_DANRE: L= 332 → esmc_emb.pt
# ✓ ZHANG_HUMAN: L= 354 → esmc_emb.pt
# ✓ ZHD10_ARATH: L= 334 → esmc_emb.pt
# ✓ ZHD11_ARATH: L= 242 → esmc_emb.pt
# ✓ ZHD14_ARATH: L= 168 → esmc_emb.pt
# ✓ ZHD2_ARATH: L= 220 → esmc_emb.pt
# ✓ ZHD4_ARATH: L= 312 → esmc_emb.pt
# ✓ ZHD5_ARATH: L= 309 → esmc_emb.pt
# ✓ ZHF1_SCHPO: L= 387 → esmc_emb.pt
# ✓ ZHX1_HUMAN: L= 873 → esmc_emb.pt
# ✓ ZHX1_RAT: L= 873 → esmc_emb.pt
# ✓ ZHX2_HUMAN: L= 837 → esmc_emb.pt
# ✓ ZHX3_HUMAN: L= 956 → esmc_emb.pt
# ✓ ZHX3_RAT: L= 951 → esmc_emb.pt
# ✓ ZIC1_MOUSE: L= 447 → esmc_emb.pt
# ✓ ZIC2_MOUSE: L= 530 → esmc_emb.pt
# ✓ ZIC3_HUMAN: L= 467 → esmc_emb.pt
# ✓ ZIC3_MOUSE: L= 466 → esmc_emb.pt
# ✓ ZIC4_HUMAN: L= 334 → esmc_emb.pt
# ✓ ZIC4_MOUSE: L= 341 → esmc_emb.pt
# ✓ ZIC5_HUMAN: L= 663 → esmc_emb.pt
# ✓ ZIC5_MOUSE: L= 622 → esmc_emb.pt
# ✓ ZIFL1_ARATH: L= 478 → esmc_emb.pt
# ✓ ZIM17_YEAST: L= 174 → esmc_emb.pt
# ✓ ZINT_ECOLI: L= 216 → esmc_emb.pt
# ✓ ZIP1_ARATH: L= 355 → esmc_emb.pt
# ✓ ZIP1_SCHPO: L= 330 → esmc_emb.pt
# ✓ ZIP1_YEAST: L= 875 → esmc_emb.pt
# ✓ ZIP2_YEAST: L= 704 → esmc_emb.pt
# ✓ ZIP3_ARATH: L= 339 → esmc_emb.pt
# ✓ ZITB_ECOLI: L= 313 → esmc_emb.pt
# ✓ ZKSC3_HUMAN: L= 538 → esmc_emb.pt
# ✓ ZKSC4_HUMAN: L= 545 → esmc_emb.pt
# ✓ ZMAT4_HUMAN: L= 229 → esmc_emb.pt
# ✓ ZMIZ1_HUMAN: L=1067 → esmc_emb.pt
# ✓ ZMIZ2_HUMAN: L= 920 → esmc_emb.pt
# ✓ ZMY10_MOUSE: L= 440 → esmc_emb.pt
# ✓ ZMY11_HUMAN: L= 602 → esmc_emb.pt
# ✓ ZMY11_MOUSE: L= 602 → esmc_emb.pt
# ✓ ZMY15_MOUSE: L= 736 → esmc_emb.pt
# ✓ ZMYM2_HUMAN: L=1377 → esmc_emb.pt
# ✓ ZMYM3_HUMAN: L=1370 → esmc_emb.pt
# ✓ ZMYM4_HUMAN: L=1548 → esmc_emb.pt
# ✓ ZMYM5_HUMAN: L= 669 → esmc_emb.pt
# ✓ ZMYM6_HUMAN: L=1325 → esmc_emb.pt
# ✓ ZN106_MOUSE: L=1888 → esmc_emb.pt
# ✓ ZN114_HUMAN: L= 417 → esmc_emb.pt
# ✓ ZN124_HUMAN: L= 351 → esmc_emb.pt
# ✓ ZN131_MOUSE: L= 619 → esmc_emb.pt
# ✓ ZN133_HUMAN: L= 654 → esmc_emb.pt
# ✓ ZN136_HUMAN: L= 540 → esmc_emb.pt
# ✓ ZN140_HUMAN: L= 457 → esmc_emb.pt
# ✓ ZN143_HUMAN: L= 638 → esmc_emb.pt
# ✓ ZN143_MOUSE: L= 638 → esmc_emb.pt
# ✓ ZN143_RAT: L= 638 → esmc_emb.pt
# ✓ ZN148_HUMAN: L= 794 → esmc_emb.pt
# ✓ ZN148_MOUSE: L= 794 → esmc_emb.pt
# ✓ ZN148_RAT: L= 794 → esmc_emb.pt
# ✓ ZN174_HUMAN: L= 407 → esmc_emb.pt
# ✓ ZN175_HUMAN: L= 711 → esmc_emb.pt
# ✓ ZN185_HUMAN: L= 689 → esmc_emb.pt
# ✓ ZN202_HUMAN: L= 648 → esmc_emb.pt
# ✓ ZN207_HUMAN: L= 478 → esmc_emb.pt
# ✓ ZN207_MOUSE: L= 495 → esmc_emb.pt
# ✓ ZN207_XENLA: L= 452 → esmc_emb.pt
# ✓ ZN212_HUMAN: L= 495 → esmc_emb.pt
# ✓ ZN217_HUMAN: L=1048 → esmc_emb.pt
# ✓ ZN219_DANRE: L=1095 → esmc_emb.pt
# ✓ ZN219_HUMAN: L= 722 → esmc_emb.pt
# ✓ ZN224_HUMAN: L= 707 → esmc_emb.pt
# ✓ ZN239_HUMAN: L= 458 → esmc_emb.pt
# ✓ ZN250_HUMAN: L= 560 → esmc_emb.pt
# ✓ ZN263_HUMAN: L= 683 → esmc_emb.pt
# ✓ ZN274_HUMAN: L= 653 → esmc_emb.pt
# ✓ ZN277_DROME: L= 452 → esmc_emb.pt
# ✓ ZN277_MOUSE: L= 583 → esmc_emb.pt
# ✓ ZN281_HUMAN: L= 895 → esmc_emb.pt
# ✓ ZN281_MOUSE: L= 893 → esmc_emb.pt
# ✓ ZN296_HUMAN: L= 475 → esmc_emb.pt
# ✓ ZN296_MOUSE: L= 445 → esmc_emb.pt
# ✓ ZN300_HUMAN: L= 604 → esmc_emb.pt
# ✓ ZN304_HUMAN: L= 659 → esmc_emb.pt
# ✓ ZN318_MOUSE: L=2237 → esmc_emb.pt
# ✓ ZN322_MOUSE: L= 410 → esmc_emb.pt
# ✓ ZN326_HUMAN: L= 582 → esmc_emb.pt
# ✓ ZN326_MOUSE: L= 580 → esmc_emb.pt
# ✓ ZN335_MOUSE: L=1337 → esmc_emb.pt
# ✓ ZN341_HUMAN: L= 854 → esmc_emb.pt
# ✓ ZN343_HUMAN: L= 599 → esmc_emb.pt
# ✓ ZN346_HUMAN: L= 294 → esmc_emb.pt
# ✓ ZN346_MOUSE: L= 294 → esmc_emb.pt
# ✓ ZN346_XENLA: L= 524 → esmc_emb.pt
# ✓ ZN350_HUMAN: L= 532 → esmc_emb.pt
# ✓ ZN363_HUMAN: L= 261 → esmc_emb.pt
# ✓ ZN365_HUMAN: L= 407 → esmc_emb.pt
# ✓ ZN366_HUMAN: L= 744 → esmc_emb.pt
# ✓ ZN367_HUMAN: L= 350 → esmc_emb.pt
# ✓ ZN382_RAT: L= 549 → esmc_emb.pt
# ✓ ZN384_HUMAN: L= 577 → esmc_emb.pt
# ✓ ZN384_RAT: L= 579 → esmc_emb.pt
# ✓ ZN395_HUMAN: L= 513 → esmc_emb.pt
# ✓ ZN396_HUMAN: L= 335 → esmc_emb.pt
# ✓ ZN397_HUMAN: L= 534 → esmc_emb.pt
# ✓ ZN408_HUMAN: L= 720 → esmc_emb.pt
# ✓ ZN410_HUMAN: L= 478 → esmc_emb.pt
# ✓ ZN423_RAT: L=1311 → esmc_emb.pt
# ✓ ZN431_MOUSE: L= 526 → esmc_emb.pt
# ✓ ZN438_HUMAN: L= 828 → esmc_emb.pt
# ✓ ZN444_HUMAN: L= 327 → esmc_emb.pt
# ✓ ZN445_HUMAN: L=1031 → esmc_emb.pt
# ✓ ZN445_MOUSE: L= 986 → esmc_emb.pt
# ✓ ZN446_HUMAN: L= 450 → esmc_emb.pt
# ✓ ZN449_HUMAN: L= 518 → esmc_emb.pt
# ✓ ZN451_HUMAN: L=1061 → esmc_emb.pt
# ✓ ZN454_HUMAN: L= 522 → esmc_emb.pt
# ✓ ZN460_HUMAN: L= 562 → esmc_emb.pt
# ✓ ZN467_MOUSE: L= 594 → esmc_emb.pt
# ✓ ZN496_MOUSE: L= 585 → esmc_emb.pt
# ✓ ZN513_HUMAN: L= 541 → esmc_emb.pt
# ✓ ZN513_MOUSE: L= 541 → esmc_emb.pt
# ✓ ZN516_MOUSE: L=1157 → esmc_emb.pt
# ✓ ZN521_HUMAN: L=1311 → esmc_emb.pt
# ✓ ZN524_HUMAN: L= 264 → esmc_emb.pt
# ✓ ZN536_HUMAN: L=1300 → esmc_emb.pt
# ✓ ZN536_MOUSE: L=1302 → esmc_emb.pt
# ✓ ZN540_HUMAN: L= 660 → esmc_emb.pt
# ✓ ZN568_MOUSE: L= 671 → esmc_emb.pt
# ✓ ZN579_HUMAN: L= 562 → esmc_emb.pt
# ✓ ZN589_HUMAN: L= 364 → esmc_emb.pt
# ✓ ZN592_MOUSE: L=1262 → esmc_emb.pt
# ✓ ZN593_HUMAN: L= 134 → esmc_emb.pt
# ✓ ZN597_HUMAN: L= 424 → esmc_emb.pt
# ✓ ZN598_HUMAN: L= 904 → esmc_emb.pt
# ✓ ZN609_MOUSE: L=1413 → esmc_emb.pt
# ✓ ZN618_HUMAN: L= 954 → esmc_emb.pt
# ✓ ZN628_MOUSE: L=1038 → esmc_emb.pt
# ✓ ZN638_HUMAN: L=1978 → esmc_emb.pt
# ✓ ZN639_HUMAN: L= 485 → esmc_emb.pt
# ✓ ZN644_HUMAN: L=1327 → esmc_emb.pt
# ✓ ZN653_HUMAN: L= 615 → esmc_emb.pt
# ✓ ZN658_HUMAN: L=1059 → esmc_emb.pt
# ✓ ZN660_HUMAN: L= 331 → esmc_emb.pt
# ✓ ZN668_MOUSE: L= 619 → esmc_emb.pt
# ✓ ZN675_HUMAN: L= 568 → esmc_emb.pt
# ✓ ZN683_HUMAN: L= 524 → esmc_emb.pt
# ✓ ZN683_MOUSE: L= 458 → esmc_emb.pt
# ✓ ZN684_HUMAN: L= 378 → esmc_emb.pt
# ✓ ZN692_HUMAN: L= 519 → esmc_emb.pt
# ✓ ZN703_DANRE: L= 589 → esmc_emb.pt
# ✓ ZN703_MOUSE: L= 594 → esmc_emb.pt
# ✓ ZN704_HUMAN: L= 412 → esmc_emb.pt
# ✓ ZN704_MOUSE: L= 566 → esmc_emb.pt
# ✓ ZN711_HUMAN: L= 761 → esmc_emb.pt
# ✓ ZN713_HUMAN: L= 443 → esmc_emb.pt
# ✓ ZN740_HUMAN: L= 193 → esmc_emb.pt
# ✓ ZN746_HUMAN: L= 644 → esmc_emb.pt
# ✓ ZN746_MOUSE: L= 652 → esmc_emb.pt
# ✓ ZN750_HUMAN: L= 723 → esmc_emb.pt
# ✓ ZN75A_HUMAN: L= 296 → esmc_emb.pt
# ✓ ZN783_HUMAN: L= 281 → esmc_emb.pt
# ✓ ZN784_HUMAN: L= 323 → esmc_emb.pt
# ✓ ZN787_HUMAN: L= 382 → esmc_emb.pt
# ✓ ZN792_HUMAN: L= 632 → esmc_emb.pt
# ✓ ZN809_MOUSE: L= 402 → esmc_emb.pt
# ✓ ZN821_HUMAN: L= 412 → esmc_emb.pt
# ✓ ZN827_HUMAN: L=1081 → esmc_emb.pt
# ✓ ZN837_HUMAN: L= 531 → esmc_emb.pt
# ✓ ZNF1_YEAST: L= 465 → esmc_emb.pt
# ✓ ZNF22_HUMAN: L= 224 → esmc_emb.pt
# ✓ ZNF22_MOUSE: L= 237 → esmc_emb.pt
# ✓ ZNF23_HUMAN: L= 643 → esmc_emb.pt
# ✓ ZNF24_HUMAN: L= 368 → esmc_emb.pt
# ✓ ZNF24_MOUSE: L= 368 → esmc_emb.pt
# ✓ ZNF32_HUMAN: L= 273 → esmc_emb.pt
# ✓ ZNF35_HUMAN: L= 527 → esmc_emb.pt
# ✓ ZNF3_HUMAN: L= 446 → esmc_emb.pt
# ✓ ZNF43_HUMAN: L= 809 → esmc_emb.pt
# ✓ ZNF48_HUMAN: L= 618 → esmc_emb.pt
# ✓ ZNF69_HUMAN: L= 566 → esmc_emb.pt
# ✓ ZNF76_HUMAN: L= 570 → esmc_emb.pt
# ✓ ZNF7_HUMAN: L= 686 → esmc_emb.pt
# ✓ ZNF85_HUMAN: L= 595 → esmc_emb.pt
# ✓ ZNF91_HUMAN: L=1191 → esmc_emb.pt
# ✓ ZNF93_HUMAN: L= 620 → esmc_emb.pt
# ✓ ZNFX1_MOUSE: L=1909 → esmc_emb.pt
# ✓ ZNG1_DANRE: L= 366 → esmc_emb.pt
# ✓ ZNG1_MOUSE: L= 393 → esmc_emb.pt
# ✓ ZNG1_YEAST: L= 429 → esmc_emb.pt
# ✓ ZNHI1_MOUSE: L= 154 → esmc_emb.pt
# ✓ ZNHI3_HUMAN: L= 155 → esmc_emb.pt
# ✓ ZNRD2_MOUSE: L= 199 → esmc_emb.pt
# ✓ ZNRF1_HUMAN: L= 227 → esmc_emb.pt
# ✓ ZNRF1_MOUSE: L= 227 → esmc_emb.pt
# ✓ ZNRF2_HUMAN: L= 242 → esmc_emb.pt
# ✓ ZNRF3_HUMAN: L= 936 → esmc_emb.pt
# ✓ ZNT10_HUMAN: L= 485 → esmc_emb.pt
# ✓ ZNT1_MOUSE: L= 503 → esmc_emb.pt
# ✓ ZNT1_RAT: L= 507 → esmc_emb.pt
# ✓ ZNT2_HUMAN: L= 323 → esmc_emb.pt
# ✓ ZNT2_RAT: L= 359 → esmc_emb.pt
# ✓ ZNT3_HUMAN: L= 388 → esmc_emb.pt
# ✓ ZNT4_RAT: L= 430 → esmc_emb.pt
# ✓ ZNT5_HUMAN: L= 765 → esmc_emb.pt
# ✓ ZNT6_HUMAN: L= 461 → esmc_emb.pt
# ✓ ZNT6_MOUSE: L= 460 → esmc_emb.pt
# ✓ ZNT7_MOUSE: L= 378 → esmc_emb.pt
# ✓ ZNT8_HUMAN: L= 369 → esmc_emb.pt
# ✓ ZNT8_MOUSE: L= 367 → esmc_emb.pt
# ✓ ZNT9_MOUSE: L= 567 → esmc_emb.pt
# ✓ ZNTA_ECOLI: L= 732 → esmc_emb.pt
# ✓ ZNTB_ECOLI: L= 327 → esmc_emb.pt
# ✓ ZNTB_SALTY: L= 327 → esmc_emb.pt
# ✓ ZNTR_ECOLI: L= 141 → esmc_emb.pt
# ✓ ZNUA_ECOLI: L= 310 → esmc_emb.pt
# ✓ ZNUB_ECOLI: L= 261 → esmc_emb.pt
# ✓ ZO1_MOUSE: L=1745 → esmc_emb.pt
# ✓ ZO1_RAT: L=1765 → esmc_emb.pt
# ✓ ZO2_HUMAN: L=1190 → esmc_emb.pt
# ✓ ZOP1_ARATH: L= 242 → esmc_emb.pt
# ✓ ZP2_HUMAN: L= 745 → esmc_emb.pt
# ✓ ZP3_HUMAN: L= 424 → esmc_emb.pt
# ✓ ZP3_MOUSE: L= 424 → esmc_emb.pt
# ✓ ZP4_HUMAN: L= 540 → esmc_emb.pt
# ✓ ZPR1_HUMAN: L= 459 → esmc_emb.pt
# ✓ ZPR1_MOUSE: L= 459 → esmc_emb.pt
# ✓ ZPR1_YEAST: L= 486 → esmc_emb.pt
# ✓ ZRAB2_HUMAN: L= 330 → esmc_emb.pt
# ✓ ZRAB3_HUMAN: L=1079 → esmc_emb.pt
# ✓ ZRAN1_HUMAN: L= 708 → esmc_emb.pt
# ✓ ZRAP_ECOLI: L= 141 → esmc_emb.pt
# ✓ ZRAP_SALTY: L= 151 → esmc_emb.pt
# ✓ ZRAR_ECOLI: L= 441 → esmc_emb.pt
# ✓ ZRAS_ECOLI: L= 465 → esmc_emb.pt
# ✓ ZRC1_YEAST: L= 442 → esmc_emb.pt
# ✓ ZRG17_SCHPO: L= 386 → esmc_emb.pt
# ✓ ZRG17_YEAST: L= 605 → esmc_emb.pt
# ✓ ZRT1_SCHPO: L= 408 → esmc_emb.pt
# ✓ ZRT1_YEAST: L= 376 → esmc_emb.pt
# ✓ ZRT2_YEAST: L= 422 → esmc_emb.pt
# ✓ ZRT3_YEAST: L= 503 → esmc_emb.pt
# ✓ ZSA5A_HUMAN: L= 496 → esmc_emb.pt
# ✓ ZSC10_MOUSE: L= 782 → esmc_emb.pt
# ✓ ZSC16_HUMAN: L= 348 → esmc_emb.pt
# ✓ ZSC21_HUMAN: L= 473 → esmc_emb.pt
# ✓ ZSC21_MOUSE: L= 555 → esmc_emb.pt
# ✓ ZSC23_HUMAN: L= 389 → esmc_emb.pt
# ✓ ZSC29_HUMAN: L= 852 → esmc_emb.pt
# ✓ ZSC31_HUMAN: L= 406 → esmc_emb.pt
# ✓ ZSC32_HUMAN: L= 697 → esmc_emb.pt
# ✓ ZSC9_HUMAN: L= 394 → esmc_emb.pt
# ✓ ZSCA1_HUMAN: L= 408 → esmc_emb.pt
# ✓ ZSCA4_HUMAN: L= 433 → esmc_emb.pt
# ✓ ZSWM2_MOUSE: L= 631 → esmc_emb.pt
# ✓ ZSWM8_HUMAN: L=1837 → esmc_emb.pt
# ✓ ZUC_DROME: L= 253 → esmc_emb.pt
# ✓ ZUO1_YEAST: L= 433 → esmc_emb.pt
# ✓ ZUPT_ECOLI: L= 257 → esmc_emb.pt
# ✓ ZUR_BACSU: L= 145 → esmc_emb.pt
# ✓ ZUR_ECOLI: L= 171 → esmc_emb.pt
# ✓ ZW10_DROME: L= 721 → esmc_emb.pt
# ✓ ZW10_HUMAN: L= 779 → esmc_emb.pt
# ✓ ZWINT_HUMAN: L= 277 → esmc_emb.pt
# ✓ ZXDA_HUMAN: L= 799 → esmc_emb.pt
# ✓ ZXDC_HUMAN: L= 858 → esmc_emb.pt
# ✓ ZYM1_SCHPO: L=  50 → esmc_emb.pt
# ✓ ZYX_XENLA: L= 663 → esmc_emb.pt
#
# Done. created=32546 | existing_skipped=0 | missing/empty_seq_skipped=0

# %%
"""
Generate Ankh3-XL encoder embeddings for PIDs that appear under the
CAFA_Style <split>/mf/* directories, *reading sequences from*
CAFA_Style/sequences/<PID>/seq.txt and *writing*
CAFA_Style/sequences/<PID>/ankh_emb_xl.pt.

Output per PID:
    sequences/<PID>/ankh_emb_xl.pt     # torch.Tensor, (1, L+2, d_model)

Logic
-----
- Positions [0] and [L+1] are zeros; positions [1..L] are per-residue embeddings.
- Uses the S2S prefix token and includes EOS in tokenization.
- If L <= WINDOW_EFF (512), run a single forward pass (fast path).
- If L > WINDOW_EFF, use sliding windows with **OVERLAP=128** and
  **context-trim** stitching (keep only the non-overlap core per window; no weighting).
  Only indices 0 and L+1 are zero.

Notes
-----
- We *only* embed PIDs that exist under <split>/mf (splits: train/val/test).
- Skips existing outputs and missing/empty sequences.
- Uses GPU if available.
"""
from __future__ import annotations

from pathlib import Path
from typing import Iterable, Set, List, Tuple

import torch
from tqdm.auto import tqdm
from transformers import T5Tokenizer, T5EncoderModel

# ─────────────────────────────── config ─────────────────────────────── #
BASE          = Path("/teamspace/studios/this_studio/CAFA_Style")
ONTOLOGY      = "mf"                       # only embed PIDs that appear under this ontology
SPLITS        = ["train", "val", "test"]
SEQS_DIR      = BASE / "sequences"        # source of seq.txt and target for outputs
OUT_FILENAME  = "ankh_emb_xl.pt"
CKPT          = "ElnaggarLab/ankh3-xl"
PREFIX        = "[S2S]"                   # Use S2S prefix for better embedding quality

DTYPE         = torch.float16
DEVICE        = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hardcoded model dimension for Ankh3-XL
D_MODEL       = 2560

# Sliding-window hyperparameters (requested)
WINDOW_EFF    = 512    # residues per window (context window)
OVERLAP       = 128    # residues of overlap between adjacent windows
# ────────────────────────────────────────────────────────────────────── #


def gather_pids_from_mf(base: Path, splits: Iterable[str]) -> Set[str]:
    """Union of subfolder names under <base>/<split>/mf/* for all splits."""
    pids: Set[str] = set()
    for split in splits:
        root = base / split / ONTOLOGY
        if not root.exists():
            tqdm.write(f"[WARN] Missing folder: {root} — skipping this split")
            continue
        for item in root.iterdir():
            if item.is_dir():
                pids.add(item.name)
    return pids


def read_sequence(seqs_dir: Path, pid: str) -> str:
    """Read FASTA-like or plain sequence, strip headers/whitespace, uppercase."""
    seq_path = seqs_dir / pid / "seq.txt"
    if not seq_path.exists():
        return ""
    parts = []
    with seq_path.open("r", encoding="utf-8") as fh:
        for line in fh:
            if line.startswith(">"):
                continue
            parts.append(line.strip())
    return ("".join(parts)).upper()


def _plan_windows(L: int) -> List[Tuple[int, int]]:
    """Return inclusive-exclusive windows [(s,e), ...] covering [0, L) with overlap."""
    if L <= WINDOW_EFF:
        return [(0, L)]
    stride = max(1, WINDOW_EFF - OVERLAP)
    windows: List[Tuple[int, int]] = []
    s = 0
    while s < L:
        e = min(s + WINDOW_EFF, L)
        windows.append((s, e))
        if e == L:
            break
        s += stride
    return windows


@torch.inference_mode()
def _embed_window_ankh(model: T5EncoderModel, tok: T5Tokenizer, subseq: str) -> torch.Tensor:
    """
    Embed a *subsequence* with Ankh3-XL and return per-residue embeddings [Li, d_model].

    We tokenize with the S2S prefix and add_special_tokens=True (includes EOS).
    The first token corresponds to the prefix; we drop the prefix and EOS,
    keeping exactly Li residue rows.
    """
    enc = tok(PREFIX + subseq, add_special_tokens=True, return_tensors="pt")
    enc = {k: v.to(model.device) for k, v in enc.items()}

    hidden = model(**enc).last_hidden_state.squeeze(0)  # [T, d_model]
    Li = len(subseq)

    # Positions: 0 -> S2S prefix; 1..Li -> residues; Li+1 -> EOS (when present)
    per_res = hidden[1 : 1 + Li]                         # [Li, d_model]
    if per_res.size(0) != Li:
        raise RuntimeError(
            f"[Ankh3-XL] Token/AA mismatch in window: expected {Li} got {per_res.size(0)}"
        )
    return per_res.to(DTYPE)


@torch.inference_mode()
def _embed_full_ankh(model: T5EncoderModel, tok: T5Tokenizer, seq: str) -> torch.Tensor:
    """
    Full-sequence Ankh3-XL embedding → (1, L+2, d_model) with zeros at [0] and [L+1],
    residues in [1..L]. (We still use S2S prefix + EOS at encode time.)
    """
    L = len(seq)
    per_res = _embed_window_ankh(model, tok, seq)        # [L, d_model]
    d = per_res.size(-1)
    out = torch.zeros(1, L + 2, d, dtype=DTYPE, device="cpu")
    out[0, 1 : L + 1] = per_res.detach().cpu()
    return out


@torch.inference_mode()
def embed_ankh_stitched(model: T5EncoderModel, tok: T5Tokenizer, seq: str) -> torch.Tensor:
    """
    Return Ankh3-XL embeddings as (1, L+2, d_model), zeros at [0] and [L+1].
    - Short sequences (L <= 512): single pass (preserves your original interface).
    - Long sequences: sliding windows + context-trim stitching (no weighting).
    """
    L = len(seq)
    if L == 0:
        raise ValueError("Empty sequence.")

    if L <= WINDOW_EFF:
        return _embed_full_ankh(model, tok, seq)

    # Sliding-window path
    windows = _plan_windows(L)
    E = torch.empty(L, D_MODEL, dtype=DTYPE, device="cpu")  # residue buffer

    for (s, e) in windows:
        subseq = seq[s:e]
        Li = e - s
        if Li > WINDOW_EFF:
            raise RuntimeError(f"Internal window larger than WINDOW_EFF: Li={Li} > {WINDOW_EFF}")

        R = _embed_window_ankh(model, tok, subseq).detach().cpu()  # [Li, d_model]

        # Context-trim: first window keeps its left edge; last keeps its right edge.
        left_trim  = 0 if s == 0 else OVERLAP // 2             # 0 or 64
        right_trim = 0 if e == L else (OVERLAP - OVERLAP // 2) # 0 or 64

        gs = s + left_trim
        ge = e - right_trim
        ls = left_trim
        le = Li - right_trim

        if ge <= gs:
            raise RuntimeError(f"Empty keep range for window {(s, e)}")
        if (le - ls) != (ge - gs):
            raise RuntimeError("Keep lengths disagree during trim-stitch.")

        E[gs:ge] = R[ls:le]

    # Pack (1, L+2, d_model) with zeros at [0] and [L+1]
    out = torch.zeros(1, L + 2, D_MODEL, dtype=DTYPE, device="cpu")
    out[0, 1 : L + 1] = E
    return out


def main() -> None:
    if not BASE.exists():
        raise FileNotFoundError(f"CAFA_Style base not found: {BASE}")
    SEQS_DIR.mkdir(parents=True, exist_ok=True)

    # Load model/tokenizer once
    print(f"⇢ Loading {CKPT} encoder on {DEVICE} …")
    tok   = T5Tokenizer.from_pretrained(CKPT)
    model = T5EncoderModel.from_pretrained(CKPT).to(DEVICE).eval()

    pids = sorted(gather_pids_from_mf(BASE, SPLITS))
    if not pids:
        print("No PIDs found under <split>/mf — nothing to do.")
        return

    print(f"Found {len(pids)} unique PIDs under mf across {SPLITS}\n")

    made, skipped_exist, skipped_empty = 0, 0, 0
    for pid in tqdm(pids, desc="Embedding (Ankh3-XL, sliding-aware)"):
        out_path = SEQS_DIR / pid / OUT_FILENAME
        if out_path.exists():
            skipped_exist += 1
            continue

        seq = read_sequence(SEQS_DIR, pid)
        if not seq:
            tqdm.write(f"[WARN] {pid}: missing/empty seq.txt in sequences — skipping")
            skipped_empty += 1
            continue

        emb = embed_ankh_stitched(model, tok, seq)  # (1, L+2, d_model)
        out_path.parent.mkdir(parents=True, exist_ok=True)
        torch.save(emb, out_path)
        made += 1
        tqdm.write(f"✓ {pid}: L={len(seq):4d} → {OUT_FILENAME}")

    print(
        f"\nDone. created={made} | existing_skipped={skipped_exist} | missing_seq_skipped={skipped_empty}"
    )


if __name__ == "__main__":
    main()
# Out:
# ⇢ Loading ElnaggarLab/ankh3-xl encoder on cuda …
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/238k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json:   0%|          | 0.00/778 [00:00<?, ?B/s]
# pytorch_model.bin.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/7.99G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/7.98G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/6.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Found 32546 unique PIDs under mf across ['train', 'val', 'test']
# Embedding (Ankh3-XL, sliding-aware):   0%|          | 0/32546 [00:00<?, ?it/s]
# ✓ PGM3_YEAST: L= 622 → ankh_emb_xl.pt
# ✓ PGM48_ARATH: L= 344 → ankh_emb_xl.pt
# ✓ PGMB_ECOLI: L= 219 → ankh_emb_xl.pt
# ✓ PGMC1_ARATH: L= 583 → ankh_emb_xl.pt
# ✓ PGMP_ARATH: L= 623 → ankh_emb_xl.pt
# ✓ PGM_DROME: L= 560 → ankh_emb_xl.pt
# ✓ PGM_ECOLI: L= 546 → ankh_emb_xl.pt
# ✓ PGPA_ECOLI: L= 172 → ankh_emb_xl.pt
# ✓ PGPB_ECOLI: L= 254 → ankh_emb_xl.pt
# ✓ PGPC_ECOLI: L= 211 → ankh_emb_xl.pt
# ✓ PGPLB_DROME: L= 232 → ankh_emb_xl.pt
# ✓ PGPLC_DROME: L= 520 → ankh_emb_xl.pt
# ✓ PGPLF_DROME: L= 369 → ankh_emb_xl.pt
# ✓ PGPP1_ARATH: L= 348 → ankh_emb_xl.pt
# ✓ PGPS1_ARATH: L= 296 → ankh_emb_xl.pt
# ✓ PGPS1_SCHPO: L= 502 → ankh_emb_xl.pt
# ✓ PGPS1_YEAST: L= 521 → ankh_emb_xl.pt
# ✓ PGPS2_ARATH: L= 233 → ankh_emb_xl.pt
# ✓ PGPSA_DROME: L= 203 → ankh_emb_xl.pt
# ✓ PGPSD_DROME: L= 186 → ankh_emb_xl.pt
# ✓ PGP_HUMAN: L= 321 → ankh_emb_xl.pt
# ✓ PGP_MOUSE: L= 321 → ankh_emb_xl.pt
# ✓ PGP_RAT: L= 321 → ankh_emb_xl.pt
# ✓ PGR5_ARATH: L= 133 → ankh_emb_xl.pt
# ✓ PGRC1_HUMAN: L= 195 → ankh_emb_xl.pt
# ✓ PGRC1_MOUSE: L= 195 → ankh_emb_xl.pt
# ✓ PGRC2_HUMAN: L= 223 → ankh_emb_xl.pt
# ✓ PGRC2_MOUSE: L= 217 → ankh_emb_xl.pt
# ✓ PGRP1_HUMAN: L= 196 → ankh_emb_xl.pt
# ✓ PGRP2_HUMAN: L= 576 → ankh_emb_xl.pt
# ✓ PGRP3_HUMAN: L= 341 → ankh_emb_xl.pt
# ✓ PGRP4_HUMAN: L= 373 → ankh_emb_xl.pt
# ✓ PGRR_ECOLI: L= 299 → ankh_emb_xl.pt
# ✓ PGS1_MOUSE: L= 369 → ankh_emb_xl.pt
# ✓ PGS2_MOUSE: L= 354 → ankh_emb_xl.pt
# ✓ PGS2_RAT: L= 354 → ankh_emb_xl.pt
# ✓ PGSA_ECOLI: L= 182 → ankh_emb_xl.pt
# ✓ PGSB1_DROME: L= 190 → ankh_emb_xl.pt
# ✓ PGT1_SCHPO: L= 851 → ankh_emb_xl.pt
# ✓ PGTA1_ARATH: L= 678 → ankh_emb_xl.pt
# ✓ PGTA_MOUSE: L= 567 → ankh_emb_xl.pt
# ✓ PGTA_RAT: L= 567 → ankh_emb_xl.pt
# ✓ PGTA_YEAST: L= 327 → ankh_emb_xl.pt
# ✓ PGTB1_ARATH: L= 375 → ankh_emb_xl.pt
# ✓ PGTB1_HUMAN: L= 377 → ankh_emb_xl.pt
# ✓ PGTB1_RAT: L= 377 → ankh_emb_xl.pt
# ✓ PGTB1_SCHPO: L= 355 → ankh_emb_xl.pt
# ✓ PGTB1_YEAST: L= 376 → ankh_emb_xl.pt
# ✓ PGTB2_ARATH: L= 317 → ankh_emb_xl.pt
# ✓ PGTB2_RAT: L= 331 → ankh_emb_xl.pt
# ✓ PGTB2_YEAST: L= 325 → ankh_emb_xl.pt
# ✓ PH1_ARATH: L= 145 → ankh_emb_xl.pt
# ✓ PH2AB_DICDI: L= 483 → ankh_emb_xl.pt
# ✓ PH4H_DICDI: L= 441 → ankh_emb_xl.pt
# ✓ PH4H_DROME: L= 452 → ankh_emb_xl.pt
# ✓ PH4H_HUMAN: L= 452 → ankh_emb_xl.pt
# ✓ PH4H_MOUSE: L= 453 → ankh_emb_xl.pt
# ✓ PH4H_RAT: L= 453 → ankh_emb_xl.pt
# ✓ PHA2_YEAST: L= 334 → ankh_emb_xl.pt
# ✓ PHAF1_RAT: L= 422 → ankh_emb_xl.pt
# ✓ PHAG1_HUMAN: L= 432 → ankh_emb_xl.pt
# ✓ PHAG1_RAT: L= 424 → ankh_emb_xl.pt
# ✓ PHAR1_MOUSE: L= 580 → ankh_emb_xl.pt
# ✓ PHAR1_RAT: L= 580 → ankh_emb_xl.pt
# ✓ PHAR3_RAT: L= 517 → ankh_emb_xl.pt
# ✓ PHAR4_MOUSE: L= 694 → ankh_emb_xl.pt
# ✓ PHAX_RAT: L= 385 → ankh_emb_xl.pt
# ✓ PHB1_HUMAN: L= 272 → ankh_emb_xl.pt
# ✓ PHB1_MOUSE: L= 272 → ankh_emb_xl.pt
# ✓ PHB2_HUMAN: L= 299 → ankh_emb_xl.pt
# ✓ PHB2_MOUSE: L= 299 → ankh_emb_xl.pt
# ✓ PHB3_ARATH: L= 277 → ankh_emb_xl.pt
# ✓ PHB_HUMAN: L= 272 → ankh_emb_xl.pt
# ✓ PHB_MOUSE: L= 272 → ankh_emb_xl.pt
# ✓ PHC1_MOUSE: L=1012 → ankh_emb_xl.pt
# ✓ PHC2_HUMAN: L= 858 → ankh_emb_xl.pt
# ✓ PHCL2_DROME: L= 526 → ankh_emb_xl.pt
# ✓ PHD1_SCHPO: L= 434 → ankh_emb_xl.pt
# ✓ PHD1_YEAST: L= 366 → ankh_emb_xl.pt
# ✓ PHEX_HUMAN: L= 749 → ankh_emb_xl.pt
# ✓ PHF12_HUMAN: L=1004 → ankh_emb_xl.pt
# ✓ PHF12_MOUSE: L=1003 → ankh_emb_xl.pt
# ✓ PHF13_HUMAN: L= 300 → ankh_emb_xl.pt
# ✓ PHF14_DANRE: L= 914 → ankh_emb_xl.pt
# ✓ PHF14_HUMAN: L= 948 → ankh_emb_xl.pt
# ✓ PHF19_HUMAN: L= 580 → ankh_emb_xl.pt
# ✓ PHF19_MOUSE: L= 578 → ankh_emb_xl.pt
# ✓ PHF1_HUMAN: L= 567 → ankh_emb_xl.pt
# ✓ PHF1_MOUSE: L= 559 → ankh_emb_xl.pt
# ✓ PHF2_HUMAN: L=1096 → ankh_emb_xl.pt
# ✓ PHF5A_HUMAN: L= 110 → ankh_emb_xl.pt
# ✓ PHF5A_RAT: L= 110 → ankh_emb_xl.pt
# ✓ PHF6_HUMAN: L= 365 → ankh_emb_xl.pt
# ✓ PHF8_HUMAN: L=1060 → ankh_emb_xl.pt
# ✓ PHG1A_DICDI: L= 641 → ankh_emb_xl.pt
# ✓ PHG1B_DICDI: L= 587 → ankh_emb_xl.pt
# ✓ PHG1C_DICDI: L= 655 → ankh_emb_xl.pt
# ✓ PHG2_DICDI: L=1387 → ankh_emb_xl.pt
# ✓ PHIP1_ARATH: L= 597 → ankh_emb_xl.pt
# ✓ PHIP_HUMAN: L=1821 → ankh_emb_xl.pt
# ✓ PHKG1_MOUSE: L= 388 → ankh_emb_xl.pt
# ✓ PHKG1_RAT: L= 388 → ankh_emb_xl.pt
# ✓ PHKG2_HUMAN: L= 406 → ankh_emb_xl.pt
# ✓ PHKG2_MOUSE: L= 406 → ankh_emb_xl.pt
# ✓ PHKG2_RAT: L= 406 → ankh_emb_xl.pt
# ✓ PHL2_ARATH: L= 295 → ankh_emb_xl.pt
# ✓ PHL3_ARATH: L= 292 → ankh_emb_xl.pt
# ✓ PHLA3_HUMAN: L= 127 → ankh_emb_xl.pt
# ✓ PHLB3_HUMAN: L= 640 → ankh_emb_xl.pt
# ✓ PHLD_HUMAN: L= 840 → ankh_emb_xl.pt
# ✓ PHLD_MOUSE: L= 837 → ankh_emb_xl.pt
# ✓ PHLD_RAT: L= 843 → ankh_emb_xl.pt
# ✓ PHLP1_RAT: L=1696 → ankh_emb_xl.pt
# ✓ PHLPP_DROME: L= 954 → ankh_emb_xl.pt
# ✓ PHLP_RAT: L= 301 → ankh_emb_xl.pt
# ✓ PHM8_YEAST: L= 321 → ankh_emb_xl.pt
# ✓ PHNH_ECOLI: L= 194 → ankh_emb_xl.pt
# ✓ PHNI_ECOLI: L= 354 → ankh_emb_xl.pt
# ✓ PHNJ_ECOLI: L= 281 → ankh_emb_xl.pt
# ✓ PHNN_ECOLI: L= 185 → ankh_emb_xl.pt
# ✓ PHNO_ECOLI: L= 144 → ankh_emb_xl.pt
# ✓ PHNP_ECOLI: L= 252 → ankh_emb_xl.pt
# ✓ PHO1_ARATH: L= 782 → ankh_emb_xl.pt
# ✓ PHO23_YEAST: L= 330 → ankh_emb_xl.pt
# ✓ PHO2_YEAST: L= 559 → ankh_emb_xl.pt
# ✓ PHO4_YEAST: L= 312 → ankh_emb_xl.pt
# ✓ PHO80_YEAST: L= 293 → ankh_emb_xl.pt
# ✓ PHO81_YEAST: L=1178 → ankh_emb_xl.pt
# ✓ PHO84_YEAST: L= 587 → ankh_emb_xl.pt
# ✓ PHO85_YEAST: L= 305 → ankh_emb_xl.pt
# ✓ PHO86_YEAST: L= 311 → ankh_emb_xl.pt
# ✓ PHO87_YEAST: L= 923 → ankh_emb_xl.pt
# ✓ PHO89_YEAST: L= 574 → ankh_emb_xl.pt
# ✓ PHO90_YEAST: L= 881 → ankh_emb_xl.pt
# ✓ PHO91_YEAST: L= 894 → ankh_emb_xl.pt
# ✓ PHOB_ECOLI: L= 229 → ankh_emb_xl.pt
# ✓ PHOCN_RAT: L= 225 → ankh_emb_xl.pt
# ✓ PHOH_ECOLI: L= 354 → ankh_emb_xl.pt
# ✓ PHOP1_HUMAN: L= 267 → ankh_emb_xl.pt
# ✓ PHOP_ECOLI: L= 223 → ankh_emb_xl.pt
# ✓ PHOP_SALTY: L= 224 → ankh_emb_xl.pt
# ✓ PHOQ_ECOLI: L= 486 → ankh_emb_xl.pt
# ✓ PHOR_ECOLI: L= 431 → ankh_emb_xl.pt
# ✓ PHOS_HUMAN: L= 246 → ankh_emb_xl.pt
# ✓ PHOT1_ARATH: L= 996 → ankh_emb_xl.pt
# ✓ PHOT2_ARATH: L= 915 → ankh_emb_xl.pt
# ✓ PHOU_ECOLI: L= 241 → ankh_emb_xl.pt
# ✓ PHOX1_ARATH: L= 745 → ankh_emb_xl.pt
# ✓ PHO_DROME: L= 520 → ankh_emb_xl.pt
# ✓ PHP14_HUMAN: L= 125 → ankh_emb_xl.pt
# ✓ PHP4_SCHPO: L= 295 → ankh_emb_xl.pt
# ✓ PHP_DROME: L=1589 → ankh_emb_xl.pt
# ✓ PHP_ECOLI: L= 292 → ankh_emb_xl.pt
# ✓ PHR1_CANAL: L= 548 → ankh_emb_xl.pt
# ✓ PHR2_CANAL: L= 544 → ankh_emb_xl.pt
# ✓ PHRF1_RAT: L=1685 → ankh_emb_xl.pt
# ✓ PHR_ARATH: L= 496 → ankh_emb_xl.pt
# ✓ PHR_ECOLI: L= 472 → ankh_emb_xl.pt
# ✓ PHR_YEAST: L= 565 → ankh_emb_xl.pt
# ✓ PHS1_ARATH: L= 962 → ankh_emb_xl.pt
# ✓ PHS1_DICDI: L= 853 → ankh_emb_xl.pt
# ✓ PHS2_ARATH: L= 841 → ankh_emb_xl.pt
# ✓ PHS2_DICDI: L= 993 → ankh_emb_xl.pt
# ✓ PHS2_MOUSE: L= 136 → ankh_emb_xl.pt
# ✓ PHSA_ARATH: L= 482 → ankh_emb_xl.pt
# ✓ PHSB_ARATH: L= 495 → ankh_emb_xl.pt
# ✓ PHSC_ARATH: L= 478 → ankh_emb_xl.pt
# ✓ PHSD_ARATH: L= 479 → ankh_emb_xl.pt
# ✓ PHSG_ECOLI: L= 815 → ankh_emb_xl.pt
# ✓ PHSG_YEAST: L= 902 → ankh_emb_xl.pt
# ✓ PHSM_ECOLI: L= 797 → ankh_emb_xl.pt
# ✓ PHS_HUMAN: L= 104 → ankh_emb_xl.pt
# ✓ PHS_MOUSE: L= 104 → ankh_emb_xl.pt
# ✓ PHS_RAT: L= 104 → ankh_emb_xl.pt
# ✓ PHT11_ARATH: L= 524 → ankh_emb_xl.pt
# ✓ PHT17_ARATH: L= 535 → ankh_emb_xl.pt
# ✓ PHT19_ARATH: L= 532 → ankh_emb_xl.pt
# ✓ PHT21_ARATH: L= 587 → ankh_emb_xl.pt
# ✓ PHX1_SCHPO: L= 942 → ankh_emb_xl.pt
# ✓ PHX2A_HUMAN: L= 284 → ankh_emb_xl.pt
# ✓ PHX2A_RAT: L= 281 → ankh_emb_xl.pt
# ✓ PHX2B_HUMAN: L= 314 → ankh_emb_xl.pt
# ✓ PHYA_ARATH: L=1122 → ankh_emb_xl.pt
# ✓ PHYB_ARATH: L=1172 → ankh_emb_xl.pt
# ✓ PHYD1_HUMAN: L= 291 → ankh_emb_xl.pt
# ✓ PHYDA_ECOLI: L= 461 → ankh_emb_xl.pt
# ✓ PHYD_ARATH: L=1164 → ankh_emb_xl.pt
# ✓ PHYIP_HUMAN: L= 330 → ankh_emb_xl.pt
# ✓ PHYK1_ARATH: L= 304 → ankh_emb_xl.pt
# ✓ PHYL_DROME: L= 400 → ankh_emb_xl.pt
# ✓ PI2R_HUMAN: L= 386 → ankh_emb_xl.pt
# ✓ PI3K1_DICDI: L=1571 → ankh_emb_xl.pt
# ✓ PI3K2_DICDI: L=1857 → ankh_emb_xl.pt
# ✓ PI3K3_DICDI: L=1697 → ankh_emb_xl.pt
# ✓ PI3R6_MOUSE: L= 756 → ankh_emb_xl.pt
# ✓ PI42B_HUMAN: L= 416 → ankh_emb_xl.pt
# ✓ PI42C_HUMAN: L= 421 → ankh_emb_xl.pt
# ✓ PI42C_RAT: L= 420 → ankh_emb_xl.pt
# ✓ PI4KA_HUMAN: L=2102 → ankh_emb_xl.pt
# ✓ PI4KA_MOUSE: L=2105 → ankh_emb_xl.pt
# ✓ PI4KA_RAT: L=2096 → ankh_emb_xl.pt
# ✓ PI4KB_HUMAN: L= 816 → ankh_emb_xl.pt
# ✓ PI4KB_RAT: L= 816 → ankh_emb_xl.pt
# ✓ PI51A_HUMAN: L= 562 → ankh_emb_xl.pt
# ✓ PI51A_MOUSE: L= 546 → ankh_emb_xl.pt
# ✓ PI51B_MOUSE: L= 539 → ankh_emb_xl.pt
# ✓ PI51C_HUMAN: L= 668 → ankh_emb_xl.pt
# ✓ PI51C_MOUSE: L= 661 → ankh_emb_xl.pt
# ✓ PI5K1_ARATH: L= 752 → ankh_emb_xl.pt
# ✓ PI5K2_ARATH: L= 754 → ankh_emb_xl.pt
# ✓ PI5K3_ARATH: L= 705 → ankh_emb_xl.pt
# ✓ PI5K4_ARATH: L= 779 → ankh_emb_xl.pt
# ✓ PI5K5_ARATH: L= 772 → ankh_emb_xl.pt
# ✓ PI5K6_ARATH: L= 715 → ankh_emb_xl.pt
# ✓ PI5KB_ARATH: L= 401 → ankh_emb_xl.pt
# ✓ PI5L1_MOUSE: L= 395 → ankh_emb_xl.pt
# ✓ PI5PA_MOUSE: L=1003 → ankh_emb_xl.pt
# ✓ PI5PA_RAT: L=1001 → ankh_emb_xl.pt
# ✓ PIA2_ARATH: L= 174 → ankh_emb_xl.pt
# ✓ PIAA_DICDI: L=1148 → ankh_emb_xl.pt
# ✓ PIAL1_ARATH: L= 847 → ankh_emb_xl.pt
# ✓ PIAL2_ARATH: L= 760 → ankh_emb_xl.pt
# ✓ PIAS1_HUMAN: L= 651 → ankh_emb_xl.pt
# ✓ PIAS1_MOUSE: L= 651 → ankh_emb_xl.pt
# ✓ PIAS2_HUMAN: L= 621 → ankh_emb_xl.pt
# ✓ PIAS2_MOUSE: L= 621 → ankh_emb_xl.pt
# ✓ PIAS2_RAT: L= 572 → ankh_emb_xl.pt
# ✓ PIAS3_HUMAN: L= 628 → ankh_emb_xl.pt
# ✓ PIAS3_MOUSE: L= 628 → ankh_emb_xl.pt
# ✓ PIAS3_RAT: L= 628 → ankh_emb_xl.pt
# ✓ PIAS4_HUMAN: L= 510 → ankh_emb_xl.pt
# ✓ PIAS4_MOUSE: L= 507 → ankh_emb_xl.pt
# ✓ PIB1_YEAST: L= 286 → ankh_emb_xl.pt
# ✓ PIBF1_HUMAN: L= 757 → ankh_emb_xl.pt
# ✓ PIC2_YEAST: L= 300 → ankh_emb_xl.pt
# ✓ PICAL_HUMAN: L= 652 → ankh_emb_xl.pt
# ✓ PICAL_RAT: L= 640 → ankh_emb_xl.pt
# ✓ PICK1_HUMAN: L= 415 → ankh_emb_xl.pt
# ✓ PICK1_MOUSE: L= 416 → ankh_emb_xl.pt
# ✓ PICK1_RAT: L= 416 → ankh_emb_xl.pt
# ✓ PIDD1_HUMAN: L= 910 → ankh_emb_xl.pt
# ✓ PID_ARATH: L= 438 → ankh_emb_xl.pt
# ✓ PIEZ1_MOUSE: L=2547 → ankh_emb_xl.pt
# ✓ PIEZO_DROME: L=2551 → ankh_emb_xl.pt
# ✓ PIF1_ARATH: L= 478 → ankh_emb_xl.pt
# ✓ PIF1_CANAL: L= 906 → ankh_emb_xl.pt
# ✓ PIF1_HUMAN: L= 641 → ankh_emb_xl.pt
# ✓ PIF1_SCHPO: L= 805 → ankh_emb_xl.pt
# ✓ PIF1_YEAST: L= 859 → ankh_emb_xl.pt
# ✓ PIF3_ARATH: L= 524 → ankh_emb_xl.pt
# ✓ PIF4_ARATH: L= 430 → ankh_emb_xl.pt
# ✓ PIF7_ARATH: L= 366 → ankh_emb_xl.pt
# ✓ PIFO_HUMAN: L= 191 → ankh_emb_xl.pt
# ✓ PIFO_MOUSE: L= 207 → ankh_emb_xl.pt
# ✓ PIG1_YEAST: L= 648 → ankh_emb_xl.pt
# ✓ PIGA_HUMAN: L= 484 → ankh_emb_xl.pt
# ✓ PIGB_HUMAN: L= 554 → ankh_emb_xl.pt
# ✓ PIGC_HUMAN: L= 297 → ankh_emb_xl.pt
# ✓ PIGF_HUMAN: L= 219 → ankh_emb_xl.pt
# ✓ PIGF_MOUSE: L= 219 → ankh_emb_xl.pt
# ✓ PIGG_HUMAN: L= 983 → ankh_emb_xl.pt
# ✓ PIGH_HUMAN: L= 188 → ankh_emb_xl.pt
# ✓ PIGM_RAT: L= 423 → ankh_emb_xl.pt
# ✓ PIGN_MOUSE: L= 931 → ankh_emb_xl.pt
# ✓ PIGO_HUMAN: L=1089 → ankh_emb_xl.pt
# ✓ PIGO_MOUSE: L=1093 → ankh_emb_xl.pt
# ✓ PIGR_HUMAN: L= 764 → ankh_emb_xl.pt
# ✓ PIGR_RAT: L= 769 → ankh_emb_xl.pt
# ✓ PIGV_HUMAN: L= 493 → ankh_emb_xl.pt
# ✓ PIGW_HUMAN: L= 504 → ankh_emb_xl.pt
# ✓ PIGZ_HUMAN: L= 579 → ankh_emb_xl.pt
# ✓ PIHD1_HUMAN: L= 290 → ankh_emb_xl.pt
# ✓ PIHD2_HUMAN: L= 315 → ankh_emb_xl.pt
# ✓ PIK1_YEAST: L=1066 → ankh_emb_xl.pt
# ✓ PIL1_YEAST: L= 339 → ankh_emb_xl.pt
# ✓ PILR1_ARATH: L= 317 → ankh_emb_xl.pt
# ✓ PILR2_ARATH: L= 317 → ankh_emb_xl.pt
# ✓ PILRB_MOUSE: L= 224 → ankh_emb_xl.pt
# ✓ PILS2_ARATH: L= 457 → ankh_emb_xl.pt
# ✓ PILS5_ARATH: L= 396 → ankh_emb_xl.pt
# ✓ PIM1_HUMAN: L= 313 → ankh_emb_xl.pt
# ✓ PIM1_MOUSE: L= 313 → ankh_emb_xl.pt
# ✓ PIM2_HUMAN: L= 311 → ankh_emb_xl.pt
# ✓ PIM2_MOUSE: L= 370 → ankh_emb_xl.pt
# ✓ PIM3_HUMAN: L= 326 → ankh_emb_xl.pt
# ✓ PIM3_RAT: L= 326 → ankh_emb_xl.pt
# ✓ PIMT1_ARATH: L= 230 → ankh_emb_xl.pt
# ✓ PIMT2_ARATH: L= 309 → ankh_emb_xl.pt
# ✓ PIMT_DROME: L= 226 → ankh_emb_xl.pt
# ✓ PIMT_ECOLI: L= 208 → ankh_emb_xl.pt
# ✓ PIMT_MOUSE: L= 227 → ankh_emb_xl.pt
# ✓ PIMT_RAT: L= 227 → ankh_emb_xl.pt
# ✓ PIN1_ARATH: L= 119 → ankh_emb_xl.pt
# ✓ PIN1_HUMAN: L= 163 → ankh_emb_xl.pt
# ✓ PIN1_MOUSE: L= 165 → ankh_emb_xl.pt
# ✓ PIN2_ARATH: L= 647 → ankh_emb_xl.pt
# ✓ PIN4_HUMAN: L= 131 → ankh_emb_xl.pt
# ✓ PIN5_ARATH: L= 351 → ankh_emb_xl.pt
# ✓ PIN7_ARATH: L= 619 → ankh_emb_xl.pt
# ✓ PINE_ECOLI: L= 184 → ankh_emb_xl.pt
# ✓ PINI_ARATH: L= 622 → ankh_emb_xl.pt
# ✓ PINK1_DROME: L= 721 → ankh_emb_xl.pt
# ✓ PINK1_HUMAN: L= 581 → ankh_emb_xl.pt
# ✓ PINK1_MOUSE: L= 580 → ankh_emb_xl.pt
# ✓ PINK1_RAT: L= 580 → ankh_emb_xl.pt
# ✓ PINTA_DROME: L= 273 → ankh_emb_xl.pt
# ✓ PINX1_HUMAN: L= 328 → ankh_emb_xl.pt
# ✓ PIP11_ARATH: L= 286 → ankh_emb_xl.pt
# ✓ PIP13_ARATH: L= 286 → ankh_emb_xl.pt
# ✓ PIP21_ARATH: L= 287 → ankh_emb_xl.pt
# ✓ PIP22_ARATH: L= 285 → ankh_emb_xl.pt
# ✓ PIP23_ARATH: L= 285 → ankh_emb_xl.pt
# ✓ PIP27_ARATH: L= 280 → ankh_emb_xl.pt
# ✓ PIP2_YEAST: L= 996 → ankh_emb_xl.pt
# ✓ PIPA_DROME: L=1095 → ankh_emb_xl.pt
# ✓ PIPE_DROME: L= 514 → ankh_emb_xl.pt
# ✓ PIPNA_HUMAN: L= 270 → ankh_emb_xl.pt
# ✓ PIPNA_RAT: L= 271 → ankh_emb_xl.pt
# ✓ PIPNB_HUMAN: L= 271 → ankh_emb_xl.pt
# ✓ PIPNB_RAT: L= 271 → ankh_emb_xl.pt
# ✓ PIP_HUMAN: L= 146 → ankh_emb_xl.pt
# ✓ PIR1_CANAL: L= 385 → ankh_emb_xl.pt
# ✓ PIR1_YEAST: L= 341 → ankh_emb_xl.pt
# ✓ PIR3_YEAST: L= 325 → ankh_emb_xl.pt
# ✓ PIRL3_ARATH: L= 464 → ankh_emb_xl.pt
# ✓ PIRT_MOUSE: L= 135 → ankh_emb_xl.pt
# ✓ PIR_HUMAN: L= 290 → ankh_emb_xl.pt
# ✓ PIR_MOUSE: L= 290 → ankh_emb_xl.pt
# ✓ PIS1_ARATH: L= 227 → ankh_emb_xl.pt
# ✓ PIST_ARATH: L= 208 → ankh_emb_xl.pt
# ✓ PIS_CANAL: L= 230 → ankh_emb_xl.pt
# ✓ PIS_SCHPO: L= 237 → ankh_emb_xl.pt
# ✓ PIS_YEAST: L= 220 → ankh_emb_xl.pt
# ✓ PIT1_HUMAN: L= 291 → ankh_emb_xl.pt
# ✓ PIT1_MOUSE: L= 291 → ankh_emb_xl.pt
# ✓ PIT1_RAT: L= 291 → ankh_emb_xl.pt
# ✓ PITA_ECOLI: L= 499 → ankh_emb_xl.pt
# ✓ PITB_ECOLI: L= 499 → ankh_emb_xl.pt
# ✓ PITC1_HUMAN: L= 332 → ankh_emb_xl.pt
# ✓ PITC1_MOUSE: L= 332 → ankh_emb_xl.pt
# ✓ PITC_DICDI: L= 364 → ankh_emb_xl.pt
# ✓ PITM1_HUMAN: L=1244 → ankh_emb_xl.pt
# ✓ PITM2_HUMAN: L=1349 → ankh_emb_xl.pt
# ✓ PITM3_HUMAN: L= 974 → ankh_emb_xl.pt
# ✓ PITP1_DICDI: L= 264 → ankh_emb_xl.pt
# ✓ PITP2_DICDI: L= 259 → ankh_emb_xl.pt
# ✓ PITX1_HUMAN: L= 314 → ankh_emb_xl.pt
# ✓ PITX1_MOUSE: L= 315 → ankh_emb_xl.pt
# ✓ PITX1_RAT: L= 315 → ankh_emb_xl.pt
# ✓ PITX2_HUMAN: L= 317 → ankh_emb_xl.pt
# ✓ PITX2_MOUSE: L= 317 → ankh_emb_xl.pt
# ✓ PITX2_RAT: L= 324 → ankh_emb_xl.pt
# ✓ PITX3_MOUSE: L= 302 → ankh_emb_xl.pt
# ✓ PITX3_RAT: L= 302 → ankh_emb_xl.pt
# ✓ PIWI_DROME: L= 843 → ankh_emb_xl.pt
# ✓ PIWL1_DANRE: L= 858 → ankh_emb_xl.pt
# ✓ PIWL1_HUMAN: L= 861 → ankh_emb_xl.pt
# ✓ PIWL1_MOUSE: L= 862 → ankh_emb_xl.pt
# ✓ PIWL2_DANRE: L=1046 → ankh_emb_xl.pt
# ✓ PIWL2_HUMAN: L= 973 → ankh_emb_xl.pt
# ✓ PIWL2_MOUSE: L= 971 → ankh_emb_xl.pt
# ✓ PIWL4_HUMAN: L= 852 → ankh_emb_xl.pt
# ✓ PIWL4_MOUSE: L= 848 → ankh_emb_xl.pt
# ✓ PJA1_MOUSE: L= 578 → ankh_emb_xl.pt
# ✓ PJA2_HUMAN: L= 708 → ankh_emb_xl.pt
# ✓ PK1R_DROME: L= 430 → ankh_emb_xl.pt
# ✓ PK2L1_HUMAN: L= 805 → ankh_emb_xl.pt
# ✓ PK2L1_MOUSE: L= 760 → ankh_emb_xl.pt
# ✓ PK2_DICDI: L= 479 → ankh_emb_xl.pt
# ✓ PK3C3_HUMAN: L= 887 → ankh_emb_xl.pt
# ✓ PK3C3_MOUSE: L= 887 → ankh_emb_xl.pt
# ✓ PK3C3_RAT: L= 887 → ankh_emb_xl.pt
# ✓ PK3CA_HUMAN: L=1068 → ankh_emb_xl.pt
# ✓ PK3CA_MOUSE: L=1068 → ankh_emb_xl.pt
# ✓ PK3CA_RAT: L=1068 → ankh_emb_xl.pt
# ✓ PK3CB_HUMAN: L=1070 → ankh_emb_xl.pt
# ✓ PK3CB_MOUSE: L=1064 → ankh_emb_xl.pt
# ✓ PK3CB_RAT: L=1070 → ankh_emb_xl.pt
# ✓ PK3CD_HUMAN: L=1044 → ankh_emb_xl.pt
# ✓ PK3CG_HUMAN: L=1102 → ankh_emb_xl.pt
# ✓ PKCB1_HUMAN: L=1186 → ankh_emb_xl.pt
# ✓ PKD2_HUMAN: L= 968 → ankh_emb_xl.pt
# ✓ PKD2_MOUSE: L= 966 → ankh_emb_xl.pt
# ✓ PKD2_SCHPO: L= 710 → ankh_emb_xl.pt
# ✓ PKDCC_HUMAN: L= 493 → ankh_emb_xl.pt
# ✓ PKDCC_MOUSE: L= 492 → ankh_emb_xl.pt
# ✓ PKH1_YEAST: L= 766 → ankh_emb_xl.pt
# ✓ PKH2_CANAL: L= 947 → ankh_emb_xl.pt
# ✓ PKH2_YEAST: L=1081 → ankh_emb_xl.pt
# ✓ PKH4B_HUMAN: L=1271 → ankh_emb_xl.pt
# ✓ PKHA1_HUMAN: L= 404 → ankh_emb_xl.pt
# ✓ PKHA2_HUMAN: L= 425 → ankh_emb_xl.pt
# ✓ PKHA2_MOUSE: L= 425 → ankh_emb_xl.pt
# ✓ PKHA3_HUMAN: L= 300 → ankh_emb_xl.pt
# ✓ PKHA4_HUMAN: L= 779 → ankh_emb_xl.pt
# ✓ PKHA7_HUMAN: L=1121 → ankh_emb_xl.pt
# ✓ PKHA8_HUMAN: L= 519 → ankh_emb_xl.pt
# ✓ PKHB1_MOUSE: L= 243 → ankh_emb_xl.pt
# ✓ PKHB2_HUMAN: L= 222 → ankh_emb_xl.pt
# ✓ PKHF1_DROME: L= 316 → ankh_emb_xl.pt
# ✓ PKHF1_HUMAN: L= 279 → ankh_emb_xl.pt
# ✓ PKHG3_HUMAN: L=1219 → ankh_emb_xl.pt
# ✓ PKHG4_HUMAN: L=1191 → ankh_emb_xl.pt
# ✓ PKHG5_MOUSE: L=1073 → ankh_emb_xl.pt
# ✓ PKHH2_MOUSE: L=1491 → ankh_emb_xl.pt
# ✓ PKHM2_HUMAN: L=1019 → ankh_emb_xl.pt
# ✓ PKHN1_HUMAN: L= 611 → ankh_emb_xl.pt
# ✓ PKN1_HUMAN: L= 942 → ankh_emb_xl.pt
# ✓ PKN1_MOUSE: L= 946 → ankh_emb_xl.pt
# ✓ PKN1_RAT: L= 946 → ankh_emb_xl.pt
# ✓ PKN2_HUMAN: L= 984 → ankh_emb_xl.pt
# ✓ PKN2_RAT: L= 985 → ankh_emb_xl.pt
# ✓ PKN3_HUMAN: L= 889 → ankh_emb_xl.pt
# ✓ PKNX1_HUMAN: L= 436 → ankh_emb_xl.pt
# ✓ PKNX1_MOUSE: L= 436 → ankh_emb_xl.pt
# ✓ PKNX2_MOUSE: L= 474 → ankh_emb_xl.pt
# ✓ PKN_DROME: L=1190 → ankh_emb_xl.pt
# ✓ PKP1_ARATH: L= 596 → ankh_emb_xl.pt
# ✓ PKP1_HUMAN: L= 747 → ankh_emb_xl.pt
# ✓ PKP2_ARATH: L= 579 → ankh_emb_xl.pt
# ✓ PKP2_HUMAN: L= 881 → ankh_emb_xl.pt
# ✓ PKP3_ARATH: L= 571 → ankh_emb_xl.pt
# ✓ PKP3_HUMAN: L= 797 → ankh_emb_xl.pt
# ✓ PKR1_RAT: L= 393 → ankh_emb_xl.pt
# ✓ PKR2_RAT: L= 383 → ankh_emb_xl.pt
# ✓ PKRA_DROME: L= 422 → ankh_emb_xl.pt
# ✓ PKRI1_MOUSE: L= 186 → ankh_emb_xl.pt
# ✓ PKSA_ARATH: L= 395 → ankh_emb_xl.pt
# ✓ PKSB_ARATH: L= 392 → ankh_emb_xl.pt
# ✓ PLA12_ARATH: L= 471 → ankh_emb_xl.pt
# ✓ PLA13_ARATH: L= 484 → ankh_emb_xl.pt
# ✓ PLA14_ARATH: L= 517 → ankh_emb_xl.pt
# ✓ PLA15_ARATH: L= 515 → ankh_emb_xl.pt
# ✓ PLA16_ARATH: L= 529 → ankh_emb_xl.pt
# ✓ PLA17_ARATH: L= 527 → ankh_emb_xl.pt
# ✓ PLA1A_HUMAN: L= 456 → ankh_emb_xl.pt
# ✓ PLA1A_MOUSE: L= 456 → ankh_emb_xl.pt
# ✓ PLA20_ARATH: L= 412 → ankh_emb_xl.pt
# ✓ PLA2A_ARATH: L= 148 → ankh_emb_xl.pt
# ✓ PLA2B_ARATH: L= 147 → ankh_emb_xl.pt
# ✓ PLA2C_ARATH: L= 187 → ankh_emb_xl.pt
# ✓ PLA2R_HUMAN: L=1463 → ankh_emb_xl.pt
# ✓ PLA2R_MOUSE: L=1487 → ankh_emb_xl.pt
# ✓ PLAC8_MOUSE: L= 112 → ankh_emb_xl.pt
# ✓ PLAG1_HUMAN: L= 500 → ankh_emb_xl.pt
# ✓ PLAK_HUMAN: L= 745 → ankh_emb_xl.pt
# ✓ PLAK_MOUSE: L= 745 → ankh_emb_xl.pt
# ✓ PLAK_RAT: L= 745 → ankh_emb_xl.pt
# ✓ PLAL1_HUMAN: L= 463 → ankh_emb_xl.pt
# ✓ PLAL2_HUMAN: L= 496 → ankh_emb_xl.pt
# ✓ PLAP_ECOLI: L= 452 → ankh_emb_xl.pt
# ✓ PLAP_HUMAN: L= 795 → ankh_emb_xl.pt
# ✓ PLAP_MOUSE: L= 794 → ankh_emb_xl.pt
# ✓ PLAS2_ARATH: L= 167 → ankh_emb_xl.pt
# ✓ PLAT1_HUMAN: L= 168 → ankh_emb_xl.pt
# ✓ PLAT1_MOUSE: L= 167 → ankh_emb_xl.pt
# ✓ PLAT1_RAT: L= 167 → ankh_emb_xl.pt
# ✓ PLAT2_HUMAN: L= 162 → ankh_emb_xl.pt
# ✓ PLAT3_HUMAN: L= 162 → ankh_emb_xl.pt
# ✓ PLAT3_MOUSE: L= 162 → ankh_emb_xl.pt
# ✓ PLAT3_RAT: L= 160 → ankh_emb_xl.pt
# ✓ PLAT4_HUMAN: L= 164 → ankh_emb_xl.pt
# ✓ PLAT5_HUMAN: L= 279 → ankh_emb_xl.pt
# ✓ PLAT5_MOUSE: L= 270 → ankh_emb_xl.pt
# ✓ PLAT5_RAT: L= 287 → ankh_emb_xl.pt
# ✓ PLB1_CANAL: L= 605 → ankh_emb_xl.pt
# ✓ PLB1_RAT: L=1450 → ankh_emb_xl.pt
# ✓ PLB1_YEAST: L= 664 → ankh_emb_xl.pt
# ✓ PLB2_YEAST: L= 706 → ankh_emb_xl.pt
# ✓ PLB3_YEAST: L= 686 → ankh_emb_xl.pt
# ✓ PLBLA_DICDI: L= 574 → ankh_emb_xl.pt
# ✓ PLC1_YEAST: L= 869 → ankh_emb_xl.pt
# ✓ PLCA_HUMAN: L= 283 → ankh_emb_xl.pt
# ✓ PLCA_MOUSE: L= 285 → ankh_emb_xl.pt
# ✓ PLCB1_HUMAN: L=1216 → ankh_emb_xl.pt
# ✓ PLCB1_MOUSE: L=1216 → ankh_emb_xl.pt
# ✓ PLCB1_RAT: L=1216 → ankh_emb_xl.pt
# ✓ PLCB2_HUMAN: L=1185 → ankh_emb_xl.pt
# ✓ PLCB2_RAT: L=1183 → ankh_emb_xl.pt
# ✓ PLCB3_HUMAN: L=1234 → ankh_emb_xl.pt
# ✓ PLCB3_RAT: L=1234 → ankh_emb_xl.pt
# ✓ PLCB4_HUMAN: L=1175 → ankh_emb_xl.pt
# ✓ PLCB4_RAT: L=1175 → ankh_emb_xl.pt
# ✓ PLCB_HUMAN: L= 278 → ankh_emb_xl.pt
# ✓ PLCB_MOUSE: L= 278 → ankh_emb_xl.pt
# ✓ PLCC_HUMAN: L= 376 → ankh_emb_xl.pt
# ✓ PLCC_MOUSE: L= 376 → ankh_emb_xl.pt
# ✓ PLCD1_ARATH: L= 561 → ankh_emb_xl.pt
# ✓ PLCD1_HUMAN: L= 756 → ankh_emb_xl.pt
# ✓ PLCD1_MOUSE: L= 756 → ankh_emb_xl.pt
# ✓ PLCD1_RAT: L= 756 → ankh_emb_xl.pt
# ✓ PLCD2_ARATH: L= 581 → ankh_emb_xl.pt
# ✓ PLCD4_HUMAN: L= 762 → ankh_emb_xl.pt
# ✓ PLCD4_MOUSE: L= 807 → ankh_emb_xl.pt
# ✓ PLCD4_RAT: L= 772 → ankh_emb_xl.pt
# ✓ PLCD9_ARATH: L= 531 → ankh_emb_xl.pt
# ✓ PLCD_MOUSE: L= 378 → ankh_emb_xl.pt
# ✓ PLCE1_HUMAN: L=2302 → ankh_emb_xl.pt
# ✓ PLCE1_RAT: L=2281 → ankh_emb_xl.pt
# ✓ PLCE_HUMAN: L= 364 → ankh_emb_xl.pt
# ✓ PLCE_MOUSE: L= 365 → ankh_emb_xl.pt
# ✓ PLCG1_HUMAN: L=1290 → ankh_emb_xl.pt
# ✓ PLCG1_MOUSE: L=1302 → ankh_emb_xl.pt
# ✓ PLCG1_RAT: L=1290 → ankh_emb_xl.pt
# ✓ PLCG2_HUMAN: L=1265 → ankh_emb_xl.pt
# ✓ PLCG2_MOUSE: L=1265 → ankh_emb_xl.pt
# ✓ PLCG2_RAT: L=1265 → ankh_emb_xl.pt
# ✓ PLCH1_HUMAN: L=1693 → ankh_emb_xl.pt
# ✓ PLCH2_MOUSE: L=1501 → ankh_emb_xl.pt
# ✓ PLCL1_HUMAN: L=1095 → ankh_emb_xl.pt
# ✓ PLCL1_RAT: L=1096 → ankh_emb_xl.pt
# ✓ PLCL2_HUMAN: L=1127 → ankh_emb_xl.pt
# ✓ PLCZ1_HUMAN: L= 608 → ankh_emb_xl.pt
# ✓ PLCZ1_MOUSE: L= 647 → ankh_emb_xl.pt
# ✓ PLC_DICDI: L= 801 → ankh_emb_xl.pt
# ✓ PLD1_RAT: L=1074 → ankh_emb_xl.pt
# ✓ PLD1_SCHPO: L=1369 → ankh_emb_xl.pt
# ✓ PLD2_MOUSE: L= 933 → ankh_emb_xl.pt
# ✓ PLD2_RAT: L= 933 → ankh_emb_xl.pt
# ✓ PLD3A_HUMAN: L= 172 → ankh_emb_xl.pt
# ✓ PLD3_HUMAN: L= 490 → ankh_emb_xl.pt
# ✓ PLD3_MOUSE: L= 488 → ankh_emb_xl.pt
# ✓ PLD4_MOUSE: L= 503 → ankh_emb_xl.pt
# ✓ PLD6_HUMAN: L= 252 → ankh_emb_xl.pt
# ✓ PLD6_MOUSE: L= 221 → ankh_emb_xl.pt
# ✓ PLDA1_ARATH: L= 810 → ankh_emb_xl.pt
# ✓ PLDA3_ARATH: L= 820 → ankh_emb_xl.pt
# ✓ PLDA4_ARATH: L= 762 → ankh_emb_xl.pt
# ✓ PLDB1_ARATH: L=1083 → ankh_emb_xl.pt
# ✓ PLDB2_ARATH: L= 927 → ankh_emb_xl.pt
# ✓ PLDB_DICDI: L=1216 → ankh_emb_xl.pt
# ✓ PLDB_ECOLI: L= 340 → ankh_emb_xl.pt
# ✓ PLDD1_ARATH: L= 868 → ankh_emb_xl.pt
# ✓ PLDG1_ARATH: L= 858 → ankh_emb_xl.pt
# ✓ PLDZ1_ARATH: L=1096 → ankh_emb_xl.pt
# ✓ PLDZ2_ARATH: L=1046 → ankh_emb_xl.pt
# ✓ PLEK2_MOUSE: L= 353 → ankh_emb_xl.pt
# ✓ PLEK_HUMAN: L= 350 → ankh_emb_xl.pt
# ✓ PLF4_HUMAN: L= 101 → ankh_emb_xl.pt
# ✓ PLG7_SCHPO: L= 438 → ankh_emb_xl.pt
# ✓ PLGF_HUMAN: L= 221 → ankh_emb_xl.pt
# ✓ PLGF_RAT: L= 158 → ankh_emb_xl.pt
# ✓ PLGG1_ARATH: L= 512 → ankh_emb_xl.pt
# ✓ PLGT2_HUMAN: L= 502 → ankh_emb_xl.pt
# ✓ PLGT3_HUMAN: L= 507 → ankh_emb_xl.pt
# ✓ PLI1_SCHPO: L= 727 → ankh_emb_xl.pt
# ✓ PLI2A_ARATH: L= 226 → ankh_emb_xl.pt
# ✓ PLI2B_ARATH: L= 205 → ankh_emb_xl.pt
# ✓ PLI2C_ARATH: L= 213 → ankh_emb_xl.pt
# ✓ PLIG_ECOLI: L= 133 → ankh_emb_xl.pt
# ✓ PLIN5_MOUSE: L= 463 → ankh_emb_xl.pt
# ✓ PLIN5_RAT: L= 475 → ankh_emb_xl.pt
# ✓ PLIP1_ARATH: L= 649 → ankh_emb_xl.pt
# ✓ PLIP2_ARATH: L= 713 → ankh_emb_xl.pt
# ✓ PLIP3_ARATH: L= 649 → ankh_emb_xl.pt
# ✓ PLIP_DICDI: L= 232 → ankh_emb_xl.pt
# ✓ PLK1_HUMAN: L= 603 → ankh_emb_xl.pt
# ✓ PLK1_MOUSE: L= 603 → ankh_emb_xl.pt
# ✓ PLK1_XENLA: L= 598 → ankh_emb_xl.pt
# ✓ PLK2_HUMAN: L= 685 → ankh_emb_xl.pt
# ✓ PLK2_MOUSE: L= 682 → ankh_emb_xl.pt
# ✓ PLK2_RAT: L= 682 → ankh_emb_xl.pt
# ✓ PLK3_HUMAN: L= 646 → ankh_emb_xl.pt
# ✓ PLK3_MOUSE: L= 631 → ankh_emb_xl.pt
# ✓ PLK3_RAT: L= 647 → ankh_emb_xl.pt
# ✓ PLK4_DROME: L= 769 → ankh_emb_xl.pt
# ✓ PLK4_HUMAN: L= 970 → ankh_emb_xl.pt
# ✓ PLK4_MOUSE: L= 925 → ankh_emb_xl.pt
# ✓ PLM2_YEAST: L= 521 → ankh_emb_xl.pt
# ✓ PLMN_HUMAN: L= 810 → ankh_emb_xl.pt
# ✓ PLMN_MOUSE: L= 812 → ankh_emb_xl.pt
# ✓ PLMN_RAT: L= 812 → ankh_emb_xl.pt
# ✓ PLMT_ARATH: L= 164 → ankh_emb_xl.pt
# ✓ PLMT_SCHPO: L= 221 → ankh_emb_xl.pt
# ✓ PLMT_YEAST: L= 206 → ankh_emb_xl.pt
# ✓ PLM_HUMAN: L=  92 → ankh_emb_xl.pt
# ✓ PLM_MOUSE: L=  92 → ankh_emb_xl.pt
# ✓ PLM_RAT: L=  92 → ankh_emb_xl.pt
# ✓ PLO1_SCHPO: L= 683 → ankh_emb_xl.pt
# ✓ PLOD1_HUMAN: L= 727 → ankh_emb_xl.pt
# ✓ PLOD1_RAT: L= 728 → ankh_emb_xl.pt
# ✓ PLOD2_HUMAN: L= 737 → ankh_emb_xl.pt
# ✓ PLOD3_HUMAN: L= 738 → ankh_emb_xl.pt
# ✓ PLOD3_MOUSE: L= 741 → ankh_emb_xl.pt
# ✓ PLOD_DROME: L= 721 → ankh_emb_xl.pt
# ✓ PLP1_ARATH: L= 414 → ankh_emb_xl.pt
# ✓ PLP1_YEAST: L= 230 → ankh_emb_xl.pt
# ✓ PLP2_ARATH: L= 407 → ankh_emb_xl.pt
# ✓ PLP2_HUMAN: L= 152 → ankh_emb_xl.pt
# ✓ PLP2_YEAST: L= 286 → ankh_emb_xl.pt
# ✓ PLP3A_ARATH: L= 230 → ankh_emb_xl.pt
# ✓ PLP3_ARATH: L= 428 → ankh_emb_xl.pt
# ✓ PLP5_ARATH: L= 414 → ankh_emb_xl.pt
# ✓ PLP6_ARATH: L= 499 → ankh_emb_xl.pt
# ✓ PLP7_ARATH: L= 488 → ankh_emb_xl.pt
# ✓ PLPHP_ECOLI: L= 234 → ankh_emb_xl.pt
# ✓ PLPHP_YEAST: L= 257 → ankh_emb_xl.pt
# ✓ PLPL1_MOUSE: L= 599 → ankh_emb_xl.pt
# ✓ PLPL2_HUMAN: L= 504 → ankh_emb_xl.pt
# ✓ PLPL2_MOUSE: L= 486 → ankh_emb_xl.pt
# ✓ PLPL3_HUMAN: L= 481 → ankh_emb_xl.pt
# ✓ PLPL3_MOUSE: L= 413 → ankh_emb_xl.pt
# ✓ PLPL4_HUMAN: L= 253 → ankh_emb_xl.pt
# ✓ PLPL5_HUMAN: L= 429 → ankh_emb_xl.pt
# ✓ PLPL6_HUMAN: L=1375 → ankh_emb_xl.pt
# ✓ PLPL6_MOUSE: L=1355 → ankh_emb_xl.pt
# ✓ PLPL7_MOUSE: L=1352 → ankh_emb_xl.pt
# ✓ PLPL7_RAT: L=1349 → ankh_emb_xl.pt
# ✓ PLPL8_HUMAN: L= 782 → ankh_emb_xl.pt
# ✓ PLPL9_HUMAN: L= 806 → ankh_emb_xl.pt
# ✓ PLPL9_MOUSE: L= 807 → ankh_emb_xl.pt
# ✓ PLPL9_RAT: L= 807 → ankh_emb_xl.pt
# ✓ PLPL_SCHPO: L= 630 → ankh_emb_xl.pt
# ✓ PLPP1_HUMAN: L= 284 → ankh_emb_xl.pt
# ✓ PLPP1_MOUSE: L= 283 → ankh_emb_xl.pt
# ✓ PLPP1_RAT: L= 282 → ankh_emb_xl.pt
# ✓ PLPP2_HUMAN: L= 288 → ankh_emb_xl.pt
# ✓ PLPP3_HUMAN: L= 311 → ankh_emb_xl.pt
# ✓ PLPP3_MOUSE: L= 312 → ankh_emb_xl.pt
# ✓ PLPP4_HUMAN: L= 271 → ankh_emb_xl.pt
# ✓ PLPP5_HUMAN: L= 264 → ankh_emb_xl.pt
# ✓ PLPP6_HUMAN: L= 295 → ankh_emb_xl.pt
# ✓ PLPP_HUMAN: L= 296 → ankh_emb_xl.pt
# ✓ PLPP_MOUSE: L= 292 → ankh_emb_xl.pt
# ✓ PLPP_RAT: L= 309 → ankh_emb_xl.pt
# ✓ PLPR4_RAT: L= 766 → ankh_emb_xl.pt
# ✓ PLR1_ARATH: L= 365 → ankh_emb_xl.pt
# ✓ PLR1_SCHPO: L= 333 → ankh_emb_xl.pt
# ✓ PLS1_HUMAN: L= 318 → ankh_emb_xl.pt
# ✓ PLS1_RAT: L= 335 → ankh_emb_xl.pt
# ✓ PLS3_HUMAN: L= 295 → ankh_emb_xl.pt
# ✓ PLS3_RAT: L= 296 → ankh_emb_xl.pt
# ✓ PLS4_HUMAN: L= 329 → ankh_emb_xl.pt
# ✓ PLSB_ARATH: L= 459 → ankh_emb_xl.pt
# ✓ PLSB_ECOLI: L= 807 → ankh_emb_xl.pt
# ✓ PLSC_ECOLI: L= 245 → ankh_emb_xl.pt
# ✓ PLSC_YEAST: L= 303 → ankh_emb_xl.pt
# ✓ PLSI_HUMAN: L= 629 → ankh_emb_xl.pt
# ✓ PLSL_HUMAN: L= 627 → ankh_emb_xl.pt
# ✓ PLSL_MOUSE: L= 627 → ankh_emb_xl.pt
# ✓ PLSP1_ARATH: L= 291 → ankh_emb_xl.pt
# ✓ PLST_MOUSE: L= 630 → ankh_emb_xl.pt
# ✓ PLT5_ARATH: L= 539 → ankh_emb_xl.pt
# ✓ PLTP_HUMAN: L= 493 → ankh_emb_xl.pt
# ✓ PLTP_MOUSE: L= 493 → ankh_emb_xl.pt
# ✓ PLVAP_RAT: L= 438 → ankh_emb_xl.pt
# ✓ PLXA1_HUMAN: L=1896 → ankh_emb_xl.pt
# ✓ PLXA1_MOUSE: L=1894 → ankh_emb_xl.pt
# ✓ PLXA2_MOUSE: L=1894 → ankh_emb_xl.pt
# ✓ PLXA3_DANRE: L=1892 → ankh_emb_xl.pt
# ✓ PLXA3_MOUSE: L=1872 → ankh_emb_xl.pt
# ✓ PLXA4_MOUSE: L=1893 → ankh_emb_xl.pt
# ✓ PLXB1_HUMAN: L=2135 → ankh_emb_xl.pt
# ✓ PLXB1_MOUSE: L=2119 → ankh_emb_xl.pt
# ✓ PLXB2_MOUSE: L=1842 → ankh_emb_xl.pt
# ✓ PLXB3_HUMAN: L=1909 → ankh_emb_xl.pt
# ✓ PLXB3_MOUSE: L=1902 → ankh_emb_xl.pt
# ✓ PLXC1_HUMAN: L=1568 → ankh_emb_xl.pt
# ✓ PLXD1_HUMAN: L=1925 → ankh_emb_xl.pt
# ✓ PLXD1_MOUSE: L=1925 → ankh_emb_xl.pt
# ✓ PM34_HUMAN: L= 307 → ankh_emb_xl.pt
# ✓ PMA10_ARATH: L= 947 → ankh_emb_xl.pt
# ✓ PMA1_ARATH: L= 949 → ankh_emb_xl.pt
# ✓ PMA1_DICDI: L=1058 → ankh_emb_xl.pt
# ✓ PMA1_SCHPO: L= 919 → ankh_emb_xl.pt
# ✓ PMA1_YEAST: L= 918 → ankh_emb_xl.pt
# ✓ PMA2_ARATH: L= 948 → ankh_emb_xl.pt
# ✓ PMA2_SCHPO: L=1010 → ankh_emb_xl.pt
# ✓ PMA2_YEAST: L= 947 → ankh_emb_xl.pt
# ✓ PMA3_ARATH: L= 949 → ankh_emb_xl.pt
# ✓ PMAP1_SCHPO: L= 398 → ankh_emb_xl.pt
# ✓ PMAT1_ARATH: L= 469 → ankh_emb_xl.pt
# ✓ PMAT2_ARATH: L= 451 → ankh_emb_xl.pt
# ✓ PMD1_ARATH: L= 318 → ankh_emb_xl.pt
# ✓ PMD1_SCHPO: L=1362 → ankh_emb_xl.pt
# ✓ PME1_ARATH: L= 586 → ankh_emb_xl.pt
# ✓ PME31_ARATH: L= 317 → ankh_emb_xl.pt
# ✓ PME34_ARATH: L= 598 → ankh_emb_xl.pt
# ✓ PME35_ARATH: L= 529 → ankh_emb_xl.pt
# ✓ PME3_ARATH: L= 592 → ankh_emb_xl.pt
# ✓ PME41_ARATH: L= 573 → ankh_emb_xl.pt
# ✓ PME46_ARATH: L= 564 → ankh_emb_xl.pt
# ✓ PME48_ARATH: L= 361 → ankh_emb_xl.pt
# ✓ PME5_ARATH: L= 595 → ankh_emb_xl.pt
# ✓ PME62_ARATH: L= 380 → ankh_emb_xl.pt
# ✓ PME6_ARATH: L= 554 → ankh_emb_xl.pt
# ✓ PMEI1_ARATH: L= 176 → ankh_emb_xl.pt
# ✓ PMEI2_ARATH: L= 173 → ankh_emb_xl.pt
# ✓ PMEI4_ARATH: L= 199 → ankh_emb_xl.pt
# ✓ PMEI5_ARATH: L= 179 → ankh_emb_xl.pt
# ✓ PMEI6_ARATH: L= 208 → ankh_emb_xl.pt
# ✓ PMEI9_ARATH: L= 204 → ankh_emb_xl.pt
# ✓ PMEL_HUMAN: L= 661 → ankh_emb_xl.pt
# ✓ PMEPA_HUMAN: L= 287 → ankh_emb_xl.pt
# ✓ PMF1_HUMAN: L= 205 → ankh_emb_xl.pt
# ✓ PMG1_ARATH: L= 557 → ankh_emb_xl.pt
# ✓ PMG1_YEAST: L= 247 → ankh_emb_xl.pt
# ✓ PMG2_ARATH: L= 560 → ankh_emb_xl.pt
# ✓ PMGE_HUMAN: L= 259 → ankh_emb_xl.pt
# ✓ PMGE_MOUSE: L= 259 → ankh_emb_xl.pt
# ✓ PMGT1_HUMAN: L= 660 → ankh_emb_xl.pt
# ✓ PMGT2_HUMAN: L= 580 → ankh_emb_xl.pt
# ✓ PMGY_SCHPO: L= 211 → ankh_emb_xl.pt
# ✓ PMI10_ARATH: L= 312 → ankh_emb_xl.pt
# ✓ PMI11_ARATH: L= 202 → ankh_emb_xl.pt
# ✓ PMI12_ARATH: L= 174 → ankh_emb_xl.pt
# ✓ PMIP_YEAST: L= 772 → ankh_emb_xl.pt
# ✓ PMK_ARATH: L= 505 → ankh_emb_xl.pt
# ✓ PML_HUMAN: L= 882 → ankh_emb_xl.pt
# ✓ PML_MOUSE: L= 885 → ankh_emb_xl.pt
# ✓ PMM1_HUMAN: L= 262 → ankh_emb_xl.pt
# ✓ PMM_ARATH: L= 246 → ankh_emb_xl.pt
# ✓ PMM_CANAL: L= 252 → ankh_emb_xl.pt
# ✓ PMM_YEAST: L= 254 → ankh_emb_xl.pt
# ✓ PMP1_SCHPO: L= 278 → ankh_emb_xl.pt
# ✓ PMP1_YEAST: L=  40 → ankh_emb_xl.pt
# ✓ PMP20_SCHPO: L= 156 → ankh_emb_xl.pt
# ✓ PMP22_MOUSE: L= 161 → ankh_emb_xl.pt
# ✓ PMP2_YEAST: L=  43 → ankh_emb_xl.pt
# ✓ PMP3_YEAST: L=  55 → ankh_emb_xl.pt
# ✓ PMS1_HUMAN: L= 932 → ankh_emb_xl.pt
# ✓ PMS1_YEAST: L= 873 → ankh_emb_xl.pt
# ✓ PMS2_HUMAN: L= 862 → ankh_emb_xl.pt
# ✓ PMT1M_SCHPO: L= 330 → ankh_emb_xl.pt
# ✓ PMT1_CANAL: L= 877 → ankh_emb_xl.pt
# ✓ PMT1_SCHPO: L= 893 → ankh_emb_xl.pt
# ✓ PMT1_YEAST: L= 817 → ankh_emb_xl.pt
# ✓ PMT2_SCHPO: L= 739 → ankh_emb_xl.pt
# ✓ PMT2_YEAST: L= 759 → ankh_emb_xl.pt
# ✓ PMT3_SCHPO: L= 117 → ankh_emb_xl.pt
# ✓ PMT4_CANAL: L= 755 → ankh_emb_xl.pt
# ✓ PMT4_YEAST: L= 762 → ankh_emb_xl.pt
# ✓ PMTD_ARATH: L= 600 → ankh_emb_xl.pt
# ✓ PMTT_ARATH: L= 684 → ankh_emb_xl.pt
# ✓ PMVK_HUMAN: L= 192 → ankh_emb_xl.pt
# ✓ PMVK_MOUSE: L= 192 → ankh_emb_xl.pt
# ✓ PMYT1_DROME: L= 533 → ankh_emb_xl.pt
# ✓ PMYT1_HUMAN: L= 499 → ankh_emb_xl.pt
# ✓ PNC1_ARATH: L= 322 → ankh_emb_xl.pt
# ✓ PNC1_YEAST: L= 216 → ankh_emb_xl.pt
# ✓ PNC2_ARATH: L= 321 → ankh_emb_xl.pt
# ✓ PNCA_ECOLI: L= 213 → ankh_emb_xl.pt
# ✓ PNCB_ECOLI: L= 400 → ankh_emb_xl.pt
# ✓ PNCB_HUMAN: L= 538 → ankh_emb_xl.pt
# ✓ PNCB_RAT: L= 538 → ankh_emb_xl.pt
# ✓ PNCC_ECOLI: L= 165 → ankh_emb_xl.pt
# ✓ PNDC1_HUMAN: L= 520 → ankh_emb_xl.pt
# ✓ PNDC1_MOUSE: L= 531 → ankh_emb_xl.pt
# ✓ PNG1_ARATH: L= 721 → ankh_emb_xl.pt
# ✓ PNG1_SCHPO: L= 333 → ankh_emb_xl.pt
# ✓ PNG1_YEAST: L= 363 → ankh_emb_xl.pt
# ✓ PNK1_SCHPO: L= 408 → ankh_emb_xl.pt
# ✓ PNKP_HUMAN: L= 521 → ankh_emb_xl.pt
# ✓ PNKP_MOUSE: L= 522 → ankh_emb_xl.pt
# ✓ PNMA5_HUMAN: L= 448 → ankh_emb_xl.pt
# ✓ PNMT_MOUSE: L= 295 → ankh_emb_xl.pt
# ✓ PNMT_RAT: L= 285 → ankh_emb_xl.pt
# ✓ PNO1_YEAST: L= 274 → ankh_emb_xl.pt
# ✓ PNOC_HUMAN: L= 176 → ankh_emb_xl.pt
# ✓ PNP1_ARATH: L= 922 → ankh_emb_xl.pt
# ✓ PNP2_ARATH: L= 991 → ankh_emb_xl.pt
# ✓ PNPH_HUMAN: L= 289 → ankh_emb_xl.pt
# ✓ PNPH_MOUSE: L= 289 → ankh_emb_xl.pt
# ✓ PNPH_RAT: L= 289 → ankh_emb_xl.pt
# ✓ PNPH_YEAST: L= 311 → ankh_emb_xl.pt
# ✓ PNPO_HUMAN: L= 261 → ankh_emb_xl.pt
# ✓ PNPO_RAT: L= 261 → ankh_emb_xl.pt
# ✓ PNPP_SCHPO: L= 298 → ankh_emb_xl.pt
# ✓ PNPP_YEAST: L= 312 → ankh_emb_xl.pt
# ✓ PNPT1_HUMAN: L= 783 → ankh_emb_xl.pt
# ✓ PNP_ECOLI: L= 711 → ankh_emb_xl.pt
# ✓ PNR_DROME: L= 540 → ankh_emb_xl.pt
# ✓ PNSL2_ARATH: L= 190 → ankh_emb_xl.pt
# ✓ PNSL3_ARATH: L= 220 → ankh_emb_xl.pt
# ✓ PNSL5_ARATH: L= 259 → ankh_emb_xl.pt
# ✓ PNTA_ECOLI: L= 510 → ankh_emb_xl.pt
# ✓ PNTB_ECOLI: L= 462 → ankh_emb_xl.pt
# ✓ PNT_DROME: L= 718 → ankh_emb_xl.pt
# ✓ PNU1_SCHPO: L= 322 → ankh_emb_xl.pt
# ✓ PNUC_ECOLI: L= 239 → ankh_emb_xl.pt
# ✓ PNUT_DROME: L= 539 → ankh_emb_xl.pt
# ✓ PO121_RAT: L=1199 → ankh_emb_xl.pt
# ✓ PO152_YEAST: L=1337 → ankh_emb_xl.pt
# ✓ PO2F1_HUMAN: L= 743 → ankh_emb_xl.pt
# ✓ PO2F1_MOUSE: L= 770 → ankh_emb_xl.pt
# ✓ PO2F1_RAT: L= 632 → ankh_emb_xl.pt
# ✓ PO2F1_XENLA: L= 758 → ankh_emb_xl.pt
# ✓ PO2F2_HUMAN: L= 479 → ankh_emb_xl.pt
# ✓ PO2F2_MOUSE: L= 463 → ankh_emb_xl.pt
# ✓ PO2F3_HUMAN: L= 436 → ankh_emb_xl.pt
# ✓ PO2F3_MOUSE: L= 431 → ankh_emb_xl.pt
# ✓ PO3F1_HUMAN: L= 451 → ankh_emb_xl.pt
# ✓ PO3F1_MOUSE: L= 449 → ankh_emb_xl.pt
# ✓ PO3F1_RAT: L= 451 → ankh_emb_xl.pt
# ✓ PO3F2_HUMAN: L= 443 → ankh_emb_xl.pt
# ✓ PO3F2_MOUSE: L= 445 → ankh_emb_xl.pt
# ✓ PO3F2_RAT: L= 445 → ankh_emb_xl.pt
# ✓ PO3F3_HUMAN: L= 500 → ankh_emb_xl.pt
# ✓ PO3F3_MOUSE: L= 497 → ankh_emb_xl.pt
# ✓ PO3F3_RAT: L= 497 → ankh_emb_xl.pt
# ✓ PO3F4_HUMAN: L= 361 → ankh_emb_xl.pt
# ✓ PO3F4_MOUSE: L= 361 → ankh_emb_xl.pt
# ✓ PO3F4_RAT: L= 361 → ankh_emb_xl.pt
# ✓ PO4F1_HUMAN: L= 419 → ankh_emb_xl.pt
# ✓ PO4F1_MOUSE: L= 421 → ankh_emb_xl.pt
# ✓ PO4F2_HUMAN: L= 409 → ankh_emb_xl.pt
# ✓ PO4F2_MOUSE: L= 411 → ankh_emb_xl.pt
# ✓ PO4F3_HUMAN: L= 338 → ankh_emb_xl.pt
# ✓ PO4F3_MOUSE: L= 338 → ankh_emb_xl.pt
# ✓ PO5F1_DANRE: L= 472 → ankh_emb_xl.pt
# ✓ PO5F1_HUMAN: L= 360 → ankh_emb_xl.pt
# ✓ PO5F1_MOUSE: L= 352 → ankh_emb_xl.pt
# ✓ PO5F2_MOUSE: L= 329 → ankh_emb_xl.pt
# ✓ PO6F1_HUMAN: L= 301 → ankh_emb_xl.pt
# ✓ PO6F1_MOUSE: L= 301 → ankh_emb_xl.pt
# ✓ PO6F1_RAT: L= 301 → ankh_emb_xl.pt
# ✓ PO6F2_HUMAN: L= 691 → ankh_emb_xl.pt
# ✓ POA1_YEAST: L= 177 → ankh_emb_xl.pt
# ✓ POB1_ARATH: L= 561 → ankh_emb_xl.pt
# ✓ PODN_HUMAN: L= 613 → ankh_emb_xl.pt
# ✓ POED1_ARATH: L= 320 → ankh_emb_xl.pt
# ✓ POF1B_HUMAN: L= 589 → ankh_emb_xl.pt
# ✓ POF1_SCHPO: L= 605 → ankh_emb_xl.pt
# ✓ POF1_YEAST: L= 258 → ankh_emb_xl.pt
# ✓ POF3_SCHPO: L= 577 → ankh_emb_xl.pt
# ✓ POF4_SCHPO: L= 263 → ankh_emb_xl.pt
# ✓ POF8_SCHPO: L= 402 → ankh_emb_xl.pt
# ✓ POF_DROME: L= 495 → ankh_emb_xl.pt
# ✓ POG1_YEAST: L= 351 → ankh_emb_xl.pt
# ✓ POK_DROME: L= 732 → ankh_emb_xl.pt
# ✓ POLH_ARATH: L= 672 → ankh_emb_xl.pt
# ✓ POLH_DROME: L= 885 → ankh_emb_xl.pt
# ✓ POLH_HUMAN: L= 713 → ankh_emb_xl.pt
# ✓ POLH_MOUSE: L= 694 → ankh_emb_xl.pt
# ✓ POLH_YEAST: L= 632 → ankh_emb_xl.pt
# ✓ POLI_DROME: L= 737 → ankh_emb_xl.pt
# ✓ POLI_MOUSE: L= 717 → ankh_emb_xl.pt
# ✓ POLK_ARATH: L= 671 → ankh_emb_xl.pt
# ✓ POLO_DROME: L= 576 → ankh_emb_xl.pt
# ✓ POLS2_HUMAN: L= 855 → ankh_emb_xl.pt
# ✓ POM1_SCHPO: L=1087 → ankh_emb_xl.pt
# ✓ POM34_YEAST: L= 299 → ankh_emb_xl.pt
# ✓ POMT1_DANRE: L= 720 → ankh_emb_xl.pt
# ✓ POMT1_DROME: L= 886 → ankh_emb_xl.pt
# ✓ POMT1_HUMAN: L= 747 → ankh_emb_xl.pt
# ✓ POMT2_DANRE: L= 756 → ankh_emb_xl.pt
# ✓ POMT2_DROME: L= 765 → ankh_emb_xl.pt
# ✓ POMT2_HUMAN: L= 750 → ankh_emb_xl.pt
# ✓ PON1_HUMAN: L= 355 → ankh_emb_xl.pt
# ✓ PON1_MOUSE: L= 355 → ankh_emb_xl.pt
# ✓ PON1_RAT: L= 355 → ankh_emb_xl.pt
# ✓ PON2_HUMAN: L= 354 → ankh_emb_xl.pt
# ✓ PON3_HUMAN: L= 354 → ankh_emb_xl.pt
# ✓ PON3_RAT: L= 354 → ankh_emb_xl.pt
# ✓ PONA_DICDI: L= 143 → ankh_emb_xl.pt
# ✓ POP1_HUMAN: L=1024 → ankh_emb_xl.pt
# ✓ POP1_SCHPO: L= 775 → ankh_emb_xl.pt
# ✓ POP1_YEAST: L= 875 → ankh_emb_xl.pt
# ✓ POP2_SCHPO: L= 703 → ankh_emb_xl.pt
# ✓ POP2_YEAST: L= 433 → ankh_emb_xl.pt
# ✓ POP4_YEAST: L= 279 → ankh_emb_xl.pt
# ✓ POP5_HUMAN: L= 163 → ankh_emb_xl.pt
# ✓ POP5_MOUSE: L= 169 → ankh_emb_xl.pt
# ✓ POP5_YEAST: L= 173 → ankh_emb_xl.pt
# ✓ POP6_YEAST: L= 158 → ankh_emb_xl.pt
# ✓ POP7_HUMAN: L= 140 → ankh_emb_xl.pt
# ✓ POP7_YEAST: L= 140 → ankh_emb_xl.pt
# ✓ POPD1_HUMAN: L= 360 → ankh_emb_xl.pt
# ✓ POPD1_MOUSE: L= 358 → ankh_emb_xl.pt
# ✓ POPD2_MOUSE: L= 367 → ankh_emb_xl.pt
# ✓ POPD3_MOUSE: L= 291 → ankh_emb_xl.pt
# ✓ POPI_SCHPO: L= 698 → ankh_emb_xl.pt
# ✓ PORA_ARATH: L= 405 → ankh_emb_xl.pt
# ✓ PORB_ARATH: L= 401 → ankh_emb_xl.pt
# ✓ PORCN_DROME: L= 525 → ankh_emb_xl.pt
# ✓ PORCN_MOUSE: L= 461 → ankh_emb_xl.pt
# ✓ PORC_ARATH: L= 401 → ankh_emb_xl.pt
# ✓ PORED_HUMAN: L= 318 → ankh_emb_xl.pt
# ✓ POS5_YEAST: L= 414 → ankh_emb_xl.pt
# ✓ POSTN_HUMAN: L= 836 → ankh_emb_xl.pt
# ✓ POSTN_MOUSE: L= 838 → ankh_emb_xl.pt
# ✓ POT1A_ARATH: L= 467 → ankh_emb_xl.pt
# ✓ POT1B_ARATH: L= 454 → ankh_emb_xl.pt
# ✓ POT1_SCHPO: L= 555 → ankh_emb_xl.pt
# ✓ POT5_ARATH: L= 785 → ankh_emb_xl.pt
# ✓ POT7_ARATH: L= 858 → ankh_emb_xl.pt
# ✓ POTA_ECOLI: L= 378 → ankh_emb_xl.pt
# ✓ POTB_ECOLI: L= 275 → ankh_emb_xl.pt
# ✓ POTC_ECOLI: L= 264 → ankh_emb_xl.pt
# ✓ POTD_ECOLI: L= 348 → ankh_emb_xl.pt
# ✓ POTE1_HUMAN: L= 634 → ankh_emb_xl.pt
# ✓ POTE1_MOUSE: L= 640 → ankh_emb_xl.pt
# ✓ POTE_ECOLI: L= 439 → ankh_emb_xl.pt
# ✓ POTF_ECOLI: L= 370 → ankh_emb_xl.pt
# ✓ POXA_DICDI: L= 531 → ankh_emb_xl.pt
# ✓ POXB_ECOLI: L= 572 → ankh_emb_xl.pt
# ✓ PP113_ARATH: L= 879 → ankh_emb_xl.pt
# ✓ PP115_ARATH: L= 689 → ankh_emb_xl.pt
# ✓ PP11_ARATH: L= 318 → ankh_emb_xl.pt
# ✓ PP11_SCHPO: L= 327 → ankh_emb_xl.pt
# ✓ PP11_YEAST: L= 311 → ankh_emb_xl.pt
# ✓ PP12_ARATH: L= 312 → ankh_emb_xl.pt
# ✓ PP12_DROME: L= 302 → ankh_emb_xl.pt
# ✓ PP12_YEAST: L= 312 → ankh_emb_xl.pt
# ✓ PP131_ARATH: L= 576 → ankh_emb_xl.pt
# ✓ PP133_ARATH: L= 780 → ankh_emb_xl.pt
# ✓ PP13G_MOUSE: L= 347 → ankh_emb_xl.pt
# ✓ PP13_ARATH: L= 322 → ankh_emb_xl.pt
# ✓ PP13_DROME: L= 302 → ankh_emb_xl.pt
# ✓ PP13_HUMAN: L= 139 → ankh_emb_xl.pt
# ✓ PP143_ARATH: L= 761 → ankh_emb_xl.pt
# ✓ PP14A_RAT: L= 147 → ankh_emb_xl.pt
# ✓ PP14B_RAT: L= 147 → ankh_emb_xl.pt
# ✓ PP14C_MOUSE: L= 164 → ankh_emb_xl.pt
# ✓ PP14C_RAT: L= 164 → ankh_emb_xl.pt
# ✓ PP14D_HUMAN: L= 145 → ankh_emb_xl.pt
# ✓ PP14_ARATH: L= 321 → ankh_emb_xl.pt
# ✓ PP156_ARATH: L= 743 → ankh_emb_xl.pt
# ✓ PP15_ARATH: L= 312 → ankh_emb_xl.pt
# ✓ PP163_ARATH: L= 822 → ankh_emb_xl.pt
# ✓ PP16A_ARATH: L= 156 → ankh_emb_xl.pt
# ✓ PP16B_HUMAN: L= 567 → ankh_emb_xl.pt
# ✓ PP16_ARATH: L= 322 → ankh_emb_xl.pt
# ✓ PP177_ARATH: L= 452 → ankh_emb_xl.pt
# ✓ PP178_ARATH: L= 918 → ankh_emb_xl.pt
# ✓ PP18_ARATH: L= 324 → ankh_emb_xl.pt
# ✓ PP190_ARATH: L= 757 → ankh_emb_xl.pt
# ✓ PP199_ARATH: L= 822 → ankh_emb_xl.pt
# ✓ PP19_ARATH: L= 318 → ankh_emb_xl.pt
# ✓ PP1A_HUMAN: L= 330 → ankh_emb_xl.pt
# ✓ PP1A_MOUSE: L= 330 → ankh_emb_xl.pt
# ✓ PP1A_RAT: L= 330 → ankh_emb_xl.pt
# ✓ PP1B_DROME: L= 330 → ankh_emb_xl.pt
# ✓ PP1B_HUMAN: L= 327 → ankh_emb_xl.pt
# ✓ PP1B_MOUSE: L= 327 → ankh_emb_xl.pt
# ✓ PP1B_RAT: L= 327 → ankh_emb_xl.pt
# ✓ PP1GA_XENLA: L= 323 → ankh_emb_xl.pt
# ✓ PP1G_HUMAN: L= 323 → ankh_emb_xl.pt
# ✓ PP1G_MOUSE: L= 323 → ankh_emb_xl.pt
# ✓ PP1G_RAT: L= 323 → ankh_emb_xl.pt
# ✓ PP1R7_HUMAN: L= 360 → ankh_emb_xl.pt
# ✓ PP1R8_HUMAN: L= 351 → ankh_emb_xl.pt
# ✓ PP1R8_MOUSE: L= 351 → ankh_emb_xl.pt
# ✓ PP1RA_RAT: L= 872 → ankh_emb_xl.pt
# ✓ PP1RB_HUMAN: L= 126 → ankh_emb_xl.pt
# ✓ PP1RB_MOUSE: L= 131 → ankh_emb_xl.pt
# ✓ PP209_ARATH: L= 576 → ankh_emb_xl.pt
# ✓ PP213_ARATH: L= 602 → ankh_emb_xl.pt
# ✓ PP216_ARATH: L= 486 → ankh_emb_xl.pt
# ✓ PP222_ARATH: L= 778 → ankh_emb_xl.pt
# ✓ PP225_ARATH: L= 551 → ankh_emb_xl.pt
# ✓ PP257_ARATH: L= 455 → ankh_emb_xl.pt
# ✓ PP261_ARATH: L= 600 → ankh_emb_xl.pt
# ✓ PP264_ARATH: L= 665 → ankh_emb_xl.pt
# ✓ PP273_ARATH: L= 629 → ankh_emb_xl.pt
# ✓ PP2A1_SCHPO: L= 309 → ankh_emb_xl.pt
# ✓ PP2A1_YEAST: L= 369 → ankh_emb_xl.pt
# ✓ PP2A2_SCHPO: L= 322 → ankh_emb_xl.pt
# ✓ PP2A2_YEAST: L= 377 → ankh_emb_xl.pt
# ✓ PP2A3_ARATH: L= 313 → ankh_emb_xl.pt
# ✓ PP2AA_DICDI: L= 306 → ankh_emb_xl.pt
# ✓ PP2AA_HUMAN: L= 309 → ankh_emb_xl.pt
# ✓ PP2AA_MOUSE: L= 309 → ankh_emb_xl.pt
# ✓ PP2AA_RAT: L= 309 → ankh_emb_xl.pt
# ✓ PP2AB_RAT: L= 309 → ankh_emb_xl.pt
# ✓ PP2A_DROME: L= 309 → ankh_emb_xl.pt
# ✓ PP2B2_DROME: L= 570 → ankh_emb_xl.pt
# ✓ PP2B3_DROME: L= 584 → ankh_emb_xl.pt
# ✓ PP2BA_DICDI: L= 623 → ankh_emb_xl.pt
# ✓ PP2BA_HUMAN: L= 521 → ankh_emb_xl.pt
# ✓ PP2BA_MOUSE: L= 521 → ankh_emb_xl.pt
# ✓ PP2BA_RAT: L= 521 → ankh_emb_xl.pt
# ✓ PP2BB_HUMAN: L= 524 → ankh_emb_xl.pt
# ✓ PP2BB_MOUSE: L= 525 → ankh_emb_xl.pt
# ✓ PP2BB_RAT: L= 525 → ankh_emb_xl.pt
# ✓ PP2BC_HUMAN: L= 512 → ankh_emb_xl.pt
# ✓ PP2B_SCHPO: L= 554 → ankh_emb_xl.pt
# ✓ PP2C1_SCHPO: L= 347 → ankh_emb_xl.pt
# ✓ PP2C1_YEAST: L= 281 → ankh_emb_xl.pt
# ✓ PP2C2_SCHPO: L= 370 → ankh_emb_xl.pt
# ✓ PP2C2_YEAST: L= 464 → ankh_emb_xl.pt
# ✓ PP2C3_SCHPO: L= 414 → ankh_emb_xl.pt
# ✓ PP2C3_YEAST: L= 468 → ankh_emb_xl.pt
# ✓ PP2C4_SCHPO: L= 383 → ankh_emb_xl.pt
# ✓ PP2C4_YEAST: L= 393 → ankh_emb_xl.pt
# ✓ PP2C7_YEAST: L= 343 → ankh_emb_xl.pt
# ✓ PP300_ARATH: L= 502 → ankh_emb_xl.pt
# ✓ PP312_ARATH: L= 684 → ankh_emb_xl.pt
# ✓ PP314_ARATH: L= 702 → ankh_emb_xl.pt
# ✓ PP342_ARATH: L= 904 → ankh_emb_xl.pt
# ✓ PP352_ARATH: L= 412 → ankh_emb_xl.pt
# ✓ PP354_ARATH: L= 632 → ankh_emb_xl.pt
# ✓ PP361_ARATH: L= 852 → ankh_emb_xl.pt
# ✓ PP376_ARATH: L= 816 → ankh_emb_xl.pt
# ✓ PP387_ARATH: L= 668 → ankh_emb_xl.pt
# ✓ PP395_ARATH: L= 831 → ankh_emb_xl.pt
# ✓ PP399_ARATH: L=1038 → ankh_emb_xl.pt
# ✓ PP413_ARATH: L= 709 → ankh_emb_xl.pt
# ✓ PP438_ARATH: L= 521 → ankh_emb_xl.pt
# ✓ PP4C_DICDI: L= 305 → ankh_emb_xl.pt
# ✓ PP4C_DROME: L= 307 → ankh_emb_xl.pt
# ✓ PP4C_HUMAN: L= 307 → ankh_emb_xl.pt
# ✓ PP4C_MOUSE: L= 307 → ankh_emb_xl.pt
# ✓ PP4C_RAT: L= 307 → ankh_emb_xl.pt
# ✓ PP4C_YEAST: L= 308 → ankh_emb_xl.pt
# ✓ PP4P1_HUMAN: L= 277 → ankh_emb_xl.pt
# ✓ PP4P2_HUMAN: L= 257 → ankh_emb_xl.pt
# ✓ PP4R2_HUMAN: L= 417 → ankh_emb_xl.pt
# ✓ PP4R2_YEAST: L= 441 → ankh_emb_xl.pt
# ✓ PP4R3_YEAST: L= 858 → ankh_emb_xl.pt
# ✓ PP4R4_HUMAN: L= 873 → ankh_emb_xl.pt
# ✓ PP6R1_HUMAN: L= 881 → ankh_emb_xl.pt
# ✓ PP6R3_HUMAN: L= 873 → ankh_emb_xl.pt
# ✓ PPA10_ARATH: L= 468 → ankh_emb_xl.pt
# ✓ PPA12_ARATH: L= 469 → ankh_emb_xl.pt
# ✓ PPA15_ARATH: L= 532 → ankh_emb_xl.pt
# ✓ PPA17_ARATH: L= 338 → ankh_emb_xl.pt
# ✓ PPA1_SCHPO: L= 453 → ankh_emb_xl.pt
# ✓ PPA25_ARATH: L= 466 → ankh_emb_xl.pt
# ✓ PPA26_ARATH: L= 475 → ankh_emb_xl.pt
# ✓ PPA2_ARATH: L= 656 → ankh_emb_xl.pt
# ✓ PPA2_SCHPO: L= 463 → ankh_emb_xl.pt
# ✓ PPA3_YEAST: L= 467 → ankh_emb_xl.pt
# ✓ PPA5_HUMAN: L= 325 → ankh_emb_xl.pt
# ✓ PPA5_MOUSE: L= 327 → ankh_emb_xl.pt
# ✓ PPA5_RAT: L= 327 → ankh_emb_xl.pt
# ✓ PPA5_YEAST: L= 467 → ankh_emb_xl.pt
# ✓ PPA6_HUMAN: L= 428 → ankh_emb_xl.pt
# ✓ PPAB_YEAST: L= 467 → ankh_emb_xl.pt
# ✓ PPAC1_DROME: L= 155 → ankh_emb_xl.pt
# ✓ PPAC2_DROME: L= 164 → ankh_emb_xl.pt
# ✓ PPAC_HUMAN: L= 158 → ankh_emb_xl.pt
# ✓ PPAC_MOUSE: L= 158 → ankh_emb_xl.pt
# ✓ PPAC_RAT: L= 158 → ankh_emb_xl.pt
# ✓ PPAC_YEAST: L= 467 → ankh_emb_xl.pt
# ✓ PPAL_HUMAN: L= 423 → ankh_emb_xl.pt
# ✓ PPAL_MOUSE: L= 423 → ankh_emb_xl.pt
# ✓ PPAL_RAT: L= 423 → ankh_emb_xl.pt
# ✓ PPAL_SCHPO: L= 156 → ankh_emb_xl.pt
# ✓ PPAL_YEAST: L= 161 → ankh_emb_xl.pt
# ✓ PPAP_HUMAN: L= 386 → ankh_emb_xl.pt
# ✓ PPAP_MOUSE: L= 381 → ankh_emb_xl.pt
# ✓ PPAP_RAT: L= 381 → ankh_emb_xl.pt
# ✓ PPARA_HUMAN: L= 468 → ankh_emb_xl.pt
# ✓ PPARA_MOUSE: L= 468 → ankh_emb_xl.pt
# ✓ PPARA_RAT: L= 468 → ankh_emb_xl.pt
# ✓ PPARD_HUMAN: L= 441 → ankh_emb_xl.pt
# ✓ PPARD_MOUSE: L= 440 → ankh_emb_xl.pt
# ✓ PPARG_HUMAN: L= 505 → ankh_emb_xl.pt
# ✓ PPARG_MOUSE: L= 505 → ankh_emb_xl.pt
# ✓ PPARG_RAT: L= 505 → ankh_emb_xl.pt
# ✓ PPAT_HUMAN: L= 426 → ankh_emb_xl.pt
# ✓ PPA_ECOLI: L= 432 → ankh_emb_xl.pt
# ✓ PPB1_HUMAN: L= 535 → ankh_emb_xl.pt
# ✓ PPBI1_RAT: L= 540 → ankh_emb_xl.pt
# ✓ PPBI_HUMAN: L= 528 → ankh_emb_xl.pt
# ✓ PPBN_HUMAN: L= 532 → ankh_emb_xl.pt
# ✓ PPBN_MOUSE: L= 529 → ankh_emb_xl.pt
# ✓ PPBT_HUMAN: L= 524 → ankh_emb_xl.pt
# ✓ PPBT_MOUSE: L= 524 → ankh_emb_xl.pt
# ✓ PPBT_RAT: L= 524 → ankh_emb_xl.pt
# ✓ PPB_ECOLI: L= 471 → ankh_emb_xl.pt
# ✓ PPB_SCHPO: L= 532 → ankh_emb_xl.pt
# ✓ PPB_YEAST: L= 566 → ankh_emb_xl.pt
# ✓ PPCEL_HUMAN: L= 727 → ankh_emb_xl.pt
# ✓ PPCEL_MOUSE: L= 725 → ankh_emb_xl.pt
# ✓ PPCE_DICDI: L= 760 → ankh_emb_xl.pt
# ✓ PPCE_HUMAN: L= 710 → ankh_emb_xl.pt
# ✓ PPCE_RAT: L= 710 → ankh_emb_xl.pt
# ✓ PPCK1_ARATH: L= 284 → ankh_emb_xl.pt
# ✓ PPCK2_ARATH: L= 278 → ankh_emb_xl.pt
# ✓ PPCS1_ARATH: L= 317 → ankh_emb_xl.pt
# ✓ PPCS_HUMAN: L= 311 → ankh_emb_xl.pt
# ✓ PPCS_YEAST: L= 365 → ankh_emb_xl.pt
# ✓ PPCT_HUMAN: L= 214 → ankh_emb_xl.pt
# ✓ PPD_ARATH: L= 262 → ankh_emb_xl.pt
# ✓ PPE1_SCHPO: L= 305 → ankh_emb_xl.pt
# ✓ PPE2_HUMAN: L= 753 → ankh_emb_xl.pt
# ✓ PPG1_CANAL: L= 416 → ankh_emb_xl.pt
# ✓ PPGB_HUMAN: L= 480 → ankh_emb_xl.pt
# ✓ PPH_ARATH: L= 484 → ankh_emb_xl.pt
# ✓ PPI1_ARATH: L= 612 → ankh_emb_xl.pt
# ✓ PPIA_CANAL: L= 162 → ankh_emb_xl.pt
# ✓ PPIA_ECOLI: L= 190 → ankh_emb_xl.pt
# ✓ PPIA_HUMAN: L= 165 → ankh_emb_xl.pt
# ✓ PPIA_RAT: L= 164 → ankh_emb_xl.pt
# ✓ PPIB_ECOLI: L= 164 → ankh_emb_xl.pt
# ✓ PPIB_HUMAN: L= 216 → ankh_emb_xl.pt
# ✓ PPIB_SCHPO: L= 201 → ankh_emb_xl.pt
# ✓ PPIC_ECOLI: L=  93 → ankh_emb_xl.pt
# ✓ PPIC_HUMAN: L= 212 → ankh_emb_xl.pt
# ✓ PPIC_MOUSE: L= 212 → ankh_emb_xl.pt
# ✓ PPID_ECOLI: L= 623 → ankh_emb_xl.pt
# ✓ PPID_HUMAN: L= 370 → ankh_emb_xl.pt
# ✓ PPID_MOUSE: L= 370 → ankh_emb_xl.pt
# ✓ PPID_RAT: L= 370 → ankh_emb_xl.pt
# ✓ PPID_SCHPO: L= 356 → ankh_emb_xl.pt
# ✓ PPID_YEAST: L= 371 → ankh_emb_xl.pt
# ✓ PPIE_HUMAN: L= 301 → ankh_emb_xl.pt
# ✓ PPIF_HUMAN: L= 207 → ankh_emb_xl.pt
# ✓ PPIF_RAT: L= 206 → ankh_emb_xl.pt
# ✓ PPIG_HUMAN: L= 754 → ankh_emb_xl.pt
# ✓ PPIG_RAT: L= 752 → ankh_emb_xl.pt
# ✓ PPIH_HUMAN: L= 177 → ankh_emb_xl.pt
# ✓ PPIH_SCHPO: L= 173 → ankh_emb_xl.pt
# ✓ PPIL1_HUMAN: L= 166 → ankh_emb_xl.pt
# ✓ PPIL1_SCHPO: L= 155 → ankh_emb_xl.pt
# ✓ PPIL2_HUMAN: L= 520 → ankh_emb_xl.pt
# ✓ PPIP1_HUMAN: L= 416 → ankh_emb_xl.pt
# ✓ PPIP1_MOUSE: L= 415 → ankh_emb_xl.pt
# ✓ PPK13_SCHPO: L= 344 → ankh_emb_xl.pt
# ✓ PPK18_SCHPO: L=1318 → ankh_emb_xl.pt
# ✓ PPK1_DICDI: L=1053 → ankh_emb_xl.pt
# ✓ PPK1_ECOLI: L= 688 → ankh_emb_xl.pt
# ✓ PPK23_SCHPO: L= 398 → ankh_emb_xl.pt
# ✓ PPK32_SCHPO: L= 749 → ankh_emb_xl.pt
# ✓ PPK4_SCHPO: L=1072 → ankh_emb_xl.pt
# ✓ PPK5_SCHPO: L= 836 → ankh_emb_xl.pt
# ✓ PPLA_HUMAN: L=  52 → ankh_emb_xl.pt
# ✓ PPLA_MOUSE: L=  52 → ankh_emb_xl.pt
# ✓ PPLA_RAT: L=  52 → ankh_emb_xl.pt
# ✓ PPM1A_HUMAN: L= 382 → ankh_emb_xl.pt
# ✓ PPM1A_MOUSE: L= 382 → ankh_emb_xl.pt
# ✓ PPM1A_RAT: L= 382 → ankh_emb_xl.pt
# ✓ PPM1B_HUMAN: L= 479 → ankh_emb_xl.pt
# ✓ PPM1D_HUMAN: L= 605 → ankh_emb_xl.pt
# ✓ PPM1E_HUMAN: L= 755 → ankh_emb_xl.pt
# ✓ PPM1E_RAT: L= 750 → ankh_emb_xl.pt
# ✓ PPM1F_HUMAN: L= 454 → ankh_emb_xl.pt
# ✓ PPM1F_RAT: L= 450 → ankh_emb_xl.pt
# ✓ PPM1G_HUMAN: L= 546 → ankh_emb_xl.pt
# ✓ PPM1G_MOUSE: L= 542 → ankh_emb_xl.pt
# ✓ PPM1H_HUMAN: L= 514 → ankh_emb_xl.pt
# ✓ PPM1J_MOUSE: L= 507 → ankh_emb_xl.pt
# ✓ PPM1L_MOUSE: L= 360 → ankh_emb_xl.pt
# ✓ PPM1M_MOUSE: L= 406 → ankh_emb_xl.pt
# ✓ PPME1_ARATH: L= 361 → ankh_emb_xl.pt
# ✓ PPME1_HUMAN: L= 386 → ankh_emb_xl.pt
# ✓ PPME1_MOUSE: L= 386 → ankh_emb_xl.pt
# ✓ PPME1_RAT: L= 386 → ankh_emb_xl.pt
# ✓ PPME1_YEAST: L= 400 → ankh_emb_xl.pt
# ✓ PPN1_YEAST: L= 674 → ankh_emb_xl.pt
# ✓ PPNN_ECOLI: L= 454 → ankh_emb_xl.pt
# ✓ PPNP_ECOLI: L=  94 → ankh_emb_xl.pt
# ✓ PPO2_DROME: L= 684 → ankh_emb_xl.pt
# ✓ PPO3_DROME: L= 683 → ankh_emb_xl.pt
# ✓ PPOX1_ARATH: L= 530 → ankh_emb_xl.pt
# ✓ PPOX2_ARATH: L= 198 → ankh_emb_xl.pt
# ✓ PPOX_HUMAN: L= 477 → ankh_emb_xl.pt
# ✓ PPOX_MOUSE: L= 477 → ankh_emb_xl.pt
# ✓ PPOX_YEAST: L= 539 → ankh_emb_xl.pt
# ✓ PPP5_ARATH: L= 538 → ankh_emb_xl.pt
# ✓ PPP5_HUMAN: L= 499 → ankh_emb_xl.pt
# ✓ PPP5_MOUSE: L= 499 → ankh_emb_xl.pt
# ✓ PPP5_RAT: L= 499 → ankh_emb_xl.pt
# ✓ PPP6_HUMAN: L= 305 → ankh_emb_xl.pt
# ✓ PPP6_MOUSE: L= 305 → ankh_emb_xl.pt
# ✓ PPP6_RAT: L= 305 → ankh_emb_xl.pt
# ✓ PPP7_ARATH: L= 413 → ankh_emb_xl.pt
# ✓ PPPA_ECOLI: L= 269 → ankh_emb_xl.pt
# ✓ PPQ1_YEAST: L= 549 → ankh_emb_xl.pt
# ✓ PPR17_MOUSE: L= 159 → ankh_emb_xl.pt
# ✓ PPR1A_HUMAN: L= 171 → ankh_emb_xl.pt
# ✓ PPR1B_HUMAN: L= 204 → ankh_emb_xl.pt
# ✓ PPR1B_MOUSE: L= 194 → ankh_emb_xl.pt
# ✓ PPR1B_RAT: L= 205 → ankh_emb_xl.pt
# ✓ PPR1_YEAST: L= 904 → ankh_emb_xl.pt
# ✓ PPR27_HUMAN: L= 154 → ankh_emb_xl.pt
# ✓ PPR32_ARATH: L= 809 → ankh_emb_xl.pt
# ✓ PPR32_HUMAN: L= 425 → ankh_emb_xl.pt
# ✓ PPR36_ARATH: L= 637 → ankh_emb_xl.pt
# ✓ PPR3B_RAT: L= 284 → ankh_emb_xl.pt
# ✓ PPR3C_HUMAN: L= 317 → ankh_emb_xl.pt
# ✓ PPR3C_MOUSE: L= 317 → ankh_emb_xl.pt
# ✓ PPR3C_RAT: L= 317 → ankh_emb_xl.pt
# ✓ PPR3D_HUMAN: L= 299 → ankh_emb_xl.pt
# ✓ PPR3E_RAT: L= 279 → ankh_emb_xl.pt
# ✓ PPR3F_HUMAN: L= 799 → ankh_emb_xl.pt
# ✓ PPR3_ARATH: L= 524 → ankh_emb_xl.pt
# ✓ PPR42_MOUSE: L= 357 → ankh_emb_xl.pt
# ✓ PPR48_ARATH: L= 970 → ankh_emb_xl.pt
# ✓ PPR68_ARATH: L= 606 → ankh_emb_xl.pt
# ✓ PPR74_ARATH: L= 239 → ankh_emb_xl.pt
# ✓ PPR77_ARATH: L= 819 → ankh_emb_xl.pt
# ✓ PPR85_ARATH: L= 638 → ankh_emb_xl.pt
# ✓ PPR90_ARATH: L= 634 → ankh_emb_xl.pt
# ✓ PPR91_ARATH: L= 630 → ankh_emb_xl.pt
# ✓ PPS1_YEAST: L= 807 → ankh_emb_xl.pt
# ✓ PPSA_ECOLI: L= 792 → ankh_emb_xl.pt
# ✓ PPSP1_ARATH: L= 295 → ankh_emb_xl.pt
# ✓ PPSP2_ARATH: L= 279 → ankh_emb_xl.pt
# ✓ PPSP3_ARATH: L= 245 → ankh_emb_xl.pt
# ✓ PPT1_ARATH: L= 408 → ankh_emb_xl.pt
# ✓ PPT1_DROME: L= 314 → ankh_emb_xl.pt
# ✓ PPT1_HUMAN: L= 306 → ankh_emb_xl.pt
# ✓ PPT1_MOUSE: L= 306 → ankh_emb_xl.pt
# ✓ PPT1_YEAST: L= 513 → ankh_emb_xl.pt
# ✓ PPT2_ARATH: L= 383 → ankh_emb_xl.pt
# ✓ PPT2_DROME: L= 288 → ankh_emb_xl.pt
# ✓ PPT2_HUMAN: L= 302 → ankh_emb_xl.pt
# ✓ PPT2_YEAST: L= 173 → ankh_emb_xl.pt
# ✓ PPTA_ECOLI: L=  77 → ankh_emb_xl.pt
# ✓ PPTC7_HUMAN: L= 304 → ankh_emb_xl.pt
# ✓ PPWD1_HUMAN: L= 646 → ankh_emb_xl.pt
# ✓ PPX1_ARATH: L= 305 → ankh_emb_xl.pt
# ✓ PPX1_YEAST: L= 397 → ankh_emb_xl.pt
# ✓ PPX_ECOLI: L= 513 → ankh_emb_xl.pt
# ✓ PPY_DROME: L= 314 → ankh_emb_xl.pt
# ✓ PPZ1_YEAST: L= 692 → ankh_emb_xl.pt
# ✓ PPZ_SCHPO: L= 515 → ankh_emb_xl.pt
# ✓ PQBP1_HUMAN: L= 265 → ankh_emb_xl.pt
# ✓ PQBP1_RAT: L= 263 → ankh_emb_xl.pt
# ✓ PQIB_ECOLI: L= 546 → ankh_emb_xl.pt
# ✓ PQIC_ECOLI: L= 187 → ankh_emb_xl.pt
# ✓ PQL3_ARATH: L= 187 → ankh_emb_xl.pt
# ✓ PQT3_ARATH: L= 826 → ankh_emb_xl.pt
# ✓ PR15A_HUMAN: L= 674 → ankh_emb_xl.pt
# ✓ PR15A_MOUSE: L= 657 → ankh_emb_xl.pt
# ✓ PR15A_RAT: L= 578 → ankh_emb_xl.pt
# ...
# ✓ Z3H7B_HUMAN: L= 977 → ankh_emb_xl.pt
# ✓ Z600_DROME: L=  90 → ankh_emb_xl.pt
# ✓ ZACN_HUMAN: L= 412 → ankh_emb_xl.pt
# ✓ ZAK1_DICDI: L= 781 → ankh_emb_xl.pt
# ✓ ZAK2_DICDI: L= 635 → ankh_emb_xl.pt
# ✓ ZAP1_YEAST: L= 880 → ankh_emb_xl.pt
# ✓ ZAP70_HUMAN: L= 619 → ankh_emb_xl.pt
# ✓ ZAP70_MOUSE: L= 618 → ankh_emb_xl.pt
# ✓ ZAPA_ECOLI: L= 109 → ankh_emb_xl.pt
# ✓ ZAPB_ECOLI: L=  81 → ankh_emb_xl.pt
# ✓ ZAPC_ECOLI: L= 180 → ankh_emb_xl.pt
# ✓ ZAPD_ECOLI: L= 247 → ankh_emb_xl.pt
# ✓ ZAPE_ECOLI: L= 375 → ankh_emb_xl.pt
# ✓ ZAR1_ARATH: L= 716 → ankh_emb_xl.pt
# ✓ ZAR1_DANRE: L= 329 → ankh_emb_xl.pt
# ✓ ZAS1_SCHPO: L= 897 → ankh_emb_xl.pt
# ✓ ZASP_DROME: L=2194 → ankh_emb_xl.pt
# ✓ ZAT10_ARATH: L= 227 → ankh_emb_xl.pt
# ✓ ZAT6_ARATH: L= 238 → ankh_emb_xl.pt
# ✓ ZBED1_HUMAN: L= 694 → ankh_emb_xl.pt
# ✓ ZBED2_HUMAN: L= 218 → ankh_emb_xl.pt
# ✓ ZBP1_HUMAN: L= 429 → ankh_emb_xl.pt
# ✓ ZBP1_MOUSE: L= 411 → ankh_emb_xl.pt
# ✓ ZBT10_RAT: L= 836 → ankh_emb_xl.pt
# ✓ ZBT12_HUMAN: L= 459 → ankh_emb_xl.pt
# ✓ ZBT14_HUMAN: L= 449 → ankh_emb_xl.pt
# ✓ ZBT14_MOUSE: L= 449 → ankh_emb_xl.pt
# ✓ ZBT16_HUMAN: L= 673 → ankh_emb_xl.pt
# ✓ ZBT17_HUMAN: L= 803 → ankh_emb_xl.pt
# ✓ ZBT17_MOUSE: L= 794 → ankh_emb_xl.pt
# ✓ ZBT18_HUMAN: L= 522 → ankh_emb_xl.pt
# ✓ ZBT20_MOUSE: L= 741 → ankh_emb_xl.pt
# ✓ ZBT21_HUMAN: L=1066 → ankh_emb_xl.pt
# ✓ ZBT22_HUMAN: L= 634 → ankh_emb_xl.pt
# ✓ ZBT25_HUMAN: L= 435 → ankh_emb_xl.pt
# ✓ ZBT26_HUMAN: L= 441 → ankh_emb_xl.pt
# ✓ ZBT32_HUMAN: L= 487 → ankh_emb_xl.pt
# ✓ ZBT32_MOUSE: L= 465 → ankh_emb_xl.pt
# ✓ ZBT37_HUMAN: L= 503 → ankh_emb_xl.pt
# ✓ ZBT38_HUMAN: L=1195 → ankh_emb_xl.pt
# ✓ ZBT38_RAT: L=1203 → ankh_emb_xl.pt
# ✓ ZBT43_HUMAN: L= 467 → ankh_emb_xl.pt
# ✓ ZBT45_HUMAN: L= 511 → ankh_emb_xl.pt
# ✓ ZBT49_HUMAN: L= 765 → ankh_emb_xl.pt
# ✓ ZBT7A_HUMAN: L= 584 → ankh_emb_xl.pt
# ✓ ZBT7A_MOUSE: L= 569 → ankh_emb_xl.pt
# ✓ ZBT7A_RAT: L= 569 → ankh_emb_xl.pt
# ✓ ZBT7B_MOUSE: L= 544 → ankh_emb_xl.pt
# ✓ ZBT8A_HUMAN: L= 441 → ankh_emb_xl.pt
# ✓ ZBTB1_HUMAN: L= 713 → ankh_emb_xl.pt
# ✓ ZBTB1_MOUSE: L= 713 → ankh_emb_xl.pt
# ✓ ZBTB2_HUMAN: L= 514 → ankh_emb_xl.pt
# ✓ ZBTB4_HUMAN: L=1013 → ankh_emb_xl.pt
# ✓ ZBTB5_HUMAN: L= 677 → ankh_emb_xl.pt
# ✓ ZBTB6_HUMAN: L= 424 → ankh_emb_xl.pt
# ✓ ZBTB9_HUMAN: L= 473 → ankh_emb_xl.pt
# ✓ ZC12A_HUMAN: L= 599 → ankh_emb_xl.pt
# ✓ ZC12A_MOUSE: L= 596 → ankh_emb_xl.pt
# ✓ ZC3C1_HUMAN: L= 502 → ankh_emb_xl.pt
# ✓ ZC3H3_MOUSE: L= 950 → ankh_emb_xl.pt
# ✓ ZC3H4_MOUSE: L=1304 → ankh_emb_xl.pt
# ✓ ZC3H8_HUMAN: L= 291 → ankh_emb_xl.pt
# ✓ ZC3H8_MOUSE: L= 305 → ankh_emb_xl.pt
# ✓ ZC3HA_HUMAN: L= 434 → ankh_emb_xl.pt
# ✓ ZCC17_HUMAN: L= 241 → ankh_emb_xl.pt
# ✓ ZCCHV_RAT: L= 776 → ankh_emb_xl.pt
# ✓ ZCH12_MOUSE: L= 402 → ankh_emb_xl.pt
# ✓ ZCHC3_HUMAN: L= 403 → ankh_emb_xl.pt
# ✓ ZCHC4_HUMAN: L= 513 → ankh_emb_xl.pt
# ✓ ZCHC8_HUMAN: L= 707 → ankh_emb_xl.pt
# ✓ ZCIS_ARATH: L= 367 → ankh_emb_xl.pt
# ✓ ZCPW1_HUMAN: L= 648 → ankh_emb_xl.pt
# ✓ ZCPW1_MOUSE: L= 630 → ankh_emb_xl.pt
# ✓ ZCPW2_HUMAN: L= 356 → ankh_emb_xl.pt
# ✓ ZDH11_HUMAN: L= 412 → ankh_emb_xl.pt
# ✓ ZDH11_MOUSE: L= 347 → ankh_emb_xl.pt
# ✓ ZDH12_HUMAN: L= 267 → ankh_emb_xl.pt
# ✓ ZDH12_MOUSE: L= 267 → ankh_emb_xl.pt
# ✓ ZDH13_MOUSE: L= 622 → ankh_emb_xl.pt
# ✓ ZDH14_ARATH: L= 307 → ankh_emb_xl.pt
# ✓ ZDH14_HUMAN: L= 488 → ankh_emb_xl.pt
# ✓ ZDH15_HUMAN: L= 337 → ankh_emb_xl.pt
# ✓ ZDH15_MOUSE: L= 337 → ankh_emb_xl.pt
# ✓ ZDH16_HUMAN: L= 377 → ankh_emb_xl.pt
# ✓ ZDH16_MOUSE: L= 361 → ankh_emb_xl.pt
# ✓ ZDH17_HUMAN: L= 632 → ankh_emb_xl.pt
# ✓ ZDH17_MOUSE: L= 632 → ankh_emb_xl.pt
# ✓ ZDH18_HUMAN: L= 388 → ankh_emb_xl.pt
# ✓ ZDH18_MOUSE: L= 380 → ankh_emb_xl.pt
# ✓ ZDH19_HUMAN: L= 309 → ankh_emb_xl.pt
# ✓ ZDH20_HUMAN: L= 365 → ankh_emb_xl.pt
# ✓ ZDH21_HUMAN: L= 265 → ankh_emb_xl.pt
# ✓ ZDH21_MOUSE: L= 265 → ankh_emb_xl.pt
# ✓ ZDH22_ARATH: L= 620 → ankh_emb_xl.pt
# ✓ ZDHC1_HUMAN: L= 485 → ankh_emb_xl.pt
# ✓ ZDHC1_MOUSE: L= 484 → ankh_emb_xl.pt
# ✓ ZDHC2_HUMAN: L= 367 → ankh_emb_xl.pt
# ✓ ZDHC2_MOUSE: L= 366 → ankh_emb_xl.pt
# ✓ ZDHC3_ARATH: L= 565 → ankh_emb_xl.pt
# ✓ ZDHC3_HUMAN: L= 299 → ankh_emb_xl.pt
# ✓ ZDHC3_MOUSE: L= 299 → ankh_emb_xl.pt
# ✓ ZDHC5_HUMAN: L= 715 → ankh_emb_xl.pt
# ✓ ZDHC5_MOUSE: L= 715 → ankh_emb_xl.pt
# ✓ ZDHC6_HUMAN: L= 413 → ankh_emb_xl.pt
# ✓ ZDHC7_DANRE: L= 299 → ankh_emb_xl.pt
# ✓ ZDHC7_HUMAN: L= 308 → ankh_emb_xl.pt
# ✓ ZDHC7_MOUSE: L= 308 → ankh_emb_xl.pt
# ✓ ZDHC8_HUMAN: L= 765 → ankh_emb_xl.pt
# ✓ ZDHC9_HUMAN: L= 364 → ankh_emb_xl.pt
# ✓ ZDS1_YEAST: L= 915 → ankh_emb_xl.pt
# ✓ ZDS_ARATH: L= 558 → ankh_emb_xl.pt
# ✓ ZEB1_HUMAN: L=1124 → ankh_emb_xl.pt
# ✓ ZEB1_MOUSE: L=1117 → ankh_emb_xl.pt
# ✓ ZEB1_RAT: L=1109 → ankh_emb_xl.pt
# ✓ ZEB2_HUMAN: L=1214 → ankh_emb_xl.pt
# ✓ ZEB2_MOUSE: L=1215 → ankh_emb_xl.pt
# ✓ ZEN1_DROME: L= 353 → ankh_emb_xl.pt
# ✓ ZEP2_HUMAN: L=2446 → ankh_emb_xl.pt
# ✓ ZEP3_MOUSE: L=2348 → ankh_emb_xl.pt
# ✓ ZEP_ARATH: L= 667 → ankh_emb_xl.pt
# ✓ ZEST_DROME: L= 575 → ankh_emb_xl.pt
# ✓ ZFAN1_HUMAN: L= 268 → ankh_emb_xl.pt
# ✓ ZFAN6_MOUSE: L= 223 → ankh_emb_xl.pt
# ✓ ZFAT_MOUSE: L=1237 → ankh_emb_xl.pt
# ✓ ZFH1_DROME: L=1054 → ankh_emb_xl.pt
# ✓ ZFN2B_HUMAN: L= 257 → ankh_emb_xl.pt
# ✓ ZFN2B_MOUSE: L= 257 → ankh_emb_xl.pt
# ✓ ZFP13_MOUSE: L= 512 → ankh_emb_xl.pt
# ✓ ZFP1_HUMAN: L= 407 → ankh_emb_xl.pt
# ✓ ZFP37_MOUSE: L= 594 → ankh_emb_xl.pt
# ✓ ZFP41_HUMAN: L= 198 → ankh_emb_xl.pt
# ✓ ZFP42_MOUSE: L= 288 → ankh_emb_xl.pt
# ✓ ZFP57_HUMAN: L= 452 → ankh_emb_xl.pt
# ✓ ZFP57_MOUSE: L= 421 → ankh_emb_xl.pt
# ✓ ZFP7_ARATH: L= 209 → ankh_emb_xl.pt
# ✓ ZFP90_MOUSE: L= 636 → ankh_emb_xl.pt
# ✓ ZFP91_HUMAN: L= 570 → ankh_emb_xl.pt
# ✓ ZFS1_SCHPO: L= 404 → ankh_emb_xl.pt
# ✓ ZFX_HUMAN: L= 805 → ankh_emb_xl.pt
# ✓ ZFY16_HUMAN: L=1539 → ankh_emb_xl.pt
# ✓ ZFY26_HUMAN: L=2539 → ankh_emb_xl.pt
# ✓ ZFY27_HUMAN: L= 411 → ankh_emb_xl.pt
# ✓ ZFYV1_HUMAN: L= 777 → ankh_emb_xl.pt
# ✓ ZFYV9_HUMAN: L=1425 → ankh_emb_xl.pt
# ✓ ZG16_MOUSE: L= 167 → ankh_emb_xl.pt
# ✓ ZGPAT_HUMAN: L= 531 → ankh_emb_xl.pt
# ✓ ZH15B_DANRE: L= 332 → ankh_emb_xl.pt
# ✓ ZHANG_HUMAN: L= 354 → ankh_emb_xl.pt
# ✓ ZHD10_ARATH: L= 334 → ankh_emb_xl.pt
# ✓ ZHD11_ARATH: L= 242 → ankh_emb_xl.pt
# ✓ ZHD14_ARATH: L= 168 → ankh_emb_xl.pt
# ✓ ZHD2_ARATH: L= 220 → ankh_emb_xl.pt
# ✓ ZHD4_ARATH: L= 312 → ankh_emb_xl.pt
# ✓ ZHD5_ARATH: L= 309 → ankh_emb_xl.pt
# ✓ ZHF1_SCHPO: L= 387 → ankh_emb_xl.pt
# ✓ ZHX1_HUMAN: L= 873 → ankh_emb_xl.pt
# ✓ ZHX1_RAT: L= 873 → ankh_emb_xl.pt
# ✓ ZHX2_HUMAN: L= 837 → ankh_emb_xl.pt
# ✓ ZHX3_HUMAN: L= 956 → ankh_emb_xl.pt
# ✓ ZHX3_RAT: L= 951 → ankh_emb_xl.pt
# ✓ ZIC1_MOUSE: L= 447 → ankh_emb_xl.pt
# ✓ ZIC2_MOUSE: L= 530 → ankh_emb_xl.pt
# ✓ ZIC3_HUMAN: L= 467 → ankh_emb_xl.pt
# ✓ ZIC3_MOUSE: L= 466 → ankh_emb_xl.pt
# ✓ ZIC4_HUMAN: L= 334 → ankh_emb_xl.pt
# ✓ ZIC4_MOUSE: L= 341 → ankh_emb_xl.pt
# ✓ ZIC5_HUMAN: L= 663 → ankh_emb_xl.pt
# ✓ ZIC5_MOUSE: L= 622 → ankh_emb_xl.pt
# ✓ ZIFL1_ARATH: L= 478 → ankh_emb_xl.pt
# ✓ ZIM17_YEAST: L= 174 → ankh_emb_xl.pt
# ✓ ZINT_ECOLI: L= 216 → ankh_emb_xl.pt
# ✓ ZIP1_ARATH: L= 355 → ankh_emb_xl.pt
# ✓ ZIP1_SCHPO: L= 330 → ankh_emb_xl.pt
# ✓ ZIP1_YEAST: L= 875 → ankh_emb_xl.pt
# ✓ ZIP2_YEAST: L= 704 → ankh_emb_xl.pt
# ✓ ZIP3_ARATH: L= 339 → ankh_emb_xl.pt
# ✓ ZITB_ECOLI: L= 313 → ankh_emb_xl.pt
# ✓ ZKSC3_HUMAN: L= 538 → ankh_emb_xl.pt
# ✓ ZKSC4_HUMAN: L= 545 → ankh_emb_xl.pt
# ✓ ZMAT4_HUMAN: L= 229 → ankh_emb_xl.pt
# ✓ ZMIZ1_HUMAN: L=1067 → ankh_emb_xl.pt
# ✓ ZMIZ2_HUMAN: L= 920 → ankh_emb_xl.pt
# ✓ ZMY10_MOUSE: L= 440 → ankh_emb_xl.pt
# ✓ ZMY11_HUMAN: L= 602 → ankh_emb_xl.pt
# ✓ ZMY11_MOUSE: L= 602 → ankh_emb_xl.pt
# ✓ ZMY15_MOUSE: L= 736 → ankh_emb_xl.pt
# ✓ ZMYM2_HUMAN: L=1377 → ankh_emb_xl.pt
# ✓ ZMYM3_HUMAN: L=1370 → ankh_emb_xl.pt
# ✓ ZMYM4_HUMAN: L=1548 → ankh_emb_xl.pt
# ✓ ZMYM5_HUMAN: L= 669 → ankh_emb_xl.pt
# ✓ ZMYM6_HUMAN: L=1325 → ankh_emb_xl.pt
# ✓ ZN106_MOUSE: L=1888 → ankh_emb_xl.pt
# ✓ ZN114_HUMAN: L= 417 → ankh_emb_xl.pt
# ✓ ZN124_HUMAN: L= 351 → ankh_emb_xl.pt
# ✓ ZN131_MOUSE: L= 619 → ankh_emb_xl.pt
# ✓ ZN133_HUMAN: L= 654 → ankh_emb_xl.pt
# ✓ ZN136_HUMAN: L= 540 → ankh_emb_xl.pt
# ✓ ZN140_HUMAN: L= 457 → ankh_emb_xl.pt
# ✓ ZN143_HUMAN: L= 638 → ankh_emb_xl.pt
# ✓ ZN143_MOUSE: L= 638 → ankh_emb_xl.pt
# ✓ ZN143_RAT: L= 638 → ankh_emb_xl.pt
# ✓ ZN148_HUMAN: L= 794 → ankh_emb_xl.pt
# ✓ ZN148_MOUSE: L= 794 → ankh_emb_xl.pt
# ✓ ZN148_RAT: L= 794 → ankh_emb_xl.pt
# ✓ ZN174_HUMAN: L= 407 → ankh_emb_xl.pt
# ✓ ZN175_HUMAN: L= 711 → ankh_emb_xl.pt
# ✓ ZN185_HUMAN: L= 689 → ankh_emb_xl.pt
# ✓ ZN202_HUMAN: L= 648 → ankh_emb_xl.pt
# ✓ ZN207_HUMAN: L= 478 → ankh_emb_xl.pt
# ✓ ZN207_MOUSE: L= 495 → ankh_emb_xl.pt
# ✓ ZN207_XENLA: L= 452 → ankh_emb_xl.pt
# ✓ ZN212_HUMAN: L= 495 → ankh_emb_xl.pt
# ✓ ZN217_HUMAN: L=1048 → ankh_emb_xl.pt
# ✓ ZN219_DANRE: L=1095 → ankh_emb_xl.pt
# ✓ ZN219_HUMAN: L= 722 → ankh_emb_xl.pt
# ✓ ZN224_HUMAN: L= 707 → ankh_emb_xl.pt
# ✓ ZN239_HUMAN: L= 458 → ankh_emb_xl.pt
# ✓ ZN250_HUMAN: L= 560 → ankh_emb_xl.pt
# ✓ ZN263_HUMAN: L= 683 → ankh_emb_xl.pt
# ✓ ZN274_HUMAN: L= 653 → ankh_emb_xl.pt
# ✓ ZN277_DROME: L= 452 → ankh_emb_xl.pt
# ✓ ZN277_MOUSE: L= 583 → ankh_emb_xl.pt
# ✓ ZN281_HUMAN: L= 895 → ankh_emb_xl.pt
# ✓ ZN281_MOUSE: L= 893 → ankh_emb_xl.pt
# ✓ ZN296_HUMAN: L= 475 → ankh_emb_xl.pt
# ✓ ZN296_MOUSE: L= 445 → ankh_emb_xl.pt
# ✓ ZN300_HUMAN: L= 604 → ankh_emb_xl.pt
# ✓ ZN304_HUMAN: L= 659 → ankh_emb_xl.pt
# ✓ ZN318_MOUSE: L=2237 → ankh_emb_xl.pt
# ✓ ZN322_MOUSE: L= 410 → ankh_emb_xl.pt
# ✓ ZN326_HUMAN: L= 582 → ankh_emb_xl.pt
# ✓ ZN326_MOUSE: L= 580 → ankh_emb_xl.pt
# ✓ ZN335_MOUSE: L=1337 → ankh_emb_xl.pt
# ✓ ZN341_HUMAN: L= 854 → ankh_emb_xl.pt
# ✓ ZN343_HUMAN: L= 599 → ankh_emb_xl.pt
# ✓ ZN346_HUMAN: L= 294 → ankh_emb_xl.pt
# ✓ ZN346_MOUSE: L= 294 → ankh_emb_xl.pt
# ✓ ZN346_XENLA: L= 524 → ankh_emb_xl.pt
# ✓ ZN350_HUMAN: L= 532 → ankh_emb_xl.pt
# ✓ ZN363_HUMAN: L= 261 → ankh_emb_xl.pt
# ✓ ZN365_HUMAN: L= 407 → ankh_emb_xl.pt
# ✓ ZN366_HUMAN: L= 744 → ankh_emb_xl.pt
# ✓ ZN367_HUMAN: L= 350 → ankh_emb_xl.pt
# ✓ ZN382_RAT: L= 549 → ankh_emb_xl.pt
# ✓ ZN384_HUMAN: L= 577 → ankh_emb_xl.pt
# ✓ ZN384_RAT: L= 579 → ankh_emb_xl.pt
# ✓ ZN395_HUMAN: L= 513 → ankh_emb_xl.pt
# ✓ ZN396_HUMAN: L= 335 → ankh_emb_xl.pt
# ✓ ZN397_HUMAN: L= 534 → ankh_emb_xl.pt
# ✓ ZN408_HUMAN: L= 720 → ankh_emb_xl.pt
# ✓ ZN410_HUMAN: L= 478 → ankh_emb_xl.pt
# ✓ ZN423_RAT: L=1311 → ankh_emb_xl.pt
# ✓ ZN431_MOUSE: L= 526 → ankh_emb_xl.pt
# ✓ ZN438_HUMAN: L= 828 → ankh_emb_xl.pt
# ✓ ZN444_HUMAN: L= 327 → ankh_emb_xl.pt
# ✓ ZN445_HUMAN: L=1031 → ankh_emb_xl.pt
# ✓ ZN445_MOUSE: L= 986 → ankh_emb_xl.pt
# ✓ ZN446_HUMAN: L= 450 → ankh_emb_xl.pt
# ✓ ZN449_HUMAN: L= 518 → ankh_emb_xl.pt
# ✓ ZN451_HUMAN: L=1061 → ankh_emb_xl.pt
# ✓ ZN454_HUMAN: L= 522 → ankh_emb_xl.pt
# ✓ ZN460_HUMAN: L= 562 → ankh_emb_xl.pt
# ✓ ZN467_MOUSE: L= 594 → ankh_emb_xl.pt
# ✓ ZN496_MOUSE: L= 585 → ankh_emb_xl.pt
# ✓ ZN513_HUMAN: L= 541 → ankh_emb_xl.pt
# ✓ ZN513_MOUSE: L= 541 → ankh_emb_xl.pt
# ✓ ZN516_MOUSE: L=1157 → ankh_emb_xl.pt
# ✓ ZN521_HUMAN: L=1311 → ankh_emb_xl.pt
# ✓ ZN524_HUMAN: L= 264 → ankh_emb_xl.pt
# ✓ ZN536_HUMAN: L=1300 → ankh_emb_xl.pt
# ✓ ZN536_MOUSE: L=1302 → ankh_emb_xl.pt
# ✓ ZN540_HUMAN: L= 660 → ankh_emb_xl.pt
# ✓ ZN568_MOUSE: L= 671 → ankh_emb_xl.pt
# ✓ ZN579_HUMAN: L= 562 → ankh_emb_xl.pt
# ✓ ZN589_HUMAN: L= 364 → ankh_emb_xl.pt
# ✓ ZN592_MOUSE: L=1262 → ankh_emb_xl.pt
# ✓ ZN593_HUMAN: L= 134 → ankh_emb_xl.pt
# ✓ ZN597_HUMAN: L= 424 → ankh_emb_xl.pt
# ✓ ZN598_HUMAN: L= 904 → ankh_emb_xl.pt
# ✓ ZN609_MOUSE: L=1413 → ankh_emb_xl.pt
# ✓ ZN618_HUMAN: L= 954 → ankh_emb_xl.pt
# ✓ ZN628_MOUSE: L=1038 → ankh_emb_xl.pt
# ✓ ZN638_HUMAN: L=1978 → ankh_emb_xl.pt
# ✓ ZN639_HUMAN: L= 485 → ankh_emb_xl.pt
# ✓ ZN644_HUMAN: L=1327 → ankh_emb_xl.pt
# ✓ ZN653_HUMAN: L= 615 → ankh_emb_xl.pt
# ✓ ZN658_HUMAN: L=1059 → ankh_emb_xl.pt
# ✓ ZN660_HUMAN: L= 331 → ankh_emb_xl.pt
# ✓ ZN668_MOUSE: L= 619 → ankh_emb_xl.pt
# ✓ ZN675_HUMAN: L= 568 → ankh_emb_xl.pt
# ✓ ZN683_HUMAN: L= 524 → ankh_emb_xl.pt
# ✓ ZN683_MOUSE: L= 458 → ankh_emb_xl.pt
# ✓ ZN684_HUMAN: L= 378 → ankh_emb_xl.pt
# ✓ ZN692_HUMAN: L= 519 → ankh_emb_xl.pt
# ✓ ZN703_DANRE: L= 589 → ankh_emb_xl.pt
# ✓ ZN703_MOUSE: L= 594 → ankh_emb_xl.pt
# ✓ ZN704_HUMAN: L= 412 → ankh_emb_xl.pt
# ✓ ZN704_MOUSE: L= 566 → ankh_emb_xl.pt
# ✓ ZN711_HUMAN: L= 761 → ankh_emb_xl.pt
# ✓ ZN713_HUMAN: L= 443 → ankh_emb_xl.pt
# ✓ ZN740_HUMAN: L= 193 → ankh_emb_xl.pt
# ✓ ZN746_HUMAN: L= 644 → ankh_emb_xl.pt
# ✓ ZN746_MOUSE: L= 652 → ankh_emb_xl.pt
# ✓ ZN750_HUMAN: L= 723 → ankh_emb_xl.pt
# ✓ ZN75A_HUMAN: L= 296 → ankh_emb_xl.pt
# ✓ ZN783_HUMAN: L= 281 → ankh_emb_xl.pt
# ✓ ZN784_HUMAN: L= 323 → ankh_emb_xl.pt
# ✓ ZN787_HUMAN: L= 382 → ankh_emb_xl.pt
# ✓ ZN792_HUMAN: L= 632 → ankh_emb_xl.pt
# ✓ ZN809_MOUSE: L= 402 → ankh_emb_xl.pt
# ✓ ZN821_HUMAN: L= 412 → ankh_emb_xl.pt
# ✓ ZN827_HUMAN: L=1081 → ankh_emb_xl.pt
# ✓ ZN837_HUMAN: L= 531 → ankh_emb_xl.pt
# ✓ ZNF1_YEAST: L= 465 → ankh_emb_xl.pt
# ✓ ZNF22_HUMAN: L= 224 → ankh_emb_xl.pt
# ✓ ZNF22_MOUSE: L= 237 → ankh_emb_xl.pt
# ✓ ZNF23_HUMAN: L= 643 → ankh_emb_xl.pt
# ✓ ZNF24_HUMAN: L= 368 → ankh_emb_xl.pt
# ✓ ZNF24_MOUSE: L= 368 → ankh_emb_xl.pt
# ✓ ZNF32_HUMAN: L= 273 → ankh_emb_xl.pt
# ✓ ZNF35_HUMAN: L= 527 → ankh_emb_xl.pt
# ✓ ZNF3_HUMAN: L= 446 → ankh_emb_xl.pt
# ✓ ZNF43_HUMAN: L= 809 → ankh_emb_xl.pt
# ✓ ZNF48_HUMAN: L= 618 → ankh_emb_xl.pt
# ✓ ZNF69_HUMAN: L= 566 → ankh_emb_xl.pt
# ✓ ZNF76_HUMAN: L= 570 → ankh_emb_xl.pt
# ✓ ZNF7_HUMAN: L= 686 → ankh_emb_xl.pt
# ✓ ZNF85_HUMAN: L= 595 → ankh_emb_xl.pt
# ✓ ZNF91_HUMAN: L=1191 → ankh_emb_xl.pt
# ✓ ZNF93_HUMAN: L= 620 → ankh_emb_xl.pt
# ✓ ZNFX1_MOUSE: L=1909 → ankh_emb_xl.pt
# ✓ ZNG1_DANRE: L= 366 → ankh_emb_xl.pt
# ✓ ZNG1_MOUSE: L= 393 → ankh_emb_xl.pt
# ✓ ZNG1_YEAST: L= 429 → ankh_emb_xl.pt
# ✓ ZNHI1_MOUSE: L= 154 → ankh_emb_xl.pt
# ✓ ZNHI3_HUMAN: L= 155 → ankh_emb_xl.pt
# ✓ ZNRD2_MOUSE: L= 199 → ankh_emb_xl.pt
# ✓ ZNRF1_HUMAN: L= 227 → ankh_emb_xl.pt
# ✓ ZNRF1_MOUSE: L= 227 → ankh_emb_xl.pt
# ✓ ZNRF2_HUMAN: L= 242 → ankh_emb_xl.pt
# ✓ ZNRF3_HUMAN: L= 936 → ankh_emb_xl.pt
# ✓ ZNT10_HUMAN: L= 485 → ankh_emb_xl.pt
# ✓ ZNT1_MOUSE: L= 503 → ankh_emb_xl.pt
# ✓ ZNT1_RAT: L= 507 → ankh_emb_xl.pt
# ✓ ZNT2_HUMAN: L= 323 → ankh_emb_xl.pt
# ✓ ZNT2_RAT: L= 359 → ankh_emb_xl.pt
# ✓ ZNT3_HUMAN: L= 388 → ankh_emb_xl.pt
# ✓ ZNT4_RAT: L= 430 → ankh_emb_xl.pt
# ✓ ZNT5_HUMAN: L= 765 → ankh_emb_xl.pt
# ✓ ZNT6_HUMAN: L= 461 → ankh_emb_xl.pt
# ✓ ZNT6_MOUSE: L= 460 → ankh_emb_xl.pt
# ✓ ZNT7_MOUSE: L= 378 → ankh_emb_xl.pt
# ✓ ZNT8_HUMAN: L= 369 → ankh_emb_xl.pt
# ✓ ZNT8_MOUSE: L= 367 → ankh_emb_xl.pt
# ✓ ZNT9_MOUSE: L= 567 → ankh_emb_xl.pt
# ✓ ZNTA_ECOLI: L= 732 → ankh_emb_xl.pt
# ✓ ZNTB_ECOLI: L= 327 → ankh_emb_xl.pt
# ✓ ZNTB_SALTY: L= 327 → ankh_emb_xl.pt
# ✓ ZNTR_ECOLI: L= 141 → ankh_emb_xl.pt
# ✓ ZNUA_ECOLI: L= 310 → ankh_emb_xl.pt
# ✓ ZNUB_ECOLI: L= 261 → ankh_emb_xl.pt
# ✓ ZO1_MOUSE: L=1745 → ankh_emb_xl.pt
# ✓ ZO1_RAT: L=1765 → ankh_emb_xl.pt
# ✓ ZO2_HUMAN: L=1190 → ankh_emb_xl.pt
# ✓ ZOP1_ARATH: L= 242 → ankh_emb_xl.pt
# ✓ ZP2_HUMAN: L= 745 → ankh_emb_xl.pt
# ✓ ZP3_HUMAN: L= 424 → ankh_emb_xl.pt
# ✓ ZP3_MOUSE: L= 424 → ankh_emb_xl.pt
# ✓ ZP4_HUMAN: L= 540 → ankh_emb_xl.pt
# ✓ ZPR1_HUMAN: L= 459 → ankh_emb_xl.pt
# ✓ ZPR1_MOUSE: L= 459 → ankh_emb_xl.pt
# ✓ ZPR1_YEAST: L= 486 → ankh_emb_xl.pt
# ✓ ZRAB2_HUMAN: L= 330 → ankh_emb_xl.pt
# ✓ ZRAB3_HUMAN: L=1079 → ankh_emb_xl.pt
# ✓ ZRAN1_HUMAN: L= 708 → ankh_emb_xl.pt
# ✓ ZRAP_ECOLI: L= 141 → ankh_emb_xl.pt
# ✓ ZRAP_SALTY: L= 151 → ankh_emb_xl.pt
# ✓ ZRAR_ECOLI: L= 441 → ankh_emb_xl.pt
# ✓ ZRAS_ECOLI: L= 465 → ankh_emb_xl.pt
# ✓ ZRC1_YEAST: L= 442 → ankh_emb_xl.pt
# ✓ ZRG17_SCHPO: L= 386 → ankh_emb_xl.pt
# ✓ ZRG17_YEAST: L= 605 → ankh_emb_xl.pt
# ✓ ZRT1_SCHPO: L= 408 → ankh_emb_xl.pt
# ✓ ZRT1_YEAST: L= 376 → ankh_emb_xl.pt
# ✓ ZRT2_YEAST: L= 422 → ankh_emb_xl.pt
# ✓ ZRT3_YEAST: L= 503 → ankh_emb_xl.pt
# ✓ ZSA5A_HUMAN: L= 496 → ankh_emb_xl.pt
# ✓ ZSC10_MOUSE: L= 782 → ankh_emb_xl.pt
# ✓ ZSC16_HUMAN: L= 348 → ankh_emb_xl.pt
# ✓ ZSC21_HUMAN: L= 473 → ankh_emb_xl.pt
# ✓ ZSC21_MOUSE: L= 555 → ankh_emb_xl.pt
# ✓ ZSC23_HUMAN: L= 389 → ankh_emb_xl.pt
# ✓ ZSC29_HUMAN: L= 852 → ankh_emb_xl.pt
# ✓ ZSC31_HUMAN: L= 406 → ankh_emb_xl.pt
# ✓ ZSC32_HUMAN: L= 697 → ankh_emb_xl.pt
# ✓ ZSC9_HUMAN: L= 394 → ankh_emb_xl.pt
# ✓ ZSCA1_HUMAN: L= 408 → ankh_emb_xl.pt
# ✓ ZSCA4_HUMAN: L= 433 → ankh_emb_xl.pt
# ✓ ZSWM2_MOUSE: L= 631 → ankh_emb_xl.pt
# ✓ ZSWM8_HUMAN: L=1837 → ankh_emb_xl.pt
# ✓ ZUC_DROME: L= 253 → ankh_emb_xl.pt
# ✓ ZUO1_YEAST: L= 433 → ankh_emb_xl.pt
# ✓ ZUPT_ECOLI: L= 257 → ankh_emb_xl.pt
# ✓ ZUR_BACSU: L= 145 → ankh_emb_xl.pt
# ✓ ZUR_ECOLI: L= 171 → ankh_emb_xl.pt
# ✓ ZW10_DROME: L= 721 → ankh_emb_xl.pt
# ✓ ZW10_HUMAN: L= 779 → ankh_emb_xl.pt
# ✓ ZWINT_HUMAN: L= 277 → ankh_emb_xl.pt
# ✓ ZXDA_HUMAN: L= 799 → ankh_emb_xl.pt
# ✓ ZXDC_HUMAN: L= 858 → ankh_emb_xl.pt
# ✓ ZYM1_SCHPO: L=  50 → ankh_emb_xl.pt
# ✓ ZYX_XENLA: L= 663 → ankh_emb_xl.pt
#
# Done. created=11725 | existing_skipped=20821 | missing_seq_skipped=0

# %%
"""
Generate ProteinGLM per-residue embeddings for PIDs that appear under the
CAFA_Style <split>/mf/* directories, *reading sequences from*
CAFA_Style/sequences/<PID>/seq.txt and *writing*
CAFA_Style/sequences/<PID>/pglm_emb.pt.

This preserves your original per-residue embedding layout and only changes how we
handle long sequences: if L > WINDOW_EFF, we use sliding windows with overlap
and **context-trim** stitching (no weighting). For long sequences, indices 1..L
contain per-residue embeddings; indices 0 and L+1 are zero.

Layout expected:
    /teamspace/studios/this_studio/CAFA_Style/
      ├─ train/mf/<PID>/
      ├─ val/mf/<PID>/
      ├─ test/mf/<PID>/
      └─ sequences/<PID>/seq.txt   # created by your flat builder

Output per PID:
    sequences/<PID>/pglm_emb.pt  # torch.Tensor, shape (1, L+2, 2560)

Run:
    python embed_pglm_cafa_style.py

Notes:
- Skips PIDs whose embeddings already exist.
- Skips PIDs with missing/empty sequences, with a warning.
- Uses GPU if available.
"""
from __future__ import annotations

from pathlib import Path
from typing import Iterable, Set, List, Tuple

import torch
from tqdm.auto import tqdm
from transformers import AutoTokenizer, AutoModelForMaskedLM

# ─────────────────────────────── config ─────────────────────────────── #
BASE          = Path("/teamspace/studios/this_studio/CAFA_Style")
ONTOLOGY      = "mf"                       # only embed PIDs that appear under this ontology
SPLITS        = ["train", "val", "test"]
SEQS_DIR      = BASE / "sequences"        # source of seq.txt and target for outputs

MODEL_ID      = "biomap-research/proteinglm-3b-mlm"   # HF repo id
OUT_FILENAME  = "pglm_emb.pt"                         # per-protein output
DTYPE_SAVE    = torch.float32
DEVICE        = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ProteinGLM specifics (as requested)
DIM              = 2560
MAX_LEN_TOKENS   = 2048      # model token limit incl. specials
N_SPECIALS_WIN   = 1         # assume only <eos> is added; set to 2 if BOS is present
WINDOW_EFF       = MAX_LEN_TOKENS - N_SPECIALS_WIN  # residues per window
OVERLAP          = 256        # residues overlap between windows
# ────────────────────────────────────────────────────────────────────── #


def gather_pids_from_mf(base: Path, splits: Iterable[str]) -> Set[str]:
    """Union of subfolder names under <base>/<split>/mf/* for all splits."""
    pids: Set[str] = set()
    for split in splits:
        root = base / split / ONTOLOGY
        if not root.exists():
            tqdm.write(f"[WARN] Missing folder: {root} — skipping this split")
            continue
        for item in root.iterdir():
            if item.is_dir():
                pids.add(item.name)
    return pids


def read_sequence(seqs_dir: Path, pid: str) -> str:
    """Read FASTA-like or plain sequence, strip headers/whitespace, uppercase."""
    seq_path = seqs_dir / pid / "seq.txt"
    if not seq_path.exists():
        return ""
    seq_parts = []
    with seq_path.open("r", encoding="utf-8") as fh:
        for line in fh:
            if line.startswith(">"):
                continue
            seq_parts.append(line.strip())
    return ("".join(seq_parts)).upper().replace(" ", "")


def _plan_windows(L: int) -> List[Tuple[int, int]]:
    """Return inclusive-exclusive windows [(s,e), ...] covering [0, L) with overlap."""
    if L <= WINDOW_EFF:
        return [(0, L)]
    stride = max(1, WINDOW_EFF - OVERLAP)
    windows: List[Tuple[int, int]] = []
    s = 0
    while s < L:
        e = min(s + WINDOW_EFF, L)
        windows.append((s, e))
        if e == L:
            break
        s += stride
    return windows


@torch.inference_mode()
def _embed_window_pglm(model: AutoModelForMaskedLM, tok: AutoTokenizer, subseq: str) -> torch.Tensor:
    """
    Embed a *subsequence* with ProteinGLM, returning per-residue embeddings [Li, DIM].
    Uses exact logic from the original embedding function.
    """
    # Tokenize with special tokens (adds <eos>)
    out = tok(subseq, add_special_tokens=True, return_tensors='pt')
    inputs = {
        "input_ids": out["input_ids"].to(model.device),
        "attention_mask": out["attention_mask"].to(model.device),
    }

    # Model forward per Hugging Face usage; drop trailing <eos> token embeddings
    out_m = model(**inputs, output_hidden_states=True, return_last_hidden_state=True)
    token_emb = out_m.hidden_states[:-1, 0]  # per docs: remove <eos>, take batch=0 → [Li, d]

    if token_emb.size(0) != len(subseq):
        raise RuntimeError(
            f"[ProteinGLM] Token/AA mismatch in window: tokens_no_specials={token_emb.size(0)} vs Li={len(subseq)}"
        )
    return token_emb.to(DTYPE_SAVE)


@torch.inference_mode()
def _embed_full_pglm(model: AutoModelForMaskedLM, tok: AutoTokenizer, seq: str) -> torch.Tensor:
    """
    Full-sequence per-residue embeddings packed to (1, L+2, DIM) with zeros at [0] and [L+1].
    Uses exact logic from the original embedding function.
    """
    L = len(seq)

    # Tokenize with special tokens (adds <eos>)
    out = tok(seq, add_special_tokens=True, return_tensors='pt')
    inputs = {
        "input_ids": out["input_ids"].to(model.device),
        "attention_mask": out["attention_mask"].to(model.device),
    }

    # Model forward per Hugging Face usage; drop trailing <eos> token embeddings
    out_m = model(**inputs, output_hidden_states=True, return_last_hidden_state=True)
    token_emb = out_m.hidden_states[:-1, 0]  # per docs: remove <eos>, take batch=0 → [L, d]

    if token_emb.size(0) != L:
        raise RuntimeError(f"[ProteinGLM] Full pass token/AA mismatch: got {token_emb.size(0)} vs L={L}")

    # Pack to (1, L+2, d); zero at positions 0 and L+1; move to CPU float32 for saving
    token_emb = token_emb.to(DTYPE_SAVE).cpu()  # [L, d]
    d = token_emb.size(-1)
    emb = torch.zeros(1, L + 2, d, dtype=DTYPE_SAVE, device="cpu")
    emb[0, 1:L+1] = token_emb
    return emb


@torch.inference_mode()
def embed_pglm_stitched(model: AutoModelForMaskedLM, tok: AutoTokenizer, seq: str) -> torch.Tensor:
    """
    Return ProteinGLM embeddings as (1, L+2, DIM).

    - Short sequences (L <= WINDOW_EFF): single pass; zeros at [0] and [L+1].
    - Long sequences: sliding windows + context-trim stitching for residues;
      pack to (1, L+2, DIM) with zeros at [0] and [L+1].
    """
    L = len(seq)
    if L == 0:
        raise ValueError("Empty sequence.")

    # Fast path
    if L <= WINDOW_EFF:
        return _embed_full_pglm(model, tok, seq)

    # Sliding-window path
    windows = _plan_windows(L)
    E = torch.empty(L, DIM, dtype=DTYPE_SAVE, device="cpu")

    for (s, e) in windows:
        subseq = seq[s:e]
        Li = e - s
        if Li > WINDOW_EFF:
            raise RuntimeError(f"Internal window larger than WINDOW_EFF: Li={Li} > {WINDOW_EFF}")

        R = _embed_window_pglm(model, tok, subseq).detach().cpu()  # (Li, DIM)

        # Context-trim stitching (identical pattern to your ProtT5 script)
        left_trim  = 0 if s == 0 else OVERLAP // 2
        right_trim = 0 if e == L else (OVERLAP - OVERLAP // 2)

        gs = s + left_trim           # global start (inclusive)
        ge = e - right_trim          # global end   (exclusive)
        ls = left_trim               # local  start
        le = Li - right_trim         # local  end

        if ge <= gs:
            raise RuntimeError(f"Empty keep range for window {(s, e)}")
        if (le - ls) != (ge - gs):
            raise RuntimeError("Keep lengths disagree during trim-stitch.")

        E[gs:ge] = R[ls:le]

    # Pack to (1, L+2, DIM) with zeros at [0] and [L+1]
    emb = torch.zeros(1, L + 2, DIM, dtype=DTYPE_SAVE, device="cpu")
    emb[0, 1:L+1] = E
    return emb


# ─────────────────────────────────── main ───────────────────────────── #

def main() -> None:
    if not BASE.exists():
        raise FileNotFoundError(f"CAFA_Style base not found: {BASE}")
    SEQS_DIR.mkdir(parents=True, exist_ok=True)

    pids = sorted(gather_pids_from_mf(BASE, SPLITS))
    if not pids:
        print("No PIDs found under <split>/mf — nothing to do.")
        return

    print(f"Found {len(pids)} unique PIDs under mf across {SPLITS}\n")
    print(f"⇢ Loading {MODEL_ID} onto {DEVICE} …")

    tok = AutoTokenizer.from_pretrained(MODEL_ID)
    model = AutoModelForMaskedLM.from_pretrained(MODEL_ID).to(DEVICE).eval()

    made, skipped_exist, skipped_empty = 0, 0, 0
    for pid in tqdm(pids, desc="Embedding (ProteinGLM, sliding-aware)"):
        out_path = SEQS_DIR / pid / OUT_FILENAME
        if out_path.exists():
            skipped_exist += 1
            continue

        seq = read_sequence(SEQS_DIR, pid)
        if not seq:
            tqdm.write(f"[WARN] {pid}: missing/empty seq.txt in sequences — skipping")
            skipped_empty += 1
            continue

        emb = embed_pglm_stitched(model, tok, seq)  # (1, L+2, 2560)
        out_path.parent.mkdir(parents=True, exist_ok=True)
        torch.save(emb, out_path)
        made += 1
        tqdm.write(f"✓ {pid}: L={len(seq):4d} → {OUT_FILENAME}")

    print(
        f"\nDone. created={made} | existing_skipped={skipped_exist} | missing_seq_skipped={skipped_empty}"
    )


if __name__ == "__main__":
    main()
# Out:
# Found 32546 unique PIDs under mf across ['train', 'val', 'test']
#
# ⇢ Loading biomap-research/proteinglm-3b-mlm onto cuda …
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Embedding (ProteinGLM, sliding-aware):   0%|          | 0/32546 [00:00<?, ?it/s]
# ✓ 7LESS_DROME: L=2554 → pglm_emb.pt
# ✓ A1M_RAT: L=1500 → pglm_emb.pt
# ✓ A2MG_ECOLI: L=1653 → pglm_emb.pt
# ✓ A2MG_HUMAN: L=1474 → pglm_emb.pt
# ✓ A2MG_MOUSE: L=1474 → pglm_emb.pt
# ✓ A2MG_RAT: L=1472 → pglm_emb.pt
# ✓ A2ML1_HUMAN: L=1454 → pglm_emb.pt
# ✓ AB19B_ARATH: L=1252 → pglm_emb.pt
# ✓ AB1B_ARATH: L=1286 → pglm_emb.pt
# ✓ AB1C_ARATH: L=1622 → pglm_emb.pt
# ✓ AB21B_ARATH: L=1296 → pglm_emb.pt
# ✓ AB2C_ARATH: L=1623 → pglm_emb.pt
# ✓ AB30G_ARATH: L=1400 → pglm_emb.pt
# ✓ AB31G_ARATH: L=1426 → pglm_emb.pt
# ✓ AB36G_ARATH: L=1469 → pglm_emb.pt
# ✓ AB37G_ARATH: L=1450 → pglm_emb.pt
# ✓ AB3C_ARATH: L=1514 → pglm_emb.pt
# ✓ AB40G_ARATH: L=1423 → pglm_emb.pt
# ✓ AB4B_ARATH: L=1286 → pglm_emb.pt
# ✓ AB5C_ARATH: L=1514 → pglm_emb.pt
# ✓ ABC2_SCHPO: L=1478 → pglm_emb.pt
# ✓ ABC3_SCHPO: L=1465 → pglm_emb.pt
# ✓ ABCA1_HUMAN: L=2261 → pglm_emb.pt
# ✓ ABCA1_MOUSE: L=2261 → pglm_emb.pt
# ✓ ABCA2_HUMAN: L=2435 → pglm_emb.pt
# ✓ ABCA2_RAT: L=2434 → pglm_emb.pt
# ✓ ABCA4_HUMAN: L=2273 → pglm_emb.pt
# ✓ ABCA4_MOUSE: L=2310 → pglm_emb.pt
# ✓ ABCA7_HUMAN: L=2146 → pglm_emb.pt
# ✓ ABCA7_MOUSE: L=2159 → pglm_emb.pt
# ✓ ABCA8_HUMAN: L=1581 → pglm_emb.pt
# ✓ ABCAC_HUMAN: L=2595 → pglm_emb.pt
# ✓ ABCB5_HUMAN: L=1257 → pglm_emb.pt
# ✓ ABCBB_HUMAN: L=1321 → pglm_emb.pt
# ✓ ABCBB_MOUSE: L=1321 → pglm_emb.pt
# ✓ ABCBB_RAT: L=1321 → pglm_emb.pt
# ✓ ABCC8_HUMAN: L=1581 → pglm_emb.pt
# ✓ ABCC9_HUMAN: L=1549 → pglm_emb.pt
# ✓ ABCC9_RAT: L=1545 → pglm_emb.pt
# ✓ ABCCB_HUMAN: L=1382 → pglm_emb.pt
# ✓ ABL1_HUMAN: L=1130 → pglm_emb.pt
# ✓ ABL1_MOUSE: L=1123 → pglm_emb.pt
# ✓ ABL2_HUMAN: L=1182 → pglm_emb.pt
# ✓ ABL2_MOUSE: L=1182 → pglm_emb.pt
# ✓ ABL_DROME: L=1620 → pglm_emb.pt
# ✓ AC78C_DROME: L=1718 → pglm_emb.pt
# ✓ ACA4_ARATH: L=1030 → pglm_emb.pt
# ✓ ACA8_ARATH: L=1074 → pglm_emb.pt
# ✓ ACA9_ARATH: L=1086 → pglm_emb.pt
# ✓ ACACA_HUMAN: L=2346 → pglm_emb.pt
# ✓ ACACA_MOUSE: L=2345 → pglm_emb.pt
# ✓ ACACA_RAT: L=2345 → pglm_emb.pt
# ✓ ACACB_HUMAN: L=2458 → pglm_emb.pt
# ✓ ACACB_MOUSE: L=2448 → pglm_emb.pt
# ✓ ACAC_YEAST: L=2233 → pglm_emb.pt
# ✓ ACC2_ARATH: L=2355 → pglm_emb.pt
# ✓ ACD10_HUMAN: L=1059 → pglm_emb.pt
# ✓ ACE_HUMAN: L=1306 → pglm_emb.pt
# ✓ ACE_MOUSE: L=1312 → pglm_emb.pt
# ✓ ACE_RAT: L=1313 → pglm_emb.pt
# ✓ ACK1_HUMAN: L=1038 → pglm_emb.pt
# ✓ ACK1_MOUSE: L=1055 → pglm_emb.pt
# ✓ ACK1_RAT: L=1040 → pglm_emb.pt
# ✓ ACK_DROME: L=1073 → pglm_emb.pt
# ✓ ACLY_HUMAN: L=1101 → pglm_emb.pt
# ✓ ACLY_MOUSE: L=1091 → pglm_emb.pt
# ✓ ACLY_RAT: L=1100 → pglm_emb.pt
# ✓ ACRB_ECOLI: L=1049 → pglm_emb.pt
# ✓ ACRD_ECOLI: L=1037 → pglm_emb.pt
# ✓ ADCY1_MOUSE: L=1118 → pglm_emb.pt
# ✓ ADCY2_DROME: L=1307 → pglm_emb.pt
# ✓ ADCY2_MOUSE: L=1090 → pglm_emb.pt
# ✓ ADCY2_RAT: L=1090 → pglm_emb.pt
# ✓ ADCY3_MOUSE: L=1145 → pglm_emb.pt
# ✓ ADCY3_RAT: L=1144 → pglm_emb.pt
# ✓ ADCY4_HUMAN: L=1077 → pglm_emb.pt
# ✓ ADCY4_RAT: L=1064 → pglm_emb.pt
# ✓ ADCY5_HUMAN: L=1261 → pglm_emb.pt
# ✓ ADCY5_MOUSE: L=1262 → pglm_emb.pt
# ✓ ADCY5_RAT: L=1262 → pglm_emb.pt
# ✓ ADCY6_HUMAN: L=1168 → pglm_emb.pt
# ✓ ADCY6_MOUSE: L=1165 → pglm_emb.pt
# ✓ ADCY6_RAT: L=1166 → pglm_emb.pt
# ✓ ADCY7_HUMAN: L=1080 → pglm_emb.pt
# ✓ ADCY7_MOUSE: L=1099 → pglm_emb.pt
# ✓ ADCY8_MOUSE: L=1249 → pglm_emb.pt
# ✓ ADCY8_RAT: L=1248 → pglm_emb.pt
# ✓ ADCY9_HUMAN: L=1353 → pglm_emb.pt
# ✓ ADCY9_MOUSE: L=1353 → pglm_emb.pt
# ✓ ADCYA_HUMAN: L=1610 → pglm_emb.pt
# ✓ ADCYA_RAT: L=1608 → pglm_emb.pt
# ✓ ADNP_MOUSE: L=1108 → pglm_emb.pt
# ✓ ADNP_RAT: L=1103 → pglm_emb.pt
# ✓ ADR1_YEAST: L=1323 → pglm_emb.pt
# ✓ AEBP1_HUMAN: L=1158 → pglm_emb.pt
# ✓ AEBP1_MOUSE: L=1128 → pglm_emb.pt
# ✓ AF10_HUMAN: L=1068 → pglm_emb.pt
# ✓ AF17_HUMAN: L=1093 → pglm_emb.pt
# ✓ AFAD_HUMAN: L=1824 → pglm_emb.pt
# ✓ AFAD_MOUSE: L=1820 → pglm_emb.pt
# ✓ AFAD_RAT: L=1829 → pglm_emb.pt
# ✓ AFF1_MOUSE: L=1216 → pglm_emb.pt
# ✓ AFF2_MOUSE: L=1272 → pglm_emb.pt
# ✓ AFF3_HUMAN: L=1226 → pglm_emb.pt
# ✓ AFF3_MOUSE: L=1254 → pglm_emb.pt
# ✓ AFFL_DROME: L=1673 → pglm_emb.pt
# ✓ AGAP2_HUMAN: L=1192 → pglm_emb.pt
# ✓ AGAP2_RAT: L=1186 → pglm_emb.pt
# ✓ AGO1_ARATH: L=1048 → pglm_emb.pt
# ✓ AGO2_DROME: L=1214 → pglm_emb.pt
# ✓ AGRA2_HUMAN: L=1338 → pglm_emb.pt
# ✓ AGRA3_HUMAN: L=1321 → pglm_emb.pt
# ✓ AGRB1_HUMAN: L=1584 → pglm_emb.pt
# ✓ AGRB1_MOUSE: L=1582 → pglm_emb.pt
# ✓ AGRB2_HUMAN: L=1585 → pglm_emb.pt
# ✓ AGRB3_MOUSE: L=1522 → pglm_emb.pt
# ✓ AGRF3_HUMAN: L=1079 → pglm_emb.pt
# ✓ AGRF5_HUMAN: L=1346 → pglm_emb.pt
# ✓ AGRG6_DANRE: L=1185 → pglm_emb.pt
# ✓ AGRG6_HUMAN: L=1221 → pglm_emb.pt
# ✓ AGRG6_MOUSE: L=1165 → pglm_emb.pt
# ✓ AGRIN_HUMAN: L=2068 → pglm_emb.pt
# ✓ AGRIN_MOUSE: L=1950 → pglm_emb.pt
# ✓ AGRIN_RAT: L=1959 → pglm_emb.pt
# ✓ AGRL1_RAT: L=1515 → pglm_emb.pt
# ✓ AGRL2_RAT: L=1487 → pglm_emb.pt
# ✓ AGRL3_HUMAN: L=1447 → pglm_emb.pt
# ✓ AGRL3_MOUSE: L=1537 → pglm_emb.pt
# ✓ AGS1_SCHPO: L=2410 → pglm_emb.pt
# ✓ AHDC1_HUMAN: L=1603 → pglm_emb.pt
# ✓ AHI1_HUMAN: L=1196 → pglm_emb.pt
# ✓ AHK1_ARATH: L=1207 → pglm_emb.pt
# ✓ AHK2_ARATH: L=1176 → pglm_emb.pt
# ✓ AHK3_ARATH: L=1036 → pglm_emb.pt
# ✓ AHK4_ARATH: L=1080 → pglm_emb.pt
# ✓ AK1_DICDI: L=1352 → pglm_emb.pt
# ✓ AKA11_HUMAN: L=1901 → pglm_emb.pt
# ✓ AKA11_RAT: L=1129 → pglm_emb.pt
# ✓ AKA12_HUMAN: L=1782 → pglm_emb.pt
# ✓ AKA12_MOUSE: L=1684 → pglm_emb.pt
# ✓ AKAP6_HUMAN: L=2319 → pglm_emb.pt
# ✓ AKAP6_RAT: L=2314 → pglm_emb.pt
# ✓ AKL1_YEAST: L=1108 → pglm_emb.pt
# ✓ AKNA_HUMAN: L=1439 → pglm_emb.pt
# ✓ ALA10_ARATH: L=1202 → pglm_emb.pt
# ✓ ALA3_ARATH: L=1213 → pglm_emb.pt
# ✓ ALA5_ARATH: L=1228 → pglm_emb.pt
# ✓ ALA6_ARATH: L=1240 → pglm_emb.pt
# ✓ ALDO1_ARATH: L=1368 → pglm_emb.pt
# ✓ ALDO2_ARATH: L=1321 → pglm_emb.pt
# ✓ ALDO3_ARATH: L=1332 → pglm_emb.pt
# ✓ ALDO4_ARATH: L=1337 → pglm_emb.pt
# ✓ ALK_HUMAN: L=1620 → pglm_emb.pt
# ✓ ALM1_SCHPO: L=1727 → pglm_emb.pt
# ✓ ALMS1_DROME: L=1322 → pglm_emb.pt
# ✓ ALP1_SCHPO: L=1105 → pglm_emb.pt
# ✓ ALPK1_HUMAN: L=1244 → pglm_emb.pt
# ✓ ALS1_CANAL: L=1260 → pglm_emb.pt
# ✓ ALS2_DROME: L=1486 → pglm_emb.pt
# ✓ ALS2_HUMAN: L=1657 → pglm_emb.pt
# ✓ ALS3_CANAL: L=1155 → pglm_emb.pt
# ✓ ALS5_CANAL: L=1347 → pglm_emb.pt
# ✓ ALY2_YEAST: L=1046 → pglm_emb.pt
# ✓ AMER1_HUMAN: L=1135 → pglm_emb.pt
# ✓ AMOT_HUMAN: L=1084 → pglm_emb.pt
# ✓ AMRA1_HUMAN: L=1298 → pglm_emb.pt
# ✓ AN36B_HUMAN: L=1353 → pglm_emb.pt
# ✓ ANFY1_HUMAN: L=1169 → pglm_emb.pt
# ✓ ANK1_HUMAN: L=1881 → pglm_emb.pt
# ✓ ANK3_MOUSE: L=1961 → pglm_emb.pt
# ✓ ANK3_RAT: L=2622 → pglm_emb.pt
# ✓ ANLN_DROME: L=1239 → pglm_emb.pt
# ✓ ANLN_HUMAN: L=1124 → pglm_emb.pt
# ✓ ANO8_HUMAN: L=1232 → pglm_emb.pt
# ✓ ANPRA_HUMAN: L=1061 → pglm_emb.pt
# ✓ ANPRA_MOUSE: L=1057 → pglm_emb.pt
# ✓ ANPRA_RAT: L=1057 → pglm_emb.pt
# ✓ ANPRB_HUMAN: L=1047 → pglm_emb.pt
# ✓ ANPRB_MOUSE: L=1047 → pglm_emb.pt
# ✓ ANPRB_RAT: L=1047 → pglm_emb.pt
# ✓ ANR17_HUMAN: L=2603 → pglm_emb.pt
# ✓ ANR27_HUMAN: L=1050 → pglm_emb.pt
# ✓ ANR27_MOUSE: L=1048 → pglm_emb.pt
# ✓ ANS1A_MOUSE: L=1150 → pglm_emb.pt
# ✓ ANS1B_HUMAN: L=1248 → pglm_emb.pt
# ✓ AOXA_HUMAN: L=1338 → pglm_emb.pt
# ✓ AOXA_MOUSE: L=1333 → pglm_emb.pt
# ✓ AOXA_RAT: L=1333 → pglm_emb.pt
# ✓ AOXC_MOUSE: L=1335 → pglm_emb.pt
# ✓ AP3B1_HUMAN: L=1094 → pglm_emb.pt
# ✓ APAF_HUMAN: L=1248 → pglm_emb.pt
# ✓ APAF_MOUSE: L=1249 → pglm_emb.pt
# ✓ APAF_RAT: L=1249 → pglm_emb.pt
# ✓ APC1_SCHPO: L=1458 → pglm_emb.pt
# ✓ APC1_YEAST: L=1748 → pglm_emb.pt
# ✓ APCL_HUMAN: L=2303 → pglm_emb.pt
# ✓ ARAK_ARATH: L=1039 → pglm_emb.pt
# ✓ ARAP1_HUMAN: L=1450 → pglm_emb.pt
# ✓ ARAP2_HUMAN: L=1704 → pglm_emb.pt
# ✓ ARAP3_HUMAN: L=1544 → pglm_emb.pt
# ✓ ARAP3_MOUSE: L=1538 → pglm_emb.pt
# ✓ ARFG_ARATH: L=1164 → pglm_emb.pt
# ✓ ARFS_ARATH: L=1086 → pglm_emb.pt
# ✓ ARG28_HUMAN: L=1705 → pglm_emb.pt
# ✓ ARGAL_HUMAN: L=1279 → pglm_emb.pt
# ✓ ARHG5_HUMAN: L=1597 → pglm_emb.pt
# ✓ ARHGA_HUMAN: L=1369 → pglm_emb.pt
# ✓ ARHGB_HUMAN: L=1522 → pglm_emb.pt
# ✓ ARHGC_HUMAN: L=1544 → pglm_emb.pt
# ✓ ARHGH_HUMAN: L=2063 → pglm_emb.pt
# ✓ ARHGI_HUMAN: L=1361 → pglm_emb.pt
# ✓ ARI1A_HUMAN: L=2285 → pglm_emb.pt
# ✓ ARI1B_HUMAN: L=2236 → pglm_emb.pt
# ✓ ARI4A_HUMAN: L=1257 → pglm_emb.pt
# ✓ ARI5B_HUMAN: L=1188 → pglm_emb.pt
# ✓ ARID2_HUMAN: L=1835 → pglm_emb.pt
# ✓ ARIP4_MOUSE: L=1466 → pglm_emb.pt
# ✓ ARO1_YEAST: L=1588 → pglm_emb.pt
# ✓ ASAP1_MOUSE: L=1147 → pglm_emb.pt
# ✓ ASCC3_HUMAN: L=2202 → pglm_emb.pt
# ✓ ASH1_DROME: L=2226 → pglm_emb.pt
# ✓ ASHH2_ARATH: L=1759 → pglm_emb.pt
# ✓ ASK10_YEAST: L=1146 → pglm_emb.pt
# ✓ ASPP2_HUMAN: L=1128 → pglm_emb.pt
# ✓ ASP_DROME: L=1954 → pglm_emb.pt
# ✓ ASTN2_HUMAN: L=1339 → pglm_emb.pt
# ✓ ASXL1_MOUSE: L=1514 → pglm_emb.pt
# ✓ ASXL2_HUMAN: L=1435 → pglm_emb.pt
# ✓ ASX_DROME: L=1669 → pglm_emb.pt
# ✓ AT131_HUMAN: L=1204 → pglm_emb.pt
# ✓ AT132_HUMAN: L=1180 → pglm_emb.pt
# ✓ AT133_HUMAN: L=1226 → pglm_emb.pt
# ✓ AT134_MOUSE: L=1193 → pglm_emb.pt
# ✓ AT1A1_XENLA: L=1025 → pglm_emb.pt
# ✓ AT1A4_HUMAN: L=1029 → pglm_emb.pt
# ✓ AT1A4_MOUSE: L=1032 → pglm_emb.pt
# ✓ AT1A4_RAT: L=1028 → pglm_emb.pt
# ✓ AT2A2_HUMAN: L=1042 → pglm_emb.pt
# ✓ AT2A2_MOUSE: L=1044 → pglm_emb.pt
# ✓ AT2A2_RAT: L=1043 → pglm_emb.pt
# ✓ AT2A3_HUMAN: L=1043 → pglm_emb.pt
# ✓ AT2A3_MOUSE: L=1038 → pglm_emb.pt
# ✓ AT2A3_RAT: L=1061 → pglm_emb.pt
# ✓ AT2B1_HUMAN: L=1220 → pglm_emb.pt
# ✓ AT2B1_RAT: L=1220 → pglm_emb.pt
# ✓ AT2B2_HUMAN: L=1243 → pglm_emb.pt
# ✓ AT2B2_MOUSE: L=1198 → pglm_emb.pt
# ✓ AT2B2_RAT: L=1243 → pglm_emb.pt
# ✓ AT2B3_HUMAN: L=1220 → pglm_emb.pt
# ✓ AT2B3_RAT: L=1258 → pglm_emb.pt
# ✓ AT2B4_HUMAN: L=1241 → pglm_emb.pt
# ✓ AT2B4_RAT: L=1203 → pglm_emb.pt
# ✓ AT8A1_MOUSE: L=1164 → pglm_emb.pt
# ✓ AT8A2_MOUSE: L=1148 → pglm_emb.pt
# ✓ AT8B1_MOUSE: L=1251 → pglm_emb.pt
# ✓ AT8B1_RAT: L=1251 → pglm_emb.pt
# ✓ AT8B5_MOUSE: L=1183 → pglm_emb.pt
# ✓ ATAD2_HUMAN: L=1390 → pglm_emb.pt
# ✓ ATAD2_YEAST: L=1379 → pglm_emb.pt
# ✓ ATAD5_HUMAN: L=1844 → pglm_emb.pt
# ✓ ATC1_CANAL: L=1078 → pglm_emb.pt
# ✓ ATC1_DICDI: L=1115 → pglm_emb.pt
# ✓ ATC2_SCHPO: L=1292 → pglm_emb.pt
# ✓ ATC2_YEAST: L=1173 → pglm_emb.pt
# ✓ ATC3_SCHPO: L=1037 → pglm_emb.pt
# ✓ ATC3_YEAST: L=1355 → pglm_emb.pt
# ✓ ATC4_SCHPO: L=1211 → pglm_emb.pt
# ✓ ATC4_YEAST: L=1612 → pglm_emb.pt
# ✓ ATC5_YEAST: L=1571 → pglm_emb.pt
# ✓ ATC6_YEAST: L=1215 → pglm_emb.pt
# ✓ ATC8_YEAST: L=1656 → pglm_emb.pt
# ✓ ATCX_SCHPO: L=1402 → pglm_emb.pt
# ✓ ATD2B_HUMAN: L=1458 → pglm_emb.pt
# ✓ ATD2_SCHPO: L=1190 → pglm_emb.pt
# ✓ ATG11_ARATH: L=1148 → pglm_emb.pt
# ✓ ATG11_YEAST: L=1178 → pglm_emb.pt
# ✓ ATG26_CANAL: L=1512 → pglm_emb.pt
# ✓ ATG26_YEAST: L=1198 → pglm_emb.pt
# ✓ ATG2_YEAST: L=1592 → pglm_emb.pt
# ✓ ATH1_YEAST: L=1211 → pglm_emb.pt
# ✓ ATL4_HUMAN: L=1074 → pglm_emb.pt
# ✓ ATN1_HUMAN: L=1190 → pglm_emb.pt
# ✓ ATN1_MOUSE: L=1175 → pglm_emb.pt
# ✓ ATN1_RAT: L=1183 → pglm_emb.pt
# ✓ ATN1_YEAST: L=1091 → pglm_emb.pt
# ✓ ATN2_YEAST: L=1091 → pglm_emb.pt
# ✓ ATNA_DROME: L=1041 → pglm_emb.pt
# ✓ ATP4A_MOUSE: L=1033 → pglm_emb.pt
# ✓ ATP7A_HUMAN: L=1500 → pglm_emb.pt
# ✓ ATP7A_MOUSE: L=1491 → pglm_emb.pt
# ✓ ATP7A_RAT: L=1492 → pglm_emb.pt
# ✓ ATP7B_HUMAN: L=1465 → pglm_emb.pt
# ✓ ATP7B_MOUSE: L=1462 → pglm_emb.pt
# ✓ ATP7B_RAT: L=1451 → pglm_emb.pt
# ✓ ATP9A_HUMAN: L=1047 → pglm_emb.pt
# ✓ ATRN_HUMAN: L=1429 → pglm_emb.pt
# ✓ ATRN_MOUSE: L=1428 → pglm_emb.pt
# ✓ ATRX_DROME: L=1311 → pglm_emb.pt
# ✓ ATRX_HUMAN: L=2492 → pglm_emb.pt
# ✓ ATRX_MOUSE: L=2476 → pglm_emb.pt
# ✓ ATR_HUMAN: L=2644 → pglm_emb.pt
# ✓ ATR_MOUSE: L=2635 → pglm_emb.pt
# ✓ ATR_XENLA: L=2654 → pglm_emb.pt
# ✓ ATR_YEAST: L=2368 → pglm_emb.pt
# ✓ ATS12_HUMAN: L=1594 → pglm_emb.pt
# ✓ ATS13_HUMAN: L=1427 → pglm_emb.pt
# ✓ ATS13_MOUSE: L=1426 → pglm_emb.pt
# ✓ ATS20_MOUSE: L=1906 → pglm_emb.pt
# ✓ ATS2_HUMAN: L=1211 → pglm_emb.pt
# ✓ ATS2_MOUSE: L=1213 → pglm_emb.pt
# ✓ ATS3_HUMAN: L=1205 → pglm_emb.pt
# ✓ ATS6_HUMAN: L=1117 → pglm_emb.pt
# ✓ ATS7_HUMAN: L=1686 → pglm_emb.pt
# ✓ ATS7_MOUSE: L=1657 → pglm_emb.pt
# ✓ ATS9_HUMAN: L=1935 → pglm_emb.pt
# ✓ ATU1_YEAST: L=1216 → pglm_emb.pt
# ✓ ATX1_ARATH: L=1062 → pglm_emb.pt
# ✓ ATX2_ARATH: L=1083 → pglm_emb.pt
# ✓ ATX2_DROME: L=1084 → pglm_emb.pt
# ✓ ATX2_HUMAN: L=1313 → pglm_emb.pt
# ✓ ATXR3_ARATH: L=2335 → pglm_emb.pt
# ✓ AUS1_YEAST: L=1394 → pglm_emb.pt
# ✓ AUTS2_HUMAN: L=1259 → pglm_emb.pt
# ✓ AVO1_YEAST: L=1176 → pglm_emb.pt
# ✓ AXL1_YEAST: L=1208 → pglm_emb.pt
# ✓ B3A2_HUMAN: L=1241 → pglm_emb.pt
# ✓ B3A2_MOUSE: L=1237 → pglm_emb.pt
# ✓ B3A2_RAT: L=1234 → pglm_emb.pt
# ✓ B3A3_HUMAN: L=1232 → pglm_emb.pt
# ✓ B3A3_RAT: L=1227 → pglm_emb.pt
# ✓ B4GN4_HUMAN: L=1039 → pglm_emb.pt
# ✓ BAB2_DROME: L=1067 → pglm_emb.pt
# ✓ BAG6_ARATH: L=1043 → pglm_emb.pt
# ✓ BAG6_HUMAN: L=1132 → pglm_emb.pt
# ✓ BAG6_MOUSE: L=1154 → pglm_emb.pt
# ✓ BAIP3_HUMAN: L=1187 → pglm_emb.pt
# ✓ BAZ1B_HUMAN: L=1483 → pglm_emb.pt
# ✓ BAZ1B_MOUSE: L=1479 → pglm_emb.pt
# ✓ BAZ2A_HUMAN: L=1905 → pglm_emb.pt
# ✓ BAZ2A_MOUSE: L=1889 → pglm_emb.pt
# ✓ BBC1_YEAST: L=1157 → pglm_emb.pt
# ✓ BCK1_YEAST: L=1478 → pglm_emb.pt
# ✓ BCL9L_HUMAN: L=1499 → pglm_emb.pt
# ✓ BCL9L_MOUSE: L=1494 → pglm_emb.pt
# ✓ BCL9_DROME: L=1469 → pglm_emb.pt
# ✓ BCL9_MOUSE: L=1425 → pglm_emb.pt
# ✓ BCOR_HUMAN: L=1755 → pglm_emb.pt
# ✓ BCOR_MOUSE: L=1759 → pglm_emb.pt
# ✓ BCR_HUMAN: L=1271 → pglm_emb.pt
# ✓ BCR_MOUSE: L=1270 → pglm_emb.pt
# ✓ BCR_RAT: L=1062 → pglm_emb.pt
# ✓ BEM2_YEAST: L=2167 → pglm_emb.pt
# ✓ BEM3_YEAST: L=1128 → pglm_emb.pt
# ✓ BGCN_DROME: L=1215 → pglm_emb.pt
# ✓ BGS1_SCHPO: L=1729 → pglm_emb.pt
# ✓ BGS4_SCHPO: L=1955 → pglm_emb.pt
# ✓ BICRA_HUMAN: L=1560 → pglm_emb.pt
# ✓ BIG1_HUMAN: L=1849 → pglm_emb.pt
# ✓ BIG2_HUMAN: L=1785 → pglm_emb.pt
# ✓ BIG2_RAT: L=1791 → pglm_emb.pt
# ✓ BIR1A_MOUSE: L=1403 → pglm_emb.pt
# ✓ BIR1E_MOUSE: L=1403 → pglm_emb.pt
# ✓ BIRC1_HUMAN: L=1403 → pglm_emb.pt
# ✓ BLM10_YEAST: L=2143 → pglm_emb.pt
# ✓ BLM_DROME: L=1487 → pglm_emb.pt
# ✓ BLM_HUMAN: L=1417 → pglm_emb.pt
# ✓ BLM_MOUSE: L=1416 → pglm_emb.pt
# ✓ BMP2K_MOUSE: L=1138 → pglm_emb.pt
# ✓ BMPR2_HUMAN: L=1038 → pglm_emb.pt
# ✓ BMPR2_MOUSE: L=1038 → pglm_emb.pt
# ✓ BMS1_YEAST: L=1183 → pglm_emb.pt
# ✓ BNC2_MOUSE: L=1127 → pglm_emb.pt
# ✓ BNI1_CANAL: L=1732 → pglm_emb.pt
# ✓ BNI1_YEAST: L=1953 → pglm_emb.pt
# ✓ BNR1_CANAL: L=1485 → pglm_emb.pt
# ✓ BNR1_YEAST: L=1375 → pglm_emb.pt
# ✓ BPT1_YEAST: L=1559 → pglm_emb.pt
# ✓ BRAT_DROME: L=1037 → pglm_emb.pt
# ✓ BRCA1_HUMAN: L=1863 → pglm_emb.pt
# ✓ BRCA1_MOUSE: L=1812 → pglm_emb.pt
# ✓ BRD1_HUMAN: L=1058 → pglm_emb.pt
# ✓ BRD4_DANRE: L=1444 → pglm_emb.pt
# ✓ BRD4_HUMAN: L=1362 → pglm_emb.pt
# ✓ BRD4_MOUSE: L=1400 → pglm_emb.pt
# ✓ BRD8_HUMAN: L=1235 → pglm_emb.pt
# ✓ BRDH_DROME: L=1430 → pglm_emb.pt
# ✓ BRI1_ARATH: L=1196 → pglm_emb.pt
# ✓ BRM_ARATH: L=2193 → pglm_emb.pt
# ✓ BRM_DROME: L=1638 → pglm_emb.pt
# ✓ BRR2_YEAST: L=2163 → pglm_emb.pt
# ✓ BST1_YEAST: L=1029 → pglm_emb.pt
# ✓ BTAF1_HUMAN: L=1849 → pglm_emb.pt
# ✓ BTSL1_ARATH: L=1254 → pglm_emb.pt
# ✓ BTSL2_ARATH: L=1259 → pglm_emb.pt
# ✓ BTS_ARATH: L=1254 → pglm_emb.pt
# ✓ BUB1_SCHPO: L=1044 → pglm_emb.pt
# ✓ BUD2_CANAL: L=1237 → pglm_emb.pt
# ✓ BUD2_YEAST: L=1104 → pglm_emb.pt
# ✓ BUD3_YEAST: L=1636 → pglm_emb.pt
# ✓ BUD4_CANAL: L=1709 → pglm_emb.pt
# ✓ BUD4_YEAST: L=1447 → pglm_emb.pt
# ✓ C163A_HUMAN: L=1156 → pglm_emb.pt
# ✓ C1716_DROME: L=2313 → pglm_emb.pt
# ✓ C2TA_HUMAN: L=1130 → pglm_emb.pt
# ✓ C3G_DROME: L=1571 → pglm_emb.pt
# ✓ C3H19_ARATH: L=1773 → pglm_emb.pt
# ✓ C8AP2_HUMAN: L=1982 → pglm_emb.pt
# ✓ C8AP2_MOUSE: L=1962 → pglm_emb.pt
# ✓ CA2D1_HUMAN: L=1103 → pglm_emb.pt
# ✓ CA2D1_RAT: L=1091 → pglm_emb.pt
# ✓ CA2D2_MOUSE: L=1154 → pglm_emb.pt
# ✓ CA2D2_RAT: L=1157 → pglm_emb.pt
# ✓ CA2D3_RAT: L=1085 → pglm_emb.pt
# ✓ CA2D4_HUMAN: L=1137 → pglm_emb.pt
# ✓ CABIN_RAT: L=2182 → pglm_emb.pt
# ✓ CAC1A_DROME: L=1851 → pglm_emb.pt
# ✓ CAC1A_HUMAN: L=2506 → pglm_emb.pt
# ✓ CAC1A_MOUSE: L=2368 → pglm_emb.pt
# ✓ CAC1A_RAT: L=2212 → pglm_emb.pt
# ✓ CAC1B_HUMAN: L=2339 → pglm_emb.pt
# ✓ CAC1B_MOUSE: L=2327 → pglm_emb.pt
# ✓ CAC1B_RAT: L=2336 → pglm_emb.pt
# ✓ CAC1C_HUMAN: L=2221 → pglm_emb.pt
# ✓ CAC1C_MOUSE: L=2139 → pglm_emb.pt
# ✓ CAC1C_RAT: L=2169 → pglm_emb.pt
# ✓ CAC1D_DROME: L=2516 → pglm_emb.pt
# ✓ CAC1D_HUMAN: L=2161 → pglm_emb.pt
# ✓ CAC1D_MOUSE: L=2179 → pglm_emb.pt
# ✓ CAC1D_RAT: L=2203 → pglm_emb.pt
# ✓ CAC1E_HUMAN: L=2313 → pglm_emb.pt
# ✓ CAC1E_MOUSE: L=2272 → pglm_emb.pt
# ✓ CAC1E_RAT: L=2222 → pglm_emb.pt
# ✓ CAC1F_HUMAN: L=1977 → pglm_emb.pt
# ✓ CAC1F_MOUSE: L=1985 → pglm_emb.pt
# ✓ CAC1G_HUMAN: L=2377 → pglm_emb.pt
# ✓ CAC1G_RAT: L=2254 → pglm_emb.pt
# ✓ CAC1H_HUMAN: L=2353 → pglm_emb.pt
# ✓ CAC1H_RAT: L=2359 → pglm_emb.pt
# ✓ CAC1I_HUMAN: L=2223 → pglm_emb.pt
# ✓ CAC1I_RAT: L=2201 → pglm_emb.pt
# ✓ CAC1S_HUMAN: L=1873 → pglm_emb.pt
# ✓ CAC1S_MOUSE: L=1880 → pglm_emb.pt
# ✓ CAC1S_RAT: L=1850 → pglm_emb.pt
# ✓ CAD99_DROME: L=1706 → pglm_emb.pt
# ✓ CADE_DROME: L=1507 → pglm_emb.pt
# ✓ CALS7_ARATH: L=1958 → pglm_emb.pt
# ✓ CAMP1_HUMAN: L=1602 → pglm_emb.pt
# ✓ CAMP1_RAT: L=1604 → pglm_emb.pt
# ✓ CAMP2_HUMAN: L=1489 → pglm_emb.pt
# ✓ CAMP3_HUMAN: L=1249 → pglm_emb.pt
# ✓ CAMP3_MOUSE: L=1252 → pglm_emb.pt
# ✓ CAND1_RAT: L=1230 → pglm_emb.pt
# ✓ CAND2_MOUSE: L=1235 → pglm_emb.pt
# ✓ CAND2_RAT: L=1273 → pglm_emb.pt
# ✓ CAPR2_HUMAN: L=1127 → pglm_emb.pt
# ✓ CAPS1_MOUSE: L=1355 → pglm_emb.pt
# ✓ CAPS1_RAT: L=1289 → pglm_emb.pt
# ✓ CAPU_DROME: L=1059 → pglm_emb.pt
# ✓ CAR11_HUMAN: L=1154 → pglm_emb.pt
# ✓ CARB_ARATH: L=1187 → pglm_emb.pt
# ✓ CARB_ECOLI: L=1073 → pglm_emb.pt
# ✓ CARL1_HUMAN: L=1371 → pglm_emb.pt
# ✓ CARL1_MOUSE: L=1374 → pglm_emb.pt
# ✓ CARL2_HUMAN: L=1435 → pglm_emb.pt
# ✓ CARML_DICDI: L=1050 → pglm_emb.pt
# ✓ CASR_HUMAN: L=1078 → pglm_emb.pt
# ✓ CASR_RAT: L=1079 → pglm_emb.pt
# ✓ CAT8_YEAST: L=1433 → pglm_emb.pt
# ✓ CBPC1_MOUSE: L=1218 → pglm_emb.pt
# ✓ CBPC4_MOUSE: L=1122 → pglm_emb.pt
# ✓ CBPD_DROME: L=1406 → pglm_emb.pt
# ✓ CBPD_HUMAN: L=1380 → pglm_emb.pt
# ✓ CBPD_RAT: L=1378 → pglm_emb.pt
# ✓ CBP_HUMAN: L=2442 → pglm_emb.pt
# ✓ CBP_MOUSE: L=2441 → pglm_emb.pt
# ✓ CBP_RAT: L=2442 → pglm_emb.pt
# ✓ CCAR1_HUMAN: L=1150 → pglm_emb.pt
# ✓ CCAR1_MOUSE: L=1146 → pglm_emb.pt
# ✓ CCH1_SCHPO: L=1854 → pglm_emb.pt
# ✓ CCH1_YEAST: L=2039 → pglm_emb.pt
# ✓ CD109_HUMAN: L=1445 → pglm_emb.pt
# ✓ CDC11_SCHPO: L=1045 → pglm_emb.pt
# ✓ CDC12_SCHPO: L=1841 → pglm_emb.pt
# ✓ CDC25_CANAL: L=1333 → pglm_emb.pt
# ✓ CDC25_YEAST: L=1589 → pglm_emb.pt
# ✓ CDC28_SCHPO: L=1055 → pglm_emb.pt
# ✓ CDC7_SCHPO: L=1062 → pglm_emb.pt
# ✓ CDHR2_HUMAN: L=1310 → pglm_emb.pt
# ✓ CDK12_DROME: L=1157 → pglm_emb.pt
# ✓ CDK12_HUMAN: L=1490 → pglm_emb.pt
# ✓ CDK12_MOUSE: L=1484 → pglm_emb.pt
# ✓ CDK12_RAT: L=1484 → pglm_emb.pt
# ✓ CDK13_HUMAN: L=1512 → pglm_emb.pt
# ✓ CDK13_MOUSE: L=1511 → pglm_emb.pt
# ✓ CDKL5_HUMAN: L=1030 → pglm_emb.pt
# ✓ CDR1_CANAL: L=1501 → pglm_emb.pt
# ✓ CDR2_CANAL: L=1499 → pglm_emb.pt
# ✓ CE152_HUMAN: L=1710 → pglm_emb.pt
# ✓ CE192_HUMAN: L=2537 → pglm_emb.pt
# ✓ CE290_HUMAN: L=2479 → pglm_emb.pt
# ✓ CE295_HUMAN: L=2601 → pglm_emb.pt
# ✓ CEBPZ_HUMAN: L=1054 → pglm_emb.pt
# ✓ CEIP2_DANRE: L=1378 → pglm_emb.pt
# ✓ CEIP2_HUMAN: L=1383 → pglm_emb.pt
# ✓ CEMIP_HUMAN: L=1361 → pglm_emb.pt
# ✓ CEMIP_MOUSE: L=1361 → pglm_emb.pt
# ✓ CENPE_MOUSE: L=2474 → pglm_emb.pt
# ✓ CENPJ_HUMAN: L=1338 → pglm_emb.pt
# ✓ CERU_HUMAN: L=1065 → pglm_emb.pt
# ✓ CERU_MOUSE: L=1061 → pglm_emb.pt
# ✓ CERU_RAT: L=1059 → pglm_emb.pt
# ✓ CFAH_HUMAN: L=1231 → pglm_emb.pt
# ✓ CFAH_MOUSE: L=1234 → pglm_emb.pt
# ✓ CFT1_YEAST: L=1357 → pglm_emb.pt
# ✓ CFTR_DANRE: L=1485 → pglm_emb.pt
# ✓ CFTR_HUMAN: L=1480 → pglm_emb.pt
# ✓ CFTR_MOUSE: L=1476 → pglm_emb.pt
# ✓ CHD1_DROME: L=1883 → pglm_emb.pt
# ✓ CHD1_HUMAN: L=1710 → pglm_emb.pt
# ✓ CHD1_YEAST: L=1468 → pglm_emb.pt
# ✓ CHD2_HUMAN: L=1828 → pglm_emb.pt
# ✓ CHD2_MOUSE: L=1827 → pglm_emb.pt
# ✓ CHD3_HUMAN: L=2000 → pglm_emb.pt
# ✓ CHD4_HUMAN: L=1912 → pglm_emb.pt
# ✓ CHD4_MOUSE: L=1915 → pglm_emb.pt
# ✓ CHD5_HUMAN: L=1954 → pglm_emb.pt
# ✓ CHD5_MOUSE: L=1946 → pglm_emb.pt
# ✓ CHD5_RAT: L=1948 → pglm_emb.pt
# ✓ CHD8_HUMAN: L=2581 → pglm_emb.pt
# ✓ CHD8_MOUSE: L=2582 → pglm_emb.pt
# ✓ CHD8_RAT: L=2581 → pglm_emb.pt
# ✓ CHDM_DROME: L=1982 → pglm_emb.pt
# ✓ CHIF_DROME: L=1711 → pglm_emb.pt
# ✓ CHN_DROME: L=1214 → pglm_emb.pt
# ✓ CHR20_ARATH: L=1479 → pglm_emb.pt
# ✓ CHR23_ARATH: L=1064 → pglm_emb.pt
# ✓ CHS1_YEAST: L=1131 → pglm_emb.pt
# ✓ CHS3_YEAST: L=1165 → pglm_emb.pt
# ✓ CIC_DROME: L=1832 → pglm_emb.pt
# ✓ CIC_MOUSE: L=2510 → pglm_emb.pt
# ✓ CID16_SCHPO: L=1202 → pglm_emb.pt
# ✓ CING_MOUSE: L=1191 → pglm_emb.pt
# ✓ CING_XENLA: L=1360 → pglm_emb.pt
# ✓ CI_DROME: L=1397 → pglm_emb.pt
# ✓ CK5P2_HUMAN: L=1893 → pglm_emb.pt
# ✓ CK5P2_RAT: L=1903 → pglm_emb.pt
# ✓ CKAP5_HUMAN: L=2032 → pglm_emb.pt
# ✓ CKI1_ARATH: L=1122 → pglm_emb.pt
# ✓ CL16A_DROME: L=1067 → pglm_emb.pt
# ✓ CL190_DROME: L=1690 → pglm_emb.pt
# ✓ CLAH2_ARATH: L=1703 → pglm_emb.pt
# ✓ CLAP1_HUMAN: L=1538 → pglm_emb.pt
# ✓ CLAP1_MOUSE: L=1535 → pglm_emb.pt
# ✓ CLAP2_HUMAN: L=1294 → pglm_emb.pt
# ✓ CLAP2_MOUSE: L=1286 → pglm_emb.pt
# ✓ CLAP2_RAT: L=1286 → pglm_emb.pt
# ✓ CLASP_ARATH: L=1439 → pglm_emb.pt
# ✓ CLASP_DROME: L=1491 → pglm_emb.pt
# ✓ CLCN2_DROME: L=1193 → pglm_emb.pt
# ✓ CLH1_HUMAN: L=1675 → pglm_emb.pt
# ✓ CLH1_MOUSE: L=1675 → pglm_emb.pt
# ✓ CLH1_RAT: L=1675 → pglm_emb.pt
# ✓ CLH_YEAST: L=1653 → pglm_emb.pt
# ✓ CLIP1_HUMAN: L=1438 → pglm_emb.pt
# ✓ CLIP1_MOUSE: L=1391 → pglm_emb.pt
# ✓ CLIP1_RAT: L=1320 → pglm_emb.pt
# ✓ CLIP2_MOUSE: L=1047 → pglm_emb.pt
# ✓ CLIP2_RAT: L=1046 → pglm_emb.pt
# ✓ CLOCK_DROME: L=1027 → pglm_emb.pt
# ✓ CLSPN_HUMAN: L=1339 → pglm_emb.pt
# ✓ CLU_DROME: L=1448 → pglm_emb.pt
# ✓ CLU_HUMAN: L=1309 → pglm_emb.pt
# ✓ CLU_YEAST: L=1277 → pglm_emb.pt
# ✓ CMT2_ARATH: L=1295 → pglm_emb.pt
# ✓ CMTA1_MOUSE: L=1682 → pglm_emb.pt
# ✓ CMTA2_ARATH: L=1050 → pglm_emb.pt
# ✓ CMTA2_HUMAN: L=1202 → pglm_emb.pt
# ✓ CMTA2_MOUSE: L=1208 → pglm_emb.pt
# ✓ CMTA3_ARATH: L=1032 → pglm_emb.pt
# ✓ CNC_DROME: L=1383 → pglm_emb.pt
# ✓ CND1_HUMAN: L=1401 → pglm_emb.pt
# ✓ CND3_YEAST: L=1035 → pglm_emb.pt
# ✓ CNDD3_HUMAN: L=1498 → pglm_emb.pt
# ✓ CNDG2_HUMAN: L=1143 → pglm_emb.pt
# ✓ CNDG2_MOUSE: L=1138 → pglm_emb.pt
# ✓ CNGB1_HUMAN: L=1251 → pglm_emb.pt
# ✓ CNKR2_HUMAN: L=1034 → pglm_emb.pt
# ✓ CNKR2_RAT: L=1032 → pglm_emb.pt
# ✓ CNOT1_HUMAN: L=2376 → pglm_emb.pt
# ✓ CNTLN_HUMAN: L=1405 → pglm_emb.pt
# ✓ CNTN2_HUMAN: L=1040 → pglm_emb.pt
# ✓ CNTN2_MOUSE: L=1040 → pglm_emb.pt
# ✓ CNTP1_HUMAN: L=1384 → pglm_emb.pt
# ✓ CNTP1_RAT: L=1381 → pglm_emb.pt
# ✓ CNTP2_HUMAN: L=1331 → pglm_emb.pt
# ✓ CO1A1_HUMAN: L=1464 → pglm_emb.pt
# ✓ CO1A1_MOUSE: L=1453 → pglm_emb.pt
# ✓ CO1A2_HUMAN: L=1366 → pglm_emb.pt
# ✓ CO1A2_MOUSE: L=1372 → pglm_emb.pt
# ✓ CO2A1_HUMAN: L=1487 → pglm_emb.pt
# ✓ CO2A1_MOUSE: L=1487 → pglm_emb.pt
# ✓ CO3A1_HUMAN: L=1466 → pglm_emb.pt
# ✓ CO3A1_MOUSE: L=1464 → pglm_emb.pt
# ✓ CO3_HUMAN: L=1663 → pglm_emb.pt
# ✓ CO3_RAT: L=1663 → pglm_emb.pt
# ✓ CO4A1_DROME: L=1779 → pglm_emb.pt
# ✓ CO4A1_HUMAN: L=1669 → pglm_emb.pt
# ✓ CO4A3_HUMAN: L=1670 → pglm_emb.pt
# ✓ CO4A4_HUMAN: L=1690 → pglm_emb.pt
# ✓ CO4A4_MOUSE: L=1682 → pglm_emb.pt
# ✓ CO4A_HUMAN: L=1744 → pglm_emb.pt
# ✓ CO4B_HUMAN: L=1744 → pglm_emb.pt
# ✓ CO5A1_HUMAN: L=1838 → pglm_emb.pt
# ✓ CO5A1_MOUSE: L=1838 → pglm_emb.pt
# ✓ CO5A1_RAT: L=1840 → pglm_emb.pt
# ✓ CO5A2_MOUSE: L=1497 → pglm_emb.pt
# ✓ CO5_HUMAN: L=1676 → pglm_emb.pt
# ✓ CO6A1_HUMAN: L=1028 → pglm_emb.pt
# ✓ CO6A4_MOUSE: L=2309 → pglm_emb.pt
# ✓ COBA1_RAT: L=1804 → pglm_emb.pt
# ✓ COBL_MOUSE: L=1337 → pglm_emb.pt
# ✓ COGA1_HUMAN: L=1604 → pglm_emb.pt
# ✓ COIA1_HUMAN: L=1754 → pglm_emb.pt
# ✓ COPA_MOUSE: L=1224 → pglm_emb.pt
# ✓ COPA_YEAST: L=1201 → pglm_emb.pt
# ✓ CORA1_MOUSE: L=1845 → pglm_emb.pt
# ✓ CORIN_HUMAN: L=1042 → pglm_emb.pt
# ✓ CORIN_MOUSE: L=1113 → pglm_emb.pt
# ✓ COS_DROME: L=1201 → pglm_emb.pt
# ✓ CP131_HUMAN: L=1083 → pglm_emb.pt
# ✓ CP131_MOUSE: L=1060 → pglm_emb.pt
# ✓ CP135_HUMAN: L=1140 → pglm_emb.pt
# ✓ CP190_DROME: L=1096 → pglm_emb.pt
# ✓ CP250_HUMAN: L=2442 → pglm_emb.pt
# ✓ CPL3_ARATH: L=1241 → pglm_emb.pt
# ✓ CPSF1_DROME: L=1455 → pglm_emb.pt
# ✓ CPSF1_HUMAN: L=1443 → pglm_emb.pt
# ✓ CPSM_HUMAN: L=1500 → pglm_emb.pt
# ✓ CPSM_MOUSE: L=1500 → pglm_emb.pt
# ✓ CPSM_RAT: L=1500 → pglm_emb.pt
# ✓ CR1_HUMAN: L=2039 → pglm_emb.pt
# ✓ CR2_HUMAN: L=1033 → pglm_emb.pt
# ✓ CR2_MOUSE: L=1025 → pglm_emb.pt
# ✓ CRAG_DROME: L=1671 → pglm_emb.pt
# ✓ CRB_DROME: L=2146 → pglm_emb.pt
# ✓ CRIM1_HUMAN: L=1036 → pglm_emb.pt
# ✓ CROCC_MOUSE: L=2009 → pglm_emb.pt
# ✓ CRUM2_HUMAN: L=1285 → pglm_emb.pt
# ✓ CSI1_ARATH: L=2150 → pglm_emb.pt
# ✓ CSKI1_HUMAN: L=1431 → pglm_emb.pt
# ✓ CSKI1_RAT: L=1430 → pglm_emb.pt
# ✓ CSLD2_ARATH: L=1145 → pglm_emb.pt
# ✓ CSLD3_ARATH: L=1145 → pglm_emb.pt
# ✓ CSLD5_ARATH: L=1181 → pglm_emb.pt
# ✓ CSPG4_HUMAN: L=2322 → pglm_emb.pt
# ✓ CSPG4_MOUSE: L=2327 → pglm_emb.pt
# ✓ CSPG4_RAT: L=2326 → pglm_emb.pt
# ✓ CSR2_YEAST: L=1121 → pglm_emb.pt
# ✓ CTA5_SCHPO: L=1096 → pglm_emb.pt
# ✓ CTC1_HUMAN: L=1217 → pglm_emb.pt
# ✓ CTC1_MOUSE: L=1212 → pglm_emb.pt
# ✓ CTND2_HUMAN: L=1225 → pglm_emb.pt
# ✓ CTR9_MOUSE: L=1173 → pglm_emb.pt
# ✓ CTR9_YEAST: L=1077 → pglm_emb.pt
# ✓ CTRO_HUMAN: L=2027 → pglm_emb.pt
# ✓ CTRO_MOUSE: L=2055 → pglm_emb.pt
# ✓ CTTB2_RAT: L=1649 → pglm_emb.pt
# ✓ CUP_DROME: L=1117 → pglm_emb.pt
# ✓ CUSA_ECOLI: L=1047 → pglm_emb.pt
# ✓ CUT1_SCHPO: L=1828 → pglm_emb.pt
# ✓ CUT7_SCHPO: L=1085 → pglm_emb.pt
# ✓ CUT_DROME: L=2175 → pglm_emb.pt
# ✓ CUX1_HUMAN: L=1505 → pglm_emb.pt
# ✓ CUX1_MOUSE: L=1515 → pglm_emb.pt
# ✓ CUX1_RAT: L=1504 → pglm_emb.pt
# ✓ CUX2_HUMAN: L=1486 → pglm_emb.pt
# ✓ CUX2_MOUSE: L=1426 → pglm_emb.pt
# ✓ CYA1_DROME: L=2248 → pglm_emb.pt
# ✓ CYAA_DICDI: L=1407 → pglm_emb.pt
# ✓ CYAA_SCHPO: L=1692 → pglm_emb.pt
# ✓ CYAA_YEAST: L=2026 → pglm_emb.pt
# ✓ CYAD_DICDI: L=2123 → pglm_emb.pt
# ✓ CYFP1_MOUSE: L=1253 → pglm_emb.pt
# ✓ CYPB_BACSU: L=1054 → pglm_emb.pt
# ✓ CYPD_BACSU: L=1061 → pglm_emb.pt
# ✓ CYTSA_MOUSE: L=1118 → pglm_emb.pt
# ✓ DAAF8_XENLA: L=1572 → pglm_emb.pt
# ✓ DAAM1_HUMAN: L=1078 → pglm_emb.pt
# ✓ DAB2P_HUMAN: L=1189 → pglm_emb.pt
# ✓ DAB2P_MOUSE: L=1189 → pglm_emb.pt
# ✓ DAB_DROME: L=2224 → pglm_emb.pt
# ✓ DAPK1_HUMAN: L=1430 → pglm_emb.pt
# ✓ DAPK1_MOUSE: L=1442 → pglm_emb.pt
# ✓ DAPLE_DANRE: L=2023 → pglm_emb.pt
# ✓ DAPLE_HUMAN: L=2028 → pglm_emb.pt
# ✓ DAPLE_MOUSE: L=2009 → pglm_emb.pt
# ✓ DAPLE_XENLA: L=2058 → pglm_emb.pt
# ✓ DC2I1_HUMAN: L=1066 → pglm_emb.pt
# ✓ DCAF1_HUMAN: L=1507 → pglm_emb.pt
# ✓ DCC_HUMAN: L=1447 → pglm_emb.pt
# ✓ DCC_RAT: L=1445 → pglm_emb.pt
# ✓ DCDC1_HUMAN: L=1783 → pglm_emb.pt
# ✓ DCL1_ARATH: L=1909 → pglm_emb.pt
# ✓ DCL3_ARATH: L=1580 → pglm_emb.pt
# ✓ DCR1A_HUMAN: L=1040 → pglm_emb.pt
# ✓ DCR1_DROME: L=2249 → pglm_emb.pt
# ✓ DCR1_SCHPO: L=1374 → pglm_emb.pt
# ✓ DCSA_DICDI: L=1059 → pglm_emb.pt
# ✓ DCTN1_DROME: L=1265 → pglm_emb.pt
# ✓ DCTN1_HUMAN: L=1278 → pglm_emb.pt
# ✓ DCTN1_MOUSE: L=1281 → pglm_emb.pt
# ✓ DCTN1_RAT: L=1280 → pglm_emb.pt
# ✓ DDB1_HUMAN: L=1140 → pglm_emb.pt
# ✓ DDB1_RAT: L=1140 → pglm_emb.pt
# ✓ DDB1_SCHPO: L=1072 → pglm_emb.pt
# ✓ DDX60_HUMAN: L=1712 → pglm_emb.pt
# ✓ DEAH5_ARATH: L=1168 → pglm_emb.pt
# ✓ DEC11_DROME: L=1208 → pglm_emb.pt
# ✓ DEC13_DROME: L=1590 → pglm_emb.pt
# ✓ DEGP7_ARATH: L=1097 → pglm_emb.pt
# ✓ DEK1_ARATH: L=2151 → pglm_emb.pt
# ✓ DEN2B_HUMAN: L=1137 → pglm_emb.pt
# ✓ DEN4B_HUMAN: L=1496 → pglm_emb.pt
# ✓ DEN4C_HUMAN: L=1909 → pglm_emb.pt
# ✓ DEN4C_MOUSE: L=1906 → pglm_emb.pt
# ✓ DEN5A_HUMAN: L=1287 → pglm_emb.pt
# ✓ DEN5A_MOUSE: L=1287 → pglm_emb.pt
# ✓ DEN5B_HUMAN: L=1274 → pglm_emb.pt
# ✓ DEND3_HUMAN: L=1198 → pglm_emb.pt
# ✓ DEND3_MOUSE: L=1274 → pglm_emb.pt
# ✓ DEPD5_HUMAN: L=1603 → pglm_emb.pt
# ✓ DEXHE_ARATH: L=2157 → pglm_emb.pt
# ✓ DGK1_DROME: L=1211 → pglm_emb.pt
# ✓ DGKD_HUMAN: L=1214 → pglm_emb.pt
# ✓ DGKD_MOUSE: L=1220 → pglm_emb.pt
# ✓ DGKH_HUMAN: L=1220 → pglm_emb.pt
# ✓ DGKH_MOUSE: L=1211 → pglm_emb.pt
# ✓ DGKI_HUMAN: L=1065 → pglm_emb.pt
# ✓ DGKI_MOUSE: L=1071 → pglm_emb.pt
# ✓ DGKI_RAT: L=1050 → pglm_emb.pt
# ✓ DGKK_HUMAN: L=1271 → pglm_emb.pt
# ✓ DGLA_MOUSE: L=1044 → pglm_emb.pt
# ✓ DHE2_YEAST: L=1092 → pglm_emb.pt
# ✓ DHKA_DICDI: L=2150 → pglm_emb.pt
# ✓ DHR1_YEAST: L=1267 → pglm_emb.pt
# ✓ DHX16_HUMAN: L=1041 → pglm_emb.pt
# ✓ DHX29_HUMAN: L=1369 → pglm_emb.pt
# ✓ DHX30_HUMAN: L=1194 → pglm_emb.pt
# ✓ DHX30_MOUSE: L=1217 → pglm_emb.pt
# ✓ DHX8_HUMAN: L=1220 → pglm_emb.pt
# ✓ DHX9_HUMAN: L=1270 → pglm_emb.pt
# ✓ DHX9_MOUSE: L=1380 → pglm_emb.pt
# ✓ DI3L1_HUMAN: L=1054 → pglm_emb.pt
# ✓ DIAP1_HUMAN: L=1272 → pglm_emb.pt
# ✓ DIAP1_MOUSE: L=1255 → pglm_emb.pt
# ✓ DIAP2_HUMAN: L=1101 → pglm_emb.pt
# ✓ DIAP2_MOUSE: L=1098 → pglm_emb.pt
# ✓ DIA_DROME: L=1091 → pglm_emb.pt
# ✓ DICER_DANRE: L=1865 → pglm_emb.pt
# ✓ DICER_HUMAN: L=1922 → pglm_emb.pt
# ✓ DICER_MOUSE: L=1916 → pglm_emb.pt
# ✓ DIMA_DICDI: L=1230 → pglm_emb.pt
# ✓ DIP2B_MOUSE: L=1574 → pglm_emb.pt
# ✓ DISP1_MOUSE: L=1521 → pglm_emb.pt
# ✓ DLG5_HUMAN: L=1919 → pglm_emb.pt
# ✓ DLGP2_RAT: L=1059 → pglm_emb.pt
# ✓ DMBT1_HUMAN: L=2413 → pglm_emb.pt
# ✓ DMBT1_MOUSE: L=2085 → pglm_emb.pt
# ✓ DMDB_DROME: L=1669 → pglm_emb.pt
# ✓ DMDD_DROME: L=1854 → pglm_emb.pt
# ✓ DMDE_DROME: L=1051 → pglm_emb.pt
# ✓ DME_ARATH: L=1987 → pglm_emb.pt
# ✓ DML3_ARATH: L=1044 → pglm_emb.pt
# ✓ DNA2_HUMAN: L=1060 → pglm_emb.pt
# ✓ DNA2_MOUSE: L=1062 → pglm_emb.pt
# ✓ DNA2_SCHPO: L=1397 → pglm_emb.pt
# ✓ DNA2_YEAST: L=1522 → pglm_emb.pt
# ✓ DNLI4_ARATH: L=1219 → pglm_emb.pt
# ✓ DNMBP_HUMAN: L=1577 → pglm_emb.pt
# ✓ DNMBP_MOUSE: L=1580 → pglm_emb.pt
# ✓ DNMT1_ARATH: L=1534 → pglm_emb.pt
# ✓ DNMT1_HUMAN: L=1616 → pglm_emb.pt
# ✓ DNMT1_MOUSE: L=1620 → pglm_emb.pt
# ✓ DNMT1_RAT: L=1622 → pglm_emb.pt
# ✓ DOA10_YEAST: L=1319 → pglm_emb.pt
# ✓ DOC10_MOUSE: L=2150 → pglm_emb.pt
# ✓ DOC11_MOUSE: L=2073 → pglm_emb.pt
# ✓ DOCK1_HUMAN: L=1865 → pglm_emb.pt
# ✓ DOCK2_HUMAN: L=1830 → pglm_emb.pt
# ✓ DOCK2_MOUSE: L=1828 → pglm_emb.pt
# ✓ DOCK3_HUMAN: L=2030 → pglm_emb.pt
# ✓ DOCK4_HUMAN: L=1966 → pglm_emb.pt
# ✓ DOCK5_MOUSE: L=1868 → pglm_emb.pt
# ✓ DOCK7_HUMAN: L=2140 → pglm_emb.pt
# ✓ DOCK7_MOUSE: L=2130 → pglm_emb.pt
# ✓ DOCK8_HUMAN: L=2099 → pglm_emb.pt
# ✓ DOCK8_MOUSE: L=2100 → pglm_emb.pt
# ✓ DOCK9_MOUSE: L=2055 → pglm_emb.pt
# ✓ DOKA_DICDI: L=1671 → pglm_emb.pt
# ✓ DOME_DROME: L=1282 → pglm_emb.pt
# ✓ DOP1_YEAST: L=1698 → pglm_emb.pt
# ✓ DOT1L_DICDI: L=1845 → pglm_emb.pt
# ✓ DOT1L_DROME: L=1848 → pglm_emb.pt
# ✓ DOT1L_HUMAN: L=1537 → pglm_emb.pt
# ✓ DPO3A_ECOLI: L=1160 → pglm_emb.pt
# ✓ DPOA_SCHPO: L=1405 → pglm_emb.pt
# ✓ DPOA_YEAST: L=1468 → pglm_emb.pt
# ✓ DPOD1_DROME: L=1092 → pglm_emb.pt
# ✓ DPOD1_HUMAN: L=1107 → pglm_emb.pt
# ✓ DPOD1_MOUSE: L=1105 → pglm_emb.pt
# ✓ DPOD1_RAT: L=1103 → pglm_emb.pt
# ✓ DPOD_SCHPO: L=1086 → pglm_emb.pt
# ✓ DPOD_YEAST: L=1097 → pglm_emb.pt
# ✓ DPOE1_DROME: L=2236 → pglm_emb.pt
# ✓ DPOE1_HUMAN: L=2286 → pglm_emb.pt
# ✓ DPOE_SCHPO: L=2199 → pglm_emb.pt
# ✓ DPOE_YEAST: L=2222 → pglm_emb.pt
# ✓ DPOG1_DROME: L=1145 → pglm_emb.pt
# ✓ DPOG1_HUMAN: L=1239 → pglm_emb.pt
# ✓ DPOG1_MOUSE: L=1218 → pglm_emb.pt
# ✓ DPOG1_RAT: L=1216 → pglm_emb.pt
# ✓ DPOG_YEAST: L=1254 → pglm_emb.pt
# ✓ DPOLA_DROME: L=1488 → pglm_emb.pt
# ✓ DPOLA_HUMAN: L=1462 → pglm_emb.pt
# ✓ DPOLA_MOUSE: L=1465 → pglm_emb.pt
# ✓ DPOLA_RAT: L=1451 → pglm_emb.pt
# ✓ DPOLA_SCHPO: L=1405 → pglm_emb.pt
# ✓ DPOLA_YEAST: L=1468 → pglm_emb.pt
# ✓ DPOLQ_DROME: L=2059 → pglm_emb.pt
# ✓ DPOLQ_HUMAN: L=2590 → pglm_emb.pt
# ✓ DPOLQ_MOUSE: L=2544 → pglm_emb.pt
# ✓ DPOZ_DROME: L=2130 → pglm_emb.pt
# ✓ DPOZ_YEAST: L=1504 → pglm_emb.pt
# ✓ DPYD_HUMAN: L=1025 → pglm_emb.pt
# ✓ DPYD_MOUSE: L=1025 → pglm_emb.pt
# ✓ DPYD_RAT: L=1025 → pglm_emb.pt
# ✓ DRL21_ARATH: L=1424 → pglm_emb.pt
# ✓ DRPR_DROME: L=1031 → pglm_emb.pt
# ✓ DSCAM_HUMAN: L=2012 → pglm_emb.pt
# ✓ DSCAM_MOUSE: L=2013 → pglm_emb.pt
# ✓ DSCL1_HUMAN: L=2053 → pglm_emb.pt
# ✓ DSCL_DROME: L=2074 → pglm_emb.pt
# ✓ DSEL_MOUSE: L=1207 → pglm_emb.pt
# ✓ DSG1_HUMAN: L=1049 → pglm_emb.pt
# ✓ DSG2_HUMAN: L=1118 → pglm_emb.pt
# ✓ DSG4_RAT: L=1040 → pglm_emb.pt
# ✓ DSPP_HUMAN: L=1301 → pglm_emb.pt
# ✓ DSRAD_HUMAN: L=1226 → pglm_emb.pt
# ✓ DSRAD_MOUSE: L=1178 → pglm_emb.pt
# ✓ DUF1_YEAST: L=1116 → pglm_emb.pt
# ✓ DUOX2_HUMAN: L=1548 → pglm_emb.pt
# ✓ DUOX_DROME: L=1537 → pglm_emb.pt
# ✓ DUR1_YEAST: L=1835 → pglm_emb.pt
# ✓ DYSF_HUMAN: L=2080 → pglm_emb.pt
# ✓ DYSF_MOUSE: L=2090 → pglm_emb.pt
# ✓ DZIP3_HUMAN: L=1208 → pglm_emb.pt
# ✓ E2AK3_DROME: L=1162 → pglm_emb.pt
# ✓ E2AK3_HUMAN: L=1116 → pglm_emb.pt
# ✓ E2AK3_MOUSE: L=1114 → pglm_emb.pt
# ✓ E2AK3_RAT: L=1108 → pglm_emb.pt
# ✓ E2AK4_HUMAN: L=1649 → pglm_emb.pt
# ✓ E2AK4_MOUSE: L=1648 → pglm_emb.pt
# ✓ E41L3_HUMAN: L=1087 → pglm_emb.pt
# ✓ E75BA_DROME: L=1355 → pglm_emb.pt
# ✓ E75BB_DROME: L=1412 → pglm_emb.pt
# ✓ E75BC_DROME: L=1199 → pglm_emb.pt
# ✓ ECA1_ARATH: L=1061 → pglm_emb.pt
# ✓ ECM21_YEAST: L=1117 → pglm_emb.pt
# ✓ ECM29_HUMAN: L=1845 → pglm_emb.pt
# ✓ ECM29_YEAST: L=1868 → pglm_emb.pt
# ✓ ECM32_YEAST: L=1121 → pglm_emb.pt
# ✓ ECMA_DICDI: L=1710 → pglm_emb.pt
# ✓ EDE1_YEAST: L=1381 → pglm_emb.pt
# ✓ EDM2_ARATH: L=1297 → pglm_emb.pt
# ✓ EEA1_HUMAN: L=1411 → pglm_emb.pt
# ✓ EF3A_YEAST: L=1044 → pglm_emb.pt
# ✓ EF3B_YEAST: L=1044 → pglm_emb.pt
# ✓ EF3_CANAL: L=1050 → pglm_emb.pt
# ✓ EF3_SCHPO: L=1047 → pglm_emb.pt
# ✓ EFL1_HUMAN: L=1120 → pglm_emb.pt
# ✓ EFR_ARATH: L=1031 → pglm_emb.pt
# ✓ EGFR_DROME: L=1426 → pglm_emb.pt
# ✓ EGFR_HUMAN: L=1210 → pglm_emb.pt
# ✓ EGFR_MOUSE: L=1210 → pglm_emb.pt
# ✓ EGF_HUMAN: L=1207 → pglm_emb.pt
# ✓ EGF_MOUSE: L=1217 → pglm_emb.pt
# ✓ EGF_RAT: L=1133 → pglm_emb.pt
# ✓ EGT2_YEAST: L=1041 → pglm_emb.pt
# ✓ EHMT1_HUMAN: L=1298 → pglm_emb.pt
# ✓ EHMT1_MOUSE: L=1296 → pglm_emb.pt
# ✓ EHMT2_HUMAN: L=1210 → pglm_emb.pt
# ✓ EHMT2_MOUSE: L=1263 → pglm_emb.pt
# ✓ EIF3A_HUMAN: L=1382 → pglm_emb.pt
# ✓ EIF3A_RAT: L=1354 → pglm_emb.pt
# ✓ EIN2_ARATH: L=1294 → pglm_emb.pt
# ✓ ELF1_DROME: L=1333 → pglm_emb.pt
# ✓ ELF1_SCHPO: L=1057 → pglm_emb.pt
# ✓ ELL_DROME: L=1059 → pglm_emb.pt
# ✓ ELMOE_DICDI: L=1677 → pglm_emb.pt
# ✓ ELP1_RAT: L=1331 → pglm_emb.pt
# ✓ ELP1_YEAST: L=1349 → pglm_emb.pt
# ✓ ELYS_DROME: L=2111 → pglm_emb.pt
# ✓ ELYS_MOUSE: L=2243 → pglm_emb.pt
# ✓ EMAL_DROME: L=1076 → pglm_emb.pt
# ✓ EMF1_ARATH: L=1096 → pglm_emb.pt
# ✓ EMSY_MOUSE: L=1264 → pglm_emb.pt
# ✓ ENAM_MOUSE: L=1274 → pglm_emb.pt
# ✓ ENG1_CANAL: L=1145 → pglm_emb.pt
# ✓ ENG1_YEAST: L=1117 → pglm_emb.pt
# ✓ ENTF_ECOLI: L=1293 → pglm_emb.pt
# ✓ EP300_HUMAN: L=2414 → pglm_emb.pt
# ✓ EP300_MOUSE: L=2412 → pglm_emb.pt
# ✓ ER6L2_HUMAN: L=1561 → pglm_emb.pt
# ✓ ERBB2_HUMAN: L=1255 → pglm_emb.pt
# ✓ ERBB2_RAT: L=1257 → pglm_emb.pt
# ✓ ERBB3_HUMAN: L=1342 → pglm_emb.pt
# ✓ ERBB3_RAT: L=1339 → pglm_emb.pt
# ✓ ERBB4_HUMAN: L=1308 → pglm_emb.pt
# ✓ ERBB4_MOUSE: L=1308 → pglm_emb.pt
# ✓ ERBIN_HUMAN: L=1412 → pglm_emb.pt
# ✓ ERC6L_HUMAN: L=1250 → pglm_emb.pt
# ✓ ERCC5_HUMAN: L=1186 → pglm_emb.pt
# ✓ ERCC6_HUMAN: L=1493 → pglm_emb.pt
# ✓ ERPG3_HUMAN: L=1061 → pglm_emb.pt
# ✓ ESP1_ARATH: L=2180 → pglm_emb.pt
# ✓ ESP1_YEAST: L=1630 → pglm_emb.pt
# ✓ ESPL1_HUMAN: L=2120 → pglm_emb.pt
# ✓ ESPL1_MOUSE: L=2118 → pglm_emb.pt
# ✓ EST1A_HUMAN: L=1419 → pglm_emb.pt
# ✓ ESYT1_HUMAN: L=1104 → pglm_emb.pt
# ✓ EVGS_ECOLI: L=1197 → pglm_emb.pt
# ✓ EXA1_ARATH: L=1714 → pglm_emb.pt
# ✓ EXOC6_DICDI: L=1025 → pglm_emb.pt
# ✓ EXPA_DROME: L=1427 → pglm_emb.pt
# ✓ EXPH5_HUMAN: L=1989 → pglm_emb.pt
# ✓ EYS_DROME: L=2176 → pglm_emb.pt
# ✓ FA83H_HUMAN: L=1179 → pglm_emb.pt
# ✓ FAB1A_ARATH: L=1757 → pglm_emb.pt
# ✓ FAB1B_ARATH: L=1791 → pglm_emb.pt
# ✓ FAB1C_ARATH: L=1648 → pglm_emb.pt
# ✓ FAB1_SCHPO: L=1932 → pglm_emb.pt
# ✓ FAB1_YEAST: L=2278 → pglm_emb.pt
# ✓ FACD2_HUMAN: L=1451 → pglm_emb.pt
# ✓ FAK1_HUMAN: L=1052 → pglm_emb.pt
# ✓ FAK1_MOUSE: L=1052 → pglm_emb.pt
# ✓ FAK1_RAT: L=1055 → pglm_emb.pt
# ✓ FANCI_HUMAN: L=1328 → pglm_emb.pt
# ✓ FANCM_HUMAN: L=2048 → pglm_emb.pt
# ✓ FARP1_HUMAN: L=1045 → pglm_emb.pt
# ✓ FARP1_RAT: L=1049 → pglm_emb.pt
# ✓ FARP2_HUMAN: L=1054 → pglm_emb.pt
# ✓ FARP2_MOUSE: L=1065 → pglm_emb.pt
# ✓ FAS1_SCHPO: L=2073 → pglm_emb.pt
# ✓ FAS1_YEAST: L=2051 → pglm_emb.pt
# ✓ FAS2_SCHPO: L=1842 → pglm_emb.pt
# ✓ FAS2_YEAST: L=1887 → pglm_emb.pt
# ✓ FAS_MOUSE: L=2504 → pglm_emb.pt
# ✓ FAS_RAT: L=2505 → pglm_emb.pt
# ✓ FBH1_HUMAN: L=1043 → pglm_emb.pt
# ✓ FBLN2_HUMAN: L=1184 → pglm_emb.pt
# ✓ FBLN2_MOUSE: L=1221 → pglm_emb.pt
# ✓ FBXW7_DROME: L=1326 → pglm_emb.pt
# ✓ FCSK_HUMAN: L=1084 → pglm_emb.pt
# ✓ FCSK_MOUSE: L=1090 → pglm_emb.pt
# ✓ FGFR2_DROME: L=1052 → pglm_emb.pt
# ✓ FGT1_ARATH: L=1295 → pglm_emb.pt
# ✓ FH14_ARATH: L=1230 → pglm_emb.pt
# ✓ FH1_ARATH: L=1051 → pglm_emb.pt
# ✓ FHDC1_MOUSE: L=1149 → pglm_emb.pt
# ✓ FHOD1_HUMAN: L=1164 → pglm_emb.pt
# ✓ FINC_HUMAN: L=2477 → pglm_emb.pt
# ✓ FINC_MOUSE: L=2477 → pglm_emb.pt
# ✓ FINC_RAT: L=2477 → pglm_emb.pt
# ✓ FIPS5_ARATH: L=1196 → pglm_emb.pt
# ✓ FKGP_ARATH: L=1055 → pglm_emb.pt
# ✓ FKS1_YEAST: L=1876 → pglm_emb.pt
# ✓ FKS2_YEAST: L=1895 → pglm_emb.pt
# ✓ FLII_HUMAN: L=1269 → pglm_emb.pt
# ✓ FLNA_HUMAN: L=2647 → pglm_emb.pt
# ✓ FLNA_MOUSE: L=2647 → pglm_emb.pt
# ✓ FLNB_HUMAN: L=2602 → pglm_emb.pt
# ✓ FLO11_YEAST: L=1367 → pglm_emb.pt
# ✓ FLO1_YEAST: L=1537 → pglm_emb.pt
# ✓ FLO5_YEAST: L=1075 → pglm_emb.pt
# ✓ FLS2_ARATH: L=1173 → pglm_emb.pt
# ✓ FMN1_MOUSE: L=1466 → pglm_emb.pt
# ✓ FMN2_HUMAN: L=1722 → pglm_emb.pt
# ✓ FMNL1_HUMAN: L=1100 → pglm_emb.pt
# ✓ FMNL1_MOUSE: L=1094 → pglm_emb.pt
# ✓ FMNL3_MOUSE: L=1028 → pglm_emb.pt
# ✓ FNIP1_HUMAN: L=1166 → pglm_emb.pt
# ✓ FNIP2_HUMAN: L=1114 → pglm_emb.pt
# ✓ FOG2_HUMAN: L=1151 → pglm_emb.pt
# ✓ FOG2_MOUSE: L=1151 → pglm_emb.pt
# ✓ FORA_DICDI: L=1218 → pglm_emb.pt
# ✓ FORC_DICDI: L=1158 → pglm_emb.pt
# ✓ FORF_DICDI: L=1220 → pglm_emb.pt
# ✓ FORG_DICDI: L=1074 → pglm_emb.pt
# ✓ FORH_DICDI: L=1087 → pglm_emb.pt
# ✓ FRL_DROME: L=1183 → pglm_emb.pt
# ✓ FRPD2_HUMAN: L=1309 → pglm_emb.pt
# ✓ FRPD4_HUMAN: L=1322 → pglm_emb.pt
# ✓ FSCB_MOUSE: L=1074 → pglm_emb.pt
# ✓ FTM_HUMAN: L=1315 → pglm_emb.pt
# ✓ FTSI5_ARATH: L=1320 → pglm_emb.pt
# ✓ FTSK_ECOLI: L=1329 → pglm_emb.pt
# ✓ FTZF1_DROME: L=1027 → pglm_emb.pt
# ✓ FUN30_YEAST: L=1131 → pglm_emb.pt
# ✓ FUR11_DROME: L=1269 → pglm_emb.pt
# ✓ FUR1C_DROME: L=1101 → pglm_emb.pt
# ✓ FUR2_DROME: L=1679 → pglm_emb.pt
# ✓ FYV1_DROME: L=1809 → pglm_emb.pt
# ✓ FYV1_HUMAN: L=2098 → pglm_emb.pt
# ✓ FYV1_MOUSE: L=2097 → pglm_emb.pt
# ✓ GACW_DICDI: L=1115 → pglm_emb.pt
# ✓ GAK_HUMAN: L=1311 → pglm_emb.pt
# ✓ GAK_RAT: L=1305 → pglm_emb.pt
# ✓ GANP_HUMAN: L=1980 → pglm_emb.pt
# ✓ GAPD1_HUMAN: L=1478 → pglm_emb.pt
# ✓ GAPD1_MOUSE: L=1458 → pglm_emb.pt
# ✓ GBF1_HUMAN: L=1859 → pglm_emb.pt
# ✓ GBPC_DICDI: L=2631 → pglm_emb.pt
# ✓ GBPD_DICDI: L=1312 → pglm_emb.pt
# ✓ GC76C_DROME: L=1525 → pglm_emb.pt
# ✓ GCA_DICDI: L=1483 → pglm_emb.pt
# ✓ GCC2_HUMAN: L=1684 → pglm_emb.pt
# ✓ GCN1_SCHPO: L=2670 → pglm_emb.pt
# ✓ GCN1_YEAST: L=2672 → pglm_emb.pt
# ✓ GCN2_SCHPO: L=1576 → pglm_emb.pt
# ✓ GCN2_YEAST: L=1659 → pglm_emb.pt
# ✓ GCNA_DROME: L=1030 → pglm_emb.pt
# ✓ GCP6_HUMAN: L=1819 → pglm_emb.pt
# ✓ GCSP2_ARATH: L=1044 → pglm_emb.pt
# ✓ GCSP_YEAST: L=1034 → pglm_emb.pt
# ✓ GCY8E_DROME: L=1097 → pglm_emb.pt
# ✓ GDE1_CANAL: L=1162 → pglm_emb.pt
# ✓ GDE1_YEAST: L=1223 → pglm_emb.pt
# ✓ GDE_HUMAN: L=1532 → pglm_emb.pt
# ✓ GDE_YEAST: L=1536 → pglm_emb.pt
# ✓ GDH2_SCHPO: L=1106 → pglm_emb.pt
# ✓ GEA1_YEAST: L=1408 → pglm_emb.pt
# ✓ GEA2_YEAST: L=1459 → pglm_emb.pt
# ✓ GEF2_SCHPO: L=1101 → pglm_emb.pt
# ✓ GEFB_DICDI: L=1529 → pglm_emb.pt
# ✓ GEFQ_DICDI: L=1298 → pglm_emb.pt
# ✓ GEFR_DICDI: L=1721 → pglm_emb.pt
# ✓ GEK_DROME: L=1637 → pglm_emb.pt
# ✓ GEMI4_HUMAN: L=1058 → pglm_emb.pt
# ✓ GEMI5_HUMAN: L=1508 → pglm_emb.pt
# ✓ GEMI5_MOUSE: L=1502 → pglm_emb.pt
# ✓ GFLB_DICDI: L=1601 → pglm_emb.pt
# ✓ GGYF2_HUMAN: L=1299 → pglm_emb.pt
# ✓ GHR1_ARATH: L=1053 → pglm_emb.pt
# ✓ GIN4_CANAL: L=1349 → pglm_emb.pt
# ✓ GIP3_YEAST: L=1276 → pglm_emb.pt
# ✓ GLD2A_DROME: L=1364 → pglm_emb.pt
# ✓ GLD2B_DROME: L=1373 → pglm_emb.pt
# ✓ GLI1_HUMAN: L=1106 → pglm_emb.pt
# ✓ GLI1_MOUSE: L=1111 → pglm_emb.pt
# ✓ GLI2_HUMAN: L=1586 → pglm_emb.pt
# ✓ GLI2_MOUSE: L=1544 → pglm_emb.pt
# ✓ GLI3_HUMAN: L=1580 → pglm_emb.pt
# ✓ GLI3_MOUSE: L=1583 → pglm_emb.pt
# ✓ GLT1_SCHPO: L=2111 → pglm_emb.pt
# ✓ GLT1_YEAST: L=2145 → pglm_emb.pt
# ✓ GLTB1_ARATH: L=1622 → pglm_emb.pt
# ✓ GLTB_ECOLI: L=1486 → pglm_emb.pt
# ✓ GLUT1_ARATH: L=2208 → pglm_emb.pt
# ✓ GMAN2_ARATH: L=1173 → pglm_emb.pt
# ✓ GNAS1_RAT: L=1144 → pglm_emb.pt
# ✓ GNOM_ARATH: L=1451 → pglm_emb.pt
# ✓ GNPTA_DANRE: L=1219 → pglm_emb.pt
# ✓ GNPTA_HUMAN: L=1256 → pglm_emb.pt
# ✓ GOGA4_HUMAN: L=2230 → pglm_emb.pt
# ✓ GON4L_MOUSE: L=2260 → pglm_emb.pt
# ✓ GRDN_HUMAN: L=1871 → pglm_emb.pt
# ✓ GRDN_MOUSE: L=1873 → pglm_emb.pt
# ✓ GRIP1_HUMAN: L=1128 → pglm_emb.pt
# ✓ GRIP1_RAT: L=1112 → pglm_emb.pt
# ✓ GRIP2_RAT: L=1043 → pglm_emb.pt
# ✓ GRM1_HUMAN: L=1194 → pglm_emb.pt
# ✓ GRM1_MOUSE: L=1199 → pglm_emb.pt
# ✓ GRM1_RAT: L=1199 → pglm_emb.pt
# ✓ GRM5_HUMAN: L=1212 → pglm_emb.pt
# ✓ GRM5_MOUSE: L=1203 → pglm_emb.pt
# ✓ GRM5_RAT: L=1203 → pglm_emb.pt
# ✓ GRR1_YEAST: L=1151 → pglm_emb.pt
# ✓ GRRE1_HUMAN: L=1070 → pglm_emb.pt
# ✓ GSF2_SCHPO: L=1563 → pglm_emb.pt
# ✓ GSLG1_HUMAN: L=1179 → pglm_emb.pt
# ✓ GSLG1_RAT: L=1171 → pglm_emb.pt
# ✓ GT2D1_MOUSE: L=1104 → pglm_emb.pt
# ✓ GUC2C_MOUSE: L=1072 → pglm_emb.pt
# ✓ GUC2C_RAT: L=1072 → pglm_emb.pt
# ✓ GUC2D_HUMAN: L=1103 → pglm_emb.pt
# ✓ GUC2D_MOUSE: L=1117 → pglm_emb.pt
# ✓ GUC2D_RAT: L=1110 → pglm_emb.pt
# ✓ GUC2E_MOUSE: L=1108 → pglm_emb.pt
# ✓ GUC2E_RAT: L=1108 → pglm_emb.pt
# ✓ GUC2F_HUMAN: L=1108 → pglm_emb.pt
# ✓ GUC2F_RAT: L=1108 → pglm_emb.pt
# ✓ GUC2G_MOUSE: L=1100 → pglm_emb.pt
# ✓ GWD1_ARATH: L=1399 → pglm_emb.pt
# ✓ GXCB_DICDI: L=1198 → pglm_emb.pt
# ✓ GXCDD_DICDI: L=1632 → pglm_emb.pt
# ✓ HAC12_ARATH: L=1706 → pglm_emb.pt
# ✓ HAC5_ARATH: L=1670 → pglm_emb.pt
# ✓ HAIR_MOUSE: L=1182 → pglm_emb.pt
# ✓ HAIR_RAT: L=1181 → pglm_emb.pt
# ✓ HANG_DROME: L=1959 → pglm_emb.pt
# ✓ HAP1_YEAST: L=1502 → pglm_emb.pt
# ✓ HCFC1_HUMAN: L=2035 → pglm_emb.pt
# ✓ HCFC1_MOUSE: L=2045 → pglm_emb.pt
# ✓ HCF_DROME: L=1500 → pglm_emb.pt
# ✓ HCN4_HUMAN: L=1203 → pglm_emb.pt
# ✓ HCN4_MOUSE: L=1186 → pglm_emb.pt
# ✓ HCN4_RAT: L=1198 → pglm_emb.pt
# ✓ HDAC4_HUMAN: L=1084 → pglm_emb.pt
# ✓ HDAC4_MOUSE: L=1076 → pglm_emb.pt
# ✓ HDAC4_RAT: L=1077 → pglm_emb.pt
# ✓ HDAC5_HUMAN: L=1122 → pglm_emb.pt
# ✓ HDAC5_MOUSE: L=1113 → pglm_emb.pt
# ✓ HDAC6_HUMAN: L=1215 → pglm_emb.pt
# ✓ HDAC6_MOUSE: L=1149 → pglm_emb.pt
# ✓ HECD1_HUMAN: L=2610 → pglm_emb.pt
# ✓ HECD1_MOUSE: L=2618 → pglm_emb.pt
# ✓ HELB_HUMAN: L=1087 → pglm_emb.pt
# ✓ HELB_MOUSE: L=1074 → pglm_emb.pt
# ✓ HELZ2_HUMAN: L=2649 → pglm_emb.pt
# ✓ HEPH_HUMAN: L=1158 → pglm_emb.pt
# ✓ HEP_DROME: L=1178 → pglm_emb.pt
# ✓ HERC4_MOUSE: L=1057 → pglm_emb.pt
# ✓ HFA1_YEAST: L=2273 → pglm_emb.pt
# ✓ HFM1_YEAST: L=1187 → pglm_emb.pt
# ✓ HIP1R_HUMAN: L=1068 → pglm_emb.pt
# ✓ HIP1R_MOUSE: L=1068 → pglm_emb.pt
# ✓ HIP1_HUMAN: L=1037 → pglm_emb.pt
# ✓ HIPK2_HUMAN: L=1198 → pglm_emb.pt
# ✓ HIPK2_MOUSE: L=1196 → pglm_emb.pt
# ✓ HIPK3_HUMAN: L=1215 → pglm_emb.pt
# ✓ HIPK3_MOUSE: L=1192 → pglm_emb.pt
# ✓ HIR3_YEAST: L=1648 → pglm_emb.pt
# ✓ HIRA_DROME: L=1047 → pglm_emb.pt
# ✓ HKR1_YEAST: L=1802 → pglm_emb.pt
# ✓ HLES_DROME: L=1077 → pglm_emb.pt
# ✓ HMDH1_YEAST: L=1054 → pglm_emb.pt
# ✓ HMDH2_YEAST: L=1045 → pglm_emb.pt
# ✓ HMDH_SCHPO: L=1053 → pglm_emb.pt
# ✓ HPHL1_HUMAN: L=1159 → pglm_emb.pt
# ✓ HR38_DROME: L=1073 → pglm_emb.pt
# ✓ HR4_DROME: L=1518 → pglm_emb.pt
# ✓ HRP1_SCHPO: L=1373 → pglm_emb.pt
# ✓ HRP3_SCHPO: L=1388 → pglm_emb.pt
# ✓ HRPA_ECOLI: L=1300 → pglm_emb.pt
# ✓ HRQ1_SCHPO: L=1063 → pglm_emb.pt
# ✓ HRQ1_YEAST: L=1077 → pglm_emb.pt
# ✓ HSL1_YEAST: L=1518 → pglm_emb.pt
# ✓ HUS2_SCHPO: L=1328 → pglm_emb.pt
# ✓ IBTK_HUMAN: L=1353 → pglm_emb.pt
# ✓ ICE1_DROME: L=1395 → pglm_emb.pt
# ✓ ICE1_HUMAN: L=2266 → pglm_emb.pt
# ✓ IDM1_ARATH: L=1189 → pglm_emb.pt
# ✓ IF172_RAT: L=1749 → pglm_emb.pt
# ✓ IF2P_HUMAN: L=1220 → pglm_emb.pt
# ✓ IF2P_SCHPO: L=1079 → pglm_emb.pt
# ✓ IF4G1_HUMAN: L=1599 → pglm_emb.pt
# ✓ IF4G3_HUMAN: L=1585 → pglm_emb.pt
# ✓ IF4G_ARATH: L=1727 → pglm_emb.pt
# ✓ IF4G_SCHPO: L=1403 → pglm_emb.pt
# ✓ IFH1_YEAST: L=1085 → pglm_emb.pt
# ✓ IFIH1_HUMAN: L=1025 → pglm_emb.pt
# ✓ IFKA_DICDI: L=2258 → pglm_emb.pt
# ✓ IFKB_DICDI: L=1358 → pglm_emb.pt
# ✓ IGF1R_HUMAN: L=1367 → pglm_emb.pt
# ✓ IGF1R_MOUSE: L=1373 → pglm_emb.pt
# ✓ IGF1R_RAT: L=1370 → pglm_emb.pt
# ✓ IGF1R_XENLA: L=1358 → pglm_emb.pt
# ✓ IGSF1_HUMAN: L=1336 → pglm_emb.pt
# ✓ IGSF1_RAT: L=1320 → pglm_emb.pt
# ✓ IL16_HUMAN: L=1332 → pglm_emb.pt
# ✓ IL16_MOUSE: L=1322 → pglm_emb.pt
# ✓ IMB3_SCHPO: L=1095 → pglm_emb.pt
# ✓ IMB3_YEAST: L=1089 → pglm_emb.pt
# ✓ IMB4_YEAST: L=1113 → pglm_emb.pt
# ✓ IML1_SCHPO: L=1496 → pglm_emb.pt
# ✓ IML1_YEAST: L=1584 → pglm_emb.pt
# ✓ IMPG2_HUMAN: L=1241 → pglm_emb.pt
# ✓ IMPG2_MOUSE: L=1243 → pglm_emb.pt
# ✓ INO80_DROME: L=1638 → pglm_emb.pt
# ✓ INO80_HUMAN: L=1556 → pglm_emb.pt
# ✓ INO80_YEAST: L=1489 → pglm_emb.pt
# ✓ INP52_YEAST: L=1183 → pglm_emb.pt
# ✓ INP53_YEAST: L=1107 → pglm_emb.pt
# ✓ INSRR_HUMAN: L=1297 → pglm_emb.pt
# ✓ INSR_DROME: L=2144 → pglm_emb.pt
# ✓ INSR_HUMAN: L=1382 → pglm_emb.pt
# ✓ INSR_RAT: L=1383 → pglm_emb.pt
# ✓ IP5PD_ARATH: L=1136 → pglm_emb.pt
# ✓ IPO5_HUMAN: L=1097 → pglm_emb.pt
# ✓ IPO5_MOUSE: L=1097 → pglm_emb.pt
# ✓ IPO7_HUMAN: L=1038 → pglm_emb.pt
# ✓ IPO7_MOUSE: L=1038 → pglm_emb.pt
# ✓ IPO8_HUMAN: L=1037 → pglm_emb.pt
# ✓ IPO9_HUMAN: L=1041 → pglm_emb.pt
# ✓ IPO9_MOUSE: L=1041 → pglm_emb.pt
# ✓ IQEC2_HUMAN: L=1488 → pglm_emb.pt
# ✓ IQG1_CANAL: L=1647 → pglm_emb.pt
# ✓ IQG1_YEAST: L=1495 → pglm_emb.pt
# ✓ IQGA1_HUMAN: L=1657 → pglm_emb.pt
# ✓ IQGA1_MOUSE: L=1657 → pglm_emb.pt
# ✓ IQGA2_HUMAN: L=1575 → pglm_emb.pt
# ✓ IQGA3_HUMAN: L=1631 → pglm_emb.pt
# ✓ IRC20_YEAST: L=1556 → pglm_emb.pt
# ✓ IRE1_SCHPO: L=1072 → pglm_emb.pt
# ✓ IRE1_YEAST: L=1115 → pglm_emb.pt
# ✓ IREH1_ARATH: L=1296 → pglm_emb.pt
# ✓ IRS1_HUMAN: L=1242 → pglm_emb.pt
# ✓ IRS1_MOUSE: L=1233 → pglm_emb.pt
# ✓ IRS1_RAT: L=1235 → pglm_emb.pt
# ✓ IRS2_MOUSE: L=1321 → pglm_emb.pt
# ✓ ISE2_ARATH: L=1171 → pglm_emb.pt
# ✓ ISK5_HUMAN: L=1064 → pglm_emb.pt
# ✓ ISW1_YEAST: L=1129 → pglm_emb.pt
# ✓ ISW2_YEAST: L=1120 → pglm_emb.pt
# ✓ ISWI_DROME: L=1027 → pglm_emb.pt
# ✓ ITA10_HUMAN: L=1167 → pglm_emb.pt
# ✓ ITA11_HUMAN: L=1188 → pglm_emb.pt
# ✓ ITA1_DROME: L=1146 → pglm_emb.pt
# ✓ ITA1_HUMAN: L=1179 → pglm_emb.pt
# ✓ ITA1_RAT: L=1180 → pglm_emb.pt
# ✓ ITA2B_HUMAN: L=1039 → pglm_emb.pt
# ✓ ITA2B_MOUSE: L=1033 → pglm_emb.pt
# ✓ ITA2_DROME: L=1396 → pglm_emb.pt
# ✓ ITA2_HUMAN: L=1181 → pglm_emb.pt
# ✓ ITA2_MOUSE: L=1178 → pglm_emb.pt
# ✓ ITA3_DROME: L=1115 → pglm_emb.pt
# ✓ ITA3_HUMAN: L=1051 → pglm_emb.pt
# ✓ ITA4_HUMAN: L=1032 → pglm_emb.pt
# ✓ ITA4_MOUSE: L=1039 → pglm_emb.pt
# ✓ ITA5_HUMAN: L=1049 → pglm_emb.pt
# ✓ ITA5_MOUSE: L=1053 → pglm_emb.pt
# ✓ ITA6_HUMAN: L=1130 → pglm_emb.pt
# ✓ ITA6_MOUSE: L=1091 → pglm_emb.pt
# ✓ ITA7_RAT: L=1135 → pglm_emb.pt
# ✓ ITAD_RAT: L=1161 → pglm_emb.pt
# ✓ ITAL_HUMAN: L=1170 → pglm_emb.pt
# ✓ ITAM_HUMAN: L=1152 → pglm_emb.pt
# ✓ ITAM_MOUSE: L=1153 → pglm_emb.pt
# ✓ ITAV_HUMAN: L=1048 → pglm_emb.pt
# ✓ ITAV_MOUSE: L=1044 → pglm_emb.pt
# ✓ ITAX_HUMAN: L=1163 → pglm_emb.pt
# ✓ ITB4_HUMAN: L=1822 → pglm_emb.pt
# ✓ ITB4_RAT: L=1807 → pglm_emb.pt
# ✓ ITPI2_HUMAN: L=1259 → pglm_emb.pt
# ✓ ITPR3_HUMAN: L=2671 → pglm_emb.pt
# ✓ ITPR3_MOUSE: L=2670 → pglm_emb.pt
# ✓ ITPR3_RAT: L=2670 → pglm_emb.pt
# ✓ ITSN1_HUMAN: L=1721 → pglm_emb.pt
# ✓ ITSN1_MOUSE: L=1714 → pglm_emb.pt
# ✓ JAG1_HUMAN: L=1218 → pglm_emb.pt
# ✓ JAG1_MOUSE: L=1218 → pglm_emb.pt
# ✓ JAG1_RAT: L=1219 → pglm_emb.pt
# ✓ JAG2_HUMAN: L=1238 → pglm_emb.pt
# ✓ JAG2_MOUSE: L=1247 → pglm_emb.pt
# ✓ JAK1_HUMAN: L=1154 → pglm_emb.pt
# ✓ JAK1_MOUSE: L=1153 → pglm_emb.pt
# ✓ JAK2_HUMAN: L=1132 → pglm_emb.pt
# ✓ JAK2_MOUSE: L=1129 → pglm_emb.pt
# ✓ JAK2_RAT: L=1132 → pglm_emb.pt
# ✓ JAK3_HUMAN: L=1124 → pglm_emb.pt
# ✓ JAK3_MOUSE: L=1100 → pglm_emb.pt
# ✓ JAK_DROME: L=1177 → pglm_emb.pt
# ✓ JARD2_MOUSE: L=1234 → pglm_emb.pt
# ✓ JHD1_DROME: L=1345 → pglm_emb.pt
# ✓ JHD2C_HUMAN: L=2540 → pglm_emb.pt
# ✓ JIL1_DROME: L=1207 → pglm_emb.pt
# ✓ JIP3_DROME: L=1227 → pglm_emb.pt
# ✓ JIP3_MOUSE: L=1337 → pglm_emb.pt
# ✓ JIP3_RAT: L=1322 → pglm_emb.pt
# ✓ JIP4_MOUSE: L=1321 → pglm_emb.pt
# ✓ JMJ17_ARATH: L=1208 → pglm_emb.pt
# ✓ JMJ25_ARATH: L=1027 → pglm_emb.pt
# ✓ JSN1_YEAST: L=1091 → pglm_emb.pt
# ✓ K0754_MOUSE: L=3305 → pglm_emb.pt
# ✓ KA120_YEAST: L=1032 → pglm_emb.pt
# ✓ KA122_YEAST: L=1081 → pglm_emb.pt
# ✓ KAD9_HUMAN: L=1911 → pglm_emb.pt
# ✓ KANK1_HUMAN: L=1352 → pglm_emb.pt
# ✓ KAT6A_HUMAN: L=2004 → pglm_emb.pt
# ✓ KAT6A_MOUSE: L=2003 → pglm_emb.pt
# ✓ KAT6B_HUMAN: L=2073 → pglm_emb.pt
# ✓ KAT6B_MOUSE: L=1872 → pglm_emb.pt
# ✓ KCC4_YEAST: L=1037 → pglm_emb.pt
# ✓ KCMA1_HUMAN: L=1236 → pglm_emb.pt
# ✓ KCMA1_MOUSE: L=1209 → pglm_emb.pt
# ✓ KCMA1_RAT: L=1209 → pglm_emb.pt
# ✓ KCNAE_DROME: L=1174 → pglm_emb.pt
# ✓ KCNH2_HUMAN: L=1159 → pglm_emb.pt
# ✓ KCNH2_MOUSE: L=1162 → pglm_emb.pt
# ✓ KCNH2_RAT: L=1163 → pglm_emb.pt
# ✓ KCNH7_RAT: L=1195 → pglm_emb.pt
# ✓ KCNH8_RAT: L=1102 → pglm_emb.pt
# ✓ KCNT1_RAT: L=1237 → pglm_emb.pt
# ✓ KCNT2_HUMAN: L=1135 → pglm_emb.pt
# ✓ KCNT2_RAT: L=1142 → pglm_emb.pt
# ✓ KCNU1_MOUSE: L=1121 → pglm_emb.pt
# ✓ KCS1_YEAST: L=1050 → pglm_emb.pt
# ✓ KDISB_DANRE: L=1680 → pglm_emb.pt
# ✓ KDIS_RAT: L=1762 → pglm_emb.pt
# ✓ KDM2A_HUMAN: L=1162 → pglm_emb.pt
# ✓ KDM2A_MOUSE: L=1161 → pglm_emb.pt
# ✓ KDM2B_HUMAN: L=1336 → pglm_emb.pt
# ✓ KDM2B_MOUSE: L=1309 → pglm_emb.pt
# ✓ KDM3A_HUMAN: L=1321 → pglm_emb.pt
# ✓ KDM3A_MOUSE: L=1323 → pglm_emb.pt
# ✓ KDM4A_HUMAN: L=1064 → pglm_emb.pt
# ✓ KDM4A_MOUSE: L=1064 → pglm_emb.pt
# ✓ KDM4B_HUMAN: L=1096 → pglm_emb.pt
# ✓ KDM4B_MOUSE: L=1086 → pglm_emb.pt
# ✓ KDM4C_HUMAN: L=1056 → pglm_emb.pt
# ✓ KDM4C_MOUSE: L=1054 → pglm_emb.pt
# ✓ KDM5A_HUMAN: L=1690 → pglm_emb.pt
# ✓ KDM5A_MOUSE: L=1690 → pglm_emb.pt
# ✓ KDM5B_HUMAN: L=1544 → pglm_emb.pt
# ✓ KDM5B_MOUSE: L=1544 → pglm_emb.pt
# ✓ KDM5C_HUMAN: L=1560 → pglm_emb.pt
# ✓ KDM5D_HUMAN: L=1539 → pglm_emb.pt
# ✓ KDM5_DROME: L=1838 → pglm_emb.pt
# ✓ KDM6A_MOUSE: L=1401 → pglm_emb.pt
# ✓ KDM6B_HUMAN: L=1643 → pglm_emb.pt
# ✓ KDM6B_MOUSE: L=1641 → pglm_emb.pt
# ✓ KEA2_ARATH: L=1174 → pglm_emb.pt
# ✓ KEG_ARATH: L=1625 → pglm_emb.pt
# ✓ KEL1_YEAST: L=1164 → pglm_emb.pt
# ✓ KGP24_DROME: L=1088 → pglm_emb.pt
# ✓ KI11A_XENLA: L=1067 → pglm_emb.pt
# ✓ KI11B_XENLA: L=1067 → pglm_emb.pt
# ✓ KI13A_MOUSE: L=1749 → pglm_emb.pt
# ✓ KI13B_HUMAN: L=1826 → pglm_emb.pt
# ✓ KI15B_XENLA: L=1387 → pglm_emb.pt
# ✓ KI16B_HUMAN: L=1317 → pglm_emb.pt
# ✓ KI16B_MOUSE: L=1312 → pglm_emb.pt
# ✓ KI20B_HUMAN: L=1820 → pglm_emb.pt
# ✓ KI26A_MOUSE: L=1881 → pglm_emb.pt
# ✓ KIBRA_HUMAN: L=1113 → pglm_emb.pt
# ✓ KIC1_YEAST: L=1080 → pglm_emb.pt
# ✓ KIF10_DICDI: L=1238 → pglm_emb.pt
# ✓ KIF11_HUMAN: L=1056 → pglm_emb.pt
# ✓ KIF14_HUMAN: L=1648 → pglm_emb.pt
# ✓ KIF14_MOUSE: L=1674 → pglm_emb.pt
# ✓ KIF15_HUMAN: L=1388 → pglm_emb.pt
# ✓ KIF17_MOUSE: L=1038 → pglm_emb.pt
# ✓ KIF1A_DROME: L=1670 → pglm_emb.pt
# ...
# ✓ SYGP1_RAT: L=1308 → pglm_emb.pt
# ✓ SYIC_HUMAN: L=1262 → pglm_emb.pt
# ✓ SYIC_MOUSE: L=1262 → pglm_emb.pt
# ✓ SYIC_YEAST: L=1072 → pglm_emb.pt
# ✓ SYJ1_SCHPO: L=1076 → pglm_emb.pt
# ✓ SYLC_HUMAN: L=1176 → pglm_emb.pt
# ✓ SYLC_MOUSE: L=1178 → pglm_emb.pt
# ✓ SYLC_YEAST: L=1090 → pglm_emb.pt
# ✓ SYNEM_HUMAN: L=1565 → pglm_emb.pt
# ✓ SYNEM_MOUSE: L=1561 → pglm_emb.pt
# ✓ SYNJ1_HUMAN: L=1573 → pglm_emb.pt
# ✓ SYNJ1_MOUSE: L=1574 → pglm_emb.pt
# ✓ SYNJ1_RAT: L=1574 → pglm_emb.pt
# ✓ SYNJ2_MOUSE: L=1434 → pglm_emb.pt
# ✓ SYNJ2_RAT: L=1496 → pglm_emb.pt
# ✓ SYNP2_HUMAN: L=1093 → pglm_emb.pt
# ✓ SYNP2_MOUSE: L=1087 → pglm_emb.pt
# ✓ SYNP2_RAT: L=1262 → pglm_emb.pt
# ✓ SYT1_YEAST: L=1226 → pglm_emb.pt
# ✓ SYVC_HUMAN: L=1264 → pglm_emb.pt
# ✓ SYVC_RAT: L=1264 → pglm_emb.pt
# ✓ SYV_YEAST: L=1104 → pglm_emb.pt
# ✓ TACC2_MOUSE: L=1149 → pglm_emb.pt
# ✓ TADA_ARATH: L=1307 → pglm_emb.pt
# ✓ TAF1L_HUMAN: L=1826 → pglm_emb.pt
# ✓ TAF1_DROME: L=2129 → pglm_emb.pt
# ✓ TAF1_HUMAN: L=1872 → pglm_emb.pt
# ✓ TAF1_MOUSE: L=1891 → pglm_emb.pt
# ✓ TAF1_YEAST: L=1066 → pglm_emb.pt
# ✓ TAF2_DROME: L=1221 → pglm_emb.pt
# ✓ TAF2_HUMAN: L=1199 → pglm_emb.pt
# ✓ TAF2_YEAST: L=1407 → pglm_emb.pt
# ✓ TAF4_HUMAN: L=1085 → pglm_emb.pt
# ✓ TAGC_DICDI: L=1741 → pglm_emb.pt
# ✓ TALA_DICDI: L=1279 → pglm_emb.pt
# ✓ TALB_DICDI: L=2614 → pglm_emb.pt
# ✓ TAOK2_HUMAN: L=1235 → pglm_emb.pt
# ✓ TAOK2_MOUSE: L=1240 → pglm_emb.pt
# ✓ TAOK2_RAT: L=1235 → pglm_emb.pt
# ✓ TAO_DROME: L=1039 → pglm_emb.pt
# ✓ TARA_HUMAN: L=2365 → pglm_emb.pt
# ✓ TARA_MOUSE: L=2014 → pglm_emb.pt
# ✓ TARB1_HUMAN: L=1621 → pglm_emb.pt
# ✓ TASOR_HUMAN: L=1670 → pglm_emb.pt
# ✓ TB182_HUMAN: L=1729 → pglm_emb.pt
# ✓ TBCD_HUMAN: L=1192 → pglm_emb.pt
# ✓ TBP7_YEAST: L=1379 → pglm_emb.pt
# ✓ TC132_ARATH: L=1206 → pglm_emb.pt
# ✓ TC159_ARATH: L=1503 → pglm_emb.pt
# ✓ TCB1_YEAST: L=1186 → pglm_emb.pt
# ✓ TCB2_YEAST: L=1178 → pglm_emb.pt
# ✓ TCB3_YEAST: L=1545 → pglm_emb.pt
# ✓ TCF20_MOUSE: L=1987 → pglm_emb.pt
# ✓ TCOF_HUMAN: L=1488 → pglm_emb.pt
# ✓ TCPR1_HUMAN: L=1165 → pglm_emb.pt
# ✓ TCRG1_HUMAN: L=1098 → pglm_emb.pt
# ✓ TCRG1_MOUSE: L=1100 → pglm_emb.pt
# ✓ TDA9_YEAST: L=1251 → pglm_emb.pt
# ✓ TDRD1_DANRE: L=1175 → pglm_emb.pt
# ✓ TDRD7_HUMAN: L=1098 → pglm_emb.pt
# ✓ TDRD7_RAT: L=1113 → pglm_emb.pt
# ✓ TDRD9_MOUSE: L=1383 → pglm_emb.pt
# ✓ TECTA_MOUSE: L=2155 → pglm_emb.pt
# ✓ TENA_HUMAN: L=2201 → pglm_emb.pt
# ✓ TENN_MOUSE: L=1560 → pglm_emb.pt
# ✓ TENR_MOUSE: L=1358 → pglm_emb.pt
# ✓ TENR_RAT: L=1356 → pglm_emb.pt
# ✓ TEP1_HUMAN: L=2627 → pglm_emb.pt
# ✓ TEP1_MOUSE: L=2629 → pglm_emb.pt
# ✓ TERT_ARATH: L=1123 → pglm_emb.pt
# ✓ TERT_HUMAN: L=1132 → pglm_emb.pt
# ✓ TERT_MOUSE: L=1122 → pglm_emb.pt
# ✓ TET1_HUMAN: L=2136 → pglm_emb.pt
# ✓ TET1_MOUSE: L=2007 → pglm_emb.pt
# ✓ TET2_HUMAN: L=2002 → pglm_emb.pt
# ✓ TET2_MOUSE: L=1912 → pglm_emb.pt
# ✓ TET3_HUMAN: L=1795 → pglm_emb.pt
# ✓ TET3_MOUSE: L=1803 → pglm_emb.pt
# ✓ TEX14_HUMAN: L=1497 → pglm_emb.pt
# ✓ TGO1_HUMAN: L=1907 → pglm_emb.pt
# ✓ THADA_DROME: L=1746 → pglm_emb.pt
# ✓ THO2_YEAST: L=1597 → pglm_emb.pt
# ✓ THOC2_ARATH: L=1823 → pglm_emb.pt
# ✓ THOC2_MOUSE: L=1594 → pglm_emb.pt
# ✓ TIAM1_HUMAN: L=1591 → pglm_emb.pt
# ✓ TIAM1_MOUSE: L=1591 → pglm_emb.pt
# ✓ TIAM2_HUMAN: L=1701 → pglm_emb.pt
# ✓ TIAM2_MOUSE: L=1715 → pglm_emb.pt
# ✓ TICRR_HUMAN: L=1910 → pglm_emb.pt
# ✓ TIE2_HUMAN: L=1124 → pglm_emb.pt
# ✓ TIE2_MOUSE: L=1122 → pglm_emb.pt
# ✓ TIF1A_HUMAN: L=1050 → pglm_emb.pt
# ✓ TIF1A_MOUSE: L=1051 → pglm_emb.pt
# ✓ TIG_DROME: L=2188 → pglm_emb.pt
# ✓ TIM_DROME: L=1398 → pglm_emb.pt
# ✓ TIO_ARATH: L=1322 → pglm_emb.pt
# ✓ TLD_DROME: L=1067 → pglm_emb.pt
# ✓ TLN1_HUMAN: L=2541 → pglm_emb.pt
# ✓ TLN1_MOUSE: L=2541 → pglm_emb.pt
# ✓ TLR7_HUMAN: L=1049 → pglm_emb.pt
# ✓ TLR7_MOUSE: L=1050 → pglm_emb.pt
# ✓ TLR8_HUMAN: L=1041 → pglm_emb.pt
# ✓ TLR9_HUMAN: L=1032 → pglm_emb.pt
# ✓ TMF1_HUMAN: L=1093 → pglm_emb.pt
# ✓ TMPS9_MOUSE: L=1065 → pglm_emb.pt
# ✓ TNIK_HUMAN: L=1360 → pglm_emb.pt
# ✓ TNKS1_HUMAN: L=1327 → pglm_emb.pt
# ✓ TNKS2_HUMAN: L=1166 → pglm_emb.pt
# ✓ TNKS_DROME: L=1181 → pglm_emb.pt
# ✓ TOB1A_XENLA: L=1513 → pglm_emb.pt
# ✓ TOLL6_DROME: L=1514 → pglm_emb.pt
# ✓ TOLL7_DROME: L=1446 → pglm_emb.pt
# ✓ TOLL_DROME: L=1097 → pglm_emb.pt
# ✓ TONSL_HUMAN: L=1378 → pglm_emb.pt
# ✓ TOP2A_HUMAN: L=1531 → pglm_emb.pt
# ✓ TOP2A_MOUSE: L=1528 → pglm_emb.pt
# ✓ TOP2A_RAT: L=1526 → pglm_emb.pt
# ✓ TOP2B_HUMAN: L=1626 → pglm_emb.pt
# ✓ TOP2_DROME: L=1447 → pglm_emb.pt
# ✓ TOP2_SCHPO: L=1485 → pglm_emb.pt
# ✓ TOP2_YEAST: L=1428 → pglm_emb.pt
# ✓ TOP3A_DROME: L=1250 → pglm_emb.pt
# ✓ TOPB1_HUMAN: L=1522 → pglm_emb.pt
# ✓ TOPRS_DROME: L=1038 → pglm_emb.pt
# ✓ TOPRS_HUMAN: L=1045 → pglm_emb.pt
# ✓ TOR1_SCHPO: L=2335 → pglm_emb.pt
# ✓ TOR1_YEAST: L=2470 → pglm_emb.pt
# ✓ TOR2_SCHPO: L=2337 → pglm_emb.pt
# ✓ TOR2_YEAST: L=2474 → pglm_emb.pt
# ✓ TOR_ARATH: L=2481 → pglm_emb.pt
# ✓ TOR_DROME: L=2470 → pglm_emb.pt
# ✓ TP53B_HUMAN: L=1972 → pglm_emb.pt
# ✓ TP53B_MOUSE: L=1969 → pglm_emb.pt
# ✓ TPLAT_ARATH: L=1176 → pglm_emb.pt
# ✓ TPL_ARATH: L=1131 → pglm_emb.pt
# ✓ TPP2_DROME: L=1441 → pglm_emb.pt
# ✓ TPP2_HUMAN: L=1249 → pglm_emb.pt
# ✓ TPP2_RAT: L=1249 → pglm_emb.pt
# ✓ TPP2_SCHPO: L=1274 → pglm_emb.pt
# ✓ TPPII_ARATH: L=1380 → pglm_emb.pt
# ✓ TPR4_ARATH: L=1135 → pglm_emb.pt
# ✓ TPR_DROME: L=2346 → pglm_emb.pt
# ✓ TPR_HUMAN: L=2363 → pglm_emb.pt
# ✓ TPS3_YEAST: L=1054 → pglm_emb.pt
# ✓ TREF1_HUMAN: L=1200 → pglm_emb.pt
# ✓ TRF1A_ARATH: L=1055 → pglm_emb.pt
# ✓ TRHDE_RAT: L=1025 → pglm_emb.pt
# ✓ TRHY_HUMAN: L=1943 → pglm_emb.pt
# ✓ TRI33_HUMAN: L=1127 → pglm_emb.pt
# ✓ TRI66_MOUSE: L=1242 → pglm_emb.pt
# ✓ TRIPB_HUMAN: L=1979 → pglm_emb.pt
# ✓ TRIPC_HUMAN: L=1992 → pglm_emb.pt
# ✓ TRK1_YEAST: L=1235 → pglm_emb.pt
# ✓ TRM3_YEAST: L=1436 → pglm_emb.pt
# ✓ TRPA1_DROME: L=1197 → pglm_emb.pt
# ✓ TRPA1_HUMAN: L=1119 → pglm_emb.pt
# ✓ TRPA1_MOUSE: L=1125 → pglm_emb.pt
# ✓ TRPA1_RAT: L=1125 → pglm_emb.pt
# ✓ TRPC2_MOUSE: L=1172 → pglm_emb.pt
# ✓ TRPCG_DROME: L=2023 → pglm_emb.pt
# ✓ TRPG_DROME: L=1128 → pglm_emb.pt
# ✓ TRPL_DROME: L=1124 → pglm_emb.pt
# ✓ TRPM1_HUMAN: L=1603 → pglm_emb.pt
# ✓ TRPM1_MOUSE: L=1622 → pglm_emb.pt
# ✓ TRPM2_DANRE: L=1470 → pglm_emb.pt
# ✓ TRPM2_HUMAN: L=1503 → pglm_emb.pt
# ✓ TRPM2_MOUSE: L=1506 → pglm_emb.pt
# ✓ TRPM3_HUMAN: L=1732 → pglm_emb.pt
# ✓ TRPM4_HUMAN: L=1214 → pglm_emb.pt
# ✓ TRPM4_MOUSE: L=1213 → pglm_emb.pt
# ✓ TRPM4_RAT: L=1208 → pglm_emb.pt
# ✓ TRPM5_HUMAN: L=1165 → pglm_emb.pt
# ✓ TRPM5_MOUSE: L=1158 → pglm_emb.pt
# ✓ TRPM6_MOUSE: L=2028 → pglm_emb.pt
# ✓ TRPM7_MOUSE: L=1863 → pglm_emb.pt
# ✓ TRPM8_MOUSE: L=1104 → pglm_emb.pt
# ✓ TRPM8_RAT: L=1104 → pglm_emb.pt
# ✓ TRPS1_HUMAN: L=1281 → pglm_emb.pt
# ✓ TRP_DROME: L=1275 → pglm_emb.pt
# ✓ TRRAP_MOUSE: L=2565 → pglm_emb.pt
# ✓ TRR_DROME: L=2431 → pglm_emb.pt
# ✓ TSC1_HUMAN: L=1164 → pglm_emb.pt
# ✓ TSC1_MOUSE: L=1161 → pglm_emb.pt
# ✓ TSC1_RAT: L=1163 → pglm_emb.pt
# ✓ TSC2_HUMAN: L=1807 → pglm_emb.pt
# ✓ TSC2_MOUSE: L=1814 → pglm_emb.pt
# ✓ TSC2_RAT: L=1809 → pglm_emb.pt
# ✓ TSC2_SCHPO: L=1339 → pglm_emb.pt
# ✓ TSH3_HUMAN: L=1081 → pglm_emb.pt
# ✓ TSL1_YEAST: L=1098 → pglm_emb.pt
# ✓ TSP1_HUMAN: L=1170 → pglm_emb.pt
# ✓ TSP1_MOUSE: L=1170 → pglm_emb.pt
# ✓ TSP2_HUMAN: L=1172 → pglm_emb.pt
# ✓ TTBK1_HUMAN: L=1321 → pglm_emb.pt
# ✓ TTBK2_HUMAN: L=1244 → pglm_emb.pt
# ✓ TTBK2_MOUSE: L=1243 → pglm_emb.pt
# ✓ TTC28_HUMAN: L=2481 → pglm_emb.pt
# ✓ TTC3_HUMAN: L=2025 → pglm_emb.pt
# ✓ TTF2_DROME: L=1061 → pglm_emb.pt
# ✓ TTF2_HUMAN: L=1162 → pglm_emb.pt
# ✓ TTLL4_MOUSE: L=1193 → pglm_emb.pt
# ✓ TUS1_YEAST: L=1307 → pglm_emb.pt
# ✓ TUT4_HUMAN: L=1644 → pglm_emb.pt
# ✓ TUT4_MOUSE: L=1644 → pglm_emb.pt
# ✓ TUT7_HUMAN: L=1495 → pglm_emb.pt
# ✓ TUT7_MOUSE: L=1491 → pglm_emb.pt
# ✓ TUTLA_MOUSE: L=1179 → pglm_emb.pt
# ✓ TUTLB_MOUSE: L=1328 → pglm_emb.pt
# ✓ TUTL_DROME: L=1531 → pglm_emb.pt
# ✓ TYK2_HUMAN: L=1187 → pglm_emb.pt
# ✓ U520_HUMAN: L=2136 → pglm_emb.pt
# ✓ UBA1Y_MOUSE: L=1058 → pglm_emb.pt
# ✓ UBA1_HUMAN: L=1058 → pglm_emb.pt
# ✓ UBA1_MOUSE: L=1058 → pglm_emb.pt
# ✓ UBA6_HUMAN: L=1052 → pglm_emb.pt
# ✓ UBA6_MOUSE: L=1053 → pglm_emb.pt
# ✓ UBE11_ARATH: L=1080 → pglm_emb.pt
# ✓ UBE12_ARATH: L=1077 → pglm_emb.pt
# ✓ UBE2O_HUMAN: L=1292 → pglm_emb.pt
# ✓ UBE3C_HUMAN: L=1083 → pglm_emb.pt
# ✓ UBE4A_MOUSE: L=1028 → pglm_emb.pt
# ✓ UBE4B_MOUSE: L=1173 → pglm_emb.pt
# ✓ UBE4_ARATH: L=1038 → pglm_emb.pt
# ✓ UBP12_ARATH: L=1116 → pglm_emb.pt
# ✓ UBP12_YEAST: L=1254 → pglm_emb.pt
# ✓ UBP13_ARATH: L=1115 → pglm_emb.pt
# ✓ UBP15_YEAST: L=1230 → pglm_emb.pt
# ✓ UBP19_HUMAN: L=1318 → pglm_emb.pt
# ✓ UBP19_MOUSE: L=1360 → pglm_emb.pt
# ✓ UBP21_SCHPO: L=1129 → pglm_emb.pt
# ✓ UBP24_HUMAN: L=2620 → pglm_emb.pt
# ✓ UBP25_HUMAN: L=1055 → pglm_emb.pt
# ✓ UBP28_HUMAN: L=1077 → pglm_emb.pt
# ✓ UBP2_SCHPO: L=1141 → pglm_emb.pt
# ✓ UBP2_YEAST: L=1272 → pglm_emb.pt
# ✓ UBP31_HUMAN: L=1352 → pglm_emb.pt
# ✓ UBP32_HUMAN: L=1604 → pglm_emb.pt
# ✓ UBP36_DROME: L=1038 → pglm_emb.pt
# ✓ UBP36_HUMAN: L=1123 → pglm_emb.pt
# ✓ UBP38_HUMAN: L=1042 → pglm_emb.pt
# ✓ UBP42_HUMAN: L=1324 → pglm_emb.pt
# ✓ UBP42_MOUSE: L=1324 → pglm_emb.pt
# ✓ UBP43_HUMAN: L=1123 → pglm_emb.pt
# ✓ UBP47_HUMAN: L=1375 → pglm_emb.pt
# ✓ UBP5_SCHPO: L=1108 → pglm_emb.pt
# ✓ UBP6_HUMAN: L=1406 → pglm_emb.pt
# ✓ UBP7_DROME: L=1129 → pglm_emb.pt
# ✓ UBP7_HUMAN: L=1102 → pglm_emb.pt
# ✓ UBP7_MOUSE: L=1103 → pglm_emb.pt
# ✓ UBP7_RAT: L=1103 → pglm_emb.pt
# ✓ UBP7_YEAST: L=1071 → pglm_emb.pt
# ✓ UBP8_HUMAN: L=1118 → pglm_emb.pt
# ✓ UBP8_MOUSE: L=1080 → pglm_emb.pt
# ✓ UBPE_DROME: L=1556 → pglm_emb.pt
# ✓ UBR11_SCHPO: L=2052 → pglm_emb.pt
# ✓ UBR1_HUMAN: L=1749 → pglm_emb.pt
# ✓ UBR1_MOUSE: L=1757 → pglm_emb.pt
# ✓ UBR1_SCHPO: L=1958 → pglm_emb.pt
# ✓ UBR1_YEAST: L=1950 → pglm_emb.pt
# ✓ UBR2_HUMAN: L=1755 → pglm_emb.pt
# ✓ UBR2_MOUSE: L=1755 → pglm_emb.pt
# ✓ UBR2_YEAST: L=1872 → pglm_emb.pt
# ✓ UBR3_DROME: L=2219 → pglm_emb.pt
# ✓ UBR3_MOUSE: L=1889 → pglm_emb.pt
# ✓ UFD4_YEAST: L=1483 → pglm_emb.pt
# ✓ UGGG1_HUMAN: L=1555 → pglm_emb.pt
# ✓ UGGG1_RAT: L=1551 → pglm_emb.pt
# ✓ UGGG_DROME: L=1548 → pglm_emb.pt
# ✓ UGGG_SCHPO: L=1448 → pglm_emb.pt
# ✓ UGT52_DICDI: L=1697 → pglm_emb.pt
# ✓ UH1BL_HUMAN: L=1464 → pglm_emb.pt
# ✓ ULK1_HUMAN: L=1050 → pglm_emb.pt
# ✓ ULK1_MOUSE: L=1051 → pglm_emb.pt
# ✓ ULK2_HUMAN: L=1036 → pglm_emb.pt
# ✓ ULK2_MOUSE: L=1037 → pglm_emb.pt
# ✓ ULP2_YEAST: L=1034 → pglm_emb.pt
# ✓ ULS1_YEAST: L=1619 → pglm_emb.pt
# ✓ UN13A_MOUSE: L=1712 → pglm_emb.pt
# ✓ UN13A_RAT: L=1735 → pglm_emb.pt
# ✓ UN13B_HUMAN: L=1591 → pglm_emb.pt
# ✓ UN13B_MOUSE: L=1602 → pglm_emb.pt
# ✓ UN13B_RAT: L=1622 → pglm_emb.pt
# ✓ UN13C_MOUSE: L=2210 → pglm_emb.pt
# ✓ UN13C_RAT: L=2204 → pglm_emb.pt
# ✓ UN13D_HUMAN: L=1090 → pglm_emb.pt
# ✓ URFB1_HUMAN: L=1440 → pglm_emb.pt
# ✓ USH_DROME: L=1191 → pglm_emb.pt
# ✓ USP9X_HUMAN: L=2570 → pglm_emb.pt
# ✓ USP9X_MOUSE: L=2559 → pglm_emb.pt
# ✓ USP9Y_HUMAN: L=2555 → pglm_emb.pt
# ✓ USPL1_HUMAN: L=1092 → pglm_emb.pt
# ✓ UTP10_YEAST: L=1769 → pglm_emb.pt
# ✓ UTY_MOUSE: L=1212 → pglm_emb.pt
# ✓ VAM6_YEAST: L=1049 → pglm_emb.pt
# ✓ VATA_YEAST: L=1071 → pglm_emb.pt
# ✓ VCIP1_HUMAN: L=1222 → pglm_emb.pt
# ✓ VCIP1_RAT: L=1221 → pglm_emb.pt
# ✓ VCS_ARATH: L=1344 → pglm_emb.pt
# ✓ VGFR1_HUMAN: L=1338 → pglm_emb.pt
# ✓ VGFR1_MOUSE: L=1333 → pglm_emb.pt
# ✓ VGFR1_RAT: L=1336 → pglm_emb.pt
# ✓ VGFR2_HUMAN: L=1356 → pglm_emb.pt
# ✓ VGFR2_MOUSE: L=1367 → pglm_emb.pt
# ✓ VGFR2_RAT: L=1343 → pglm_emb.pt
# ✓ VGFR3_DANRE: L=1357 → pglm_emb.pt
# ✓ VGFR3_HUMAN: L=1363 → pglm_emb.pt
# ✓ VGFR3_MOUSE: L=1363 → pglm_emb.pt
# ✓ VGFR3_RAT: L=1363 → pglm_emb.pt
# ✓ VGFR4_DANRE: L=1302 → pglm_emb.pt
# ✓ VHC1_YEAST: L=1120 → pglm_emb.pt
# ✓ VIGLN_HUMAN: L=1268 → pglm_emb.pt
# ✓ VINC_HUMAN: L=1134 → pglm_emb.pt
# ✓ VINC_RAT: L=1066 → pglm_emb.pt
# ✓ VIP1L_ARATH: L=1050 → pglm_emb.pt
# ✓ VIP1_HUMAN: L=1433 → pglm_emb.pt
# ✓ VIP1_RAT: L=1434 → pglm_emb.pt
# ✓ VIP1_YEAST: L=1146 → pglm_emb.pt
# ✓ VIP2L_ARATH: L=1049 → pglm_emb.pt
# ✓ VIP2_HUMAN: L=1243 → pglm_emb.pt
# ✓ VIP2_MOUSE: L=1129 → pglm_emb.pt
# ✓ VPS10_YEAST: L=1579 → pglm_emb.pt
# ✓ VPS15_YEAST: L=1454 → pglm_emb.pt
# ✓ VPS8_YEAST: L=1274 → pglm_emb.pt
# ✓ VTH1_YEAST: L=1549 → pglm_emb.pt
# ✓ VTH2_YEAST: L=1549 → pglm_emb.pt
# ✓ VWA8_MOUSE: L=1905 → pglm_emb.pt
# ✓ WAC2C_HUMAN: L=1320 → pglm_emb.pt
# ✓ WAPA_BACSU: L=2334 → pglm_emb.pt
# ✓ WARTS_DROME: L=1105 → pglm_emb.pt
# ✓ WASC5_DICDI: L=1164 → pglm_emb.pt
# ✓ WDHD1_HUMAN: L=1129 → pglm_emb.pt
# ✓ WDHD1_MOUSE: L=1117 → pglm_emb.pt
# ✓ WDR60_HUMAN: L=1066 → pglm_emb.pt
# ✓ WDR6_RAT: L=1125 → pglm_emb.pt
# ✓ WDR81_HUMAN: L=1941 → pglm_emb.pt
# ✓ WIN1_SCHPO: L=1436 → pglm_emb.pt
# ✓ WIS4_SCHPO: L=1401 → pglm_emb.pt
# ✓ WIZ_HUMAN: L=1651 → pglm_emb.pt
# ✓ WIZ_MOUSE: L=1684 → pglm_emb.pt
# ✓ WNK1_HUMAN: L=2382 → pglm_emb.pt
# ✓ WNK1_MOUSE: L=2377 → pglm_emb.pt
# ✓ WNK1_RAT: L=2126 → pglm_emb.pt
# ✓ WNK3_HUMAN: L=1800 → pglm_emb.pt
# ✓ WNK4_HUMAN: L=1243 → pglm_emb.pt
# ✓ WNK4_RAT: L=1222 → pglm_emb.pt
# ✓ WRK52_ARATH: L=1288 → pglm_emb.pt
# ✓ WRN_HUMAN: L=1432 → pglm_emb.pt
# ✓ WRN_MOUSE: L=1401 → pglm_emb.pt
# ✓ WWC2_HUMAN: L=1192 → pglm_emb.pt
# ✓ WWC3_HUMAN: L=1092 → pglm_emb.pt
# ✓ XDH1_ARATH: L=1361 → pglm_emb.pt
# ✓ XDH_DROME: L=1335 → pglm_emb.pt
# ✓ XDH_HUMAN: L=1333 → pglm_emb.pt
# ✓ XDH_MOUSE: L=1335 → pglm_emb.pt
# ✓ XDH_RAT: L=1331 → pglm_emb.pt
# ✓ XIRP1_HUMAN: L=1843 → pglm_emb.pt
# ✓ XMAS_DROME: L=2079 → pglm_emb.pt
# ✓ XPO1_DROME: L=1063 → pglm_emb.pt
# ✓ XPO1_HUMAN: L=1071 → pglm_emb.pt
# ✓ XPO1_MOUSE: L=1071 → pglm_emb.pt
# ✓ XPO1_RAT: L=1071 → pglm_emb.pt
# ✓ XPO1_SCHPO: L=1078 → pglm_emb.pt
# ✓ XPO1_YEAST: L=1084 → pglm_emb.pt
# ✓ XPO5_HUMAN: L=1204 → pglm_emb.pt
# ✓ XPO5_MOUSE: L=1204 → pglm_emb.pt
# ✓ XPO6_HUMAN: L=1125 → pglm_emb.pt
# ✓ XPO7_HUMAN: L=1087 → pglm_emb.pt
# ✓ XPO7_MOUSE: L=1087 → pglm_emb.pt
# ✓ XPOT_YEAST: L=1100 → pglm_emb.pt
# ✓ XRN1_HUMAN: L=1706 → pglm_emb.pt
# ✓ XRN1_MOUSE: L=1719 → pglm_emb.pt
# ✓ XRN1_SCHPO: L=1328 → pglm_emb.pt
# ✓ XRN1_YEAST: L=1528 → pglm_emb.pt
# ✓ Y1591_ARATH: L=1210 → pglm_emb.pt
# ✓ Y1806_DICDI: L=1167 → pglm_emb.pt
# ✓ Y7071_DICDI: L=2454 → pglm_emb.pt
# ✓ YAKA_DICDI: L=1458 → pglm_emb.pt
# ✓ YBT1_YEAST: L=1661 → pglm_emb.pt
# ✓ YC31_SCHPO: L=1429 → pglm_emb.pt
# ✓ YCF2_ARATH: L=2294 → pglm_emb.pt
# ✓ YCFI_YEAST: L=1515 → pglm_emb.pt
# ✓ YDY2_SCHPO: L=1237 → pglm_emb.pt
# ✓ YE38_SCHPO: L=1076 → pglm_emb.pt
# ✓ YEG5_SCHPO: L=1151 → pglm_emb.pt
# ✓ YETS2_HUMAN: L=1422 → pglm_emb.pt
# ✓ YF49_SCHPO: L=2699 → pglm_emb.pt
# ✓ YG42_SCHPO: L=1040 → pglm_emb.pt
# ✓ YGFK_ECOLI: L=1032 → pglm_emb.pt
# ✓ YKQ7_SCHPO: L=1038 → pglm_emb.pt
# ✓ YL016_YEAST: L=1048 → pglm_emb.pt
# ✓ YLPM1_MOUSE: L=1386 → pglm_emb.pt
# ✓ YNSG_SCHPO: L=1050 → pglm_emb.pt
# ✓ YOR1_YEAST: L=1477 → pglm_emb.pt
# ✓ YP097_YEAST: L=1073 → pglm_emb.pt
# ✓ YP204_YEAST: L=1032 → pglm_emb.pt
# ✓ YPK9_YEAST: L=1472 → pglm_emb.pt
# ✓ YRF11_YEAST: L=1796 → pglm_emb.pt
# ✓ YRF12_YEAST: L=1681 → pglm_emb.pt
# ✓ YRF13_YEAST: L=1859 → pglm_emb.pt
# ✓ YRF14_YEAST: L=1382 → pglm_emb.pt
# ✓ YSP2_YEAST: L=1438 → pglm_emb.pt
# ✓ YTDC2_HUMAN: L=1430 → pglm_emb.pt
# ✓ YTDC2_MOUSE: L=1445 → pglm_emb.pt
# ✓ ZASP_DROME: L=2194 → pglm_emb.pt
# ✓ ZBT21_HUMAN: L=1066 → pglm_emb.pt
# ✓ ZBT38_HUMAN: L=1195 → pglm_emb.pt
# ✓ ZBT38_RAT: L=1203 → pglm_emb.pt
# ✓ ZC3H4_MOUSE: L=1304 → pglm_emb.pt
# ✓ ZEB1_HUMAN: L=1124 → pglm_emb.pt
# ✓ ZEB1_MOUSE: L=1117 → pglm_emb.pt
# ✓ ZEB1_RAT: L=1109 → pglm_emb.pt
# ✓ ZEB2_HUMAN: L=1214 → pglm_emb.pt
# ✓ ZEB2_MOUSE: L=1215 → pglm_emb.pt
# ✓ ZEP2_HUMAN: L=2446 → pglm_emb.pt
# ✓ ZEP3_MOUSE: L=2348 → pglm_emb.pt
# ✓ ZFAT_MOUSE: L=1237 → pglm_emb.pt
# ✓ ZFH1_DROME: L=1054 → pglm_emb.pt
# ✓ ZFY16_HUMAN: L=1539 → pglm_emb.pt
# ✓ ZFY26_HUMAN: L=2539 → pglm_emb.pt
# ✓ ZFYV9_HUMAN: L=1425 → pglm_emb.pt
# ✓ ZMIZ1_HUMAN: L=1067 → pglm_emb.pt
# ✓ ZMYM2_HUMAN: L=1377 → pglm_emb.pt
# ✓ ZMYM3_HUMAN: L=1370 → pglm_emb.pt
# ✓ ZMYM4_HUMAN: L=1548 → pglm_emb.pt
# ✓ ZMYM6_HUMAN: L=1325 → pglm_emb.pt
# ✓ ZN106_MOUSE: L=1888 → pglm_emb.pt
# ✓ ZN217_HUMAN: L=1048 → pglm_emb.pt
# ✓ ZN219_DANRE: L=1095 → pglm_emb.pt
# ✓ ZN318_MOUSE: L=2237 → pglm_emb.pt
# ✓ ZN335_MOUSE: L=1337 → pglm_emb.pt
# ✓ ZN423_RAT: L=1311 → pglm_emb.pt
# ✓ ZN445_HUMAN: L=1031 → pglm_emb.pt
# ✓ ZN451_HUMAN: L=1061 → pglm_emb.pt
# ✓ ZN516_MOUSE: L=1157 → pglm_emb.pt
# ✓ ZN521_HUMAN: L=1311 → pglm_emb.pt
# ✓ ZN536_HUMAN: L=1300 → pglm_emb.pt
# ✓ ZN536_MOUSE: L=1302 → pglm_emb.pt
# ✓ ZN592_MOUSE: L=1262 → pglm_emb.pt
# ✓ ZN609_MOUSE: L=1413 → pglm_emb.pt
# ✓ ZN628_MOUSE: L=1038 → pglm_emb.pt
# ✓ ZN638_HUMAN: L=1978 → pglm_emb.pt
# ✓ ZN644_HUMAN: L=1327 → pglm_emb.pt
# ✓ ZN658_HUMAN: L=1059 → pglm_emb.pt
# ✓ ZN827_HUMAN: L=1081 → pglm_emb.pt
# ✓ ZNF91_HUMAN: L=1191 → pglm_emb.pt
# ✓ ZNFX1_MOUSE: L=1909 → pglm_emb.pt
# ✓ ZO1_MOUSE: L=1745 → pglm_emb.pt
# ✓ ZO1_RAT: L=1765 → pglm_emb.pt
# ✓ ZO2_HUMAN: L=1190 → pglm_emb.pt
# ✓ ZRAB3_HUMAN: L=1079 → pglm_emb.pt
# ✓ ZSWM8_HUMAN: L=1837 → pglm_emb.pt
#
# Done. created=3153 | existing_skipped=29393 | missing_seq_skipped=0

# %%
# JUPYTER CELL — Batched check + confirm + delete (no quarantine, no spam)
from __future__ import annotations
from pathlib import Path
import json
import torch
from tqdm.auto import tqdm

# ── config ─────────────────────────────────────────────────────────────
BASE      = Path("/teamspace/studios/this_studio/CAFA_Style")
SEQS_DIR  = BASE / "sequences"
STATE_F   = BASE / ".batch_state.json"
BATCH_SIZE = 10_000  # process this many PID folders per run

EMB_FILES = {
    "esmc":      "esmc_emb.pt",
    "prot_t5":   "prot_t5_emb.pt",
    "pglm":      "pglm_emb.pt",
    "ankh_xl":   "ankh_emb_xl.pt",
}
CAP = {  # sequences strictly greater than this must be re-embedded with sliding window
    "esmc":    20480,
    "prot_t5": 512,
    "pglm":    20480,
    "ankh_xl": 5120,
}
assert set(EMB_FILES) == set(CAP), "CAP/EMB_FILES key mismatch"

# ── helpers ────────────────────────────────────────────────────────────
def load_state() -> int:
    """Return starting index (offset) for this batch."""
    try:
        with STATE_F.open("r", encoding="utf-8") as fh:
            s = json.load(fh)
            return int(s.get("offset", 0))
    except Exception:
        return 0

def save_state(offset: int) -> None:
    STATE_F.write_text(json.dumps({"offset": int(offset)}), encoding="utf-8")

def read_seq_len(seq_path: Path) -> int:
    if not seq_path.exists(): return 0
    L = 0
    with seq_path.open("r", encoding="utf-8") as fh:
        for line in fh:
            if line.startswith(">"): continue
            L += len(line.strip().replace(" ", ""))
    return L

def pt_shape(p: Path):
    try:
        obj = torch.load(p, map_location="cpu")
        if isinstance(obj, torch.Tensor): return tuple(obj.shape)
        if isinstance(obj, dict):
            for k in ("emb", "embeddings", "tensor"):
                if k in obj and isinstance(obj[k], torch.Tensor):
                    return tuple(obj[k].shape)
    except Exception:
        return None
    return None

# ── gather & slice batch ───────────────────────────────────────────────
if not SEQS_DIR.exists():
    raise FileNotFoundError(f"Sequences folder not found: {SEQS_DIR}")

all_pid_dirs = [p for p in SEQS_DIR.iterdir() if p.is_dir() and not p.name.startswith(".")]
all_pid_dirs.sort(key=lambda p: p.name)
N = len(all_pid_dirs)

start = load_state()
end = min(start + BATCH_SIZE, N)
if start >= N:
    print(f"All done. Total PID dirs: {N}. Nothing left to process.")
    raise SystemExit

batch = all_pid_dirs[start:end]
print(f"Processing PIDs {start}..{end-1} of {N} (batch size {BATCH_SIZE})")

# ── scan (batch only) ──────────────────────────────────────────────────
missing = {k: 0 for k in EMB_FILES}
badshape = {k: 0 for k in EMB_FILES}
to_delete = {k: [] for k in EMB_FILES}

total_pids = 0
for pid_dir in tqdm(batch, desc="Analyzing proteins"):
    pid = pid_dir.name
    L = read_seq_len(pid_dir / "seq.txt")
    if L <= 0:
        continue
    total_pids += 1

    for mk, fname in EMB_FILES.items():
        f = pid_dir / fname
        if not f.exists():
            missing[mk] += 1
            continue

        shp = pt_shape(f)
        if shp is None or len(shp) != 3 or shp[0] != 1 or shp[1] != (L + 2):
            badshape[mk] += 1

        # deletion rule: seq length exceeds model cap ⇒ will re-make with sliding window
        if L > CAP[mk]:
            to_delete[mk].append(f)

# ── concise summary ────────────────────────────────────────────────────
def csum(d): return ", ".join(f"{k}:{v}" for k,v in d.items())

total_delete = sum(len(v) for v in to_delete.values())
print("\n=== BATCH SUMMARY ===")
print(f"PIDs scanned in batch: {total_pids}  (global {start}..{end-1} of {N})")
print("Missing      :", csum(missing))
print("Bad shapes   :", csum(badshape))
print("To DELETE    :", ", ".join(f"{k}:{len(v)}" for k,v in to_delete.items()), f"(total {total_delete})")

# ── confirmation & delete (batch only) ─────────────────────────────────
if total_delete > 0:
    ans = input("\nDelete ALL files above caps in THIS BATCH (no undo)? [y/N]: ").strip().lower()
    if ans == "y":
        print("Deleting files...")
        deleted = 0
        all_files = []
        for files in to_delete.values():
            all_files.extend(files)
        for f in tqdm(all_files, desc="Deleting files"):
            try:
                f.unlink()
                deleted += 1
            except Exception as e:
                print(f"Failed to delete {f}: {e}")
        print(f"Deleted {deleted} files.")
    else:
        print("No files deleted in this batch.")
else:
    print("\nNo files to delete in this batch.")

# ── advance to next batch ──────────────────────────────────────────────
save_state(end)
remaining = max(0, N - end)
print(f"\nNext start offset saved: {end}. Remaining PID dirs: {remaining}.")
print("Re-run this cell to process the next batch.")
# Out:
# Processing PIDs 20000..29999 of 59397 (batch size 10000)
# Analyzing proteins:   0%|          | 0/10000 [00:00<?, ?it/s]
# /tmp/ipykernel_8669/1064448980.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   obj = torch.load(p, map_location="cpu")
# === BATCH SUMMARY ===
# PIDs scanned in batch: 10000  (global 20000..29999 of 59397)
# Missing      : esmc:4324, prot_t5:6519, pglm:4324, ankh_xl:4324
# Bad shapes   : esmc:0, prot_t5:0, pglm:0, ankh_xl:0
# To DELETE    : esmc:0, prot_t5:0, pglm:0, ankh_xl:0 (total 0)
#
# No files to delete in this batch.
#
# Next start offset saved: 30000. Remaining PID dirs: 29397.
# Re-run this cell to process the next batch.

# %%
from pathlib import Path
from tqdm.auto import tqdm

SEQS_DIR = Path("/teamspace/studios/this_studio/CAFA_Style/sequences")
TARGET_NAME = "esmc_emb.pt"

files = []
for pid_dir in SEQS_DIR.iterdir():
    if pid_dir.is_dir() and not pid_dir.name.startswith("."):
        f = pid_dir / TARGET_NAME
        if f.exists():
            files.append(f)

deleted = 0
for f in tqdm(files, desc="Deleting ankh embeddings"):
    try:
        f.unlink()
        deleted += 1
    except Exception as e:
        print(f"Failed to delete {f}: {e}")

print(f"Deleted {deleted} files." if deleted else "No ankh embeddings found.")
# Out:
# Deleting ankh embeddings:   0%|          | 0/32546 [00:00<?, ?it/s]
# Deleted 32546 files.

# %%
from pathlib import Path
from tqdm.auto import tqdm
import torch

SEQS_DIR = Path("/teamspace/studios/this_studio/CAFA_Style/sequences")
TARGET = "ankh_emb_xl.pt"

paths = list(SEQS_DIR.rglob(TARGET))
converted = 0

for f in tqdm(paths, desc="Converting ankh_emb_xl.pt → FP16"):
    try:
        obj = torch.load(f, map_location="cpu")
        if isinstance(obj, torch.Tensor) and obj.dtype != torch.float16:
            torch.save(obj.half(), f)
            converted += 1
    except Exception as e:
        print(f"Skip {f}: {e}")

print(f"Converted {converted} file(s) to FP16.")
# Out:
# Converting ankh_emb_xl.pt → FP16:   0%|          | 0/20821 [00:00<?, ?it/s]
# /tmp/ipykernel_18004/3282480711.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   obj = torch.load(f, map_location="cpu")
# Skip /teamspace/studios/this_studio/CAFA_Style/sequences/GRRE1_HUMAN/ankh_emb_xl.pt: File /teamspace/studios/this_studio/CAFA_Style/sequences/GRRE1_HUMAN/ankh_emb_xl.pt cannot be opened.
# Skip /teamspace/studios/this_studio/CAFA_Style/sequences/JAZF1_HUMAN/ankh_emb_xl.pt: File /teamspace/studios/this_studio/CAFA_Style/sequences/JAZF1_HUMAN/ankh_emb_xl.pt cannot be opened.
# Skip /teamspace/studios/this_studio/CAFA_Style/sequences/KPCD2_HUMAN/ankh_emb_xl.pt: File /teamspace/studios/this_studio/CAFA_Style/sequences/KPCD2_HUMAN/ankh_emb_xl.pt cannot be opened.
# Skip /teamspace/studios/this_studio/CAFA_Style/sequences/MMP8_HUMAN/ankh_emb_xl.pt: File /teamspace/studios/this_studio/CAFA_Style/sequences/MMP8_HUMAN/ankh_emb_xl.pt cannot be opened.
# Skip /teamspace/studios/this_studio/CAFA_Style/sequences/NMS_RAT/ankh_emb_xl.pt: File /teamspace/studios/this_studio/CAFA_Style/sequences/NMS_RAT/ankh_emb_xl.pt cannot be opened.
# Skip /teamspace/studios/this_studio/CAFA_Style/sequences/NMT1_ARATH/ankh_emb_xl.pt: File /teamspace/studios/this_studio/CAFA_Style/sequences/NMT1_ARATH/ankh_emb_xl.pt cannot be opened.
# Skip /teamspace/studios/this_studio/CAFA_Style/sequences/OX2G_RAT/ankh_emb_xl.pt: File /teamspace/studios/this_studio/CAFA_Style/sequences/OX2G_RAT/ankh_emb_xl.pt cannot be opened.
# Converted 20814 file(s) to FP16.

# %%
import torch

# Load the two embedding files
ankh_emb = torch.load('/teamspace/studios/this_studio/CAFA_Style/sequences/1A1L1_HUMAN/ankh_emb_xl.pt')
pglm_emb = torch.load('/teamspace/studios/this_studio/CAFA_Style/sequences/1A1L1_HUMAN/pglm_emb.pt')

# Compare the sizes
print(f"ANKH embedding shape: {ankh_emb.shape}")
print(f"PGLM embedding shape: {pglm_emb.shape}")
print(f"ANKH embedding size: {ankh_emb.numel()}")
print(f"PGLM embedding size: {pglm_emb.numel()}")

# Calculate memory sizes in gigabytes
ankh_size_gb = ankh_emb.numel() * ankh_emb.element_size() / (1024**3)
pglm_size_gb = pglm_emb.numel() * pglm_emb.element_size() / (1024**3)

print(f"ANKH embedding size: {ankh_size_gb:.4f} GB")
print(f"PGLM embedding size: {pglm_size_gb:.4f} GB")
print(f"Size difference: {abs(ankh_size_gb - pglm_size_gb):.4f} GB")
# Out:
# ANKH embedding shape: torch.Size([1, 503, 2560])
# PGLM embedding shape: torch.Size([1, 503, 2560])
# ANKH embedding size: 1287680
# PGLM embedding size: 1287680
# ANKH embedding size: 0.0048 GB
# PGLM embedding size: 0.0024 GB
# Size difference: 0.0024 GB
# /tmp/ipykernel_44239/1969575187.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ankh_emb = torch.load('/teamspace/studios/this_studio/CAFA_Style/sequences/1A1L1_HUMAN/ankh_emb_xl.pt')
# /tmp/ipykernel_44239/1969575187.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pglm_emb = torch.load('/teamspace/studios/this_studio/CAFA_Style/sequences/1A1L1_HUMAN/pglm_emb.pt')
